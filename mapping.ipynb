# %%
import pandas as pd
import os

# %%
# zibbase = 'zibs2020'
zibbase = 'zibs2024'
zibspath = os.path.join(zibbase, 'mappable')
zibs = os.listdir(zibspath)
[(i, zib) for i, zib in enumerate(zibs)]
# Out:
# [(0, 'Nl.zorg.Alert-v5.0(2024EN).xlsx'),
#  (1, 'Nl.zorg.Condition-v1.1(2024EN).xlsx'),
#  (2, 'Nl.zorg.Diagnosis-v2.0(2024EN).xlsx'),
#  (3, 'Nl.zorg.Exclusion-v1.1(2024EN).xlsx'),
#  (4, 'Nl.zorg.HealthcareProvider-v3.6(2024EN).xlsx'),
#  (5, 'Nl.zorg.HealthProfessional-v4.0(2024EN).xlsx'),
#  (6, 'Nl.zorg.MedicalDevice-v5.0(2024EN).xlsx'),
#  (7, 'Nl.zorg.NursingIntervention-v5.0(2024EN).xlsx'),
#  (8, 'Nl.zorg.part.AddressInformation-v1.2(2024EN).xlsx'),
#  (9, 'Nl.zorg.part.AnatomicalLocation-v1.0.4(2024EN).xlsx'),
#  (10, 'Nl.zorg.part.ContactInformation-v1.3.1(2024EN).xlsx'),
#  (11, 'Nl.zorg.part.NameInformation-v1.2(2024EN).xlsx'),
#  (12, 'Nl.zorg.Patient-v4.3(2024EN).xlsx'),
#  (13, 'Nl.zorg.Procedure-v6.0(2024EN).xlsx'),
#  (14, 'Nl.zorg.process.RegistrationData-v1.1.2(2024EN).xlsx'),
#  (15, 'Nl.zorg.Symptom-v2.0(2024EN).xlsx')]

# %%
zib = zibs[7]
print(zib)
zibpath = os.path.join(zibspath, zib)
zibdf = pd.read_excel(zibpath)
zibdf
# Out:
# Nl.zorg.NursingIntervention-v5.0(2024EN).xlsx
#                              name  \
# 0             NursingIntervention
# 1    Indication::NursingDiagnosis
# 2                    Intervention
# 3                         Comment
# 4   Requester::HealthProfessional
# 5          ProcedureStartDateTime
# 6            ProcedureEndDateTime
# 7                       Frequency
# 8                        Interval
# 9                       Performer
# 10             HealthProfessional
# 11       Caregiver::ContactPerson
# 12                        Patient
# 13                    Instruction
# 14                  MedicalDevice
# 15             TreatmentObjective
#
#                                                  path  \
# 0                                 NursingIntervention
# 1    NursingIntervention.Indication::NursingDiagnosis
# 2                    NursingIntervention.Intervention
# 3                         NursingIntervention.Comment
# 4   NursingIntervention.Requester::HealthProfessional
# 5          NursingIntervention.ProcedureStartDateTime
# 6            NursingIntervention.ProcedureEndDateTime
# 7                       NursingIntervention.Frequency
# 8                        NursingIntervention.Interval
# 9                       NursingIntervention.Performer
# 10   NursingIntervention.Performer.HealthProfessional
# 11  NursingIntervention.Performer.Caregiver::Conta...
# 12              NursingIntervention.Performer.Patient
# 13                    NursingIntervention.Instruction
# 14                  NursingIntervention.MedicalDevice
# 15             NursingIntervention.TreatmentObjective
#
#                                      alias type   card.         stereotype  \
# 0           NL: VerpleegkundigeInterventie  NaN     NaN        rootconcept
# 1   NL: Indicatie::VerpleegkundigeDiagnose  NaN    0..1     data,reference
# 2                          NL: Interventie   CD       1               data
# 3                          NL: Toelichting   ST    0..1               data
# 4              NL: Aanvrager::Zorgverlener  NaN    0..*  context,reference
# 5                  NL: ActieStartDatumTijd   TS    0..1               data
# 6                   NL: ActieEindDatumTijd   TS    0..1               data
# 7                           NL: Frequentie   PQ    0..1               data
# 8                             NL: Interval   PQ    0..1               data
# 9                           NL: Uitvoerder  NaN    0..1          container
# 10                        NL: Zorgverlener  NaN  (0..1)  context,reference
# 11           NL: Verzorger::ContactPersoon  NaN  (0..1)  context,reference
# 12                             NL: Patient  NaN  (0..1)  context,reference
# 13                          NL: Instructie   ST    0..1               data
# 14                   NL: MedischHulpmiddel  NaN    0..*     data,reference
# 15                        NL: Behandeldoel  NaN    0..1     data,reference
#
#                id                                         definition  \
# 0    NL-CM:14.2.1  Root concept of the NursingIntervention inform...
# 1   NL-CM:14.2.19  The nursing diagnosis that serves as the indic...
# 2    NL-CM:14.2.2  A nursing intervention is a treatment carried ...
# 3    NL-CM:14.2.5               Comment on the nursing intervention.
# 4    NL-CM:14.2.8  The health professional who requested the nurs...
# 5   NL-CM:14.2.11  The start date (and if possible start time) of...
# 6   NL-CM:14.2.12  The end date (and if possible end time) of the...
# 7    NL-CM:14.2.4  The frequency describes how often and in which...
# 8    NL-CM:14.2.3  Interval indicates the time between planned pr...
# 9   NL-CM:14.2.15     The person carrying out the nursing procedure.
# 10   NL-CM:14.2.7  The health professional carrying out the nursi...
# 11  NL-CM:14.2.16  The caregiver carrying out the nursing procedure.
# 12  NL-CM:14.2.17    The patient carrying out the nursing procedure.
# 13  NL-CM:14.2.18  Instructions for performing the nursing action...
# 14  NL-CM:14.2.13  Description of the materials used for the nurs...
# 15  NL-CM:14.2.14  The description of the treatment goal that the...
#
#                                        definitioncode
# 0                SNOMED CT: 9632001 Nursing procedure
# 1                                                 NaN
# 2                                                 NaN
# 3   LOINC: 48767-8 Annotation comment [Interpretat...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7      SNOMED CT: 153681000146109 Procedure frequency
# 8   SNOMED CT: 153691000146106 Interval between pr...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN

# %%
xlmbase = 'xtehr'
xlmspath = os.path.join(xlmbase, 'mappable')
xlms = os.listdir(xlmspath)
[(i, xlm) for i, xlm in enumerate(xlms)]
# Out:
# [(0, '.~lock.Procedure.xlsx#'),
#  (1, 'Address.xlsx'),
#  (2, 'AlertFlag.xlsx'),
#  (3, 'AllergyIntolerance.xlsx'),
#  (4, 'BodyStructure.xlsx'),
#  (5, 'Condition.xlsx'),
#  (6, 'DataSet.xlsx'),
#  (7, 'Device.xlsx'),
#  (8, 'DeviceUse.xlsx'),
#  (9, 'HealthProfessional.xlsx'),
#  (10, 'HumanName.xlsx'),
#  (11, 'Location.xlsx'),
#  (12, 'Medication.xlsx'),
#  (13, 'Organization.xlsx'),
#  (14, 'Patient.xlsx'),
#  (15, 'Procedure.xlsx'),
#  (16, 'Telecom.xlsx')]

# %%
xlm = xlms[15]
print( xlm)
xlmpath = os.path.join(xlmspath, xlm)
xlmdf = pd.read_excel(xlmpath)
xlmdf
# only for device use and organization
#xlm = xlms[11]
#print( xlm)
#xlmpath = os.path.join(xlmspath, xlm)
#xlmdf2 = pd.read_excel(xlmpath)
#xlmdf = pd.concat([xlmdf, xlmdf2], ignore_index=True)
#xlmdf
# Out:
# Procedure.xlsx
#                                            id  \
# 0                               EHDSProcedure
# 1                        EHDSProcedure.header
# 2                EHDSProcedure.header.subject
# 3             EHDSProcedure.header.identifier
# 4             EHDSProcedure.header.authorship
# 5   EHDSProcedure.header.authorship.author[x]
# 6    EHDSProcedure.header.authorship.datetime
# 7             EHDSProcedure.header.lastUpdate
# 8                 EHDSProcedure.header.status
# 9        EHDSProcedure.header.statusReason[x]
# 10              EHDSProcedure.header.language
# 11               EHDSProcedure.header.version
# 12                EHDSProcedure.presentedForm
# 13                         EHDSProcedure.code
# 14                      EHDSProcedure.date[x]
# 15                    EHDSProcedure.performer
# 16                     EHDSProcedure.bodySite
# 17                    EHDSProcedure.reason[x]
# 18                      EHDSProcedure.outcome
# 19                 EHDSProcedure.complication
# 20                   EHDSProcedure.deviceUsed
# 21                  EHDSProcedure.focalDevice
# 22                         EHDSProcedure.note
#
#                                          path  \
# 0                               EHDSProcedure
# 1                        EHDSProcedure.header
# 2                EHDSProcedure.header.subject
# 3             EHDSProcedure.header.identifier
# 4             EHDSProcedure.header.authorship
# 5   EHDSProcedure.header.authorship.author[x]
# 6    EHDSProcedure.header.authorship.datetime
# 7             EHDSProcedure.header.lastUpdate
# 8                 EHDSProcedure.header.status
# 9        EHDSProcedure.header.statusReason[x]
# 10              EHDSProcedure.header.language
# 11               EHDSProcedure.header.version
# 12                EHDSProcedure.presentedForm
# 13                         EHDSProcedure.code
# 14                      EHDSProcedure.date[x]
# 15                    EHDSProcedure.performer
# 16                     EHDSProcedure.bodySite
# 17                    EHDSProcedure.reason[x]
# 18                      EHDSProcedure.outcome
# 19                 EHDSProcedure.complication
# 20                   EHDSProcedure.deviceUsed
# 21                  EHDSProcedure.focalDevice
# 22                         EHDSProcedure.note
#
#                                                 short  \
# 0                                     Procedure model
# 1          Common header for all patient-related data
# 2                                             Subject
# 3                  Business identifier for the object
# 4                                          Authorship
# 5                                              Author
# 6                  Date and time of authoring/issuing
# 7    Date and time of the last update to the resource
# 8                              Status of the resource
# 9      Reason for the current status of the resource.
# 10                                           Language
# 11                                            Version
# 12  A narrative easy-to-read representation of the...
# 13                     Code identifying the procedure
# 14  Date and time of the procedure or interval of ...
# 15               An actor who performed the procedure
# 16  Procedure target body site. Details of where t...
# 17  The reason why the procedure was performed. Th...
# 18  The outcome of the procedure - did it resolve ...
# 19  Any complications that occurred during the pro...
# 20               Device used to perform the procedure
# 21  Device(s) that is/are implanted, removed, or o...
# 22         Additional information about the procedure
#
#                                            definition                    type  \
# 0   EHDS refined base model for an action that is ...                     NaN
# 1          Common header for all patient-related data                    Base
# 2                         Patient/subject information             EHDSPatient
# 3                  Business identifier for the object              Identifier
# 4                          Resource authoring details                    Base
# 5   Author(s) by whom the resource was/were author...  EHDSHealthProfessional
# 6   Date and time of the issuing the document/reso...                dateTime
# 7   Date and time of the last update to the docume...                dateTime
# 8                              Status of the resource         CodeableConcept
# 9      Reason for the current status of the resource.         CodeableConcept
# 10  Language in which the resource is written. Lan...         CodeableConcept
# 11                  Business version of the resource.                  string
# 12  A narrative easy-to-read representation of the...          EHDSAttachment
# 13                     Code identifying the procedure         CodeableConcept
# 14  Date and time of the procedure or interval of ...                dateTime
# 15               An actor who performed the procedure  EHDSHealthProfessional
# 16  Procedure target body site. Details of where t...       EHDSBodyStructure
# 17  The reason why the procedure was performed. Th...         CodeableConcept
# 18  The outcome of the procedure - did it resolve ...         CodeableConcept
# 19  Any complications that occurred during the pro...         CodeableConcept
# 20               Device used to perform the procedure              EHDSDevice
# 21  Device(s) that is/are implanted, removed, or o...              EHDSDevice
# 22         Additional information about the procedure                  string
#
#    card.                                            binding
# 0   0..*                                                NaN
# 1   1..1                                                NaN
# 2   1..1                                                NaN
# 3   0..*                                                NaN
# 4   1..*                                                NaN
# 5   1..1                                                NaN
# 6   1..1                                                NaN
# 7   0..1                                                NaN
# 8   1..1                                                NaN
# 9   0..1                                                NaN
# 10  0..1  {'strength': 'preferred', 'description': 'BCP ...
# 11  0..1                                                NaN
# 12  0..*                                                NaN
# 13  0..1  {'strength': 'preferred', 'description': 'SNOM...
# 14  0..1                                                NaN
# 15  0..*                                                NaN
# 16  0..*                                                NaN
# 17  0..*  {'strength': 'preferred', 'description': 'SNOM...
# 18  0..1  {'strength': 'preferred', 'description': 'SNOM...
# 19  0..*  {'strength': 'preferred', 'description': 'ICD-...
# 20  0..*                                                NaN
# 21  0..*                                                NaN
# 22  0..1                                                NaN

# %%
mapbase = 'maps'
maps = os.listdir(mapbase)
[(i, map) for i, map in enumerate(maps)]
# Out:
# [(0, '.~lock.Procedure-NusringIntervention.xlsx#'),
#  (1, '.~lock.Procedure.xlsx#'),
#  (2, 'Address.xlsx'),
#  (3, 'AlertFlag.xlsx'),
#  (4, 'BodyStructure.xlsx'),
#  (5, 'Condition-ConditionDiagnosis.xlsx'),
#  (6, 'Condition-Symptom.xlsx'),
#  (7, 'Condition.xlsx'),
#  (8, 'DataSet.xlsx'),
#  (9, 'Device-and-DeviceUse.xlsx'),
#  (10, 'HealthProfessional.xlsx'),
#  (11, 'HumanName.xlsx'),
#  (12, 'Location-and-Organization.xlsx'),
#  (13, 'Patient.xlsx'),
#  (14, 'Procedure-NusringIntervention.xlsx'),
#  (15, 'Procedure.xlsx'),
#  (16, 'xtehr2zibs'),
#  (17, 'xtehr2zibs2024')]

# %%
file = maps[14]
print(file)
mappath = os.path.join(mapbase, file)
print(mappath)
mapdf = pd.read_excel(mappath)
mapdf
# Out:
# Procedure-NusringIntervention.xlsx
# maps\Procedure-NusringIntervention.xlsx
#                                         xtehr  \
# 0                               EHDSProcedure
# 1                        EHDSProcedure.header
# 2                EHDSProcedure.header.subject
# 3             EHDSProcedure.header.identifier
# 4             EHDSProcedure.header.authorship
# 5   EHDSProcedure.header.authorship.author[x]
# 6    EHDSProcedure.header.authorship.datetime
# 7             EHDSProcedure.header.lastUpdate
# 8                 EHDSProcedure.header.status
# 9        EHDSProcedure.header.statusReason[x]
# 10              EHDSProcedure.header.language
# 11               EHDSProcedure.header.version
# 12                EHDSProcedure.presentedForm
# 13                         EHDSProcedure.code
# 14                      EHDSProcedure.date[x]
# 15                      EHDSProcedure.date[x]
# 16                    EHDSProcedure.performer
# 17                     EHDSProcedure.bodySite
# 18                    EHDSProcedure.reason[x]
# 19                    EHDSProcedure.reason[x]
# 20                      EHDSProcedure.outcome
# 21                 EHDSProcedure.complication
# 22                   EHDSProcedure.deviceUsed
# 23                  EHDSProcedure.focalDevice
# 24                         EHDSProcedure.note
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
# 30                                        NaN
# 31                                        NaN
# 32                                        NaN
#
#                                                   zib 2020 2024
# 0                                 NursingIntervention  NaN  NaN
# 1                                                 NaN  NaN  NaN
# 2                                                 NaN  NaN  NaN
# 3                                                 NaN  NaN  NaN
# 4                                                 NaN  NaN  NaN
# 5                                                 NaN  NaN  NaN
# 6                                                 NaN  NaN  NaN
# 7                                                 NaN  NaN  NaN
# 8                                                 NaN  NaN  NaN
# 9                                                 NaN  NaN  NaN
# 10                                                NaN  NaN  NaN
# 11                                                NaN  NaN  NaN
# 12                                                NaN  NaN  NaN
# 13                   NursingIntervention.Intervention    x    x
# 14         NursingIntervention.ProcedureStartDateTime    x    x
# 15           NursingIntervention.ProcedureEndDateTime    x    x
# 16                      NursingIntervention.Performer    x    x
# 17                                                NaN  NaN  NaN
# 18   NursingIntervention.Indication::NursingDiagnosis  NaN    x
# 19            NursingIntervention.Indication::Problem    x  NaN
# 20                                                NaN  NaN  NaN
# 21                                                NaN  NaN  NaN
# 22                  NursingIntervention.MedicalDevice    x    x
# 23                                                NaN  NaN  NaN
# 24                        NursingIntervention.Comment    x    x
# 25  NursingIntervention.Requester::HealthProfessional    x    x
# 26                      NursingIntervention.Frequency    x    x
# 27                       NursingIntervention.Interval    x    x
# 28   NursingIntervention.Performer.HealthProfessional    x    x
# 29  NursingIntervention.Performer.Caregiver::Conta...    x    x
# 30              NursingIntervention.Performer.Patient    x    x
# 31                    NursingIntervention.Instruction    x    x
# 32             NursingIntervention.TreatmentObjective    x    x

# %%
mapping = mapdf[['xtehr', 'zib']].merge(zibdf.add_suffix('_zib'), left_on='zib', right_on='path_zib', how='outer').merge(xlmdf.add_suffix('_xtehr'), left_on='xtehr', right_on='path_xtehr', how='outer')
mapping
# Out:
#                                         xtehr  \
# 0                               EHDSProcedure
# 1                      EHDSProcedure.bodySite
# 2                          EHDSProcedure.code
# 3                  EHDSProcedure.complication
# 4                       EHDSProcedure.date[x]
# 5                       EHDSProcedure.date[x]
# 6                    EHDSProcedure.deviceUsed
# 7                   EHDSProcedure.focalDevice
# 8                        EHDSProcedure.header
# 9             EHDSProcedure.header.authorship
# 10  EHDSProcedure.header.authorship.author[x]
# 11   EHDSProcedure.header.authorship.datetime
# 12            EHDSProcedure.header.identifier
# 13              EHDSProcedure.header.language
# 14            EHDSProcedure.header.lastUpdate
# 15                EHDSProcedure.header.status
# 16       EHDSProcedure.header.statusReason[x]
# 17               EHDSProcedure.header.subject
# 18               EHDSProcedure.header.version
# 19                         EHDSProcedure.note
# 20                      EHDSProcedure.outcome
# 21                    EHDSProcedure.performer
# 22                EHDSProcedure.presentedForm
# 23                    EHDSProcedure.reason[x]
# 24                    EHDSProcedure.reason[x]
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
# 30                                        NaN
# 31                                        NaN
# 32                                        NaN
#
#                                                   zib  \
# 0                                 NursingIntervention
# 1                                                 NaN
# 2                    NursingIntervention.Intervention
# 3                                                 NaN
# 4            NursingIntervention.ProcedureEndDateTime
# 5          NursingIntervention.ProcedureStartDateTime
# 6                   NursingIntervention.MedicalDevice
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                        NursingIntervention.Comment
# 20                                                NaN
# 21                      NursingIntervention.Performer
# 22                                                NaN
# 23   NursingIntervention.Indication::NursingDiagnosis
# 24            NursingIntervention.Indication::Problem
# 25                      NursingIntervention.Frequency
# 26                    NursingIntervention.Instruction
# 27                       NursingIntervention.Interval
# 28  NursingIntervention.Performer.Caregiver::Conta...
# 29   NursingIntervention.Performer.HealthProfessional
# 30              NursingIntervention.Performer.Patient
# 31  NursingIntervention.Requester::HealthProfessional
# 32             NursingIntervention.TreatmentObjective
#
#                          name_zib  \
# 0             NursingIntervention
# 1                             NaN
# 2                    Intervention
# 3                             NaN
# 4            ProcedureEndDateTime
# 5          ProcedureStartDateTime
# 6                   MedicalDevice
# 7                             NaN
# 8                             NaN
# 9                             NaN
# 10                            NaN
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
# 16                            NaN
# 17                            NaN
# 18                            NaN
# 19                        Comment
# 20                            NaN
# 21                      Performer
# 22                            NaN
# 23   Indication::NursingDiagnosis
# 24                            NaN
# 25                      Frequency
# 26                    Instruction
# 27                       Interval
# 28       Caregiver::ContactPerson
# 29             HealthProfessional
# 30                        Patient
# 31  Requester::HealthProfessional
# 32             TreatmentObjective
#
#                                              path_zib  \
# 0                                 NursingIntervention
# 1                                                 NaN
# 2                    NursingIntervention.Intervention
# 3                                                 NaN
# 4            NursingIntervention.ProcedureEndDateTime
# 5          NursingIntervention.ProcedureStartDateTime
# 6                   NursingIntervention.MedicalDevice
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                        NursingIntervention.Comment
# 20                                                NaN
# 21                      NursingIntervention.Performer
# 22                                                NaN
# 23   NursingIntervention.Indication::NursingDiagnosis
# 24                                                NaN
# 25                      NursingIntervention.Frequency
# 26                    NursingIntervention.Instruction
# 27                       NursingIntervention.Interval
# 28  NursingIntervention.Performer.Caregiver::Conta...
# 29   NursingIntervention.Performer.HealthProfessional
# 30              NursingIntervention.Performer.Patient
# 31  NursingIntervention.Requester::HealthProfessional
# 32             NursingIntervention.TreatmentObjective
#
#                                  alias_zib type_zib card._zib  \
# 0           NL: VerpleegkundigeInterventie      NaN       NaN
# 1                                      NaN      NaN       NaN
# 2                          NL: Interventie       CD         1
# 3                                      NaN      NaN       NaN
# 4                   NL: ActieEindDatumTijd       TS      0..1
# 5                  NL: ActieStartDatumTijd       TS      0..1
# 6                    NL: MedischHulpmiddel      NaN      0..*
# 7                                      NaN      NaN       NaN
# 8                                      NaN      NaN       NaN
# 9                                      NaN      NaN       NaN
# 10                                     NaN      NaN       NaN
# 11                                     NaN      NaN       NaN
# 12                                     NaN      NaN       NaN
# 13                                     NaN      NaN       NaN
# 14                                     NaN      NaN       NaN
# 15                                     NaN      NaN       NaN
# 16                                     NaN      NaN       NaN
# 17                                     NaN      NaN       NaN
# 18                                     NaN      NaN       NaN
# 19                         NL: Toelichting       ST      0..1
# 20                                     NaN      NaN       NaN
# 21                          NL: Uitvoerder      NaN      0..1
# 22                                     NaN      NaN       NaN
# 23  NL: Indicatie::VerpleegkundigeDiagnose      NaN      0..1
# 24                                     NaN      NaN       NaN
# 25                          NL: Frequentie       PQ      0..1
# 26                          NL: Instructie       ST      0..1
# 27                            NL: Interval       PQ      0..1
# 28           NL: Verzorger::ContactPersoon      NaN    (0..1)
# 29                        NL: Zorgverlener      NaN    (0..1)
# 30                             NL: Patient      NaN    (0..1)
# 31             NL: Aanvrager::Zorgverlener      NaN      0..*
# 32                        NL: Behandeldoel      NaN      0..1
#
#        stereotype_zib         id_zib  \
# 0         rootconcept   NL-CM:14.2.1
# 1                 NaN            NaN
# 2                data   NL-CM:14.2.2
# 3                 NaN            NaN
# 4                data  NL-CM:14.2.12
# 5                data  NL-CM:14.2.11
# 6      data,reference  NL-CM:14.2.13
# 7                 NaN            NaN
# 8                 NaN            NaN
# 9                 NaN            NaN
# 10                NaN            NaN
# 11                NaN            NaN
# 12                NaN            NaN
# 13                NaN            NaN
# 14                NaN            NaN
# 15                NaN            NaN
# 16                NaN            NaN
# 17                NaN            NaN
# 18                NaN            NaN
# 19               data   NL-CM:14.2.5
# 20                NaN            NaN
# 21          container  NL-CM:14.2.15
# 22                NaN            NaN
# 23     data,reference  NL-CM:14.2.19
# 24                NaN            NaN
# 25               data   NL-CM:14.2.4
# 26               data  NL-CM:14.2.18
# 27               data   NL-CM:14.2.3
# 28  context,reference  NL-CM:14.2.16
# 29  context,reference   NL-CM:14.2.7
# 30  context,reference  NL-CM:14.2.17
# 31  context,reference   NL-CM:14.2.8
# 32     data,reference  NL-CM:14.2.14
#
#                                        definition_zib  \
# 0   Root concept of the NursingIntervention inform...
# 1                                                 NaN
# 2   A nursing intervention is a treatment carried ...
# 3                                                 NaN
# 4   The end date (and if possible end time) of the...
# 5   The start date (and if possible start time) of...
# 6   Description of the materials used for the nurs...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19               Comment on the nursing intervention.
# 20                                                NaN
# 21     The person carrying out the nursing procedure.
# 22                                                NaN
# 23  The nursing diagnosis that serves as the indic...
# 24                                                NaN
# 25  The frequency describes how often and in which...
# 26  Instructions for performing the nursing action...
# 27  Interval indicates the time between planned pr...
# 28  The caregiver carrying out the nursing procedure.
# 29  The health professional carrying out the nursi...
# 30    The patient carrying out the nursing procedure.
# 31  The health professional who requested the nurs...
# 32  The description of the treatment goal that the...
#
#                                    definitioncode_zib  \
# 0                SNOMED CT: 9632001 Nursing procedure
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  LOINC: 48767-8 Annotation comment [Interpretat...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25     SNOMED CT: 153681000146109 Procedure frequency
# 26                                                NaN
# 27  SNOMED CT: 153691000146106 Interval between pr...
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
#
#                                      id_xtehr  \
# 0                               EHDSProcedure
# 1                      EHDSProcedure.bodySite
# 2                          EHDSProcedure.code
# 3                  EHDSProcedure.complication
# 4                       EHDSProcedure.date[x]
# 5                       EHDSProcedure.date[x]
# 6                    EHDSProcedure.deviceUsed
# 7                   EHDSProcedure.focalDevice
# 8                        EHDSProcedure.header
# 9             EHDSProcedure.header.authorship
# 10  EHDSProcedure.header.authorship.author[x]
# 11   EHDSProcedure.header.authorship.datetime
# 12            EHDSProcedure.header.identifier
# 13              EHDSProcedure.header.language
# 14            EHDSProcedure.header.lastUpdate
# 15                EHDSProcedure.header.status
# 16       EHDSProcedure.header.statusReason[x]
# 17               EHDSProcedure.header.subject
# 18               EHDSProcedure.header.version
# 19                         EHDSProcedure.note
# 20                      EHDSProcedure.outcome
# 21                    EHDSProcedure.performer
# 22                EHDSProcedure.presentedForm
# 23                    EHDSProcedure.reason[x]
# 24                    EHDSProcedure.reason[x]
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
# 30                                        NaN
# 31                                        NaN
# 32                                        NaN
#
#                                    path_xtehr  \
# 0                               EHDSProcedure
# 1                      EHDSProcedure.bodySite
# 2                          EHDSProcedure.code
# 3                  EHDSProcedure.complication
# 4                       EHDSProcedure.date[x]
# 5                       EHDSProcedure.date[x]
# 6                    EHDSProcedure.deviceUsed
# 7                   EHDSProcedure.focalDevice
# 8                        EHDSProcedure.header
# 9             EHDSProcedure.header.authorship
# 10  EHDSProcedure.header.authorship.author[x]
# 11   EHDSProcedure.header.authorship.datetime
# 12            EHDSProcedure.header.identifier
# 13              EHDSProcedure.header.language
# 14            EHDSProcedure.header.lastUpdate
# 15                EHDSProcedure.header.status
# 16       EHDSProcedure.header.statusReason[x]
# 17               EHDSProcedure.header.subject
# 18               EHDSProcedure.header.version
# 19                         EHDSProcedure.note
# 20                      EHDSProcedure.outcome
# 21                    EHDSProcedure.performer
# 22                EHDSProcedure.presentedForm
# 23                    EHDSProcedure.reason[x]
# 24                    EHDSProcedure.reason[x]
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
# 30                                        NaN
# 31                                        NaN
# 32                                        NaN
#
#                                           short_xtehr  \
# 0                                     Procedure model
# 1   Procedure target body site. Details of where t...
# 2                      Code identifying the procedure
# 3   Any complications that occurred during the pro...
# 4   Date and time of the procedure or interval of ...
# 5   Date and time of the procedure or interval of ...
# 6                Device used to perform the procedure
# 7   Device(s) that is/are implanted, removed, or o...
# 8          Common header for all patient-related data
# 9                                          Authorship
# 10                                             Author
# 11                 Date and time of authoring/issuing
# 12                 Business identifier for the object
# 13                                           Language
# 14   Date and time of the last update to the resource
# 15                             Status of the resource
# 16     Reason for the current status of the resource.
# 17                                            Subject
# 18                                            Version
# 19         Additional information about the procedure
# 20  The outcome of the procedure - did it resolve ...
# 21               An actor who performed the procedure
# 22  A narrative easy-to-read representation of the...
# 23  The reason why the procedure was performed. Th...
# 24  The reason why the procedure was performed. Th...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
#
#                                      definition_xtehr              type_xtehr  \
# 0   EHDS refined base model for an action that is ...                     NaN
# 1   Procedure target body site. Details of where t...       EHDSBodyStructure
# 2                      Code identifying the procedure         CodeableConcept
# 3   Any complications that occurred during the pro...         CodeableConcept
# 4   Date and time of the procedure or interval of ...                dateTime
# 5   Date and time of the procedure or interval of ...                dateTime
# 6                Device used to perform the procedure              EHDSDevice
# 7   Device(s) that is/are implanted, removed, or o...              EHDSDevice
# 8          Common header for all patient-related data                    Base
# 9                          Resource authoring details                    Base
# 10  Author(s) by whom the resource was/were author...  EHDSHealthProfessional
# 11  Date and time of the issuing the document/reso...                dateTime
# 12                 Business identifier for the object              Identifier
# 13  Language in which the resource is written. Lan...         CodeableConcept
# 14  Date and time of the last update to the docume...                dateTime
# 15                             Status of the resource         CodeableConcept
# 16     Reason for the current status of the resource.         CodeableConcept
# 17                        Patient/subject information             EHDSPatient
# 18                  Business version of the resource.                  string
# 19         Additional information about the procedure                  string
# 20  The outcome of the procedure - did it resolve ...         CodeableConcept
# 21               An actor who performed the procedure  EHDSHealthProfessional
# 22  A narrative easy-to-read representation of the...          EHDSAttachment
# 23  The reason why the procedure was performed. Th...         CodeableConcept
# 24  The reason why the procedure was performed. Th...         CodeableConcept
# 25                                                NaN                     NaN
# 26                                                NaN                     NaN
# 27                                                NaN                     NaN
# 28                                                NaN                     NaN
# 29                                                NaN                     NaN
# 30                                                NaN                     NaN
# 31                                                NaN                     NaN
# 32                                                NaN                     NaN
#
#    card._xtehr                                      binding_xtehr
# 0         0..*                                                NaN
# 1         0..*                                                NaN
# 2         0..1  {'strength': 'preferred', 'description': 'SNOM...
# 3         0..*  {'strength': 'preferred', 'description': 'ICD-...
# 4         0..1                                                NaN
# 5         0..1                                                NaN
# 6         0..*                                                NaN
# 7         0..*                                                NaN
# 8         1..1                                                NaN
# 9         1..*                                                NaN
# 10        1..1                                                NaN
# 11        1..1                                                NaN
# 12        0..*                                                NaN
# 13        0..1  {'strength': 'preferred', 'description': 'BCP ...
# 14        0..1                                                NaN
# 15        1..1                                                NaN
# 16        0..1                                                NaN
# 17        1..1                                                NaN
# 18        0..1                                                NaN
# 19        0..1                                                NaN
# 20        0..1  {'strength': 'preferred', 'description': 'SNOM...
# 21        0..*                                                NaN
# 22        0..*                                                NaN
# 23        0..*  {'strength': 'preferred', 'description': 'SNOM...
# 24        0..*  {'strength': 'preferred', 'description': 'SNOM...
# 25         NaN                                                NaN
# 26         NaN                                                NaN
# 27         NaN                                                NaN
# 28         NaN                                                NaN
# 29         NaN                                                NaN
# 30         NaN                                                NaN
# 31         NaN                                                NaN
# 32         NaN                                                NaN

# %%
shortmap = mapping[['zib', 'xtehr', 'type_zib','type_xtehr', 'card._zib', 'card._xtehr']]
shortmap
# Out:
#                                                   zib  \
# 0                                 NursingIntervention
# 1                                                 NaN
# 2                    NursingIntervention.Intervention
# 3                                                 NaN
# 4            NursingIntervention.ProcedureEndDateTime
# 5          NursingIntervention.ProcedureStartDateTime
# 6                   NursingIntervention.MedicalDevice
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                        NursingIntervention.Comment
# 20                                                NaN
# 21                      NursingIntervention.Performer
# 22                                                NaN
# 23   NursingIntervention.Indication::NursingDiagnosis
# 24            NursingIntervention.Indication::Problem
# 25                      NursingIntervention.Frequency
# 26                    NursingIntervention.Instruction
# 27                       NursingIntervention.Interval
# 28  NursingIntervention.Performer.Caregiver::Conta...
# 29   NursingIntervention.Performer.HealthProfessional
# 30              NursingIntervention.Performer.Patient
# 31  NursingIntervention.Requester::HealthProfessional
# 32             NursingIntervention.TreatmentObjective
#
#                                         xtehr type_zib  \
# 0                               EHDSProcedure      NaN
# 1                      EHDSProcedure.bodySite      NaN
# 2                          EHDSProcedure.code       CD
# 3                  EHDSProcedure.complication      NaN
# 4                       EHDSProcedure.date[x]       TS
# 5                       EHDSProcedure.date[x]       TS
# 6                    EHDSProcedure.deviceUsed      NaN
# 7                   EHDSProcedure.focalDevice      NaN
# 8                        EHDSProcedure.header      NaN
# 9             EHDSProcedure.header.authorship      NaN
# 10  EHDSProcedure.header.authorship.author[x]      NaN
# 11   EHDSProcedure.header.authorship.datetime      NaN
# 12            EHDSProcedure.header.identifier      NaN
# 13              EHDSProcedure.header.language      NaN
# 14            EHDSProcedure.header.lastUpdate      NaN
# 15                EHDSProcedure.header.status      NaN
# 16       EHDSProcedure.header.statusReason[x]      NaN
# 17               EHDSProcedure.header.subject      NaN
# 18               EHDSProcedure.header.version      NaN
# 19                         EHDSProcedure.note       ST
# 20                      EHDSProcedure.outcome      NaN
# 21                    EHDSProcedure.performer      NaN
# 22                EHDSProcedure.presentedForm      NaN
# 23                    EHDSProcedure.reason[x]      NaN
# 24                    EHDSProcedure.reason[x]      NaN
# 25                                        NaN       PQ
# 26                                        NaN       ST
# 27                                        NaN       PQ
# 28                                        NaN      NaN
# 29                                        NaN      NaN
# 30                                        NaN      NaN
# 31                                        NaN      NaN
# 32                                        NaN      NaN
#
#                 type_xtehr card._zib card._xtehr
# 0                      NaN       NaN        0..*
# 1        EHDSBodyStructure       NaN        0..*
# 2          CodeableConcept         1        0..1
# 3          CodeableConcept       NaN        0..*
# 4                 dateTime      0..1        0..1
# 5                 dateTime      0..1        0..1
# 6               EHDSDevice      0..*        0..*
# 7               EHDSDevice       NaN        0..*
# 8                     Base       NaN        1..1
# 9                     Base       NaN        1..*
# 10  EHDSHealthProfessional       NaN        1..1
# 11                dateTime       NaN        1..1
# 12              Identifier       NaN        0..*
# 13         CodeableConcept       NaN        0..1
# 14                dateTime       NaN        0..1
# 15         CodeableConcept       NaN        1..1
# 16         CodeableConcept       NaN        0..1
# 17             EHDSPatient       NaN        1..1
# 18                  string       NaN        0..1
# 19                  string      0..1        0..1
# 20         CodeableConcept       NaN        0..1
# 21  EHDSHealthProfessional      0..1        0..*
# 22          EHDSAttachment       NaN        0..*
# 23         CodeableConcept      0..1        0..*
# 24         CodeableConcept       NaN        0..*
# 25                     NaN      0..1         NaN
# 26                     NaN      0..1         NaN
# 27                     NaN      0..1         NaN
# 28                     NaN    (0..1)         NaN
# 29                     NaN    (0..1)         NaN
# 30                     NaN    (0..1)         NaN
# 31                     NaN      0..*         NaN
# 32                     NaN      0..1         NaN

# %%
mapsoutpath = os.path.join(mapbase, 'xtehr2zibs2024')
filepath = file.replace('.xlsx', '-full.xlsx')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_excel(mappath, index=False)

# %%
filepath = file.replace('.xlsx', '.csv')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_csv(mappath, index=False)

# %%
from IPython.display import Markdown
import numpy as np

content = "# " + mapping.iat[0, 0][4:] + "\n\n"
content += shortmap.fillna('').to_markdown(index=False) + "\n\n"
for i, row in mapping.iterrows():
    # print(i, row)
    content += "\n\n"
    if row.iloc[0] is not np.nan:
        content += "## " + str(row.iloc[0]) + "\n\n"
    else:
        content += "## zib: " + str(row.iloc[1]) + "\n\n"
    content += "### Table" + "\n\n"
    content += "| attribute | value |" + "\n" + "|---|---|" + "\n"
    for j, att in row.fillna('')[0:2].items():
        content += "| " + str(j) + " | " + str(att) + " |" + "\n"
    for j, att in row.fillna('')[2:].sort_index().items():
        content += "| " + str(j) + " | " + str(att) + " |" + "\n"    
    content += "\n### Comments" + "\n\n"
with open(os.path.join(mapsoutpath, file.replace('.xlsx', '.md')), 'w') as f:
    f.write(content)
# PAS OP: deze overschrijft de eventueel met de hand gemaakte comments files, alleen gebriuken
# bij eerste keer dat je een mapping maakt, daarna de comments handmatig aanpassen
# with open(os.path.join(mapsoutpath, file.replace('.xlsx', '-comments.md')), 'w') as f:
#     f.write(content)
#Markdown(content)
