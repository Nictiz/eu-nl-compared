# %%
import pandas as pd
import os

# %%
# zibbase = 'zibs2020'
zibbase = 'zibs2024'
zibspath = os.path.join(zibbase, 'mappable')
zibs = os.listdir(zibspath)
zibs
# Out:
# ['Nl.zorg.Alert-v5.0(2024EN).xlsx',
#  'Nl.zorg.HealthcareProvider-v3.6(2024EN).xlsx',
#  'Nl.zorg.HealthProfessional-v4.0(2024EN).xlsx',
#  'Nl.zorg.MedicalDevice-v5.0(2024EN).xlsx',
#  'Nl.zorg.part.AddressInformation-v1.2(2024EN).xlsx',
#  'Nl.zorg.part.AnatomicalLocation-v1.0.4(2024EN).xlsx',
#  'Nl.zorg.part.ContactInformation-v1.3.1(2024EN).xlsx',
#  'Nl.zorg.part.NameInformation-v1.2(2024EN).xlsx',
#  'Nl.zorg.Patient-v4.3(2024EN).xlsx',
#  'Nl.zorg.Procedure-v6.0(2024EN).xlsx']

# %%
zib = zibs[2]
print(zib)
zibpath = os.path.join(zibspath, zib)
zibdf = pd.read_excel(zibpath)
zibdf
# Out:
# Nl.zorg.HealthProfessional-v4.0(2024EN).xlsx
#                                      name  \
# 0                      HealthProfessional
# 1  HealthProfessionalIdentificationNumber
# 2                         NameInformation
# 3                               Specialty
# 4                                  Gender
# 5                      AddressInformation
# 6                      ContactInformation
# 7                      HealthcareProvider
# 8                  HealthProfessionalRole
#
#                                                 path  \
# 0                                 HealthProfessional
# 1  HealthProfessional.HealthProfessionalIdentific...
# 2                 HealthProfessional.NameInformation
# 3                       HealthProfessional.Specialty
# 4                          HealthProfessional.Gender
# 5              HealthProfessional.AddressInformation
# 6              HealthProfessional.ContactInformation
# 7              HealthProfessional.HealthcareProvider
# 8          HealthProfessional.HealthProfessionalRole
#
#                                  alias type card.         stereotype  \
# 0                     NL: Zorgverlener  NaN   NaN        rootconcept
# 1  NL: ZorgverlenerIdentificatienummer   II  0..*               data
# 2                     NL: Naamgegevens  NaN  0..1     data,reference
# 3                      NL: Specialisme   CD  0..1               data
# 4                         NL: Geslacht   CD  0..1               data
# 5                    NL: Adresgegevens  NaN  0..*     data,reference
# 6                  NL: Contactgegevens  NaN  0..1     data,reference
# 7                    NL: Zorgaanbieder  NaN  0..1  context,reference
# 8                  NL: ZorgverlenerRol   CD  0..1               data
#
#              id                                         definition  \
# 0  NL-CM:17.1.1  Root concept of the HealthProfessional informa...
# 1  NL-CM:17.1.2  The health professional identification number ...
# 2  NL-CM:17.1.3  Health professional’s full name. If a health p...
# 3  NL-CM:17.1.4  Health professional’s medical specialty. This ...
# 4  NL-CM:17.1.9       Health professional’s administrative gender.
# 5  NL-CM:17.1.7         Health professional’s address information.
# 6  NL-CM:17.1.8  Health professional’s telephone number(s) or e...
# 7  NL-CM:17.1.6  The organization the health professional works...
# 8  NL-CM:17.1.5  The role the health professional fulfils in th...
#
#                                  definitioncode
# 0  SNOMED CT: 223366009 Healthcare professional
# 1                                           NaN
# 2                                           NaN
# 3       SNOMED CT: 394658006 Clinical specialty
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN

# %%
xlmbase = 'xtehr'
xlmspath = os.path.join(xlmbase, 'mappable')
xlms = os.listdir(xlmspath)
xlms
# Out:
# ['Address.xlsx',
#  'AlertFlag.xlsx',
#  'AllergyIntolerance.xlsx',
#  'BodyStructure.xlsx',
#  'Condition.xlsx',
#  'Device.xlsx',
#  'DeviceUse.xlsx',
#  'HealthProfessional.xlsx',
#  'HumanName.xlsx',
#  'Location.xlsx',
#  'Medication.xlsx',
#  'Organization.xlsx',
#  'Patient.xlsx',
#  'Procedure.xlsx',
#  'Telecom.xlsx']

# %%
xlm = xlms[7]
print( xlm)
xlmpath = os.path.join(xlmspath, xlm)
xlmdf = pd.read_excel(xlmpath)
xlmdf
# only for device use and organization
#xlm = xlms[11]
#print( xlm)
#xlmpath = os.path.join(xlmspath, xlm)
#xlmdf2 = pd.read_excel(xlmpath)
#xlmdf = pd.concat([xlmdf, xlmdf2], ignore_index=True)
#xlmdf
# Out:
# HealthProfessional.xlsx
#                                     id                                 path  \
# 0               EHDSHealthProfessional               EHDSHealthProfessional
# 1    EHDSHealthProfessional.identifier    EHDSHealthProfessional.identifier
# 2          EHDSHealthProfessional.name          EHDSHealthProfessional.name
# 3       EHDSHealthProfessional.address       EHDSHealthProfessional.address
# 4       EHDSHealthProfessional.telecom       EHDSHealthProfessional.telecom
# 5          EHDSHealthProfessional.role          EHDSHealthProfessional.role
# 6  EHDSHealthProfessional.organization  EHDSHealthProfessional.organization
# 7     EHDSHealthProfessional.specialty     EHDSHealthProfessional.specialty
#
#                                                short  \
# 0                          Health professional model
# 1  An identifier of the health professional that ...
# 2  Name of the health professional that has been ...
# 3  Mailing and office or home addresses. The addr...
# 4  Telecommunication contact information (address...
# 5  Health professional role. Multiple roles could...
# 6      The organization where this role is available
# 7  The specialty of a practitioner that describes...
#
#                                           definition              type card.  \
# 0  EHDS refined base model for Health professiona...               NaN  0..*
# 1  An identifier of the health professional that ...        Identifier  0..*
# 2  Name of the health professional that has been ...     EHDSHumanName  0..1
# 3  Mailing and office or home addresses. The addr...       EHDSAddress  0..1
# 4  Telecommunication contact information (address...       EHDSTelecom  0..*
# 5  Health professional role. Multiple roles could...   CodeableConcept  0..*
# 6      The organization where this role is available  EHDSOrganization  0..1
# 7  The specialty of a practitioner that describes...   CodeableConcept  0..*
#
#                                              binding
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  {'strength': 'preferred', 'description': 'ISCO...
# 6                                                NaN
# 7                                                NaN

# %%
mapbase = 'maps'
maps = os.listdir(mapbase)
maps
# Out:
# ['.~lock.HealthProfessional.xlsx#',
#  'Address.xlsx',
#  'AlertFlag.xlsx',
#  'BodyStructure.xlsx',
#  'Condition.xlsx',
#  'Device-and-DeviceUse.xlsx',
#  'HealthProfessional.xlsx',
#  'HumanName.xlsx',
#  'Location-and-Organization.xlsx',
#  'Patient.xlsx',
#  'Procedure.xlsx',
#  'xtehr2zibs',
#  'xtehr2zibs2024']

# %%
file = maps[6]
print(file)
mappath = os.path.join(mapbase, file)
print(mappath)
mapdf = pd.read_excel(mappath)
mapdf
# Out:
# HealthProfessional.xlsx
# maps\HealthProfessional.xlsx
#                                  xtehr  \
# 0               EHDSHealthProfessional
# 1    EHDSHealthProfessional.identifier
# 2          EHDSHealthProfessional.name
# 3       EHDSHealthProfessional.address
# 4       EHDSHealthProfessional.telecom
# 5          EHDSHealthProfessional.role
# 6  EHDSHealthProfessional.organization
# 7     EHDSHealthProfessional.specialty
# 8                                  NaN
#
#                                                  zib
# 0                                 HealthProfessional
# 1  HealthProfessional.HealthProfessionalIdentific...
# 2                 HealthProfessional.NameInformation
# 3              HealthProfessional.AddressInformation
# 4              HealthProfessional.ContactInformation
# 5          HealthProfessional.HealthProfessionalRole
# 6              HealthProfessional.HealthcareProvider
# 7                       HealthProfessional.Specialty
# 8                          HealthProfessional.Gender

# %%
mapping = mapdf[['xtehr', 'zib']].merge(zibdf.add_suffix('_zib'), left_on='zib', right_on='path_zib', how='outer').merge(xlmdf.add_suffix('_xtehr'), left_on='xtehr', right_on='path_xtehr', how='outer')
mapping
# Out:
#                                  xtehr  \
# 0               EHDSHealthProfessional
# 1       EHDSHealthProfessional.address
# 2    EHDSHealthProfessional.identifier
# 3          EHDSHealthProfessional.name
# 4  EHDSHealthProfessional.organization
# 5          EHDSHealthProfessional.role
# 6     EHDSHealthProfessional.specialty
# 7       EHDSHealthProfessional.telecom
# 8                                  NaN
#
#                                                  zib  \
# 0                                 HealthProfessional
# 1              HealthProfessional.AddressInformation
# 2  HealthProfessional.HealthProfessionalIdentific...
# 3                 HealthProfessional.NameInformation
# 4              HealthProfessional.HealthcareProvider
# 5          HealthProfessional.HealthProfessionalRole
# 6                       HealthProfessional.Specialty
# 7              HealthProfessional.ContactInformation
# 8                          HealthProfessional.Gender
#
#                                  name_zib  \
# 0                      HealthProfessional
# 1                      AddressInformation
# 2  HealthProfessionalIdentificationNumber
# 3                         NameInformation
# 4                      HealthcareProvider
# 5                  HealthProfessionalRole
# 6                               Specialty
# 7                      ContactInformation
# 8                                  Gender
#
#                                             path_zib  \
# 0                                 HealthProfessional
# 1              HealthProfessional.AddressInformation
# 2  HealthProfessional.HealthProfessionalIdentific...
# 3                 HealthProfessional.NameInformation
# 4              HealthProfessional.HealthcareProvider
# 5          HealthProfessional.HealthProfessionalRole
# 6                       HealthProfessional.Specialty
# 7              HealthProfessional.ContactInformation
# 8                          HealthProfessional.Gender
#
#                              alias_zib type_zib card._zib     stereotype_zib  \
# 0                     NL: Zorgverlener      NaN       NaN        rootconcept
# 1                    NL: Adresgegevens      NaN      0..*     data,reference
# 2  NL: ZorgverlenerIdentificatienummer       II      0..*               data
# 3                     NL: Naamgegevens      NaN      0..1     data,reference
# 4                    NL: Zorgaanbieder      NaN      0..1  context,reference
# 5                  NL: ZorgverlenerRol       CD      0..1               data
# 6                      NL: Specialisme       CD      0..1               data
# 7                  NL: Contactgegevens      NaN      0..1     data,reference
# 8                         NL: Geslacht       CD      0..1               data
#
#          id_zib                                     definition_zib  \
# 0  NL-CM:17.1.1  Root concept of the HealthProfessional informa...
# 1  NL-CM:17.1.7         Health professional’s address information.
# 2  NL-CM:17.1.2  The health professional identification number ...
# 3  NL-CM:17.1.3  Health professional’s full name. If a health p...
# 4  NL-CM:17.1.6  The organization the health professional works...
# 5  NL-CM:17.1.5  The role the health professional fulfils in th...
# 6  NL-CM:17.1.4  Health professional’s medical specialty. This ...
# 7  NL-CM:17.1.8  Health professional’s telephone number(s) or e...
# 8  NL-CM:17.1.9       Health professional’s administrative gender.
#
#                              definitioncode_zib  \
# 0  SNOMED CT: 223366009 Healthcare professional
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6       SNOMED CT: 394658006 Clinical specialty
# 7                                           NaN
# 8                                           NaN
#
#                               id_xtehr                           path_xtehr  \
# 0               EHDSHealthProfessional               EHDSHealthProfessional
# 1       EHDSHealthProfessional.address       EHDSHealthProfessional.address
# 2    EHDSHealthProfessional.identifier    EHDSHealthProfessional.identifier
# 3          EHDSHealthProfessional.name          EHDSHealthProfessional.name
# 4  EHDSHealthProfessional.organization  EHDSHealthProfessional.organization
# 5          EHDSHealthProfessional.role          EHDSHealthProfessional.role
# 6     EHDSHealthProfessional.specialty     EHDSHealthProfessional.specialty
# 7       EHDSHealthProfessional.telecom       EHDSHealthProfessional.telecom
# 8                                  NaN                                  NaN
#
#                                          short_xtehr  \
# 0                          Health professional model
# 1  Mailing and office or home addresses. The addr...
# 2  An identifier of the health professional that ...
# 3  Name of the health professional that has been ...
# 4      The organization where this role is available
# 5  Health professional role. Multiple roles could...
# 6  The specialty of a practitioner that describes...
# 7  Telecommunication contact information (address...
# 8                                                NaN
#
#                                     definition_xtehr        type_xtehr  \
# 0  EHDS refined base model for Health professiona...               NaN
# 1  Mailing and office or home addresses. The addr...       EHDSAddress
# 2  An identifier of the health professional that ...        Identifier
# 3  Name of the health professional that has been ...     EHDSHumanName
# 4      The organization where this role is available  EHDSOrganization
# 5  Health professional role. Multiple roles could...   CodeableConcept
# 6  The specialty of a practitioner that describes...   CodeableConcept
# 7  Telecommunication contact information (address...       EHDSTelecom
# 8                                                NaN               NaN
#
#   card._xtehr                                      binding_xtehr
# 0        0..*                                                NaN
# 1        0..1                                                NaN
# 2        0..*                                                NaN
# 3        0..1                                                NaN
# 4        0..1                                                NaN
# 5        0..*  {'strength': 'preferred', 'description': 'ISCO...
# 6        0..*                                                NaN
# 7        0..*                                                NaN
# 8         NaN                                                NaN

# %%
shortmap = mapping[['zib', 'xtehr', 'type_zib','type_xtehr', 'card._zib', 'card._xtehr']]
shortmap
# Out:
#                                                  zib  \
# 0                                 HealthProfessional
# 1              HealthProfessional.AddressInformation
# 2  HealthProfessional.HealthProfessionalIdentific...
# 3                 HealthProfessional.NameInformation
# 4              HealthProfessional.HealthcareProvider
# 5          HealthProfessional.HealthProfessionalRole
# 6                       HealthProfessional.Specialty
# 7              HealthProfessional.ContactInformation
# 8                          HealthProfessional.Gender
#
#                                  xtehr type_zib        type_xtehr card._zib  \
# 0               EHDSHealthProfessional      NaN               NaN       NaN
# 1       EHDSHealthProfessional.address      NaN       EHDSAddress      0..*
# 2    EHDSHealthProfessional.identifier       II        Identifier      0..*
# 3          EHDSHealthProfessional.name      NaN     EHDSHumanName      0..1
# 4  EHDSHealthProfessional.organization      NaN  EHDSOrganization      0..1
# 5          EHDSHealthProfessional.role       CD   CodeableConcept      0..1
# 6     EHDSHealthProfessional.specialty       CD   CodeableConcept      0..1
# 7       EHDSHealthProfessional.telecom      NaN       EHDSTelecom      0..1
# 8                                  NaN       CD               NaN      0..1
#
#   card._xtehr
# 0        0..*
# 1        0..1
# 2        0..*
# 3        0..1
# 4        0..1
# 5        0..*
# 6        0..*
# 7        0..*
# 8         NaN

# %%
mapsoutpath = os.path.join(mapbase, 'xtehr2zibs2024')
filepath = file.replace('.xlsx', '-full.xlsx')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_excel(mappath, index=False)

# %%
filepath = file.replace('.xlsx', '.csv')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_csv(mappath, index=False)

# %%
from IPython.display import Markdown
import numpy as np

content = "# " + mapping.iat[0, 0][4:] + "\n\n"
content += shortmap.fillna('').to_markdown(index=False) + "\n\n"
for i, row in mapping.iterrows():
    # print(i, row)
    content += "\n\n"
    if row.iloc[0] is not np.nan:
        content += "## " + str(row.iloc[0]) + "\n\n"
    else:
        content += "## zib: " + str(row.iloc[1]) + "\n\n"
    content += "### Table" + "\n\n"
    content += "| attribute | value |" + "\n" + "|---|---|" + "\n"
    for j, att in row.fillna('')[0:2].items():
        content += "| " + str(j) + " | " + str(att) + " |" + "\n"
    for j, att in row.fillna('')[2:].sort_index().items():
        content += "| " + str(j) + " | " + str(att) + " |" + "\n"    
    content += "\n### Comments" + "\n\n"
with open(os.path.join(mapsoutpath, file.replace('.xlsx', '.md')), 'w') as f:
    f.write(content)
# PAS OP: deze overschrijft de eventueel met de hand gemaakte comments files, alleen gebriuken
# bij eerste keer dat je een mapping maakt, daarna de comments handmatig aanpassen
with open(os.path.join(mapsoutpath, file.replace('.xlsx', '-comments.md')), 'w') as f:
    f.write(content)
#Markdown(content)
