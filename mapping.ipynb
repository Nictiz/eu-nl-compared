# %%
import pandas as pd
import os
import unicodedata as ud

# %%
# zibbase = 'zibs2020'
zibbase = 'zibs2024'
zibspath = os.path.join(zibbase, 'mappable')
zibs = os.listdir(zibspath)
[(i, zib) for i, zib in enumerate(zibs)]
# Out:
# [(0, 'Nl.zorg.Alert-v5.0(2024EN).xlsx'),
#  (1, 'Nl.zorg.Condition-v1.1(2024EN).xlsx'),
#  (2, 'Nl.zorg.Diagnosis-v2.0(2024EN).xlsx'),
#  (3, 'nl.zorg.DispenseRequest-v4.0(2024EN).xlsx'),
#  (4, 'Nl.zorg.HealthcareProvider-v3.6(2024EN).xlsx'),
#  (5, 'Nl.zorg.HealthProfessional-v4.0(2024EN).xlsx'),
#  (6, 'Nl.zorg.MedicalDevice-v5.0(2024EN).xlsx'),
#  (7, 'nl.zorg.MedicationAgreement-v4.0(2024EN).xlsx'),
#  (8, 'Nl.zorg.NursingIntervention-v5.0(2024EN).xlsx'),
#  (9, 'Nl.zorg.part.AddressInformation-v1.2(2024EN).xlsx'),
#  (10, 'Nl.zorg.part.AnatomicalLocation-v1.0.4(2024EN).xlsx'),
#  (11, 'Nl.zorg.part.ContactInformation-v1.3.1(2024EN).xlsx'),
#  (12, 'Nl.zorg.part.NameInformation-v1.2(2024EN).xlsx'),
#  (13, 'Nl.zorg.Patient-v4.3(2024EN).xlsx'),
#  (14, 'Nl.zorg.Procedure-v6.0(2024EN).xlsx'),
#  (15, 'Nl.zorg.process.RegistrationData-v1.1.2(2024EN).xlsx')]

# %%
zib = zibs[3]
print(zib)
zibpath = os.path.join(zibspath, zib)
zibdf = pd.read_excel(zibpath)
zibdf['path'] = zibdf['path'].apply(
    lambda x: ud.normalize("NFKC", str(x)).replace("\xa0", " ").strip() if pd.notna(x) else x
)
zibdf
# only for zib2024 condition and diagnosis
# zib = zibs[1]
# print( zib)
# zibpath = os.path.join(zibspath, zib)
# zibdf2 = pd.read_excel(zibpath)
# zibdf = pd.concat([zibdf, zibdf2], ignore_index=True)
# zibdf
# Out:
# nl.zorg.DispenseRequest-v4.0(2024EN).xlsx
#                                             name  \
# 0                                DispenseRequest
# 1           IntendedSupplier::HealthcareProvider
# 2   MedicineToBeDispensed::PharmaceuticalProduct
# 3                            DispenseRequestDate
# 4                     SupplyPeriod::TimeInterval
# 5                                NumberOfRefills
# 6                                         Amount
# 7                               DispenseLocation
# 8                               AdditionalWishes
# 9                          DispenseRequestStatus
# 10                                       Comment
#
#                                                  path  \
# 0                                     DispenseRequest
# 1   DispenseRequest.IntendedSupplier::HealthcarePr...
# 2   DispenseRequest.MedicineToBeDispensed::Pharmac...
# 3                 DispenseRequest.DispenseRequestDate
# 4          DispenseRequest.SupplyPeriod::TimeInterval
# 5                     DispenseRequest.NumberOfRefills
# 6                              DispenseRequest.Amount
# 7                    DispenseRequest.DispenseLocation
# 8                    DispenseRequest.AdditionalWishes
# 9               DispenseRequest.DispenseRequestStatus
# 10                            DispenseRequest.Comment
#
#                                                 alias type card.  \
# 0                            NL: Verstrekkingsverzoek  NaN   NaN
# 1                NL: BeoogdVerstrekker::Zorgaanbieder  NaN  0..1
# 2   NL: TeVerstrekkenGeneesmiddel::FarmaceutischPr...  NaN     1
# 3                       NL: VerstrekkingsverzoekDatum   TS  0..1
# 4                 NL: Verbruiksperiode::TijdsInterval  NaN  0..1
# 5                               NL: AantalHerhalingen  INT  0..1
# 6                        NL: TeVerstrekkenHoeveelheid   PQ  0..1
# 7                                  NL: Afleverlocatie   ST  0..1
# 8                               NL: AanvullendeWensen   CD  0..*
# 9                      NL: VerstrekkingsverzoekStatus   CD     1
# 10                                    NL: Toelichting   ST  0..1
#
#            stereotype                id  \
# 0         rootconcept  NL-CM:9.10.19963
# 1   context,reference  NL-CM:9.10.19966
# 2      data,reference  NL-CM:9.10.22249
# 3                data  NL-CM:9.10.20060
# 4      data,reference  NL-CM:9.10.20062
# 5                data  NL-CM:9.10.22120
# 6                data  NL-CM:9.10.19964
# 7                data  NL-CM:9.10.20068
# 8                data  NL-CM:9.10.22759
# 9                data  NL-CM:9.10.22760
# 10               data  NL-CM:9.10.22274
#
#                                            definition  \
# 0   Root concept of the DispenseRequest informatio...
# 1              The intended supplier is a pharmacist.
# 2                       The medicine to be dispensed.
# 3      Time at which the dispense request is entered.
# 4   During the approved period of use, the pharmac...
# 5   The number of additional times the medication ...
# 6   This is the number of units of the ordered pro...
# 7                                  Dispense location.
# 8   Logistics and other instructions such as: do n...
# 9   Status of the order in the ordering process, s...
# 10  Explanation for the dispense request. \n \nThi...
#
#                                        definitioncode
# 0   SNOMED CT: 52711000146108 Request to dispense ...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  LOINC: 48767-8 Annotation comment [Interpretat...

# %%
xlmbase = 'xtehr'
xlmspath = os.path.join(xlmbase, 'mappable')
xlms = os.listdir(xlmspath)
[(i, xlm) for i, xlm in enumerate(xlms)]
# Out:
# [(0, 'Address.xlsx'),
#  (1, 'AlertFlag.xlsx'),
#  (2, 'AllergyIntolerance.xlsx'),
#  (3, 'BodyStructure.xlsx'),
#  (4, 'Condition.xlsx'),
#  (5, 'DataSet.xlsx'),
#  (6, 'Device.xlsx'),
#  (7, 'DeviceUse.xlsx'),
#  (8, 'HealthProfessional.xlsx'),
#  (9, 'HumanName.xlsx'),
#  (10, 'Location.xlsx'),
#  (11, 'Medication.xlsx'),
#  (12, 'MedicationPrescription.xlsx'),
#  (13, 'Organization.xlsx'),
#  (14, 'Patient.xlsx'),
#  (15, 'Procedure.xlsx'),
#  (16, 'Telecom.xlsx')]

# %%
xlm = xlms[12]
print( xlm)
xlmpath = os.path.join(xlmspath, xlm)
xlmdf = pd.read_excel(xlmpath)
# Normalize + strip (for non-breaking spaces, Unicode issues)
xlmdf['path'] = xlmdf['path'].apply(
    lambda x: ud.normalize("NFKC", str(x)).replace("\xa0", " ").strip() if pd.notna(x) else x
)
xlmdf
# only for device use and organization
# xlm = xlms[7]
# print( xlm)
# xlmpath = os.path.join(xlmspath, xlm)
# xlmdf2 = pd.read_excel(xlmpath)
# xlmdf = pd.concat([xlmdf, xlmdf2], ignore_index=True)
# xlmdf
# Out:
# MedicationPrescription.xlsx
#                                                    id  \
# 0                          EHDSMedicationPrescription
# 1                   EHDSMedicationPrescription.header
# 2           EHDSMedicationPrescription.header.subject
# 3        EHDSMedicationPrescription.header.identifier
# 4        EHDSMedicationPrescription.header.authorship
# 5   EHDSMedicationPrescription.header.authorship.a...
# 6   EHDSMedicationPrescription.header.authorship.d...
# 7        EHDSMedicationPrescription.header.lastUpdate
# 8            EHDSMedicationPrescription.header.status
# 9   EHDSMedicationPrescription.header.statusReason[x]
# 10         EHDSMedicationPrescription.header.language
# 11          EHDSMedicationPrescription.header.version
# 12           EHDSMedicationPrescription.presentedForm
# 13         EHDSMedicationPrescription.header.recorder
# 14    EHDSMedicationPrescription.header.recordingDate
# 15        EHDSMedicationPrescription.header.validFrom
# 16       EHDSMedicationPrescription.header.validUntil
# 17                 EHDSMedicationPrescription.comment
# 18        EHDSMedicationPrescription.prescriptionItem
# 19  EHDSMedicationPrescription.prescriptionItem.id...
# 20  EHDSMedicationPrescription.prescriptionItem.ca...
# 21  EHDSMedicationPrescription.prescriptionItem.me...
# 22  EHDSMedicationPrescription.prescriptionItem.in...
# 23  EHDSMedicationPrescription.prescriptionItem.in...
# 24  EHDSMedicationPrescription.prescriptionItem.pr...
# 25  EHDSMedicationPrescription.prescriptionItem.tr...
# 26  EHDSMedicationPrescription.prescriptionItem.qu...
# 27  EHDSMedicationPrescription.prescriptionItem.do...
# 28  EHDSMedicationPrescription.prescriptionItem.pr...
# 29  EHDSMedicationPrescription.prescriptionItem.su...
# 30  EHDSMedicationPrescription.prescriptionItem.su...
# 31  EHDSMedicationPrescription.prescriptionItem.su...
# 32  EHDSMedicationPrescription.prescriptionItem.st...
# 33  EHDSMedicationPrescription.prescriptionItem.st...
# 34  EHDSMedicationPrescription.prescriptionItem.re...
# 35  EHDSMedicationPrescription.prescriptionItem.mi...
# 36  EHDSMedicationPrescription.prescriptionItem.of...
# 37  EHDSMedicationPrescription.prescriptionItem.of...
# 38  EHDSMedicationPrescription.prescriptionItem.of...
# 39  EHDSMedicationPrescription.prescriptionItem.co...
#
#                                                  path  \
# 0                          EHDSMedicationPrescription
# 1                   EHDSMedicationPrescription.header
# 2           EHDSMedicationPrescription.header.subject
# 3        EHDSMedicationPrescription.header.identifier
# 4        EHDSMedicationPrescription.header.authorship
# 5   EHDSMedicationPrescription.header.authorship.a...
# 6   EHDSMedicationPrescription.header.authorship.d...
# 7        EHDSMedicationPrescription.header.lastUpdate
# 8            EHDSMedicationPrescription.header.status
# 9   EHDSMedicationPrescription.header.statusReason[x]
# 10         EHDSMedicationPrescription.header.language
# 11          EHDSMedicationPrescription.header.version
# 12           EHDSMedicationPrescription.presentedForm
# 13         EHDSMedicationPrescription.header.recorder
# 14    EHDSMedicationPrescription.header.recordingDate
# 15        EHDSMedicationPrescription.header.validFrom
# 16       EHDSMedicationPrescription.header.validUntil
# 17                 EHDSMedicationPrescription.comment
# 18        EHDSMedicationPrescription.prescriptionItem
# 19  EHDSMedicationPrescription.prescriptionItem.id...
# 20  EHDSMedicationPrescription.prescriptionItem.ca...
# 21  EHDSMedicationPrescription.prescriptionItem.me...
# 22  EHDSMedicationPrescription.prescriptionItem.in...
# 23  EHDSMedicationPrescription.prescriptionItem.in...
# 24  EHDSMedicationPrescription.prescriptionItem.pr...
# 25  EHDSMedicationPrescription.prescriptionItem.tr...
# 26  EHDSMedicationPrescription.prescriptionItem.qu...
# 27  EHDSMedicationPrescription.prescriptionItem.do...
# 28  EHDSMedicationPrescription.prescriptionItem.pr...
# 29  EHDSMedicationPrescription.prescriptionItem.su...
# 30  EHDSMedicationPrescription.prescriptionItem.su...
# 31  EHDSMedicationPrescription.prescriptionItem.su...
# 32  EHDSMedicationPrescription.prescriptionItem.st...
# 33  EHDSMedicationPrescription.prescriptionItem.st...
# 34  EHDSMedicationPrescription.prescriptionItem.re...
# 35  EHDSMedicationPrescription.prescriptionItem.mi...
# 36  EHDSMedicationPrescription.prescriptionItem.of...
# 37  EHDSMedicationPrescription.prescriptionItem.of...
# 38  EHDSMedicationPrescription.prescriptionItem.of...
# 39  EHDSMedicationPrescription.prescriptionItem.co...
#
#                                                 short  \
# 0                       Medication prescription model
# 1                                 Prescription header
# 2   The person for whom the medication is prescrib...
# 3   Business identifier(s) for the prescription. [...
# 4                                          Authorship
# 5   The prescriber, the person who made the prescr...
# 6   Time of issuing (signing) the prescription by ...
# 7    Date and time of the last update to the resource
# 8   Status of the prescription, this should not be...
# 9   Reason for the current status of prescription,...
# 10                                           Language
# 11                                            Version
# 12  Entire prescription as issued. Various formats...
# 13  The recorder of the prescription/draft in the ...
# 14  Time of authoring the prescription/draft in th...
# 15  Effective date of the prescription. The prescr...
# 16  The validity period end date. The prescription...
# 17                 Additional information or comments
# 18  Prescription line for one medication. In many ...
# 19  Identifier for a single item on prescription, ...
# 20  Category or categories of prescription. For ex...
# 21  Prescribed product, branded, generic, virtual,...
# 22  Reason for the prescription (typically diagnos...
# 23  Reason for the prescription in textual form. T...
# 24  Intent of the prescription - prophylaxis, trea...
# 25  Period over which the medication is to be take...
# 26  Overall quantity of prescribed product (e.g nu...
# 27           Dosaging and administration instructions
# 28  Additional instructions about preparation or d...
# 29  Whether and which type of substitution is allo...
# 30  Whether and to what extent substitution is all...
# 31  Reason for the substitution requirement (e.g. ...
# 32  Status of a single item of a multi-item prescr...
# 33  Reason for the current status of prescription,...
# 34                       Number of refills authorized
# 35                          Minimum Dispense Interval
# 36  Indicates that the prescriber has knowingly pr...
# 37  Indicates off-label use. Must be 'true' when ....
# 38  Reason or related clarification for off-label use
# 39                 Additional information or comments
#
#                                            definition                    type  \
# 0   Logical model for medication prescription. A p...                     NaN
# 1                   Prescription header data elements                    Base
# 2                         Patient/subject information             EHDSPatient
# 3                  Business identifier for the object              Identifier
# 4                          Resource authoring details                    Base
# 5   Author(s) by whom the resource was/were author...  EHDSHealthProfessional
# 6   Date and time of the issuing the document/reso...                dateTime
# 7   Date and time of the last update to the docume...                dateTime
# 8                              Status of the resource         CodeableConcept
# 9      Reason for the current status of the resource.         CodeableConcept
# 10  Language in which the resource is written. Lan...         CodeableConcept
# 11                  Business version of the resource.                  string
# 12  A narrative easy-to-read representation of the...          EHDSAttachment
# 13  The recorder of the prescription/draft in the ...  EHDSHealthProfessional
# 14  Time of authoring the prescription/draft in th...                dateTime
# 15  Effective date of the prescription. The prescr...                dateTime
# 16  The validity period end date. The prescription...                dateTime
# 17                 Additional information or comments                  string
# 18  Prescription line for one medication. In many ...                    Base
# 19  Identifier for a single item on prescription, ...              Identifier
# 20  Category or categories of prescription. For ex...         CodeableConcept
# 21  Prescribed product, branded, generic, virtual,...          EHDSMedication
# 22  Reason for the prescription (typically diagnos...         CodeableConcept
# 23  Reason for the prescription in textual form. T...                  string
# 24  Intent of the prescription - prophylaxis, trea...         CodeableConcept
# 25  Period over which the medication is to be take...                  Period
# 26  Overall quantity of prescribed product (e.g nu...                Quantity
# 27           Dosaging and administration instructions            EHDSDosaging
# 28  Additional instructions about preparation or d...                  string
# 29  Whether and which type of substitution is allo...                    Base
# 30  Whether and to what extent substitution is all...                 boolean
# 31  Reason for the substitution requirement (e.g. ...         CodeableConcept
# 32  Status of a single item of a multi-item prescr...         CodeableConcept
# 33  Reason for the current status of prescription,...         CodeableConcept
# 34  How many times the prescription item can be di...                 integer
# 35  If a prescription allows for repeated dispensa...                Quantity
# 36  Indicates that the prescriber has knowingly pr...                    Base
# 37  Indicates off-label use. Must be 'true' when ....                 boolean
# 38  Reason or related clarification for off-label use         CodeableConcept
# 39                 Additional information or comments                  string
#
#    card.                                            binding
# 0   0..*                                                NaN
# 1   1..1                                                NaN
# 2   1..1                                                NaN
# 3   0..*                                                NaN
# 4   1..*                                                NaN
# 5   1..1                                                NaN
# 6   1..1                                                NaN
# 7   0..1                                                NaN
# 8   1..1                                                NaN
# 9   0..1                                                NaN
# 10  0..1  {'strength': 'preferred', 'description': 'BCP ...
# 11  0..1                                                NaN
# 12  0..*                                                NaN
# 13  0..1                                                NaN
# 14  0..1                                                NaN
# 15  0..1                                                NaN
# 16  0..1                                                NaN
# 17  0..*                                                NaN
# 18  1..*                                                NaN
# 19  0..1                                                NaN
# 20  0..*                                                NaN
# 21  1..1                                                NaN
# 22  0..*                                                NaN
# 23  0..1                                                NaN
# 24  0..1                                                NaN
# 25  0..1                                                NaN
# 26  0..1  {'strength': 'preferred', 'description': 'UCUM...
# 27  0..*                                                NaN
# 28  0..1                                                NaN
# 29  0..1                                                NaN
# 30  0..1                                                NaN
# 31  0..1                                                NaN
# 32  1..1                                                NaN
# 33  0..1                                                NaN
# 34  0..1                                                NaN
# 35  0..1                                                NaN
# 36  0..1                                                NaN
# 37  1..1                                                NaN
# 38  0..*                                                NaN
# 39  0..*                                                NaN

# %%
mapbase = 'maps'
maps = os.listdir(mapbase)
[(i, map) for i, map in enumerate(maps)]
# Out:
# [(0, 'Address.xlsx'),
#  (1, 'AlertFlag.xlsx'),
#  (2, 'BodyStructure.xlsx'),
#  (3, 'Condition.xlsx'),
#  (4, 'DataSet.xlsx'),
#  (5, 'Device-and-DeviceUse.xlsx'),
#  (6, 'Diagnosis.xlsx'),
#  (7, 'HealthProfessional.xlsx'),
#  (8, 'HumanName.xlsx'),
#  (9, 'Location-and-Organization.xlsx'),
#  (10, 'MedicationPrescription.xlsx'),
#  (11, 'Patient.xlsx'),
#  (12, 'Procedure-NusringIntervention.xlsx'),
#  (13, 'Procedure.xlsx'),
#  (14, 'xtehr2zibs'),
#  (15, 'xtehr2zibs2024')]

# %%
file = maps[10]
print(file)
mappath = os.path.join(mapbase, file)
print(mappath)
mapdf = pd.read_excel(mappath)
# Normalize + strip (for non-breaking spaces, Unicode issues)
mapdf[['zib','xtehr']] = mapdf[['zib','xtehr']].map(
    lambda x: ud.normalize("NFKC", str(x)).replace("\xa0", " ").strip() if pd.notna(x) else x
)
mapdf
# Out:
# MedicationPrescription.xlsx
# maps\MedicationPrescription.xlsx
#                                                 xtehr  \
# 0                          EHDSMedicationPrescription
# 1                   EHDSMedicationPrescription.header
# 2           EHDSMedicationPrescription.header.subject
# 3        EHDSMedicationPrescription.header.identifier
# 4        EHDSMedicationPrescription.header.authorship
# 5   EHDSMedicationPrescription.header.authorship.a...
# 6   EHDSMedicationPrescription.header.authorship.d...
# 7        EHDSMedicationPrescription.header.lastUpdate
# 8            EHDSMedicationPrescription.header.status
# 9   EHDSMedicationPrescription.header.statusReason[x]
# 10         EHDSMedicationPrescription.header.language
# 11          EHDSMedicationPrescription.header.version
# 12           EHDSMedicationPrescription.presentedForm
# 13         EHDSMedicationPrescription.header.recorder
# 14    EHDSMedicationPrescription.header.recordingDate
# 15        EHDSMedicationPrescription.header.validFrom
# 16       EHDSMedicationPrescription.header.validUntil
# 17                 EHDSMedicationPrescription.comment
# 18        EHDSMedicationPrescription.prescriptionItem
# 19  EHDSMedicationPrescription.prescriptionItem.id...
# 20  EHDSMedicationPrescription.prescriptionItem.ca...
# 21  EHDSMedicationPrescription.prescriptionItem.me...
# 22  EHDSMedicationPrescription.prescriptionItem.in...
# 23  EHDSMedicationPrescription.prescriptionItem.in...
# 24  EHDSMedicationPrescription.prescriptionItem.pr...
# 25  EHDSMedicationPrescription.prescriptionItem.tr...
# 26  EHDSMedicationPrescription.prescriptionItem.qu...
# 27  EHDSMedicationPrescription.prescriptionItem.do...
# 28  EHDSMedicationPrescription.prescriptionItem.pr...
# 29  EHDSMedicationPrescription.prescriptionItem.su...
# 30  EHDSMedicationPrescription.prescriptionItem.su...
# 31  EHDSMedicationPrescription.prescriptionItem.su...
# 32  EHDSMedicationPrescription.prescriptionItem.st...
# 33  EHDSMedicationPrescription.prescriptionItem.st...
# 34  EHDSMedicationPrescription.prescriptionItem.re...
# 35  EHDSMedicationPrescription.prescriptionItem.mi...
# 36  EHDSMedicationPrescription.prescriptionItem.of...
# 37  EHDSMedicationPrescription.prescriptionItem.of...
# 38  EHDSMedicationPrescription.prescriptionItem.of...
# 39  EHDSMedicationPrescription.prescriptionItem.co...
#
#                                                   zib  name_zib  path_zib  \
# 0                                     DispenseRequest       NaN       NaN
# 1                                                 NaN       NaN       NaN
# 2                                                 NaN       NaN       NaN
# 3                                                 NaN       NaN       NaN
# 4                                                 NaN       NaN       NaN
# 5                                                 NaN       NaN       NaN
# 6                                                 NaN       NaN       NaN
# 7                                                 NaN       NaN       NaN
# 8                                                 NaN       NaN       NaN
# 9                                                 NaN       NaN       NaN
# 10                                                NaN       NaN       NaN
# 11                                                NaN       NaN       NaN
# 12                                                NaN       NaN       NaN
# 13                                                NaN       NaN       NaN
# 14                                                NaN       NaN       NaN
# 15                                                NaN       NaN       NaN
# 16                                                NaN       NaN       NaN
# 17                                                NaN       NaN       NaN
# 18                                                NaN       NaN       NaN
# 19                                                NaN       NaN       NaN
# 20                                                NaN       NaN       NaN
# 21  DispenseRequest.MedicineToBeDispensed::Pharmac...       NaN       NaN
# 22                                                NaN       NaN       NaN
# 23                                                NaN       NaN       NaN
# 24                                                NaN       NaN       NaN
# 25         DispenseRequest.SupplyPeriod::TimeInterval       NaN       NaN
# 26                             DispenseRequest.Amount       NaN       NaN
# 27                                                NaN       NaN       NaN
# 28                   DispenseRequest.AdditionalWishes       NaN       NaN
# 29                                                NaN       NaN       NaN
# 30                                                NaN       NaN       NaN
# 31                                                NaN       NaN       NaN
# 32              DispenseRequest.DispenseRequestStatus       NaN       NaN
# 33                                                NaN       NaN       NaN
# 34                    DispenseRequest.NumberOfRefills       NaN       NaN
# 35                                                NaN       NaN       NaN
# 36                                                NaN       NaN       NaN
# 37                                                NaN       NaN       NaN
# 38                                                NaN       NaN       NaN
# 39                            DispenseRequest.Comment       NaN       NaN
#
#     alias_zib  type_zib  card._zib  stereotype_zib  id_zib  definition_zib  \
# 0         NaN       NaN        NaN             NaN     NaN             NaN
# 1         NaN       NaN        NaN             NaN     NaN             NaN
# 2         NaN       NaN        NaN             NaN     NaN             NaN
# 3         NaN       NaN        NaN             NaN     NaN             NaN
# 4         NaN       NaN        NaN             NaN     NaN             NaN
# 5         NaN       NaN        NaN             NaN     NaN             NaN
# 6         NaN       NaN        NaN             NaN     NaN             NaN
# 7         NaN       NaN        NaN             NaN     NaN             NaN
# 8         NaN       NaN        NaN             NaN     NaN             NaN
# 9         NaN       NaN        NaN             NaN     NaN             NaN
# 10        NaN       NaN        NaN             NaN     NaN             NaN
# 11        NaN       NaN        NaN             NaN     NaN             NaN
# 12        NaN       NaN        NaN             NaN     NaN             NaN
# 13        NaN       NaN        NaN             NaN     NaN             NaN
# 14        NaN       NaN        NaN             NaN     NaN             NaN
# 15        NaN       NaN        NaN             NaN     NaN             NaN
# 16        NaN       NaN        NaN             NaN     NaN             NaN
# 17        NaN       NaN        NaN             NaN     NaN             NaN
# 18        NaN       NaN        NaN             NaN     NaN             NaN
# 19        NaN       NaN        NaN             NaN     NaN             NaN
# 20        NaN       NaN        NaN             NaN     NaN             NaN
# 21        NaN       NaN        NaN             NaN     NaN             NaN
# 22        NaN       NaN        NaN             NaN     NaN             NaN
# 23        NaN       NaN        NaN             NaN     NaN             NaN
# 24        NaN       NaN        NaN             NaN     NaN             NaN
# 25        NaN       NaN        NaN             NaN     NaN             NaN
# 26        NaN       NaN        NaN             NaN     NaN             NaN
# 27        NaN       NaN        NaN             NaN     NaN             NaN
# 28        NaN       NaN        NaN             NaN     NaN             NaN
# 29        NaN       NaN        NaN             NaN     NaN             NaN
# 30        NaN       NaN        NaN             NaN     NaN             NaN
# 31        NaN       NaN        NaN             NaN     NaN             NaN
# 32        NaN       NaN        NaN             NaN     NaN             NaN
# 33        NaN       NaN        NaN             NaN     NaN             NaN
# 34        NaN       NaN        NaN             NaN     NaN             NaN
# 35        NaN       NaN        NaN             NaN     NaN             NaN
# 36        NaN       NaN        NaN             NaN     NaN             NaN
# 37        NaN       NaN        NaN             NaN     NaN             NaN
# 38        NaN       NaN        NaN             NaN     NaN             NaN
# 39        NaN       NaN        NaN             NaN     NaN             NaN
#
#     definitioncode_zib  id_xtehr  path_xtehr  short_xtehr  definition_xtehr  \
# 0                  NaN       NaN         NaN          NaN               NaN
# 1                  NaN       NaN         NaN          NaN               NaN
# 2                  NaN       NaN         NaN          NaN               NaN
# 3                  NaN       NaN         NaN          NaN               NaN
# 4                  NaN       NaN         NaN          NaN               NaN
# 5                  NaN       NaN         NaN          NaN               NaN
# 6                  NaN       NaN         NaN          NaN               NaN
# 7                  NaN       NaN         NaN          NaN               NaN
# 8                  NaN       NaN         NaN          NaN               NaN
# 9                  NaN       NaN         NaN          NaN               NaN
# 10                 NaN       NaN         NaN          NaN               NaN
# 11                 NaN       NaN         NaN          NaN               NaN
# 12                 NaN       NaN         NaN          NaN               NaN
# 13                 NaN       NaN         NaN          NaN               NaN
# 14                 NaN       NaN         NaN          NaN               NaN
# 15                 NaN       NaN         NaN          NaN               NaN
# 16                 NaN       NaN         NaN          NaN               NaN
# 17                 NaN       NaN         NaN          NaN               NaN
# 18                 NaN       NaN         NaN          NaN               NaN
# 19                 NaN       NaN         NaN          NaN               NaN
# 20                 NaN       NaN         NaN          NaN               NaN
# 21                 NaN       NaN         NaN          NaN               NaN
# 22                 NaN       NaN         NaN          NaN               NaN
# 23                 NaN       NaN         NaN          NaN               NaN
# 24                 NaN       NaN         NaN          NaN               NaN
# 25                 NaN       NaN         NaN          NaN               NaN
# 26                 NaN       NaN         NaN          NaN               NaN
# 27                 NaN       NaN         NaN          NaN               NaN
# 28                 NaN       NaN         NaN          NaN               NaN
# 29                 NaN       NaN         NaN          NaN               NaN
# 30                 NaN       NaN         NaN          NaN               NaN
# 31                 NaN       NaN         NaN          NaN               NaN
# 32                 NaN       NaN         NaN          NaN               NaN
# 33                 NaN       NaN         NaN          NaN               NaN
# 34                 NaN       NaN         NaN          NaN               NaN
# 35                 NaN       NaN         NaN          NaN               NaN
# 36                 NaN       NaN         NaN          NaN               NaN
# 37                 NaN       NaN         NaN          NaN               NaN
# 38                 NaN       NaN         NaN          NaN               NaN
# 39                 NaN       NaN         NaN          NaN               NaN
#
#     type_xtehr  card._xtehr  binding_xtehr
# 0          NaN          NaN            NaN
# 1          NaN          NaN            NaN
# 2          NaN          NaN            NaN
# 3          NaN          NaN            NaN
# 4          NaN          NaN            NaN
# 5          NaN          NaN            NaN
# 6          NaN          NaN            NaN
# 7          NaN          NaN            NaN
# 8          NaN          NaN            NaN
# 9          NaN          NaN            NaN
# 10         NaN          NaN            NaN
# 11         NaN          NaN            NaN
# 12         NaN          NaN            NaN
# 13         NaN          NaN            NaN
# 14         NaN          NaN            NaN
# 15         NaN          NaN            NaN
# 16         NaN          NaN            NaN
# 17         NaN          NaN            NaN
# 18         NaN          NaN            NaN
# 19         NaN          NaN            NaN
# 20         NaN          NaN            NaN
# 21         NaN          NaN            NaN
# 22         NaN          NaN            NaN
# 23         NaN          NaN            NaN
# 24         NaN          NaN            NaN
# 25         NaN          NaN            NaN
# 26         NaN          NaN            NaN
# 27         NaN          NaN            NaN
# 28         NaN          NaN            NaN
# 29         NaN          NaN            NaN
# 30         NaN          NaN            NaN
# 31         NaN          NaN            NaN
# 32         NaN          NaN            NaN
# 33         NaN          NaN            NaN
# 34         NaN          NaN            NaN
# 35         NaN          NaN            NaN
# 36         NaN          NaN            NaN
# 37         NaN          NaN            NaN
# 38         NaN          NaN            NaN
# 39         NaN          NaN            NaN

# %%
mapping = mapdf[['xtehr', 'zib']].merge(zibdf.add_suffix('_zib'), left_on='zib', right_on='path_zib', how='outer').merge(xlmdf.add_suffix('_xtehr'), left_on='xtehr', right_on='path_xtehr', how='outer')
mapping
# Out:
#                                                 xtehr  \
# 0                          EHDSMedicationPrescription
# 1                  EHDSMedicationPrescription.comment
# 2                   EHDSMedicationPrescription.header
# 3        EHDSMedicationPrescription.header.authorship
# 4   EHDSMedicationPrescription.header.authorship.a...
# 5   EHDSMedicationPrescription.header.authorship.d...
# 6        EHDSMedicationPrescription.header.identifier
# 7          EHDSMedicationPrescription.header.language
# 8        EHDSMedicationPrescription.header.lastUpdate
# 9          EHDSMedicationPrescription.header.recorder
# 10    EHDSMedicationPrescription.header.recordingDate
# 11           EHDSMedicationPrescription.header.status
# 12  EHDSMedicationPrescription.header.statusReason[x]
# 13          EHDSMedicationPrescription.header.subject
# 14        EHDSMedicationPrescription.header.validFrom
# 15       EHDSMedicationPrescription.header.validUntil
# 16          EHDSMedicationPrescription.header.version
# 17        EHDSMedicationPrescription.prescriptionItem
# 18  EHDSMedicationPrescription.prescriptionItem.ca...
# 19  EHDSMedicationPrescription.prescriptionItem.co...
# 20  EHDSMedicationPrescription.prescriptionItem.do...
# 21  EHDSMedicationPrescription.prescriptionItem.id...
# 22  EHDSMedicationPrescription.prescriptionItem.in...
# 23  EHDSMedicationPrescription.prescriptionItem.in...
# 24  EHDSMedicationPrescription.prescriptionItem.me...
# 25  EHDSMedicationPrescription.prescriptionItem.mi...
# 26  EHDSMedicationPrescription.prescriptionItem.of...
# 27  EHDSMedicationPrescription.prescriptionItem.of...
# 28  EHDSMedicationPrescription.prescriptionItem.of...
# 29  EHDSMedicationPrescription.prescriptionItem.pr...
# 30  EHDSMedicationPrescription.prescriptionItem.pr...
# 31  EHDSMedicationPrescription.prescriptionItem.qu...
# 32  EHDSMedicationPrescription.prescriptionItem.re...
# 33  EHDSMedicationPrescription.prescriptionItem.st...
# 34  EHDSMedicationPrescription.prescriptionItem.st...
# 35  EHDSMedicationPrescription.prescriptionItem.su...
# 36  EHDSMedicationPrescription.prescriptionItem.su...
# 37  EHDSMedicationPrescription.prescriptionItem.su...
# 38  EHDSMedicationPrescription.prescriptionItem.tr...
# 39           EHDSMedicationPrescription.presentedForm
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
#
#                                                   zib  \
# 0                                     DispenseRequest
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                            DispenseRequest.Comment
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  DispenseRequest.MedicineToBeDispensed::Pharmac...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                   DispenseRequest.AdditionalWishes
# 30                                                NaN
# 31                             DispenseRequest.Amount
# 32                    DispenseRequest.NumberOfRefills
# 33              DispenseRequest.DispenseRequestStatus
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38         DispenseRequest.SupplyPeriod::TimeInterval
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
#
#                                         name_zib  \
# 0                                DispenseRequest
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
# 14                                           NaN
# 15                                           NaN
# 16                                           NaN
# 17                                           NaN
# 18                                           NaN
# 19                                       Comment
# 20                                           NaN
# 21                                           NaN
# 22                                           NaN
# 23                                           NaN
# 24  MedicineToBeDispensed::PharmaceuticalProduct
# 25                                           NaN
# 26                                           NaN
# 27                                           NaN
# 28                                           NaN
# 29                              AdditionalWishes
# 30                                           NaN
# 31                                        Amount
# 32                               NumberOfRefills
# 33                         DispenseRequestStatus
# 34                                           NaN
# 35                                           NaN
# 36                                           NaN
# 37                                           NaN
# 38                    SupplyPeriod::TimeInterval
# 39                                           NaN
# 40                              DispenseLocation
# 41                           DispenseRequestDate
# 42          IntendedSupplier::HealthcareProvider
#
#                                              path_zib  \
# 0                                     DispenseRequest
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                            DispenseRequest.Comment
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  DispenseRequest.MedicineToBeDispensed::Pharmac...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                   DispenseRequest.AdditionalWishes
# 30                                                NaN
# 31                             DispenseRequest.Amount
# 32                    DispenseRequest.NumberOfRefills
# 33              DispenseRequest.DispenseRequestStatus
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38         DispenseRequest.SupplyPeriod::TimeInterval
# 39                                                NaN
# 40                   DispenseRequest.DispenseLocation
# 41                DispenseRequest.DispenseRequestDate
# 42  DispenseRequest.IntendedSupplier::HealthcarePr...
#
#                                             alias_zib type_zib card._zib  \
# 0                            NL: Verstrekkingsverzoek      NaN       NaN
# 1                                                 NaN      NaN       NaN
# 2                                                 NaN      NaN       NaN
# 3                                                 NaN      NaN       NaN
# 4                                                 NaN      NaN       NaN
# 5                                                 NaN      NaN       NaN
# 6                                                 NaN      NaN       NaN
# 7                                                 NaN      NaN       NaN
# 8                                                 NaN      NaN       NaN
# 9                                                 NaN      NaN       NaN
# 10                                                NaN      NaN       NaN
# 11                                                NaN      NaN       NaN
# 12                                                NaN      NaN       NaN
# 13                                                NaN      NaN       NaN
# 14                                                NaN      NaN       NaN
# 15                                                NaN      NaN       NaN
# 16                                                NaN      NaN       NaN
# 17                                                NaN      NaN       NaN
# 18                                                NaN      NaN       NaN
# 19                                    NL: Toelichting       ST      0..1
# 20                                                NaN      NaN       NaN
# 21                                                NaN      NaN       NaN
# 22                                                NaN      NaN       NaN
# 23                                                NaN      NaN       NaN
# 24  NL: TeVerstrekkenGeneesmiddel::FarmaceutischPr...      NaN         1
# 25                                                NaN      NaN       NaN
# 26                                                NaN      NaN       NaN
# 27                                                NaN      NaN       NaN
# 28                                                NaN      NaN       NaN
# 29                              NL: AanvullendeWensen       CD      0..*
# 30                                                NaN      NaN       NaN
# 31                       NL: TeVerstrekkenHoeveelheid       PQ      0..1
# 32                              NL: AantalHerhalingen      INT      0..1
# 33                     NL: VerstrekkingsverzoekStatus       CD         1
# 34                                                NaN      NaN       NaN
# 35                                                NaN      NaN       NaN
# 36                                                NaN      NaN       NaN
# 37                                                NaN      NaN       NaN
# 38                NL: Verbruiksperiode::TijdsInterval      NaN      0..1
# 39                                                NaN      NaN       NaN
# 40                                 NL: Afleverlocatie       ST      0..1
# 41                      NL: VerstrekkingsverzoekDatum       TS      0..1
# 42               NL: BeoogdVerstrekker::Zorgaanbieder      NaN      0..1
#
#        stereotype_zib            id_zib  \
# 0         rootconcept  NL-CM:9.10.19963
# 1                 NaN               NaN
# 2                 NaN               NaN
# 3                 NaN               NaN
# 4                 NaN               NaN
# 5                 NaN               NaN
# 6                 NaN               NaN
# 7                 NaN               NaN
# 8                 NaN               NaN
# 9                 NaN               NaN
# 10                NaN               NaN
# 11                NaN               NaN
# 12                NaN               NaN
# 13                NaN               NaN
# 14                NaN               NaN
# 15                NaN               NaN
# 16                NaN               NaN
# 17                NaN               NaN
# 18                NaN               NaN
# 19               data  NL-CM:9.10.22274
# 20                NaN               NaN
# 21                NaN               NaN
# 22                NaN               NaN
# 23                NaN               NaN
# 24     data,reference  NL-CM:9.10.22249
# 25                NaN               NaN
# 26                NaN               NaN
# 27                NaN               NaN
# 28                NaN               NaN
# 29               data  NL-CM:9.10.22759
# 30                NaN               NaN
# 31               data  NL-CM:9.10.19964
# 32               data  NL-CM:9.10.22120
# 33               data  NL-CM:9.10.22760
# 34                NaN               NaN
# 35                NaN               NaN
# 36                NaN               NaN
# 37                NaN               NaN
# 38     data,reference  NL-CM:9.10.20062
# 39                NaN               NaN
# 40               data  NL-CM:9.10.20068
# 41               data  NL-CM:9.10.20060
# 42  context,reference  NL-CM:9.10.19966
#
#                                        definition_zib  \
# 0   Root concept of the DispenseRequest informatio...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Explanation for the dispense request. \n \nThi...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                      The medicine to be dispensed.
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  Logistics and other instructions such as: do n...
# 30                                                NaN
# 31  This is the number of units of the ordered pro...
# 32  The number of additional times the medication ...
# 33  Status of the order in the ordering process, s...
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38  During the approved period of use, the pharmac...
# 39                                                NaN
# 40                                 Dispense location.
# 41     Time at which the dispense request is entered.
# 42             The intended supplier is a pharmacist.
#
#                                    definitioncode_zib  \
# 0   SNOMED CT: 52711000146108 Request to dispense ...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  LOINC: 48767-8 Annotation comment [Interpretat...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
#
#                                              id_xtehr  \
# 0                          EHDSMedicationPrescription
# 1                  EHDSMedicationPrescription.comment
# 2                   EHDSMedicationPrescription.header
# 3        EHDSMedicationPrescription.header.authorship
# 4   EHDSMedicationPrescription.header.authorship.a...
# 5   EHDSMedicationPrescription.header.authorship.d...
# 6        EHDSMedicationPrescription.header.identifier
# 7          EHDSMedicationPrescription.header.language
# 8        EHDSMedicationPrescription.header.lastUpdate
# 9          EHDSMedicationPrescription.header.recorder
# 10    EHDSMedicationPrescription.header.recordingDate
# 11           EHDSMedicationPrescription.header.status
# 12  EHDSMedicationPrescription.header.statusReason[x]
# 13          EHDSMedicationPrescription.header.subject
# 14        EHDSMedicationPrescription.header.validFrom
# 15       EHDSMedicationPrescription.header.validUntil
# 16          EHDSMedicationPrescription.header.version
# 17        EHDSMedicationPrescription.prescriptionItem
# 18  EHDSMedicationPrescription.prescriptionItem.ca...
# 19  EHDSMedicationPrescription.prescriptionItem.co...
# 20  EHDSMedicationPrescription.prescriptionItem.do...
# 21  EHDSMedicationPrescription.prescriptionItem.id...
# 22  EHDSMedicationPrescription.prescriptionItem.in...
# 23  EHDSMedicationPrescription.prescriptionItem.in...
# 24  EHDSMedicationPrescription.prescriptionItem.me...
# 25  EHDSMedicationPrescription.prescriptionItem.mi...
# 26  EHDSMedicationPrescription.prescriptionItem.of...
# 27  EHDSMedicationPrescription.prescriptionItem.of...
# 28  EHDSMedicationPrescription.prescriptionItem.of...
# 29  EHDSMedicationPrescription.prescriptionItem.pr...
# 30  EHDSMedicationPrescription.prescriptionItem.pr...
# 31  EHDSMedicationPrescription.prescriptionItem.qu...
# 32  EHDSMedicationPrescription.prescriptionItem.re...
# 33  EHDSMedicationPrescription.prescriptionItem.st...
# 34  EHDSMedicationPrescription.prescriptionItem.st...
# 35  EHDSMedicationPrescription.prescriptionItem.su...
# 36  EHDSMedicationPrescription.prescriptionItem.su...
# 37  EHDSMedicationPrescription.prescriptionItem.su...
# 38  EHDSMedicationPrescription.prescriptionItem.tr...
# 39           EHDSMedicationPrescription.presentedForm
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
#
#                                            path_xtehr  \
# 0                          EHDSMedicationPrescription
# 1                  EHDSMedicationPrescription.comment
# 2                   EHDSMedicationPrescription.header
# 3        EHDSMedicationPrescription.header.authorship
# 4   EHDSMedicationPrescription.header.authorship.a...
# 5   EHDSMedicationPrescription.header.authorship.d...
# 6        EHDSMedicationPrescription.header.identifier
# 7          EHDSMedicationPrescription.header.language
# 8        EHDSMedicationPrescription.header.lastUpdate
# 9          EHDSMedicationPrescription.header.recorder
# 10    EHDSMedicationPrescription.header.recordingDate
# 11           EHDSMedicationPrescription.header.status
# 12  EHDSMedicationPrescription.header.statusReason[x]
# 13          EHDSMedicationPrescription.header.subject
# 14        EHDSMedicationPrescription.header.validFrom
# 15       EHDSMedicationPrescription.header.validUntil
# 16          EHDSMedicationPrescription.header.version
# 17        EHDSMedicationPrescription.prescriptionItem
# 18  EHDSMedicationPrescription.prescriptionItem.ca...
# 19  EHDSMedicationPrescription.prescriptionItem.co...
# 20  EHDSMedicationPrescription.prescriptionItem.do...
# 21  EHDSMedicationPrescription.prescriptionItem.id...
# 22  EHDSMedicationPrescription.prescriptionItem.in...
# 23  EHDSMedicationPrescription.prescriptionItem.in...
# 24  EHDSMedicationPrescription.prescriptionItem.me...
# 25  EHDSMedicationPrescription.prescriptionItem.mi...
# 26  EHDSMedicationPrescription.prescriptionItem.of...
# 27  EHDSMedicationPrescription.prescriptionItem.of...
# 28  EHDSMedicationPrescription.prescriptionItem.of...
# 29  EHDSMedicationPrescription.prescriptionItem.pr...
# 30  EHDSMedicationPrescription.prescriptionItem.pr...
# 31  EHDSMedicationPrescription.prescriptionItem.qu...
# 32  EHDSMedicationPrescription.prescriptionItem.re...
# 33  EHDSMedicationPrescription.prescriptionItem.st...
# 34  EHDSMedicationPrescription.prescriptionItem.st...
# 35  EHDSMedicationPrescription.prescriptionItem.su...
# 36  EHDSMedicationPrescription.prescriptionItem.su...
# 37  EHDSMedicationPrescription.prescriptionItem.su...
# 38  EHDSMedicationPrescription.prescriptionItem.tr...
# 39           EHDSMedicationPrescription.presentedForm
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
#
#                                           short_xtehr  \
# 0                       Medication prescription model
# 1                  Additional information or comments
# 2                                 Prescription header
# 3                                          Authorship
# 4   The prescriber, the person who made the prescr...
# 5   Time of issuing (signing) the prescription by ...
# 6   Business identifier(s) for the prescription. [...
# 7                                            Language
# 8    Date and time of the last update to the resource
# 9   The recorder of the prescription/draft in the ...
# 10  Time of authoring the prescription/draft in th...
# 11  Status of the prescription, this should not be...
# 12  Reason for the current status of prescription,...
# 13  The person for whom the medication is prescrib...
# 14  Effective date of the prescription. The prescr...
# 15  The validity period end date. The prescription...
# 16                                            Version
# 17  Prescription line for one medication. In many ...
# 18  Category or categories of prescription. For ex...
# 19                 Additional information or comments
# 20           Dosaging and administration instructions
# 21  Identifier for a single item on prescription, ...
# 22  Reason for the prescription in textual form. T...
# 23  Reason for the prescription (typically diagnos...
# 24  Prescribed product, branded, generic, virtual,...
# 25                          Minimum Dispense Interval
# 26  Indicates that the prescriber has knowingly pr...
# 27  Indicates off-label use. Must be 'true' when ....
# 28  Reason or related clarification for off-label use
# 29  Additional instructions about preparation or d...
# 30  Intent of the prescription - prophylaxis, trea...
# 31  Overall quantity of prescribed product (e.g nu...
# 32                       Number of refills authorized
# 33  Status of a single item of a multi-item prescr...
# 34  Reason for the current status of prescription,...
# 35  Whether and which type of substitution is allo...
# 36  Whether and to what extent substitution is all...
# 37  Reason for the substitution requirement (e.g. ...
# 38  Period over which the medication is to be take...
# 39  Entire prescription as issued. Various formats...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
#
#                                      definition_xtehr              type_xtehr  \
# 0   Logical model for medication prescription. A p...                     NaN
# 1                  Additional information or comments                  string
# 2                   Prescription header data elements                    Base
# 3                          Resource authoring details                    Base
# 4   Author(s) by whom the resource was/were author...  EHDSHealthProfessional
# 5   Date and time of the issuing the document/reso...                dateTime
# 6                  Business identifier for the object              Identifier
# 7   Language in which the resource is written. Lan...         CodeableConcept
# 8   Date and time of the last update to the docume...                dateTime
# 9   The recorder of the prescription/draft in the ...  EHDSHealthProfessional
# 10  Time of authoring the prescription/draft in th...                dateTime
# 11                             Status of the resource         CodeableConcept
# 12     Reason for the current status of the resource.         CodeableConcept
# 13                        Patient/subject information             EHDSPatient
# 14  Effective date of the prescription. The prescr...                dateTime
# 15  The validity period end date. The prescription...                dateTime
# 16                  Business version of the resource.                  string
# 17  Prescription line for one medication. In many ...                    Base
# 18  Category or categories of prescription. For ex...         CodeableConcept
# 19                 Additional information or comments                  string
# 20           Dosaging and administration instructions            EHDSDosaging
# 21  Identifier for a single item on prescription, ...              Identifier
# 22  Reason for the prescription in textual form. T...                  string
# 23  Reason for the prescription (typically diagnos...         CodeableConcept
# 24  Prescribed product, branded, generic, virtual,...          EHDSMedication
# 25  If a prescription allows for repeated dispensa...                Quantity
# 26  Indicates that the prescriber has knowingly pr...                    Base
# 27  Indicates off-label use. Must be 'true' when ....                 boolean
# 28  Reason or related clarification for off-label use         CodeableConcept
# 29  Additional instructions about preparation or d...                  string
# 30  Intent of the prescription - prophylaxis, trea...         CodeableConcept
# 31  Overall quantity of prescribed product (e.g nu...                Quantity
# 32  How many times the prescription item can be di...                 integer
# 33  Status of a single item of a multi-item prescr...         CodeableConcept
# 34  Reason for the current status of prescription,...         CodeableConcept
# 35  Whether and which type of substitution is allo...                    Base
# 36  Whether and to what extent substitution is all...                 boolean
# 37  Reason for the substitution requirement (e.g. ...         CodeableConcept
# 38  Period over which the medication is to be take...                  Period
# 39  A narrative easy-to-read representation of the...          EHDSAttachment
# 40                                                NaN                     NaN
# 41                                                NaN                     NaN
# 42                                                NaN                     NaN
#
#    card._xtehr                                      binding_xtehr
# 0         0..*                                                NaN
# 1         0..*                                                NaN
# 2         1..1                                                NaN
# 3         1..*                                                NaN
# 4         1..1                                                NaN
# 5         1..1                                                NaN
# 6         0..*                                                NaN
# 7         0..1  {'strength': 'preferred', 'description': 'BCP ...
# 8         0..1                                                NaN
# 9         0..1                                                NaN
# 10        0..1                                                NaN
# 11        1..1                                                NaN
# 12        0..1                                                NaN
# 13        1..1                                                NaN
# 14        0..1                                                NaN
# 15        0..1                                                NaN
# 16        0..1                                                NaN
# 17        1..*                                                NaN
# 18        0..*                                                NaN
# 19        0..*                                                NaN
# 20        0..*                                                NaN
# 21        0..1                                                NaN
# 22        0..1                                                NaN
# 23        0..*                                                NaN
# 24        1..1                                                NaN
# 25        0..1                                                NaN
# 26        0..1                                                NaN
# 27        1..1                                                NaN
# 28        0..*                                                NaN
# 29        0..1                                                NaN
# 30        0..1                                                NaN
# 31        0..1  {'strength': 'preferred', 'description': 'UCUM...
# 32        0..1                                                NaN
# 33        1..1                                                NaN
# 34        0..1                                                NaN
# 35        0..1                                                NaN
# 36        0..1                                                NaN
# 37        0..1                                                NaN
# 38        0..1                                                NaN
# 39        0..*                                                NaN
# 40         NaN                                                NaN
# 41         NaN                                                NaN
# 42         NaN                                                NaN

# %%
shortmap = mapping[['zib', 'xtehr', 'type_zib','type_xtehr', 'card._zib', 'card._xtehr']]
shortmap
# Out:
#                                                   zib  \
# 0                                     DispenseRequest
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                            DispenseRequest.Comment
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  DispenseRequest.MedicineToBeDispensed::Pharmac...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                   DispenseRequest.AdditionalWishes
# 30                                                NaN
# 31                             DispenseRequest.Amount
# 32                    DispenseRequest.NumberOfRefills
# 33              DispenseRequest.DispenseRequestStatus
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38         DispenseRequest.SupplyPeriod::TimeInterval
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
#
#                                                 xtehr type_zib  \
# 0                          EHDSMedicationPrescription      NaN
# 1                  EHDSMedicationPrescription.comment      NaN
# 2                   EHDSMedicationPrescription.header      NaN
# 3        EHDSMedicationPrescription.header.authorship      NaN
# 4   EHDSMedicationPrescription.header.authorship.a...      NaN
# 5   EHDSMedicationPrescription.header.authorship.d...      NaN
# 6        EHDSMedicationPrescription.header.identifier      NaN
# 7          EHDSMedicationPrescription.header.language      NaN
# 8        EHDSMedicationPrescription.header.lastUpdate      NaN
# 9          EHDSMedicationPrescription.header.recorder      NaN
# 10    EHDSMedicationPrescription.header.recordingDate      NaN
# 11           EHDSMedicationPrescription.header.status      NaN
# 12  EHDSMedicationPrescription.header.statusReason[x]      NaN
# 13          EHDSMedicationPrescription.header.subject      NaN
# 14        EHDSMedicationPrescription.header.validFrom      NaN
# 15       EHDSMedicationPrescription.header.validUntil      NaN
# 16          EHDSMedicationPrescription.header.version      NaN
# 17        EHDSMedicationPrescription.prescriptionItem      NaN
# 18  EHDSMedicationPrescription.prescriptionItem.ca...      NaN
# 19  EHDSMedicationPrescription.prescriptionItem.co...       ST
# 20  EHDSMedicationPrescription.prescriptionItem.do...      NaN
# 21  EHDSMedicationPrescription.prescriptionItem.id...      NaN
# 22  EHDSMedicationPrescription.prescriptionItem.in...      NaN
# 23  EHDSMedicationPrescription.prescriptionItem.in...      NaN
# 24  EHDSMedicationPrescription.prescriptionItem.me...      NaN
# 25  EHDSMedicationPrescription.prescriptionItem.mi...      NaN
# 26  EHDSMedicationPrescription.prescriptionItem.of...      NaN
# 27  EHDSMedicationPrescription.prescriptionItem.of...      NaN
# 28  EHDSMedicationPrescription.prescriptionItem.of...      NaN
# 29  EHDSMedicationPrescription.prescriptionItem.pr...       CD
# 30  EHDSMedicationPrescription.prescriptionItem.pr...      NaN
# 31  EHDSMedicationPrescription.prescriptionItem.qu...       PQ
# 32  EHDSMedicationPrescription.prescriptionItem.re...      INT
# 33  EHDSMedicationPrescription.prescriptionItem.st...       CD
# 34  EHDSMedicationPrescription.prescriptionItem.st...      NaN
# 35  EHDSMedicationPrescription.prescriptionItem.su...      NaN
# 36  EHDSMedicationPrescription.prescriptionItem.su...      NaN
# 37  EHDSMedicationPrescription.prescriptionItem.su...      NaN
# 38  EHDSMedicationPrescription.prescriptionItem.tr...      NaN
# 39           EHDSMedicationPrescription.presentedForm      NaN
# 40                                                NaN       ST
# 41                                                NaN       TS
# 42                                                NaN      NaN
#
#                 type_xtehr card._zib card._xtehr
# 0                      NaN       NaN        0..*
# 1                   string       NaN        0..*
# 2                     Base       NaN        1..1
# 3                     Base       NaN        1..*
# 4   EHDSHealthProfessional       NaN        1..1
# 5                 dateTime       NaN        1..1
# 6               Identifier       NaN        0..*
# 7          CodeableConcept       NaN        0..1
# 8                 dateTime       NaN        0..1
# 9   EHDSHealthProfessional       NaN        0..1
# 10                dateTime       NaN        0..1
# 11         CodeableConcept       NaN        1..1
# 12         CodeableConcept       NaN        0..1
# 13             EHDSPatient       NaN        1..1
# 14                dateTime       NaN        0..1
# 15                dateTime       NaN        0..1
# 16                  string       NaN        0..1
# 17                    Base       NaN        1..*
# 18         CodeableConcept       NaN        0..*
# 19                  string      0..1        0..*
# 20            EHDSDosaging       NaN        0..*
# 21              Identifier       NaN        0..1
# 22                  string       NaN        0..1
# 23         CodeableConcept       NaN        0..*
# 24          EHDSMedication         1        1..1
# 25                Quantity       NaN        0..1
# 26                    Base       NaN        0..1
# 27                 boolean       NaN        1..1
# 28         CodeableConcept       NaN        0..*
# 29                  string      0..*        0..1
# 30         CodeableConcept       NaN        0..1
# 31                Quantity      0..1        0..1
# 32                 integer      0..1        0..1
# 33         CodeableConcept         1        1..1
# 34         CodeableConcept       NaN        0..1
# 35                    Base       NaN        0..1
# 36                 boolean       NaN        0..1
# 37         CodeableConcept       NaN        0..1
# 38                  Period      0..1        0..1
# 39          EHDSAttachment       NaN        0..*
# 40                     NaN      0..1         NaN
# 41                     NaN      0..1         NaN
# 42                     NaN      0..1         NaN

# %%
mapsoutpath = os.path.join(mapbase, 'xtehr2zibs2024')
filepath = file.replace('.xlsx', '-full.xlsx')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_excel(mappath, index=False)

# %%
filepath = file.replace('.xlsx', '.csv')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_csv(mappath, index=False)

# %%
from IPython.display import Markdown
import numpy as np

content = "# " + mapping.iat[0, 0][4:] + "\n\n"

# shortmap: linefeeds naar <br> vlak vóór to_markdown
shortmap_md = shortmap.fillna('').map(
    lambda x: x.replace("\r\n", "<br>").replace("\n", "<br>") if isinstance(x, str) else x
)
content += shortmap_md.to_markdown(index=False) + "\n\n"

for i, row in mapping.iterrows():
    content += "\n\n"
    if row.iloc[0] is not np.nan:  # desgewenst: gebruik pd.notna(row.iloc[0])
        content += "## " + str(row.iloc[0]) + "\n\n"
    else:
        content += "## zib: " + str(row.iloc[1]) + "\n\n"

    content += "### Table" + "\n\n"
    content += "| attribute | value |\n|---|---|\n"

    # Eerste 2 kolommen
    for j, att in row.fillna('')[0:2].items():
        content += "| " + str(j) + " | " + (att.replace("\r\n","<br>").replace("\n","<br>") if isinstance(att, str) else str(att)) + " |\n" 

    # Rest, gesorteerd
    for j, att in row.fillna('')[2:].sort_index().items():
        if len(str(att)) > 0:
            content += "| " + str(j) + " | " + (att.replace("\r\n","<br>").replace("\n","<br>") if isinstance(att, str) else str(att)) + " |\n"

    content += "\n### Comments\n\n"

with open(os.path.join(mapsoutpath, file.replace('.xlsx', '.md')), 'w') as f:
    f.write(content)

# PAS OP: deze overschrijft de evt. handmatige comments; alleen bij eerste keer mapping
# with open(os.path.join(mapsoutpath, file.replace('.xlsx', '-comments.md')), 'w') as f:
#     f.write(content)

Markdown(content)
# Out:
# # MedicationPrescription
#
# | zib                                                          | xtehr                                                               | type_zib   | type_xtehr             | card._zib   | card._xtehr   |
# |:-------------------------------------------------------------|:--------------------------------------------------------------------|:-----------|:-----------------------|:------------|:--------------|
# | DispenseRequest                                              | EHDSMedicationPrescription                                          |            |                        |             | 0..*          |
# |                                                              | EHDSMedicationPrescription.comment                                  |            | string                 |             | 0..*          |
# |                                                              | EHDSMedicationPrescription.header                                   |            | Base                   |             | 1..1          |
# |                                                              | EHDSMedicationPrescription.header.authorship                        |            | Base                   |             | 1..*          |
# |                                                              | EHDSMedicationPrescription.header.authorship.author[x]              |            | EHDSHealthProfessional |             | 1..1          |
# |                                                              | EHDSMedicationPrescription.header.authorship.datetime               |            | dateTime               |             | 1..1          |
# |                                                              | EHDSMedicationPrescription.header.identifier                        |            | Identifier             |             | 0..*          |
# |                                                              | EHDSMedicationPrescription.header.language                          |            | CodeableConcept        |             | 0..1          |
# |                                                              | EHDSMedicationPrescription.header.lastUpdate                        |            | dateTime               |             | 0..1          |
# |                                                              | EHDSMedicationPrescription.header.recorder                          |            | EHDSHealthProfessional |             | 0..1          |
# |                                                              | EHDSMedicationPrescription.header.recordingDate                     |            | dateTime               |             | 0..1          |
# |                                                              | EHDSMedicationPrescription.header.status                            |            | CodeableConcept        |             | 1..1          |
# |                                                              | EHDSMedicationPrescription.header.statusReason[x]                   |            | CodeableConcept        |             | 0..1          |
# |                                                              | EHDSMedicationPrescription.header.subject                           |            | EHDSPatient            |             | 1..1          |
# |                                                              | EHDSMedicationPrescription.header.validFrom                         |            | dateTime               |             | 0..1          |
# |                                                              | EHDSMedicationPrescription.header.validUntil                        |            | dateTime               |             | 0..1          |
# |                                                              | EHDSMedicationPrescription.header.version                           |            | string                 |             | 0..1          |
# |                                                              | EHDSMedicationPrescription.prescriptionItem                         |            | Base                   |             | 1..*          |
# |                                                              | EHDSMedicationPrescription.prescriptionItem.category                |            | CodeableConcept        |             | 0..*          |
# | DispenseRequest.Comment                                      | EHDSMedicationPrescription.prescriptionItem.comment                 | ST         | string                 | 0..1        | 0..*          |
# |                                                              | EHDSMedicationPrescription.prescriptionItem.dosageInstructions      |            | EHDSDosaging           |             | 0..*          |
# |                                                              | EHDSMedicationPrescription.prescriptionItem.identifier              |            | Identifier             |             | 0..1          |
# |                                                              | EHDSMedicationPrescription.prescriptionItem.indicationText          |            | string                 |             | 0..1          |
# |                                                              | EHDSMedicationPrescription.prescriptionItem.indication[x]           |            | CodeableConcept        |             | 0..*          |
# | DispenseRequest.MedicineToBeDispensed::PharmaceuticalProduct | EHDSMedicationPrescription.prescriptionItem.medication              |            | EHDSMedication         | 1           | 1..1          |
# |                                                              | EHDSMedicationPrescription.prescriptionItem.minimumDispenseInterval |            | Quantity               |             | 0..1          |
# |                                                              | EHDSMedicationPrescription.prescriptionItem.offLabel                |            | Base                   |             | 0..1          |
# |                                                              | EHDSMedicationPrescription.prescriptionItem.offLabel.isOffLabelUse  |            | boolean                |             | 1..1          |
# |                                                              | EHDSMedicationPrescription.prescriptionItem.offLabel.reason[x]      |            | CodeableConcept        |             | 0..*          |
# | DispenseRequest.AdditionalWishes                             | EHDSMedicationPrescription.prescriptionItem.preparationInstructions | CD         | string                 | 0..*        | 0..1          |
# |                                                              | EHDSMedicationPrescription.prescriptionItem.prescriptionIntent      |            | CodeableConcept        |             | 0..1          |
# | DispenseRequest.Amount                                       | EHDSMedicationPrescription.prescriptionItem.quantityPrescribed      | PQ         | Quantity               | 0..1        | 0..1          |
# | DispenseRequest.NumberOfRefills                              | EHDSMedicationPrescription.prescriptionItem.repeatsAllowed          | INT        | integer                | 0..1        | 0..1          |
# | DispenseRequest.DispenseRequestStatus                        | EHDSMedicationPrescription.prescriptionItem.status                  | CD         | CodeableConcept        | 1           | 1..1          |
# |                                                              | EHDSMedicationPrescription.prescriptionItem.statusReason[x]         |            | CodeableConcept        |             | 0..1          |
# |                                                              | EHDSMedicationPrescription.prescriptionItem.substitution            |            | Base                   |             | 0..1          |
# |                                                              | EHDSMedicationPrescription.prescriptionItem.substitution.allowed[x] |            | boolean                |             | 0..1          |
# |                                                              | EHDSMedicationPrescription.prescriptionItem.substitution.reason[x]  |            | CodeableConcept        |             | 0..1          |
# | DispenseRequest.SupplyPeriod::TimeInterval                   | EHDSMedicationPrescription.prescriptionItem.treatmentPeriod         |            | Period                 | 0..1        | 0..1          |
# |                                                              | EHDSMedicationPrescription.presentedForm                            |            | EHDSAttachment         |             | 0..*          |
# |                                                              |                                                                     | ST         |                        | 0..1        |               |
# |                                                              |                                                                     | TS         |                        | 0..1        |               |
# |                                                              |                                                                     |            |                        | 0..1        |               |
#
#
#
# ## EHDSMedicationPrescription
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription |
# | zib | DispenseRequest |
# | alias_zib | NL: Verstrekkingsverzoek |
# | card._xtehr | 0..* |
# | definition_xtehr | Logical model for medication prescription. A prescription contains one or more prescription items. |
# | definition_zib | Root concept of the DispenseRequest information model.This root concept contains all data elements of the DispenseRequest information model. |
# | definitioncode_zib | SNOMED CT: 52711000146108 Request to dispense medication to patient |
# | id_xtehr | EHDSMedicationPrescription |
# | id_zib | NL-CM:9.10.19963 |
# | name_zib | DispenseRequest |
# | path_xtehr | EHDSMedicationPrescription |
# | path_zib | DispenseRequest |
# | short_xtehr | Medication prescription model |
# | stereotype_zib | rootconcept |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.comment
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.comment |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | Additional information or comments |
# | id_xtehr | EHDSMedicationPrescription.comment |
# | path_xtehr | EHDSMedicationPrescription.comment |
# | short_xtehr | Additional information or comments |
# | type_xtehr | string |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.header
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.header |
# | zib |  |
# | card._xtehr | 1..1 |
# | definition_xtehr | Prescription header data elements |
# | id_xtehr | EHDSMedicationPrescription.header |
# | path_xtehr | EHDSMedicationPrescription.header |
# | short_xtehr | Prescription header |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.header.authorship
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.header.authorship |
# | zib |  |
# | card._xtehr | 1..* |
# | definition_xtehr | Resource authoring details |
# | id_xtehr | EHDSMedicationPrescription.header.authorship |
# | path_xtehr | EHDSMedicationPrescription.header.authorship |
# | short_xtehr | Authorship |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.header.authorship.author[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.header.authorship.author[x] |
# | zib |  |
# | card._xtehr | 1..1 |
# | definition_xtehr | Author(s) by whom the resource was/were authored. Multiple authors could be provided. |
# | id_xtehr | EHDSMedicationPrescription.header.authorship.author[x] |
# | path_xtehr | EHDSMedicationPrescription.header.authorship.author[x] |
# | short_xtehr | The prescriber, the person who made the prescription, and who takes the responsibility of the treatment. [Used for searching] |
# | type_xtehr | EHDSHealthProfessional |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.header.authorship.datetime
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.header.authorship.datetime |
# | zib |  |
# | card._xtehr | 1..1 |
# | definition_xtehr | Date and time of the issuing the document/resource by its author. |
# | id_xtehr | EHDSMedicationPrescription.header.authorship.datetime |
# | path_xtehr | EHDSMedicationPrescription.header.authorship.datetime |
# | short_xtehr | Time of issuing (signing) the prescription by health care professional. [Used for searching] |
# | type_xtehr | dateTime |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.header.identifier
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.header.identifier |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | Business identifier for the object |
# | id_xtehr | EHDSMedicationPrescription.header.identifier |
# | path_xtehr | EHDSMedicationPrescription.header.identifier |
# | short_xtehr | Business identifier(s) for the prescription. [Used for searching] |
# | type_xtehr | Identifier |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.header.language
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.header.language |
# | zib |  |
# | binding_xtehr | {'strength': 'preferred', 'description': 'BCP 47'} |
# | card._xtehr | 0..1 |
# | definition_xtehr | Language in which the resource is written. Language is expressed by the IETF language tag. |
# | id_xtehr | EHDSMedicationPrescription.header.language |
# | path_xtehr | EHDSMedicationPrescription.header.language |
# | short_xtehr | Language |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.header.lastUpdate
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.header.lastUpdate |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Date and time of the last update to the document/information |
# | id_xtehr | EHDSMedicationPrescription.header.lastUpdate |
# | path_xtehr | EHDSMedicationPrescription.header.lastUpdate |
# | short_xtehr | Date and time of the last update to the resource |
# | type_xtehr | dateTime |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.header.recorder
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.header.recorder |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | The recorder of the prescription/draft in the information system |
# | id_xtehr | EHDSMedicationPrescription.header.recorder |
# | path_xtehr | EHDSMedicationPrescription.header.recorder |
# | short_xtehr | The recorder of the prescription/draft in the information system |
# | type_xtehr | EHDSHealthProfessional |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.header.recordingDate
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.header.recordingDate |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Time of authoring the prescription/draft in the information system |
# | id_xtehr | EHDSMedicationPrescription.header.recordingDate |
# | path_xtehr | EHDSMedicationPrescription.header.recordingDate |
# | short_xtehr | Time of authoring the prescription/draft in the information system |
# | type_xtehr | dateTime |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.header.status
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.header.status |
# | zib |  |
# | card._xtehr | 1..1 |
# | definition_xtehr | Status of the resource |
# | id_xtehr | EHDSMedicationPrescription.header.status |
# | path_xtehr | EHDSMedicationPrescription.header.status |
# | short_xtehr | Status of the prescription, this should not be status of treatment. For multi-item prescription, the status of prescription is often related to statuses of single lines. In case of single-item prescriptions, the status for line is usually the status of prescription. [Used for searching] |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.header.statusReason[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.header.statusReason[x] |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Reason for the current status of the resource. |
# | id_xtehr | EHDSMedicationPrescription.header.statusReason[x] |
# | path_xtehr | EHDSMedicationPrescription.header.statusReason[x] |
# | short_xtehr | Reason for the current status of prescription, for example the reason why the prescription was made invalid or why the prescription was changed from previous |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.header.subject
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.header.subject |
# | zib |  |
# | card._xtehr | 1..1 |
# | definition_xtehr | Patient/subject information |
# | id_xtehr | EHDSMedicationPrescription.header.subject |
# | path_xtehr | EHDSMedicationPrescription.header.subject |
# | short_xtehr | The person for whom the medication is prescribed/ordered. [Used for searching] |
# | type_xtehr | EHDSPatient |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.header.validFrom
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.header.validFrom |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Effective date of the prescription. The prescription is not dispensable before this date. In most cases this information repeats issueDate. [Used for searching] |
# | id_xtehr | EHDSMedicationPrescription.header.validFrom |
# | path_xtehr | EHDSMedicationPrescription.header.validFrom |
# | short_xtehr | Effective date of the prescription. The prescription is not dispensable before this date. In most cases this information repeats issueDate. [Used for searching] |
# | type_xtehr | dateTime |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.header.validUntil
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.header.validUntil |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | The validity period end date. The prescription is not dispensable after this date. [Used for searching] |
# | id_xtehr | EHDSMedicationPrescription.header.validUntil |
# | path_xtehr | EHDSMedicationPrescription.header.validUntil |
# | short_xtehr | The validity period end date. The prescription is not dispensable after this date. [Used for searching] |
# | type_xtehr | dateTime |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.header.version
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.header.version |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Business version of the resource. |
# | id_xtehr | EHDSMedicationPrescription.header.version |
# | path_xtehr | EHDSMedicationPrescription.header.version |
# | short_xtehr | Version |
# | type_xtehr | string |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem |
# | zib |  |
# | card._xtehr | 1..* |
# | definition_xtehr | Prescription line for one medication. In many countries, only one item is allowed. In case multiple medications are allowed, all lines need to be authored together. |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem |
# | short_xtehr | Prescription line for one medication. In many countries, only one item is allowed. In case multiple medications are allowed, all lines need to be authored together. |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem.category
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem.category |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | Category or categories of prescription. For example type of reimbursement, or type of prescription (e.g. hospital, private, etc). |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem.category |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem.category |
# | short_xtehr | Category or categories of prescription. For example type of reimbursement, or type of prescription (e.g. hospital, private, etc). |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem.comment
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem.comment |
# | zib | DispenseRequest.Comment |
# | alias_zib | NL: Toelichting |
# | card._xtehr | 0..* |
# | card._zib | 0..1 |
# | definition_xtehr | Additional information or comments |
# | definition_zib | Explanation for the dispense request. <br> <br>This explanation can contain e.g. information on why a prescriber submits a dispense request that deviates from the norm, e.g. an extra dispense request needed because the patient has lost the medication. |
# | definitioncode_zib | LOINC: 48767-8 Annotation comment [Interpretation] Narrative |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem.comment |
# | id_zib | NL-CM:9.10.22274 |
# | name_zib | Comment |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem.comment |
# | path_zib | DispenseRequest.Comment |
# | short_xtehr | Additional information or comments |
# | stereotype_zib | data |
# | type_xtehr | string |
# | type_zib | ST |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem.dosageInstructions
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem.dosageInstructions |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | Dosaging and administration instructions |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem.dosageInstructions |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem.dosageInstructions |
# | short_xtehr | Dosaging and administration instructions |
# | type_xtehr | EHDSDosaging |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem.identifier
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem.identifier |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Identifier for a single item on prescription, if exists. In case of single-item prescription, this identifier is typically the same as prescription identifier. |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem.identifier |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem.identifier |
# | short_xtehr | Identifier for a single item on prescription, if exists. In case of single-item prescription, this identifier is typically the same as prescription identifier. |
# | type_xtehr | Identifier |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem.indicationText
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem.indicationText |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Reason for the prescription in textual form. This might not be allowed by some implementations. |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem.indicationText |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem.indicationText |
# | short_xtehr | Reason for the prescription in textual form. This might not be allowed by some implementations. |
# | type_xtehr | string |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem.indication[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem.indication[x] |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | Reason for the prescription (typically diagnosis, or a procedure) |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem.indication[x] |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem.indication[x] |
# | short_xtehr | Reason for the prescription (typically diagnosis, or a procedure) |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem.medication
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem.medication |
# | zib | DispenseRequest.MedicineToBeDispensed::PharmaceuticalProduct |
# | alias_zib | NL: TeVerstrekkenGeneesmiddel::FarmaceutischProduct |
# | card._xtehr | 1..1 |
# | card._zib | 1 |
# | definition_xtehr | Prescribed product, branded, generic, virtual, extemporal, etc |
# | definition_zib | The medicine to be dispensed. |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem.medication |
# | id_zib | NL-CM:9.10.22249 |
# | name_zib | MedicineToBeDispensed::PharmaceuticalProduct |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem.medication |
# | path_zib | DispenseRequest.MedicineToBeDispensed::PharmaceuticalProduct |
# | short_xtehr | Prescribed product, branded, generic, virtual, extemporal, etc |
# | stereotype_zib | data,reference |
# | type_xtehr | EHDSMedication |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem.minimumDispenseInterval
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem.minimumDispenseInterval |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | If a prescription allows for repeated dispensations, the interval between dispensations shall be stated here. |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem.minimumDispenseInterval |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem.minimumDispenseInterval |
# | short_xtehr | Minimum Dispense Interval |
# | type_xtehr | Quantity |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem.offLabel
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem.offLabel |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Indicates that the prescriber has knowingly prescribed the medication for an indication, age group, dosage, or route of administration that is not approved by the regulatory agencies and is not mentioned in the prescribing information for the drug |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem.offLabel |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem.offLabel |
# | short_xtehr | Indicates that the prescriber has knowingly prescribed the medication for an indication, age group, dosage, or route of administration that is not approved by the regulatory agencies and is not mentioned in the prescribing information for the drug |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem.offLabel.isOffLabelUse
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem.offLabel.isOffLabelUse |
# | zib |  |
# | card._xtehr | 1..1 |
# | definition_xtehr | Indicates off-label use. Must be 'true' when .reason is provided. |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem.offLabel.isOffLabelUse |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem.offLabel.isOffLabelUse |
# | short_xtehr | Indicates off-label use. Must be 'true' when .reason is provided. |
# | type_xtehr | boolean |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem.offLabel.reason[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem.offLabel.reason[x] |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | Reason or related clarification for off-label use |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem.offLabel.reason[x] |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem.offLabel.reason[x] |
# | short_xtehr | Reason or related clarification for off-label use |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem.preparationInstructions
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem.preparationInstructions |
# | zib | DispenseRequest.AdditionalWishes |
# | alias_zib | NL: AanvullendeWensen |
# | card._xtehr | 0..1 |
# | card._zib | 0..* |
# | definition_xtehr | Additional instructions about preparation or dispense |
# | definition_zib | Logistics and other instructions such as: do not enter in GDS, urgent, purposeful deviation, etc. |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem.preparationInstructions |
# | id_zib | NL-CM:9.10.22759 |
# | name_zib | AdditionalWishes |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem.preparationInstructions |
# | path_zib | DispenseRequest.AdditionalWishes |
# | short_xtehr | Additional instructions about preparation or dispense |
# | stereotype_zib | data |
# | type_xtehr | string |
# | type_zib | CD |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem.prescriptionIntent
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem.prescriptionIntent |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Intent of the prescription - prophylaxis, treatment, anesthesia, etc |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem.prescriptionIntent |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem.prescriptionIntent |
# | short_xtehr | Intent of the prescription - prophylaxis, treatment, anesthesia, etc |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem.quantityPrescribed
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem.quantityPrescribed |
# | zib | DispenseRequest.Amount |
# | alias_zib | NL: TeVerstrekkenHoeveelheid |
# | binding_xtehr | {'strength': 'preferred', 'description': 'UCUM, EDQM Standard Terms'} |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Overall quantity of prescribed product (e.g number of packages or number of tablets). |
# | definition_zib | This is the number of units of the ordered product per dispense. The number of refills indicates how often this amount is allowed to be dispensed. Optionally a translation to NHG table Gebruiksvoorschriften (Table 25) is also allowed. |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem.quantityPrescribed |
# | id_zib | NL-CM:9.10.19964 |
# | name_zib | Amount |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem.quantityPrescribed |
# | path_zib | DispenseRequest.Amount |
# | short_xtehr | Overall quantity of prescribed product (e.g number of packages or number of tablets). |
# | stereotype_zib | data |
# | type_xtehr | Quantity |
# | type_zib | PQ |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem.repeatsAllowed
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem.repeatsAllowed |
# | zib | DispenseRequest.NumberOfRefills |
# | alias_zib | NL: AantalHerhalingen |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | How many times the prescription item can be dispensed in addition to the original dispense. |
# | definition_zib | The number of additional times the medication may be dispensed after the first time. <br>In the case of Amount: The total amount that may be dispensed is: (Number of refills + 1) x amount to be dispensed.<br>In the case of Period of Use:The total period of use is: (Number of refills + 1) x period of use |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem.repeatsAllowed |
# | id_zib | NL-CM:9.10.22120 |
# | name_zib | NumberOfRefills |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem.repeatsAllowed |
# | path_zib | DispenseRequest.NumberOfRefills |
# | short_xtehr | Number of refills authorized |
# | stereotype_zib | data |
# | type_xtehr | integer |
# | type_zib | INT |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem.status
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem.status |
# | zib | DispenseRequest.DispenseRequestStatus |
# | alias_zib | NL: VerstrekkingsverzoekStatus |
# | card._xtehr | 1..1 |
# | card._zib | 1 |
# | definition_xtehr | Status of a single item of a multi-item prescription. In case of single-item prescriptions, the status of prescription has the same meaning as the status of the item. |
# | definition_zib | Status of the order in the ordering process, such as e.g. 'cancelled', 'ordered' |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem.status |
# | id_zib | NL-CM:9.10.22760 |
# | name_zib | DispenseRequestStatus |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem.status |
# | path_zib | DispenseRequest.DispenseRequestStatus |
# | short_xtehr | Status of a single item of a multi-item prescription. In case of single-item prescriptions, the status of prescription has the same meaning as the status of the item. |
# | stereotype_zib | data |
# | type_xtehr | CodeableConcept |
# | type_zib | CD |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem.statusReason[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem.statusReason[x] |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Reason for the current status of prescription, for example the reason why the prescription was made invalid or why the prescription was changed from previous |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem.statusReason[x] |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem.statusReason[x] |
# | short_xtehr | Reason for the current status of prescription, for example the reason why the prescription was made invalid or why the prescription was changed from previous |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem.substitution
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem.substitution |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Whether and which type of substitution is allowed for this medication treatment item |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem.substitution |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem.substitution |
# | short_xtehr | Whether and which type of substitution is allowed for this medication treatment item |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem.substitution.allowed[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem.substitution.allowed[x] |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Whether and to what extent substitution is allowed. |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem.substitution.allowed[x] |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem.substitution.allowed[x] |
# | short_xtehr | Whether and to what extent substitution is allowed. |
# | type_xtehr | boolean |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem.substitution.reason[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem.substitution.reason[x] |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Reason for the substitution requirement (e.g. Biological product, Patient allergic to an excipient in alternative products, etc) |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem.substitution.reason[x] |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem.substitution.reason[x] |
# | short_xtehr | Reason for the substitution requirement (e.g. Biological product, Patient allergic to an excipient in alternative products, etc) |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.prescriptionItem.treatmentPeriod
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.prescriptionItem.treatmentPeriod |
# | zib | DispenseRequest.SupplyPeriod::TimeInterval |
# | alias_zib | NL: Verbruiksperiode::TijdsInterval |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Period over which the medication is to be taken (in case of multiple dosaging schemes, this would be the overall period of all dosages.) |
# | definition_zib | During the approved period of use, the pharmacist has permission to dispense medicine so that the patient has a sufficient amount of medication.<br><br>In many cases, the approved supply period can be described by only an end date: the approved end date of use. <br><br>Toegestane eenheden voor de duur zijn:  uur, dag, week, jaar. |
# | id_xtehr | EHDSMedicationPrescription.prescriptionItem.treatmentPeriod |
# | id_zib | NL-CM:9.10.20062 |
# | name_zib | SupplyPeriod::TimeInterval |
# | path_xtehr | EHDSMedicationPrescription.prescriptionItem.treatmentPeriod |
# | path_zib | DispenseRequest.SupplyPeriod::TimeInterval |
# | short_xtehr | Period over which the medication is to be taken (in case of multiple dosaging schemes, this would be the overall period of all dosages.) |
# | stereotype_zib | data,reference |
# | type_xtehr | Period |
#
# ### Comments
#
#
#
# ## EHDSMedicationPrescription.presentedForm
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedicationPrescription.presentedForm |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | A narrative easy-to-read representation of the full data set, e.g. PDF-version of a document |
# | id_xtehr | EHDSMedicationPrescription.presentedForm |
# | path_xtehr | EHDSMedicationPrescription.presentedForm |
# | short_xtehr | Entire prescription as issued. Various formats could be provided, PDF format is recommended. |
# | type_xtehr | EHDSAttachment |
#
# ### Comments
#
#
#
# ## zib: nan
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib |  |
# | alias_zib | NL: Afleverlocatie |
# | card._zib | 0..1 |
# | definition_zib | Dispense location. |
# | id_zib | NL-CM:9.10.20068 |
# | name_zib | DispenseLocation |
# | path_zib | DispenseRequest.DispenseLocation |
# | stereotype_zib | data |
# | type_zib | ST |
#
# ### Comments
#
#
#
# ## zib: nan
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib |  |
# | alias_zib | NL: VerstrekkingsverzoekDatum |
# | card._zib | 0..1 |
# | definition_zib | Time at which the dispense request is entered. |
# | id_zib | NL-CM:9.10.20060 |
# | name_zib | DispenseRequestDate |
# | path_zib | DispenseRequest.DispenseRequestDate |
# | stereotype_zib | data |
# | type_zib | TS |
#
# ### Comments
#
#
#
# ## zib: nan
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib |  |
# | alias_zib | NL: BeoogdVerstrekker::Zorgaanbieder |
# | card._zib | 0..1 |
# | definition_zib | The intended supplier is a pharmacist. |
# | id_zib | NL-CM:9.10.19966 |
# | name_zib | IntendedSupplier::HealthcareProvider |
# | path_zib | DispenseRequest.IntendedSupplier::HealthcareProvider |
# | stereotype_zib | context,reference |
#
# ### Comments
