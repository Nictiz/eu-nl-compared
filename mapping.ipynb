# %%
import pandas as pd
import os
import unicodedata as ud

# %%
# zibbase = 'zibs2020'
zibbase = 'zibs2024'
zibspath = os.path.join(zibbase, 'mappable')
zibs = os.listdir(zibspath)
[(i, zib) for i, zib in enumerate(zibs)]
# Out:
# [(0, 'Nl.zorg.Alert-v5.0(2024EN).xlsx'),
#  (1, 'Nl.zorg.Condition-v1.1(2024EN).xlsx'),
#  (2, 'Nl.zorg.Diagnosis-v2.0(2024EN).xlsx'),
#  (3, 'nl.zorg.DispenseRequest-v4.0(2024EN).xlsx'),
#  (4, 'Nl.zorg.HealthcareProvider-v3.6(2024EN).xlsx'),
#  (5, 'Nl.zorg.HealthProfessional-v4.0(2024EN).xlsx'),
#  (6, 'Nl.zorg.MedicalDevice-v5.0(2024EN).xlsx'),
#  (7, 'nl.zorg.MedicationAgreement-v4.0(2024EN).xlsx'),
#  (8, 'Nl.zorg.NursingIntervention-v5.0(2024EN).xlsx'),
#  (9, 'Nl.zorg.part.AddressInformation-v1.2(2024EN).xlsx'),
#  (10, 'Nl.zorg.part.AnatomicalLocation-v1.0.4(2024EN).xlsx'),
#  (11, 'Nl.zorg.part.ContactInformation-v1.3.1(2024EN).xlsx'),
#  (12, 'Nl.zorg.part.InstructionsForUse-v3.1(2024EN).xlsx'),
#  (13, 'Nl.zorg.part.NameInformation-v1.2(2024EN).xlsx'),
#  (14, 'Nl.zorg.Patient-v4.3(2024EN).xlsx'),
#  (15, 'Nl.zorg.Procedure-v6.0(2024EN).xlsx'),
#  (16, 'Nl.zorg.process.RegistrationData-v1.1.2(2024EN).xlsx')]

# %%
zib = zibs[12]
print(zib)
zibpath = os.path.join(zibspath, zib)
zibdf = pd.read_excel(zibpath)
zibdf['path'] = zibdf['path'].apply(
    lambda x: ud.normalize("NFKC", str(x)).replace("\xa0", " ").strip() if pd.notna(x) else x
)
zibdf
# only for zib2024 condition and diagnosis
# zib = zibs[1]
# print( zib)
# zibpath = os.path.join(zibspath, zib)
# zibdf2 = pd.read_excel(zibpath)
# zibdf = pd.concat([zibdf, zibdf2], ignore_index=True)
# zibdf
# Out:
# Nl.zorg.part.InstructionsForUse-v3.1(2024EN).xlsx
#                                         name  \
# 0                         InstructionsForUse
# 1                     AdditionalInstructions
# 2                                Description
# 3               RepeatPeriodCyclicalSchedule
# 4                      RouteOfAdministration
# 5                         DosingInstructions
# 6                               DoseDuration
# 7                             SequenceNumber
# 8                                     Dosage
# 9                  AdministeringSpeed::Range
# 10    DurationOfAdministration::TimeInterval
# 11                               Dose::Range
# 12                                  AsNeeded
# 13                        AsNeeded.Condition
# 14                      AsNeeded.MaximumDose
# 15                     AdministeringSchedule
# 16    AdministeringSchedule.Frequency::Range
# 17             AdministeringSchedule.WeekDay
# 18           AdministeringSchedule.PartOfDay
# 19  AdministeringSchedule.AdministrationTime
# 20            AdministeringSchedule.Interval
#
#                                                  path  \
# 0                                  InstructionsForUse
# 1           InstructionsForUse.AdditionalInstructions
# 2                      InstructionsForUse.Description
# 3     InstructionsForUse.RepeatPeriodCyclicalSchedule
# 4            InstructionsForUse.RouteOfAdministration
# 5               InstructionsForUse.DosingInstructions
# 6   InstructionsForUse.DosingInstructions.DoseDura...
# 7   InstructionsForUse.DosingInstructions.Sequence...
# 8        InstructionsForUse.DosingInstructions.Dosage
# 9   InstructionsForUse.DosingInstructions.Dosage.A...
# 10  InstructionsForUse.DosingInstructions.Dosage.D...
# 11  InstructionsForUse.DosingInstructions.Dosage.D...
# 12  InstructionsForUse.DosingInstructions.Dosage.A...
# 13  InstructionsForUse.DosingInstructions.Dosage.A...
# 14  InstructionsForUse.DosingInstructions.Dosage.A...
# 15  InstructionsForUse.DosingInstructions.Dosage.A...
# 16  InstructionsForUse.DosingInstructions.Dosage.A...
# 17  InstructionsForUse.DosingInstructions.Dosage.A...
# 18  InstructionsForUse.DosingInstructions.Dosage.A...
# 19  InstructionsForUse.DosingInstructions.Dosage.A...
# 20  InstructionsForUse.DosingInstructions.Dosage.A...
#
#                                  alias type card.      stereotype  \
# 0               NL: GebruiksInstructie  NaN   NaN     rootconcept
# 1           NL: AanvullendeInstructies   CD  0..*            data
# 2                     NL: Omschrijving   ST  0..1            data
# 3     NL: HerhaalperiodeCyclischSchema   PQ  0..1            data
# 4                   NL: Toedieningsweg   CD  0..1            data
# 5                 NL: Doseerinstructie  NaN  0..*       container
# 6                       NL: Doseerduur   PQ  0..1            data
# 7                       NL: Volgnummer  INT  0..1            data
# 8                         NL: Dosering  NaN  0..*       container
# 9      NL: Toedieningssnelheid::Bereik  NaN  0..1  data,reference
# 10  NL: Toedieningsduur::TijdsInterval  NaN  0..1  data,reference
# 11               NL: Keerdosis::Bereik  NaN  0..1  data,reference
# 12                         NL: Zonodig  NaN  0..1       container
# 13                       NL: Criterium   CD  0..*            data
# 14                NL: MaximaleDosering   PQ  0..1            data
# 15               NL: Toedieningsschema  NaN  0..1       container
# 16              NL: Frequentie::Bereik  NaN  0..1  data,reference
# 17                         NL: Weekdag   CD  0..*            data
# 18                         NL: Dagdeel   CD  0..*            data
# 19                     NL: Toedientijd   TS  0..*            data
# 20                        NL: Interval   PQ  0..1            data
#
#                   id                                         definition  \
# 0   NL-CM:9.12.22504  Root concept of the InstructionsForUse partial...
# 1   NL-CM:9.12.19944  The additional instructions contain extra info...
# 2    NL-CM:9.12.9581  Textual description of the complete instructio...
# 3   NL-CM:9.12.22505  The repeated period in a cyclical schedule (of...
# 4   NL-CM:9.12.19941  The route through which the medication is admi...
# 5   NL-CM:9.12.22095                                Dosing instructions
# 6   NL-CM:9.12.22506  The intended time duration for these dosing in...
# 7   NL-CM:9.12.22503  This indicates the sequence of the dosing inst...
# 8   NL-CM:9.12.19935  Container of the Dosage concept. This containe...
# 9   NL-CM:9.12.19942  The administering speed is used in slow admini...
# 10  NL-CM:9.12.23141  The duration of administration defines the len...
# 11  NL-CM:9.12.19940  The dose indicates the amount/unit per adminis...
# 12  NL-CM:9.12.22512  As needed means that the dose is only to be ad...
# 13  NL-CM:9.12.19945  The condition for administering medication can...
# 14  NL-CM:9.12.19946  A MaximumDose maximizes (in time) the usage of...
# 15  NL-CM:9.12.19948  Specifications of the times at which the medic...
# 16  NL-CM:9.12.19949  The frequency indicates the number of dose mom...
# 17  NL-CM:9.12.19952  WeekDay indicates a pattern of doses on fixed ...
# 18  NL-CM:9.12.19953   Time of day: morning, afternoon, evening, night.
# 19  NL-CM:9.12.19951  The time of administration is a specific time ...
# 20  NL-CM:9.12.19950  Interval indicates the time between dose times...
#
#     definitioncode
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN

# %%
xlmbase = 'xtehr'
xlmspath = os.path.join(xlmbase, 'mappable')
xlms = os.listdir(xlmspath)
[(i, xlm) for i, xlm in enumerate(xlms)]
# Out:
# [(0, 'Address.xlsx'),
#  (1, 'AlertFlag.xlsx'),
#  (2, 'AllergyIntolerance.xlsx'),
#  (3, 'BodyStructure.xlsx'),
#  (4, 'Condition.xlsx'),
#  (5, 'DataSet.xlsx'),
#  (6, 'Device.xlsx'),
#  (7, 'DeviceUse.xlsx'),
#  (8, 'Dosaging.xlsx'),
#  (9, 'HealthProfessional.xlsx'),
#  (10, 'HumanName.xlsx'),
#  (11, 'Location.xlsx'),
#  (12, 'Medication.xlsx'),
#  (13, 'MedicationPrescription.xlsx'),
#  (14, 'Organization.xlsx'),
#  (15, 'Patient.xlsx'),
#  (16, 'Procedure.xlsx'),
#  (17, 'Telecom.xlsx')]

# %%
xlm = xlms[8]
print( xlm)
xlmpath = os.path.join(xlmspath, xlm)
xlmdf = pd.read_excel(xlmpath)
# Normalize + strip (for non-breaking spaces, Unicode issues)
xlmdf['path'] = xlmdf['path'].apply(
    lambda x: ud.normalize("NFKC", str(x)).replace("\xa0", " ").strip() if pd.notna(x) else x
)
xlmdf
# only for device use and organization
# xlm = xlms[7]
# print( xlm)
# xlmpath = os.path.join(xlmspath, xlm)
# xlmdf2 = pd.read_excel(xlmpath)
# xlmdf = pd.concat([xlmdf, xlmdf2], ignore_index=True)
# xlmdf
# Out:
# Dosaging.xlsx
#                                                    id  \
# 0                                        EHDSDosaging
# 1                               EHDSDosaging.sequence
# 2                                   EHDSDosaging.text
# 3                    EHDSDosaging.renderedDescription
# 4                  EHDSDosaging.additionalInstruction
# 5                     EHDSDosaging.patientInstruction
# 6                            EHDSDosaging.doseAndRate
# 7                       EHDSDosaging.doseAndRate.type
# 8                    EHDSDosaging.doseAndRate.dose[x]
# 9                    EHDSDosaging.doseAndRate.rate[x]
# 10                                EHDSDosaging.timing
# 11                          EHDSDosaging.timing.event
# 12                           EHDSDosaging.timing.code
# 13                         EHDSDosaging.timing.repeat
# 14                  EHDSDosaging.timing.repeat.bounds
# 15         EHDSDosaging.timing.repeat.bounds.duration
# 16            EHDSDosaging.timing.repeat.bounds.range
# 17           EHDSDosaging.timing.repeat.bounds.period
# 18                   EHDSDosaging.timing.repeat.count
# 19             EHDSDosaging.timing.repeat.count.count
# 20          EHDSDosaging.timing.repeat.count.countMax
# 21                EHDSDosaging.timing.repeat.duration
# 22       EHDSDosaging.timing.repeat.duration.duration
# 23    EHDSDosaging.timing.repeat.duration.durationMax
# 24               EHDSDosaging.timing.repeat.frequency
# 25  EHDSDosaging.timing.repeat.frequency.numberOfT...
# 26  EHDSDosaging.timing.repeat.frequency.maxNumber...
# 27        EHDSDosaging.timing.repeat.frequency.period
# 28     EHDSDosaging.timing.repeat.frequency.periodMax
# 29               EHDSDosaging.timing.repeat.dayOfWeek
# 30               EHDSDosaging.timing.repeat.timeOfDay
# 31               EHDSDosaging.timing.repeat.eventTime
# 32          EHDSDosaging.timing.repeat.eventTime.when
# 33        EHDSDosaging.timing.repeat.eventTime.offset
# 34                              EHDSDosaging.asNeeded
# 35                           EHDSDosaging.asNeededFor
# 36                              EHDSDosaging.bodySite
# 37                 EHDSDosaging.routeOfAdministration
# 38                EHDSDosaging.methodOfAdministration
# 39                               EHDSDosaging.maxDose
# 40              EHDSDosaging.maxDose.maxDosePerPeriod
# 41      EHDSDosaging.maxDose.maxDosePerAdministration
# 42            EHDSDosaging.maxDose.maxDosePerLifetime
#
#                                                  path  \
# 0                                        EHDSDosaging
# 1                               EHDSDosaging.sequence
# 2                                   EHDSDosaging.text
# 3                    EHDSDosaging.renderedDescription
# 4                  EHDSDosaging.additionalInstruction
# 5                     EHDSDosaging.patientInstruction
# 6                            EHDSDosaging.doseAndRate
# 7                       EHDSDosaging.doseAndRate.type
# 8                    EHDSDosaging.doseAndRate.dose[x]
# 9                    EHDSDosaging.doseAndRate.rate[x]
# 10                                EHDSDosaging.timing
# 11                          EHDSDosaging.timing.event
# 12                           EHDSDosaging.timing.code
# 13                         EHDSDosaging.timing.repeat
# 14                  EHDSDosaging.timing.repeat.bounds
# 15         EHDSDosaging.timing.repeat.bounds.duration
# 16            EHDSDosaging.timing.repeat.bounds.range
# 17           EHDSDosaging.timing.repeat.bounds.period
# 18                   EHDSDosaging.timing.repeat.count
# 19             EHDSDosaging.timing.repeat.count.count
# 20          EHDSDosaging.timing.repeat.count.countMax
# 21                EHDSDosaging.timing.repeat.duration
# 22       EHDSDosaging.timing.repeat.duration.duration
# 23    EHDSDosaging.timing.repeat.duration.durationMax
# 24               EHDSDosaging.timing.repeat.frequency
# 25  EHDSDosaging.timing.repeat.frequency.numberOfT...
# 26  EHDSDosaging.timing.repeat.frequency.maxNumber...
# 27        EHDSDosaging.timing.repeat.frequency.period
# 28     EHDSDosaging.timing.repeat.frequency.periodMax
# 29               EHDSDosaging.timing.repeat.dayOfWeek
# 30               EHDSDosaging.timing.repeat.timeOfDay
# 31               EHDSDosaging.timing.repeat.eventTime
# 32          EHDSDosaging.timing.repeat.eventTime.when
# 33        EHDSDosaging.timing.repeat.eventTime.offset
# 34                              EHDSDosaging.asNeeded
# 35                           EHDSDosaging.asNeededFor
# 36                              EHDSDosaging.bodySite
# 37                 EHDSDosaging.routeOfAdministration
# 38                EHDSDosaging.methodOfAdministration
# 39                               EHDSDosaging.maxDose
# 40              EHDSDosaging.maxDose.maxDosePerPeriod
# 41      EHDSDosaging.maxDose.maxDosePerAdministration
# 42            EHDSDosaging.maxDose.maxDosePerLifetime
#
#                                                 short  \
# 0                                      Dosaging model
# 1   Order of the dosage instruction, in case one t...
# 2   Free text usage/dosage instructions when struc...
# 3   Text representation rendered from all dosaging...
# 4   Coded instructions, e.g warnings to the patien...
# 5          Patient oriented instructions as free text
# 6   Amount of medication administered per one dose...
# 7   The kind of dose or rate specified (e.g calcul...
# 8   Amount of medication per one dose. (1 tablet, ...
# 9   Time period during which one defined dose is a...
# 10  When medication should be administered (period...
# 11       Exact date and/or time of the administration
# 12  Timing abbreviation (AM - morning, Q4H - once ...
# 13                  Repetition of the administration.
# 14  Time bounds for the treatment (current dosagin...
# 15                  Number of time units, e.g 10 days
# 16        A range of numbers of time units, 5-10 days
# 17        Start and end date, 05.08.2023 - 10.08.2023
# 18          Number of times to repeat, exact or range
# 19           Number of times (e.g 'once', '10 times')
# 20   Maximum number of times (e.g 'maximum 10 times')
# 21     Duration of one administration, exact or range
# 22  Duration of administration (e.g '5 minutes', '...
# 23  Maximum duration of administration (e.g 'maxim...
# 24  Frequency of intake/administration (e.g 'three...
# 25         Number of times per period (e.g '3 times')
# 26  Maximum number of times per period (e.g. 'maxi...
# 27  Duration to which the frequency applies (e.g '...
# 28    Upper limit of the period (e.g ... / 4-6 hours)
# 29  The day of the week of administration, e.g Mon...
# 30        Time of day of administration (e.g '10:00')
# 31  An event the administration is bound to, e.g '...
# 32  Time period or event ('before meal', 'immediat...
# 33  minutes from event, before or after (?not sure...
# 34                                     Take as needed
# 35                Take as needed for the coded reason
# 36                        Body site of administration
# 37                            Route of administration
# 38                           Method of administration
# 39                       Maximum dose for the patient
# 40         Upper limit on medication per unit of time
# 41   Upper limit on medication per one administration
# 42  Upper limit on medication per lifetime of the ...
#
#                                            definition             type card.
# 0   Logical model for usage instructions for admin...              NaN  0..*
# 1   Order of the dosage instruction, in case one t...          integer  0..1
# 2   Free text usage/dosage instructions when struc...           string  0..1
# 3   Text representation rendered from all dosaging...           string  0..1
# 4   Coded instructions, e.g warnings to the patien...  CodeableConcept  0..*
# 5          Patient oriented instructions as free text           string  0..1
# 6   Amount of medication administered per one dose...             Base  0..*
# 7   The kind of dose or rate specified (e.g calcul...  CodeableConcept  0..1
# 8   Amount of medication per one dose. (1 tablet, ...         Quantity  0..1
# 9   Time period during which one defined dose is a...            Ratio  0..1
# 10  When medication should be administered (period...             Base  0..1
# 11       Exact date and/or time of the administration         dateTime  0..*
# 12  Timing abbreviation (AM - morning, Q4H - once ...  CodeableConcept  0..1
# 13                  Repetition of the administration.             Base  0..1
# 14  Time bounds for the treatment (current dosagin...             Base  0..1
# 15                  Number of time units, e.g 10 days         Quantity  0..1
# 16        A range of numbers of time units, 5-10 days            Range  0..1
# 17        Start and end date, 05.08.2023 - 10.08.2023           Period  0..1
# 18          Number of times to repeat, exact or range             Base  0..1
# 19           Number of times (e.g 'once', '10 times')          integer  0..1
# 20   Maximum number of times (e.g 'maximum 10 times')          integer  0..1
# 21     Duration of one administration, exact or range             Base  0..1
# 22  Duration of administration (e.g '5 minutes', '...         Quantity  0..1
# 23  Maximum duration of administration (e.g 'maxim...         Quantity  0..1
# 24  Frequency of intake/administration (e.g 'three...             Base  0..1
# 25         Number of times per period (e.g '3 times')          integer  0..1
# 26  Maximum number of times per period (e.g. 'maxi...          integer  0..1
# 27  Duration to which the frequency applies (e.g '...         Quantity  0..1
# 28    Upper limit of the period (e.g ... / 4-6 hours)         Quantity  0..1
# 29  The day of the week of administration, e.g Mon...  CodeableConcept  0..*
# 30        Time of day of administration (e.g '10:00')             time  0..*
# 31  An event the administration is bound to, e.g '...             Base  0..*
# 32  Time period or event ('before meal', 'immediat...  CodeableConcept  0..*
# 33  minutes from event, before or after (?not sure...          integer  0..1
# 34                                     Take as needed          boolean  0..1
# 35                Take as needed for the coded reason  CodeableConcept  0..*
# 36                        Body site of administration  CodeableConcept  0..1
# 37                            Route of administration  CodeableConcept  0..1
# 38                           Method of administration  CodeableConcept  0..1
# 39                       Maximum dose for the patient             Base  0..*
# 40         Upper limit on medication per unit of time            Ratio  0..*
# 41   Upper limit on medication per one administration         Quantity  0..1
# 42  Upper limit on medication per lifetime of the ...         Quantity  0..1

# %%
mapbase = 'maps'
maps = os.listdir(mapbase)
[(i, map) for i, map in enumerate(maps)]
# Out:
# [(0, 'Address.xlsx'),
#  (1, 'AlertFlag.xlsx'),
#  (2, 'BodyStructure.xlsx'),
#  (3, 'Condition.xlsx'),
#  (4, 'DataSet.xlsx'),
#  (5, 'Device-and-DeviceUse.xlsx'),
#  (6, 'Diagnosis.xlsx'),
#  (7, 'Dosaging.xlsx'),
#  (8, 'HealthProfessional.xlsx'),
#  (9, 'HumanName.xlsx'),
#  (10, 'Location-and-Organization.xlsx'),
#  (11, 'MedicationPrescription.xlsx'),
#  (12, 'Patient.xlsx'),
#  (13, 'Procedure-NusringIntervention.xlsx'),
#  (14, 'Procedure.xlsx'),
#  (15, 'xtehr2zibs'),
#  (16, 'xtehr2zibs2024')]

# %%
file = maps[7]
print(file)
mappath = os.path.join(mapbase, file)
print(mappath)
mapdf = pd.read_excel(mappath)
# Normalize + strip (for non-breaking spaces, Unicode issues)
mapdf[['zib','xtehr']] = mapdf[['zib','xtehr']].map(
    lambda x: ud.normalize("NFKC", str(x)).replace("\xa0", " ").strip() if pd.notna(x) else x
)
mapdf
# Out:
# Dosaging.xlsx
# maps\Dosaging.xlsx
#                                                 xtehr  \
# 0                                        EHDSDosaging
# 1                               EHDSDosaging.sequence
# 2                                   EHDSDosaging.text
# 3                    EHDSDosaging.renderedDescription
# 4                  EHDSDosaging.additionalInstruction
# 5                     EHDSDosaging.patientInstruction
# 6                            EHDSDosaging.doseAndRate
# 7                       EHDSDosaging.doseAndRate.type
# 8                    EHDSDosaging.doseAndRate.dose[x]
# 9                    EHDSDosaging.doseAndRate.rate[x]
# 10                                EHDSDosaging.timing
# 11                          EHDSDosaging.timing.event
# 12                           EHDSDosaging.timing.code
# 13                         EHDSDosaging.timing.repeat
# 14                  EHDSDosaging.timing.repeat.bounds
# 15         EHDSDosaging.timing.repeat.bounds.duration
# 16            EHDSDosaging.timing.repeat.bounds.range
# 17           EHDSDosaging.timing.repeat.bounds.period
# 18                   EHDSDosaging.timing.repeat.count
# 19             EHDSDosaging.timing.repeat.count.count
# 20          EHDSDosaging.timing.repeat.count.countMax
# 21                EHDSDosaging.timing.repeat.duration
# 22       EHDSDosaging.timing.repeat.duration.duration
# 23    EHDSDosaging.timing.repeat.duration.durationMax
# 24               EHDSDosaging.timing.repeat.frequency
# 25  EHDSDosaging.timing.repeat.frequency.numberOfT...
# 26  EHDSDosaging.timing.repeat.frequency.maxNumber...
# 27        EHDSDosaging.timing.repeat.frequency.period
# 28     EHDSDosaging.timing.repeat.frequency.periodMax
# 29               EHDSDosaging.timing.repeat.dayOfWeek
# 30               EHDSDosaging.timing.repeat.timeOfDay
# 31               EHDSDosaging.timing.repeat.eventTime
# 32          EHDSDosaging.timing.repeat.eventTime.when
# 33        EHDSDosaging.timing.repeat.eventTime.offset
# 34                              EHDSDosaging.asNeeded
# 35                           EHDSDosaging.asNeededFor
# 36                              EHDSDosaging.bodySite
# 37                 EHDSDosaging.routeOfAdministration
# 38                EHDSDosaging.methodOfAdministration
# 39                               EHDSDosaging.maxDose
# 40              EHDSDosaging.maxDose.maxDosePerPeriod
# 41      EHDSDosaging.maxDose.maxDosePerAdministration
# 42            EHDSDosaging.maxDose.maxDosePerLifetime
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
#
#                                                   zib
# 0                                  InstructionsForUse
# 1   InstructionsForUse.DosingInstructions.Sequence...
# 2                      InstructionsForUse.Description
# 3                                                 NaN
# 4           InstructionsForUse.AdditionalInstructions
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   InstructionsForUse.DosingInstructions.Dosage.D...
# 9   InstructionsForUse.DosingInstructions.Dosage.A...
# 10  InstructionsForUse.DosingInstructions.Dosage.A...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  InstructionsForUse.DosingInstructions.DoseDura...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  InstructionsForUse.DosingInstructions.Dosage.D...
# 23                                                NaN
# 24                                                NaN
# 25  InstructionsForUse.DosingInstructions.Dosage.A...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  InstructionsForUse.DosingInstructions.Dosage.A...
# 30  InstructionsForUse.DosingInstructions.Dosage.A...
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35  InstructionsForUse.DosingInstructions.Dosage.A...
# 36                                                NaN
# 37           InstructionsForUse.RouteOfAdministration
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43    InstructionsForUse.RepeatPeriodCyclicalSchedule
# 44              InstructionsForUse.DosingInstructions
# 45       InstructionsForUse.DosingInstructions.Dosage
# 46  InstructionsForUse.DosingInstructions.Dosage.A...
# 47  InstructionsForUse.DosingInstructions.Dosage.A...
# 48  InstructionsForUse.DosingInstructions.Dosage.A...
# 49  InstructionsForUse.DosingInstructions.Dosage.A...
# 50  InstructionsForUse.DosingInstructions.Dosage.A...

# %%
mapping = mapdf[['xtehr', 'zib']].merge(zibdf.add_suffix('_zib'), left_on='zib', right_on='path_zib', how='outer').merge(xlmdf.add_suffix('_xtehr'), left_on='xtehr', right_on='path_xtehr', how='outer')
mapping
# Out:
#                                                 xtehr  \
# 0                                        EHDSDosaging
# 1                  EHDSDosaging.additionalInstruction
# 2                               EHDSDosaging.asNeeded
# 3                            EHDSDosaging.asNeededFor
# 4                               EHDSDosaging.bodySite
# 5                            EHDSDosaging.doseAndRate
# 6                    EHDSDosaging.doseAndRate.dose[x]
# 7                    EHDSDosaging.doseAndRate.rate[x]
# 8                       EHDSDosaging.doseAndRate.type
# 9                                EHDSDosaging.maxDose
# 10      EHDSDosaging.maxDose.maxDosePerAdministration
# 11            EHDSDosaging.maxDose.maxDosePerLifetime
# 12              EHDSDosaging.maxDose.maxDosePerPeriod
# 13                EHDSDosaging.methodOfAdministration
# 14                    EHDSDosaging.patientInstruction
# 15                   EHDSDosaging.renderedDescription
# 16                 EHDSDosaging.routeOfAdministration
# 17                              EHDSDosaging.sequence
# 18                                  EHDSDosaging.text
# 19                                EHDSDosaging.timing
# 20                           EHDSDosaging.timing.code
# 21                          EHDSDosaging.timing.event
# 22                         EHDSDosaging.timing.repeat
# 23                  EHDSDosaging.timing.repeat.bounds
# 24         EHDSDosaging.timing.repeat.bounds.duration
# 25           EHDSDosaging.timing.repeat.bounds.period
# 26            EHDSDosaging.timing.repeat.bounds.range
# 27                   EHDSDosaging.timing.repeat.count
# 28             EHDSDosaging.timing.repeat.count.count
# 29          EHDSDosaging.timing.repeat.count.countMax
# 30               EHDSDosaging.timing.repeat.dayOfWeek
# 31                EHDSDosaging.timing.repeat.duration
# 32       EHDSDosaging.timing.repeat.duration.duration
# 33    EHDSDosaging.timing.repeat.duration.durationMax
# 34               EHDSDosaging.timing.repeat.eventTime
# 35        EHDSDosaging.timing.repeat.eventTime.offset
# 36          EHDSDosaging.timing.repeat.eventTime.when
# 37               EHDSDosaging.timing.repeat.frequency
# 38  EHDSDosaging.timing.repeat.frequency.maxNumber...
# 39  EHDSDosaging.timing.repeat.frequency.numberOfT...
# 40        EHDSDosaging.timing.repeat.frequency.period
# 41     EHDSDosaging.timing.repeat.frequency.periodMax
# 42               EHDSDosaging.timing.repeat.timeOfDay
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
#
#                                                   zib  \
# 0                                  InstructionsForUse
# 1           InstructionsForUse.AdditionalInstructions
# 2                                                 NaN
# 3   InstructionsForUse.DosingInstructions.Dosage.A...
# 4                                                 NaN
# 5                                                 NaN
# 6   InstructionsForUse.DosingInstructions.Dosage.D...
# 7   InstructionsForUse.DosingInstructions.Dosage.A...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16           InstructionsForUse.RouteOfAdministration
# 17  InstructionsForUse.DosingInstructions.Sequence...
# 18                     InstructionsForUse.Description
# 19  InstructionsForUse.DosingInstructions.Dosage.A...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  InstructionsForUse.DosingInstructions.DoseDura...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30  InstructionsForUse.DosingInstructions.Dosage.A...
# 31                                                NaN
# 32  InstructionsForUse.DosingInstructions.Dosage.D...
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39  InstructionsForUse.DosingInstructions.Dosage.A...
# 40                                                NaN
# 41                                                NaN
# 42  InstructionsForUse.DosingInstructions.Dosage.A...
# 43              InstructionsForUse.DosingInstructions
# 44       InstructionsForUse.DosingInstructions.Dosage
# 45  InstructionsForUse.DosingInstructions.Dosage.A...
# 46  InstructionsForUse.DosingInstructions.Dosage.A...
# 47  InstructionsForUse.DosingInstructions.Dosage.A...
# 48  InstructionsForUse.DosingInstructions.Dosage.A...
# 49  InstructionsForUse.DosingInstructions.Dosage.A...
# 50    InstructionsForUse.RepeatPeriodCyclicalSchedule
#
#                                     name_zib  \
# 0                         InstructionsForUse
# 1                     AdditionalInstructions
# 2                                        NaN
# 3                         AsNeeded.Condition
# 4                                        NaN
# 5                                        NaN
# 6                                Dose::Range
# 7                  AdministeringSpeed::Range
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                     RouteOfAdministration
# 17                            SequenceNumber
# 18                               Description
# 19                     AdministeringSchedule
# 20                                       NaN
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
# 24                              DoseDuration
# 25                                       NaN
# 26                                       NaN
# 27                                       NaN
# 28                                       NaN
# 29                                       NaN
# 30             AdministeringSchedule.WeekDay
# 31                                       NaN
# 32    DurationOfAdministration::TimeInterval
# 33                                       NaN
# 34                                       NaN
# 35                                       NaN
# 36                                       NaN
# 37                                       NaN
# 38                                       NaN
# 39    AdministeringSchedule.Frequency::Range
# 40                                       NaN
# 41                                       NaN
# 42  AdministeringSchedule.AdministrationTime
# 43                        DosingInstructions
# 44                                    Dosage
# 45                     AdministeringSchedule
# 46            AdministeringSchedule.Interval
# 47           AdministeringSchedule.PartOfDay
# 48                                  AsNeeded
# 49                      AsNeeded.MaximumDose
# 50              RepeatPeriodCyclicalSchedule
#
#                                              path_zib  \
# 0                                  InstructionsForUse
# 1           InstructionsForUse.AdditionalInstructions
# 2                                                 NaN
# 3   InstructionsForUse.DosingInstructions.Dosage.A...
# 4                                                 NaN
# 5                                                 NaN
# 6   InstructionsForUse.DosingInstructions.Dosage.D...
# 7   InstructionsForUse.DosingInstructions.Dosage.A...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16           InstructionsForUse.RouteOfAdministration
# 17  InstructionsForUse.DosingInstructions.Sequence...
# 18                     InstructionsForUse.Description
# 19  InstructionsForUse.DosingInstructions.Dosage.A...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  InstructionsForUse.DosingInstructions.DoseDura...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30  InstructionsForUse.DosingInstructions.Dosage.A...
# 31                                                NaN
# 32  InstructionsForUse.DosingInstructions.Dosage.D...
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39  InstructionsForUse.DosingInstructions.Dosage.A...
# 40                                                NaN
# 41                                                NaN
# 42  InstructionsForUse.DosingInstructions.Dosage.A...
# 43              InstructionsForUse.DosingInstructions
# 44       InstructionsForUse.DosingInstructions.Dosage
# 45  InstructionsForUse.DosingInstructions.Dosage.A...
# 46  InstructionsForUse.DosingInstructions.Dosage.A...
# 47  InstructionsForUse.DosingInstructions.Dosage.A...
# 48  InstructionsForUse.DosingInstructions.Dosage.A...
# 49  InstructionsForUse.DosingInstructions.Dosage.A...
# 50    InstructionsForUse.RepeatPeriodCyclicalSchedule
#
#                              alias_zib type_zib card._zib  stereotype_zib  \
# 0               NL: GebruiksInstructie      NaN       NaN     rootconcept
# 1           NL: AanvullendeInstructies       CD      0..*            data
# 2                                  NaN      NaN       NaN             NaN
# 3                        NL: Criterium       CD      0..*            data
# 4                                  NaN      NaN       NaN             NaN
# 5                                  NaN      NaN       NaN             NaN
# 6                NL: Keerdosis::Bereik      NaN      0..1  data,reference
# 7      NL: Toedieningssnelheid::Bereik      NaN      0..1  data,reference
# 8                                  NaN      NaN       NaN             NaN
# 9                                  NaN      NaN       NaN             NaN
# 10                                 NaN      NaN       NaN             NaN
# 11                                 NaN      NaN       NaN             NaN
# 12                                 NaN      NaN       NaN             NaN
# 13                                 NaN      NaN       NaN             NaN
# 14                                 NaN      NaN       NaN             NaN
# 15                                 NaN      NaN       NaN             NaN
# 16                  NL: Toedieningsweg       CD      0..1            data
# 17                      NL: Volgnummer      INT      0..1            data
# 18                    NL: Omschrijving       ST      0..1            data
# 19               NL: Toedieningsschema      NaN      0..1       container
# 20                                 NaN      NaN       NaN             NaN
# 21                                 NaN      NaN       NaN             NaN
# 22                                 NaN      NaN       NaN             NaN
# 23                                 NaN      NaN       NaN             NaN
# 24                      NL: Doseerduur       PQ      0..1            data
# 25                                 NaN      NaN       NaN             NaN
# 26                                 NaN      NaN       NaN             NaN
# 27                                 NaN      NaN       NaN             NaN
# 28                                 NaN      NaN       NaN             NaN
# 29                                 NaN      NaN       NaN             NaN
# 30                         NL: Weekdag       CD      0..*            data
# 31                                 NaN      NaN       NaN             NaN
# 32  NL: Toedieningsduur::TijdsInterval      NaN      0..1  data,reference
# 33                                 NaN      NaN       NaN             NaN
# 34                                 NaN      NaN       NaN             NaN
# 35                                 NaN      NaN       NaN             NaN
# 36                                 NaN      NaN       NaN             NaN
# 37                                 NaN      NaN       NaN             NaN
# 38                                 NaN      NaN       NaN             NaN
# 39              NL: Frequentie::Bereik      NaN      0..1  data,reference
# 40                                 NaN      NaN       NaN             NaN
# 41                                 NaN      NaN       NaN             NaN
# 42                     NL: Toedientijd       TS      0..*            data
# 43                NL: Doseerinstructie      NaN      0..*       container
# 44                        NL: Dosering      NaN      0..*       container
# 45               NL: Toedieningsschema      NaN      0..1       container
# 46                        NL: Interval       PQ      0..1            data
# 47                         NL: Dagdeel       CD      0..*            data
# 48                         NL: Zonodig      NaN      0..1       container
# 49                NL: MaximaleDosering       PQ      0..1            data
# 50    NL: HerhaalperiodeCyclischSchema       PQ      0..1            data
#
#               id_zib                                     definition_zib  \
# 0   NL-CM:9.12.22504  Root concept of the InstructionsForUse partial...
# 1   NL-CM:9.12.19944  The additional instructions contain extra info...
# 2                NaN                                                NaN
# 3   NL-CM:9.12.19945  The condition for administering medication can...
# 4                NaN                                                NaN
# 5                NaN                                                NaN
# 6   NL-CM:9.12.19940  The dose indicates the amount/unit per adminis...
# 7   NL-CM:9.12.19942  The administering speed is used in slow admini...
# 8                NaN                                                NaN
# 9                NaN                                                NaN
# 10               NaN                                                NaN
# 11               NaN                                                NaN
# 12               NaN                                                NaN
# 13               NaN                                                NaN
# 14               NaN                                                NaN
# 15               NaN                                                NaN
# 16  NL-CM:9.12.19941  The route through which the medication is admi...
# 17  NL-CM:9.12.22503  This indicates the sequence of the dosing inst...
# 18   NL-CM:9.12.9581  Textual description of the complete instructio...
# 19  NL-CM:9.12.19948  Specifications of the times at which the medic...
# 20               NaN                                                NaN
# 21               NaN                                                NaN
# 22               NaN                                                NaN
# 23               NaN                                                NaN
# 24  NL-CM:9.12.22506  The intended time duration for these dosing in...
# 25               NaN                                                NaN
# 26               NaN                                                NaN
# 27               NaN                                                NaN
# 28               NaN                                                NaN
# 29               NaN                                                NaN
# 30  NL-CM:9.12.19952  WeekDay indicates a pattern of doses on fixed ...
# 31               NaN                                                NaN
# 32  NL-CM:9.12.23141  The duration of administration defines the len...
# 33               NaN                                                NaN
# 34               NaN                                                NaN
# 35               NaN                                                NaN
# 36               NaN                                                NaN
# 37               NaN                                                NaN
# 38               NaN                                                NaN
# 39  NL-CM:9.12.19949  The frequency indicates the number of dose mom...
# 40               NaN                                                NaN
# 41               NaN                                                NaN
# 42  NL-CM:9.12.19951  The time of administration is a specific time ...
# 43  NL-CM:9.12.22095                                Dosing instructions
# 44  NL-CM:9.12.19935  Container of the Dosage concept. This containe...
# 45  NL-CM:9.12.19948  Specifications of the times at which the medic...
# 46  NL-CM:9.12.19950  Interval indicates the time between dose times...
# 47  NL-CM:9.12.19953   Time of day: morning, afternoon, evening, night.
# 48  NL-CM:9.12.22512  As needed means that the dose is only to be ad...
# 49  NL-CM:9.12.19946  A MaximumDose maximizes (in time) the usage of...
# 50  NL-CM:9.12.22505  The repeated period in a cyclical schedule (of...
#
#     definitioncode_zib                                           id_xtehr  \
# 0                  NaN                                       EHDSDosaging
# 1                  NaN                 EHDSDosaging.additionalInstruction
# 2                  NaN                              EHDSDosaging.asNeeded
# 3                  NaN                           EHDSDosaging.asNeededFor
# 4                  NaN                              EHDSDosaging.bodySite
# 5                  NaN                           EHDSDosaging.doseAndRate
# 6                  NaN                   EHDSDosaging.doseAndRate.dose[x]
# 7                  NaN                   EHDSDosaging.doseAndRate.rate[x]
# 8                  NaN                      EHDSDosaging.doseAndRate.type
# 9                  NaN                               EHDSDosaging.maxDose
# 10                 NaN      EHDSDosaging.maxDose.maxDosePerAdministration
# 11                 NaN            EHDSDosaging.maxDose.maxDosePerLifetime
# 12                 NaN              EHDSDosaging.maxDose.maxDosePerPeriod
# 13                 NaN                EHDSDosaging.methodOfAdministration
# 14                 NaN                    EHDSDosaging.patientInstruction
# 15                 NaN                   EHDSDosaging.renderedDescription
# 16                 NaN                 EHDSDosaging.routeOfAdministration
# 17                 NaN                              EHDSDosaging.sequence
# 18                 NaN                                  EHDSDosaging.text
# 19                 NaN                                EHDSDosaging.timing
# 20                 NaN                           EHDSDosaging.timing.code
# 21                 NaN                          EHDSDosaging.timing.event
# 22                 NaN                         EHDSDosaging.timing.repeat
# 23                 NaN                  EHDSDosaging.timing.repeat.bounds
# 24                 NaN         EHDSDosaging.timing.repeat.bounds.duration
# 25                 NaN           EHDSDosaging.timing.repeat.bounds.period
# 26                 NaN            EHDSDosaging.timing.repeat.bounds.range
# 27                 NaN                   EHDSDosaging.timing.repeat.count
# 28                 NaN             EHDSDosaging.timing.repeat.count.count
# 29                 NaN          EHDSDosaging.timing.repeat.count.countMax
# 30                 NaN               EHDSDosaging.timing.repeat.dayOfWeek
# 31                 NaN                EHDSDosaging.timing.repeat.duration
# 32                 NaN       EHDSDosaging.timing.repeat.duration.duration
# 33                 NaN    EHDSDosaging.timing.repeat.duration.durationMax
# 34                 NaN               EHDSDosaging.timing.repeat.eventTime
# 35                 NaN        EHDSDosaging.timing.repeat.eventTime.offset
# 36                 NaN          EHDSDosaging.timing.repeat.eventTime.when
# 37                 NaN               EHDSDosaging.timing.repeat.frequency
# 38                 NaN  EHDSDosaging.timing.repeat.frequency.maxNumber...
# 39                 NaN  EHDSDosaging.timing.repeat.frequency.numberOfT...
# 40                 NaN        EHDSDosaging.timing.repeat.frequency.period
# 41                 NaN     EHDSDosaging.timing.repeat.frequency.periodMax
# 42                 NaN               EHDSDosaging.timing.repeat.timeOfDay
# 43                 NaN                                                NaN
# 44                 NaN                                                NaN
# 45                 NaN                                                NaN
# 46                 NaN                                                NaN
# 47                 NaN                                                NaN
# 48                 NaN                                                NaN
# 49                 NaN                                                NaN
# 50                 NaN                                                NaN
#
#                                            path_xtehr  \
# 0                                        EHDSDosaging
# 1                  EHDSDosaging.additionalInstruction
# 2                               EHDSDosaging.asNeeded
# 3                            EHDSDosaging.asNeededFor
# 4                               EHDSDosaging.bodySite
# 5                            EHDSDosaging.doseAndRate
# 6                    EHDSDosaging.doseAndRate.dose[x]
# 7                    EHDSDosaging.doseAndRate.rate[x]
# 8                       EHDSDosaging.doseAndRate.type
# 9                                EHDSDosaging.maxDose
# 10      EHDSDosaging.maxDose.maxDosePerAdministration
# 11            EHDSDosaging.maxDose.maxDosePerLifetime
# 12              EHDSDosaging.maxDose.maxDosePerPeriod
# 13                EHDSDosaging.methodOfAdministration
# 14                    EHDSDosaging.patientInstruction
# 15                   EHDSDosaging.renderedDescription
# 16                 EHDSDosaging.routeOfAdministration
# 17                              EHDSDosaging.sequence
# 18                                  EHDSDosaging.text
# 19                                EHDSDosaging.timing
# 20                           EHDSDosaging.timing.code
# 21                          EHDSDosaging.timing.event
# 22                         EHDSDosaging.timing.repeat
# 23                  EHDSDosaging.timing.repeat.bounds
# 24         EHDSDosaging.timing.repeat.bounds.duration
# 25           EHDSDosaging.timing.repeat.bounds.period
# 26            EHDSDosaging.timing.repeat.bounds.range
# 27                   EHDSDosaging.timing.repeat.count
# 28             EHDSDosaging.timing.repeat.count.count
# 29          EHDSDosaging.timing.repeat.count.countMax
# 30               EHDSDosaging.timing.repeat.dayOfWeek
# 31                EHDSDosaging.timing.repeat.duration
# 32       EHDSDosaging.timing.repeat.duration.duration
# 33    EHDSDosaging.timing.repeat.duration.durationMax
# 34               EHDSDosaging.timing.repeat.eventTime
# 35        EHDSDosaging.timing.repeat.eventTime.offset
# 36          EHDSDosaging.timing.repeat.eventTime.when
# 37               EHDSDosaging.timing.repeat.frequency
# 38  EHDSDosaging.timing.repeat.frequency.maxNumber...
# 39  EHDSDosaging.timing.repeat.frequency.numberOfT...
# 40        EHDSDosaging.timing.repeat.frequency.period
# 41     EHDSDosaging.timing.repeat.frequency.periodMax
# 42               EHDSDosaging.timing.repeat.timeOfDay
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
#
#                                           short_xtehr  \
# 0                                      Dosaging model
# 1   Coded instructions, e.g warnings to the patien...
# 2                                      Take as needed
# 3                 Take as needed for the coded reason
# 4                         Body site of administration
# 5   Amount of medication administered per one dose...
# 6   Amount of medication per one dose. (1 tablet, ...
# 7   Time period during which one defined dose is a...
# 8   The kind of dose or rate specified (e.g calcul...
# 9                        Maximum dose for the patient
# 10   Upper limit on medication per one administration
# 11  Upper limit on medication per lifetime of the ...
# 12         Upper limit on medication per unit of time
# 13                           Method of administration
# 14         Patient oriented instructions as free text
# 15  Text representation rendered from all dosaging...
# 16                            Route of administration
# 17  Order of the dosage instruction, in case one t...
# 18  Free text usage/dosage instructions when struc...
# 19  When medication should be administered (period...
# 20  Timing abbreviation (AM - morning, Q4H - once ...
# 21       Exact date and/or time of the administration
# 22                  Repetition of the administration.
# 23  Time bounds for the treatment (current dosagin...
# 24                  Number of time units, e.g 10 days
# 25        Start and end date, 05.08.2023 - 10.08.2023
# 26        A range of numbers of time units, 5-10 days
# 27          Number of times to repeat, exact or range
# 28           Number of times (e.g 'once', '10 times')
# 29   Maximum number of times (e.g 'maximum 10 times')
# 30  The day of the week of administration, e.g Mon...
# 31     Duration of one administration, exact or range
# 32  Duration of administration (e.g '5 minutes', '...
# 33  Maximum duration of administration (e.g 'maxim...
# 34  An event the administration is bound to, e.g '...
# 35  minutes from event, before or after (?not sure...
# 36  Time period or event ('before meal', 'immediat...
# 37  Frequency of intake/administration (e.g 'three...
# 38  Maximum number of times per period (e.g. 'maxi...
# 39         Number of times per period (e.g '3 times')
# 40  Duration to which the frequency applies (e.g '...
# 41    Upper limit of the period (e.g ... / 4-6 hours)
# 42        Time of day of administration (e.g '10:00')
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
#
#                                      definition_xtehr       type_xtehr  \
# 0   Logical model for usage instructions for admin...              NaN
# 1   Coded instructions, e.g warnings to the patien...  CodeableConcept
# 2                                      Take as needed          boolean
# 3                 Take as needed for the coded reason  CodeableConcept
# 4                         Body site of administration  CodeableConcept
# 5   Amount of medication administered per one dose...             Base
# 6   Amount of medication per one dose. (1 tablet, ...         Quantity
# 7   Time period during which one defined dose is a...            Ratio
# 8   The kind of dose or rate specified (e.g calcul...  CodeableConcept
# 9                        Maximum dose for the patient             Base
# 10   Upper limit on medication per one administration         Quantity
# 11  Upper limit on medication per lifetime of the ...         Quantity
# 12         Upper limit on medication per unit of time            Ratio
# 13                           Method of administration  CodeableConcept
# 14         Patient oriented instructions as free text           string
# 15  Text representation rendered from all dosaging...           string
# 16                            Route of administration  CodeableConcept
# 17  Order of the dosage instruction, in case one t...          integer
# 18  Free text usage/dosage instructions when struc...           string
# 19  When medication should be administered (period...             Base
# 20  Timing abbreviation (AM - morning, Q4H - once ...  CodeableConcept
# 21       Exact date and/or time of the administration         dateTime
# 22                  Repetition of the administration.             Base
# 23  Time bounds for the treatment (current dosagin...             Base
# 24                  Number of time units, e.g 10 days         Quantity
# 25        Start and end date, 05.08.2023 - 10.08.2023           Period
# 26        A range of numbers of time units, 5-10 days            Range
# 27          Number of times to repeat, exact or range             Base
# 28           Number of times (e.g 'once', '10 times')          integer
# 29   Maximum number of times (e.g 'maximum 10 times')          integer
# 30  The day of the week of administration, e.g Mon...  CodeableConcept
# 31     Duration of one administration, exact or range             Base
# 32  Duration of administration (e.g '5 minutes', '...         Quantity
# 33  Maximum duration of administration (e.g 'maxim...         Quantity
# 34  An event the administration is bound to, e.g '...             Base
# 35  minutes from event, before or after (?not sure...          integer
# 36  Time period or event ('before meal', 'immediat...  CodeableConcept
# 37  Frequency of intake/administration (e.g 'three...             Base
# 38  Maximum number of times per period (e.g. 'maxi...          integer
# 39         Number of times per period (e.g '3 times')          integer
# 40  Duration to which the frequency applies (e.g '...         Quantity
# 41    Upper limit of the period (e.g ... / 4-6 hours)         Quantity
# 42        Time of day of administration (e.g '10:00')             time
# 43                                                NaN              NaN
# 44                                                NaN              NaN
# 45                                                NaN              NaN
# 46                                                NaN              NaN
# 47                                                NaN              NaN
# 48                                                NaN              NaN
# 49                                                NaN              NaN
# 50                                                NaN              NaN
#
#    card._xtehr
# 0         0..*
# 1         0..*
# 2         0..1
# 3         0..*
# 4         0..1
# 5         0..*
# 6         0..1
# 7         0..1
# 8         0..1
# 9         0..*
# 10        0..1
# 11        0..1
# 12        0..*
# 13        0..1
# 14        0..1
# 15        0..1
# 16        0..1
# 17        0..1
# 18        0..1
# 19        0..1
# 20        0..1
# 21        0..*
# 22        0..1
# 23        0..1
# 24        0..1
# 25        0..1
# 26        0..1
# 27        0..1
# 28        0..1
# 29        0..1
# 30        0..*
# 31        0..1
# 32        0..1
# 33        0..1
# 34        0..*
# 35        0..1
# 36        0..*
# 37        0..1
# 38        0..1
# 39        0..1
# 40        0..1
# 41        0..1
# 42        0..*
# 43         NaN
# 44         NaN
# 45         NaN
# 46         NaN
# 47         NaN
# 48         NaN
# 49         NaN
# 50         NaN

# %%
shortmap = mapping[['zib', 'xtehr', 'type_zib','type_xtehr', 'card._zib', 'card._xtehr']]
shortmap
# Out:
#                                                   zib  \
# 0                                  InstructionsForUse
# 1           InstructionsForUse.AdditionalInstructions
# 2                                                 NaN
# 3   InstructionsForUse.DosingInstructions.Dosage.A...
# 4                                                 NaN
# 5                                                 NaN
# 6   InstructionsForUse.DosingInstructions.Dosage.D...
# 7   InstructionsForUse.DosingInstructions.Dosage.A...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16           InstructionsForUse.RouteOfAdministration
# 17  InstructionsForUse.DosingInstructions.Sequence...
# 18                     InstructionsForUse.Description
# 19  InstructionsForUse.DosingInstructions.Dosage.A...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  InstructionsForUse.DosingInstructions.DoseDura...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30  InstructionsForUse.DosingInstructions.Dosage.A...
# 31                                                NaN
# 32  InstructionsForUse.DosingInstructions.Dosage.D...
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39  InstructionsForUse.DosingInstructions.Dosage.A...
# 40                                                NaN
# 41                                                NaN
# 42  InstructionsForUse.DosingInstructions.Dosage.A...
# 43              InstructionsForUse.DosingInstructions
# 44       InstructionsForUse.DosingInstructions.Dosage
# 45  InstructionsForUse.DosingInstructions.Dosage.A...
# 46  InstructionsForUse.DosingInstructions.Dosage.A...
# 47  InstructionsForUse.DosingInstructions.Dosage.A...
# 48  InstructionsForUse.DosingInstructions.Dosage.A...
# 49  InstructionsForUse.DosingInstructions.Dosage.A...
# 50    InstructionsForUse.RepeatPeriodCyclicalSchedule
#
#                                                 xtehr type_zib  \
# 0                                        EHDSDosaging      NaN
# 1                  EHDSDosaging.additionalInstruction       CD
# 2                               EHDSDosaging.asNeeded      NaN
# 3                            EHDSDosaging.asNeededFor       CD
# 4                               EHDSDosaging.bodySite      NaN
# 5                            EHDSDosaging.doseAndRate      NaN
# 6                    EHDSDosaging.doseAndRate.dose[x]      NaN
# 7                    EHDSDosaging.doseAndRate.rate[x]      NaN
# 8                       EHDSDosaging.doseAndRate.type      NaN
# 9                                EHDSDosaging.maxDose      NaN
# 10      EHDSDosaging.maxDose.maxDosePerAdministration      NaN
# 11            EHDSDosaging.maxDose.maxDosePerLifetime      NaN
# 12              EHDSDosaging.maxDose.maxDosePerPeriod      NaN
# 13                EHDSDosaging.methodOfAdministration      NaN
# 14                    EHDSDosaging.patientInstruction      NaN
# 15                   EHDSDosaging.renderedDescription      NaN
# 16                 EHDSDosaging.routeOfAdministration       CD
# 17                              EHDSDosaging.sequence      INT
# 18                                  EHDSDosaging.text       ST
# 19                                EHDSDosaging.timing      NaN
# 20                           EHDSDosaging.timing.code      NaN
# 21                          EHDSDosaging.timing.event      NaN
# 22                         EHDSDosaging.timing.repeat      NaN
# 23                  EHDSDosaging.timing.repeat.bounds      NaN
# 24         EHDSDosaging.timing.repeat.bounds.duration       PQ
# 25           EHDSDosaging.timing.repeat.bounds.period      NaN
# 26            EHDSDosaging.timing.repeat.bounds.range      NaN
# 27                   EHDSDosaging.timing.repeat.count      NaN
# 28             EHDSDosaging.timing.repeat.count.count      NaN
# 29          EHDSDosaging.timing.repeat.count.countMax      NaN
# 30               EHDSDosaging.timing.repeat.dayOfWeek       CD
# 31                EHDSDosaging.timing.repeat.duration      NaN
# 32       EHDSDosaging.timing.repeat.duration.duration      NaN
# 33    EHDSDosaging.timing.repeat.duration.durationMax      NaN
# 34               EHDSDosaging.timing.repeat.eventTime      NaN
# 35        EHDSDosaging.timing.repeat.eventTime.offset      NaN
# 36          EHDSDosaging.timing.repeat.eventTime.when      NaN
# 37               EHDSDosaging.timing.repeat.frequency      NaN
# 38  EHDSDosaging.timing.repeat.frequency.maxNumber...      NaN
# 39  EHDSDosaging.timing.repeat.frequency.numberOfT...      NaN
# 40        EHDSDosaging.timing.repeat.frequency.period      NaN
# 41     EHDSDosaging.timing.repeat.frequency.periodMax      NaN
# 42               EHDSDosaging.timing.repeat.timeOfDay       TS
# 43                                                NaN      NaN
# 44                                                NaN      NaN
# 45                                                NaN      NaN
# 46                                                NaN       PQ
# 47                                                NaN       CD
# 48                                                NaN      NaN
# 49                                                NaN       PQ
# 50                                                NaN       PQ
#
#          type_xtehr card._zib card._xtehr
# 0               NaN       NaN        0..*
# 1   CodeableConcept      0..*        0..*
# 2           boolean       NaN        0..1
# 3   CodeableConcept      0..*        0..*
# 4   CodeableConcept       NaN        0..1
# 5              Base       NaN        0..*
# 6          Quantity      0..1        0..1
# 7             Ratio      0..1        0..1
# 8   CodeableConcept       NaN        0..1
# 9              Base       NaN        0..*
# 10         Quantity       NaN        0..1
# 11         Quantity       NaN        0..1
# 12            Ratio       NaN        0..*
# 13  CodeableConcept       NaN        0..1
# 14           string       NaN        0..1
# 15           string       NaN        0..1
# 16  CodeableConcept      0..1        0..1
# 17          integer      0..1        0..1
# 18           string      0..1        0..1
# 19             Base      0..1        0..1
# 20  CodeableConcept       NaN        0..1
# 21         dateTime       NaN        0..*
# 22             Base       NaN        0..1
# 23             Base       NaN        0..1
# 24         Quantity      0..1        0..1
# 25           Period       NaN        0..1
# 26            Range       NaN        0..1
# 27             Base       NaN        0..1
# 28          integer       NaN        0..1
# 29          integer       NaN        0..1
# 30  CodeableConcept      0..*        0..*
# 31             Base       NaN        0..1
# 32         Quantity      0..1        0..1
# 33         Quantity       NaN        0..1
# 34             Base       NaN        0..*
# 35          integer       NaN        0..1
# 36  CodeableConcept       NaN        0..*
# 37             Base       NaN        0..1
# 38          integer       NaN        0..1
# 39          integer      0..1        0..1
# 40         Quantity       NaN        0..1
# 41         Quantity       NaN        0..1
# 42             time      0..*        0..*
# 43              NaN      0..*         NaN
# 44              NaN      0..*         NaN
# 45              NaN      0..1         NaN
# 46              NaN      0..1         NaN
# 47              NaN      0..*         NaN
# 48              NaN      0..1         NaN
# 49              NaN      0..1         NaN
# 50              NaN      0..1         NaN

# %%
mapsoutpath = os.path.join(mapbase, 'xtehr2zibs2024')
filepath = file.replace('.xlsx', '-full.xlsx')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_excel(mappath, index=False)

# %%
filepath = file.replace('.xlsx', '.csv')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_csv(mappath, index=False)

# %%
from IPython.display import Markdown
import numpy as np

content = "# " + mapping.iat[0, 0][4:] + "\n\n"

# shortmap: linefeeds naar <br> vlak vóór to_markdown
shortmap_md = shortmap.fillna('').map(
    lambda x: x.replace("\r\n", "<br>").replace("\n", "<br>") if isinstance(x, str) else x
)
content += shortmap_md.to_markdown(index=False) + "\n\n"

for i, row in mapping.iterrows():
    content += "\n\n"
    if row.iloc[0] is not np.nan:  # desgewenst: gebruik pd.notna(row.iloc[0])
        content += "## " + str(row.iloc[0]) + "\n\n"
    else:
        content += "## zib: " + str(row.iloc[1]) + "\n\n"

    content += "### Table" + "\n\n"
    content += "| attribute | value |\n|---|---|\n"

    # Eerste 2 kolommen
    for j, att in row.fillna('')[0:2].items():
        content += "| " + str(j) + " | " + (att.replace("\r\n","<br>").replace("\n","<br>") if isinstance(att, str) else str(att)) + " |\n" 

    # Rest, gesorteerd
    for j, att in row.fillna('')[2:].sort_index().items():
        if len(str(att)) > 0:
            content += "| " + str(j) + " | " + (att.replace("\r\n","<br>").replace("\n","<br>") if isinstance(att, str) else str(att)) + " |\n"

    content += "\n### Comments\n\n"

with open(os.path.join(mapsoutpath, file.replace('.xlsx', '.md')), 'w') as f:
    f.write(content)

# PAS OP: deze overschrijft de evt. handmatige comments; alleen bij eerste keer mapping
# with open(os.path.join(mapsoutpath, file.replace('.xlsx', '-comments.md')), 'w') as f:
#     f.write(content)

Markdown(content)
# Out:
# # Dosaging
#
# | zib                                                                                   | xtehr                                                 | type_zib   | type_xtehr      | card._zib   | card._xtehr   |
# |:--------------------------------------------------------------------------------------|:------------------------------------------------------|:-----------|:----------------|:------------|:--------------|
# | InstructionsForUse                                                                    | EHDSDosaging                                          |            |                 |             | 0..*          |
# | InstructionsForUse.AdditionalInstructions                                             | EHDSDosaging.additionalInstruction                    | CD         | CodeableConcept | 0..*        | 0..*          |
# |                                                                                       | EHDSDosaging.asNeeded                                 |            | boolean         |             | 0..1          |
# | InstructionsForUse.DosingInstructions.Dosage.AsNeeded.Condition                       | EHDSDosaging.asNeededFor                              | CD         | CodeableConcept | 0..*        | 0..*          |
# |                                                                                       | EHDSDosaging.bodySite                                 |            | CodeableConcept |             | 0..1          |
# |                                                                                       | EHDSDosaging.doseAndRate                              |            | Base            |             | 0..*          |
# | InstructionsForUse.DosingInstructions.Dosage.Dose::Range                              | EHDSDosaging.doseAndRate.dose[x]                      |            | Quantity        | 0..1        | 0..1          |
# | InstructionsForUse.DosingInstructions.Dosage.AdministeringSpeed::Range                | EHDSDosaging.doseAndRate.rate[x]                      |            | Ratio           | 0..1        | 0..1          |
# |                                                                                       | EHDSDosaging.doseAndRate.type                         |            | CodeableConcept |             | 0..1          |
# |                                                                                       | EHDSDosaging.maxDose                                  |            | Base            |             | 0..*          |
# |                                                                                       | EHDSDosaging.maxDose.maxDosePerAdministration         |            | Quantity        |             | 0..1          |
# |                                                                                       | EHDSDosaging.maxDose.maxDosePerLifetime               |            | Quantity        |             | 0..1          |
# |                                                                                       | EHDSDosaging.maxDose.maxDosePerPeriod                 |            | Ratio           |             | 0..*          |
# |                                                                                       | EHDSDosaging.methodOfAdministration                   |            | CodeableConcept |             | 0..1          |
# |                                                                                       | EHDSDosaging.patientInstruction                       |            | string          |             | 0..1          |
# |                                                                                       | EHDSDosaging.renderedDescription                      |            | string          |             | 0..1          |
# | InstructionsForUse.RouteOfAdministration                                              | EHDSDosaging.routeOfAdministration                    | CD         | CodeableConcept | 0..1        | 0..1          |
# | InstructionsForUse.DosingInstructions.SequenceNumber                                  | EHDSDosaging.sequence                                 | INT        | integer         | 0..1        | 0..1          |
# | InstructionsForUse.Description                                                        | EHDSDosaging.text                                     | ST         | string          | 0..1        | 0..1          |
# | InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule                    | EHDSDosaging.timing                                   |            | Base            | 0..1        | 0..1          |
# |                                                                                       | EHDSDosaging.timing.code                              |            | CodeableConcept |             | 0..1          |
# |                                                                                       | EHDSDosaging.timing.event                             |            | dateTime        |             | 0..*          |
# |                                                                                       | EHDSDosaging.timing.repeat                            |            | Base            |             | 0..1          |
# |                                                                                       | EHDSDosaging.timing.repeat.bounds                     |            | Base            |             | 0..1          |
# | InstructionsForUse.DosingInstructions.DoseDuration                                    | EHDSDosaging.timing.repeat.bounds.duration            | PQ         | Quantity        | 0..1        | 0..1          |
# |                                                                                       | EHDSDosaging.timing.repeat.bounds.period              |            | Period          |             | 0..1          |
# |                                                                                       | EHDSDosaging.timing.repeat.bounds.range               |            | Range           |             | 0..1          |
# |                                                                                       | EHDSDosaging.timing.repeat.count                      |            | Base            |             | 0..1          |
# |                                                                                       | EHDSDosaging.timing.repeat.count.count                |            | integer         |             | 0..1          |
# |                                                                                       | EHDSDosaging.timing.repeat.count.countMax             |            | integer         |             | 0..1          |
# | InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule.WeekDay            | EHDSDosaging.timing.repeat.dayOfWeek                  | CD         | CodeableConcept | 0..*        | 0..*          |
# |                                                                                       | EHDSDosaging.timing.repeat.duration                   |            | Base            |             | 0..1          |
# | InstructionsForUse.DosingInstructions.Dosage.DurationOfAdministration::TimeInterval   | EHDSDosaging.timing.repeat.duration.duration          |            | Quantity        | 0..1        | 0..1          |
# |                                                                                       | EHDSDosaging.timing.repeat.duration.durationMax       |            | Quantity        |             | 0..1          |
# |                                                                                       | EHDSDosaging.timing.repeat.eventTime                  |            | Base            |             | 0..*          |
# |                                                                                       | EHDSDosaging.timing.repeat.eventTime.offset           |            | integer         |             | 0..1          |
# |                                                                                       | EHDSDosaging.timing.repeat.eventTime.when             |            | CodeableConcept |             | 0..*          |
# |                                                                                       | EHDSDosaging.timing.repeat.frequency                  |            | Base            |             | 0..1          |
# |                                                                                       | EHDSDosaging.timing.repeat.frequency.maxNumberOfTimes |            | integer         |             | 0..1          |
# | InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule.Frequency::Range   | EHDSDosaging.timing.repeat.frequency.numberOfTimes    |            | integer         | 0..1        | 0..1          |
# |                                                                                       | EHDSDosaging.timing.repeat.frequency.period           |            | Quantity        |             | 0..1          |
# |                                                                                       | EHDSDosaging.timing.repeat.frequency.periodMax        |            | Quantity        |             | 0..1          |
# | InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule.AdministrationTime | EHDSDosaging.timing.repeat.timeOfDay                  | TS         | time            | 0..*        | 0..*          |
# | InstructionsForUse.DosingInstructions                                                 |                                                       |            |                 | 0..*        |               |
# | InstructionsForUse.DosingInstructions.Dosage                                          |                                                       |            |                 | 0..*        |               |
# | InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule                    |                                                       |            |                 | 0..1        |               |
# | InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule.Interval           |                                                       | PQ         |                 | 0..1        |               |
# | InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule.PartOfDay          |                                                       | CD         |                 | 0..*        |               |
# | InstructionsForUse.DosingInstructions.Dosage.AsNeeded                                 |                                                       |            |                 | 0..1        |               |
# | InstructionsForUse.DosingInstructions.Dosage.AsNeeded.MaximumDose                     |                                                       | PQ         |                 | 0..1        |               |
# | InstructionsForUse.RepeatPeriodCyclicalSchedule                                       |                                                       | PQ         |                 | 0..1        |               |
#
#
#
# ## EHDSDosaging
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging |
# | zib | InstructionsForUse |
# | alias_zib | NL: GebruiksInstructie |
# | card._xtehr | 0..* |
# | definition_xtehr | Logical model for usage instructions for administring the requested product. Based on FHIR Dosage complex data type. When implemented, this model may be reduced significantly according to the specific use case. |
# | definition_zib | Root concept of the InstructionsForUse partial information model. This root concept contains all data elements of the InstructionsForUse partial information model. |
# | id_xtehr | EHDSDosaging |
# | id_zib | NL-CM:9.12.22504 |
# | name_zib | InstructionsForUse |
# | path_xtehr | EHDSDosaging |
# | path_zib | InstructionsForUse |
# | short_xtehr | Dosaging model |
# | stereotype_zib | rootconcept |
#
# ### Comments
#
#
#
# ## EHDSDosaging.additionalInstruction
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.additionalInstruction |
# | zib | InstructionsForUse.AdditionalInstructions |
# | alias_zib | NL: AanvullendeInstructies |
# | card._xtehr | 0..* |
# | card._zib | 0..* |
# | definition_xtehr | Coded instructions, e.g warnings to the patient, like 'may cause drowsiness' etc |
# | definition_zib | The additional instructions contain extra information on the use of the current prescription.<br>This includes all instructions for use. The text can come from the original “paper" medication prescription, but can also be generated from the coded information. <br>This concept may contain more information than what is structurally coded in the information below, but may not conflict with it. <br>The instructions may not conflict with other components of the request for administration. <br>The instructions can also refer to an existing protocol. <br>The texts in the G-standard that can support this attribute are included in table 362 and are a copy of the texts from the general practitioner' standard 'NHG-tabel Gebruiksvoorschrift' which are included in the CIM. These texts can be used to structure this concept. |
# | id_xtehr | EHDSDosaging.additionalInstruction |
# | id_zib | NL-CM:9.12.19944 |
# | name_zib | AdditionalInstructions |
# | path_xtehr | EHDSDosaging.additionalInstruction |
# | path_zib | InstructionsForUse.AdditionalInstructions |
# | short_xtehr | Coded instructions, e.g warnings to the patient, like 'may cause drowsiness' etc |
# | stereotype_zib | data |
# | type_xtehr | CodeableConcept |
# | type_zib | CD |
#
# ### Comments
#
#
#
# ## EHDSDosaging.asNeeded
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.asNeeded |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Take as needed |
# | id_xtehr | EHDSDosaging.asNeeded |
# | path_xtehr | EHDSDosaging.asNeeded |
# | short_xtehr | Take as needed |
# | type_xtehr | boolean |
#
# ### Comments
#
#
#
# ## EHDSDosaging.asNeededFor
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.asNeededFor |
# | zib | InstructionsForUse.DosingInstructions.Dosage.AsNeeded.Condition |
# | alias_zib | NL: Criterium |
# | card._xtehr | 0..* |
# | card._zib | 0..* |
# | definition_xtehr | Take as needed for the coded reason |
# | definition_zib | The condition for administering medication can be: <br>-  a physiological measurement value (plasma glucose concentration, body temperature, blood pressure);<br>-  a symptom or other circumstance (in the event of a headache, or itch).<br>Supplemental information from G-standard bst362 make up the list of values for coded entering of this concept. Also always include the textual description of that code. <br>Physiological measurement values or other conditions that do not occur in bst362 do not need to be coded. These can be expressed in free text in the Description concept. |
# | id_xtehr | EHDSDosaging.asNeededFor |
# | id_zib | NL-CM:9.12.19945 |
# | name_zib | AsNeeded.Condition |
# | path_xtehr | EHDSDosaging.asNeededFor |
# | path_zib | InstructionsForUse.DosingInstructions.Dosage.AsNeeded.Condition |
# | short_xtehr | Take as needed for the coded reason |
# | stereotype_zib | data |
# | type_xtehr | CodeableConcept |
# | type_zib | CD |
#
# ### Comments
#
#
#
# ## EHDSDosaging.bodySite
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.bodySite |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Body site of administration |
# | id_xtehr | EHDSDosaging.bodySite |
# | path_xtehr | EHDSDosaging.bodySite |
# | short_xtehr | Body site of administration |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSDosaging.doseAndRate
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.doseAndRate |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | Amount of medication administered per one dose (= one timing) |
# | id_xtehr | EHDSDosaging.doseAndRate |
# | path_xtehr | EHDSDosaging.doseAndRate |
# | short_xtehr | Amount of medication administered per one dose (= one timing) |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSDosaging.doseAndRate.dose[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.doseAndRate.dose[x] |
# | zib | InstructionsForUse.DosingInstructions.Dosage.Dose::Range |
# | alias_zib | NL: Keerdosis::Bereik |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Amount of medication per one dose. (1 tablet, 2-3 tablets, 20ml) |
# | definition_zib | The dose indicates the amount/unit per administration. The unit can be any unit that can occur with this particular medicine. |
# | id_xtehr | EHDSDosaging.doseAndRate.dose[x] |
# | id_zib | NL-CM:9.12.19940 |
# | name_zib | Dose::Range |
# | path_xtehr | EHDSDosaging.doseAndRate.dose[x] |
# | path_zib | InstructionsForUse.DosingInstructions.Dosage.Dose::Range |
# | short_xtehr | Amount of medication per one dose. (1 tablet, 2-3 tablets, 20ml) |
# | stereotype_zib | data,reference |
# | type_xtehr | Quantity |
#
# ### Comments
#
#
#
# ## EHDSDosaging.doseAndRate.rate[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.doseAndRate.rate[x] |
# | zib | InstructionsForUse.DosingInstructions.Dosage.AdministeringSpeed::Range |
# | alias_zib | NL: Toedieningssnelheid::Bereik |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Time period during which one defined dose is administered (per 1 hour, per 5-10 minutes) |
# | definition_zib | The administering speed is used in slow administration of liquid. In practice, the measuring unit is almost always ml/hour. <br>Entering an interval (such as 0-10 ml/hour) is also a commonly used option. <br><br>For example, with an administering speed of 10ml/hour: <br>-  amount = 10, <br>  <li>dose unit = ml, <br>  <li>time unit = hour <br>-  dose unit = ml, <br>  <li>time unit = hour <br>-  time unit = hour  |
# | id_xtehr | EHDSDosaging.doseAndRate.rate[x] |
# | id_zib | NL-CM:9.12.19942 |
# | name_zib | AdministeringSpeed::Range |
# | path_xtehr | EHDSDosaging.doseAndRate.rate[x] |
# | path_zib | InstructionsForUse.DosingInstructions.Dosage.AdministeringSpeed::Range |
# | short_xtehr | Time period during which one defined dose is administered (per 1 hour, per 5-10 minutes) |
# | stereotype_zib | data,reference |
# | type_xtehr | Ratio |
#
# ### Comments
#
#
#
# ## EHDSDosaging.doseAndRate.type
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.doseAndRate.type |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | The kind of dose or rate specified (e.g calculated, ordered, etc). |
# | id_xtehr | EHDSDosaging.doseAndRate.type |
# | path_xtehr | EHDSDosaging.doseAndRate.type |
# | short_xtehr | The kind of dose or rate specified (e.g calculated, ordered, etc). |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSDosaging.maxDose
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.maxDose |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | Maximum dose for the patient |
# | id_xtehr | EHDSDosaging.maxDose |
# | path_xtehr | EHDSDosaging.maxDose |
# | short_xtehr | Maximum dose for the patient |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSDosaging.maxDose.maxDosePerAdministration
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.maxDose.maxDosePerAdministration |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Upper limit on medication per one administration |
# | id_xtehr | EHDSDosaging.maxDose.maxDosePerAdministration |
# | path_xtehr | EHDSDosaging.maxDose.maxDosePerAdministration |
# | short_xtehr | Upper limit on medication per one administration |
# | type_xtehr | Quantity |
#
# ### Comments
#
#
#
# ## EHDSDosaging.maxDose.maxDosePerLifetime
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.maxDose.maxDosePerLifetime |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Upper limit on medication per lifetime of the patient |
# | id_xtehr | EHDSDosaging.maxDose.maxDosePerLifetime |
# | path_xtehr | EHDSDosaging.maxDose.maxDosePerLifetime |
# | short_xtehr | Upper limit on medication per lifetime of the patient |
# | type_xtehr | Quantity |
#
# ### Comments
#
#
#
# ## EHDSDosaging.maxDose.maxDosePerPeriod
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.maxDose.maxDosePerPeriod |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | Upper limit on medication per unit of time |
# | id_xtehr | EHDSDosaging.maxDose.maxDosePerPeriod |
# | path_xtehr | EHDSDosaging.maxDose.maxDosePerPeriod |
# | short_xtehr | Upper limit on medication per unit of time |
# | type_xtehr | Ratio |
#
# ### Comments
#
#
#
# ## EHDSDosaging.methodOfAdministration
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.methodOfAdministration |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Method of administration |
# | id_xtehr | EHDSDosaging.methodOfAdministration |
# | path_xtehr | EHDSDosaging.methodOfAdministration |
# | short_xtehr | Method of administration |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSDosaging.patientInstruction
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.patientInstruction |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Patient oriented instructions as free text |
# | id_xtehr | EHDSDosaging.patientInstruction |
# | path_xtehr | EHDSDosaging.patientInstruction |
# | short_xtehr | Patient oriented instructions as free text |
# | type_xtehr | string |
#
# ### Comments
#
#
#
# ## EHDSDosaging.renderedDescription
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.renderedDescription |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Text representation rendered from all dosaging data elements with a value |
# | id_xtehr | EHDSDosaging.renderedDescription |
# | path_xtehr | EHDSDosaging.renderedDescription |
# | short_xtehr | Text representation rendered from all dosaging data elements with a value |
# | type_xtehr | string |
#
# ### Comments
#
#
#
# ## EHDSDosaging.routeOfAdministration
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.routeOfAdministration |
# | zib | InstructionsForUse.RouteOfAdministration |
# | alias_zib | NL: Toedieningsweg |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Route of administration |
# | definition_zib | The route through which the medication is administered (oral, nasal, intravenous, etc.). |
# | id_xtehr | EHDSDosaging.routeOfAdministration |
# | id_zib | NL-CM:9.12.19941 |
# | name_zib | RouteOfAdministration |
# | path_xtehr | EHDSDosaging.routeOfAdministration |
# | path_zib | InstructionsForUse.RouteOfAdministration |
# | short_xtehr | Route of administration |
# | stereotype_zib | data |
# | type_xtehr | CodeableConcept |
# | type_zib | CD |
#
# ### Comments
#
#
#
# ## EHDSDosaging.sequence
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.sequence |
# | zib | InstructionsForUse.DosingInstructions.SequenceNumber |
# | alias_zib | NL: Volgnummer |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Order of the dosage instruction, in case one treatment consists of several dosaging schemes |
# | definition_zib | This indicates the sequence of the dosing instructions within the medication agreement. |
# | id_xtehr | EHDSDosaging.sequence |
# | id_zib | NL-CM:9.12.22503 |
# | name_zib | SequenceNumber |
# | path_xtehr | EHDSDosaging.sequence |
# | path_zib | InstructionsForUse.DosingInstructions.SequenceNumber |
# | short_xtehr | Order of the dosage instruction, in case one treatment consists of several dosaging schemes |
# | stereotype_zib | data |
# | type_xtehr | integer |
# | type_zib | INT |
#
# ### Comments
#
#
#
# ## EHDSDosaging.text
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.text |
# | zib | InstructionsForUse.Description |
# | alias_zib | NL: Omschrijving |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Free text usage/dosage instructions when structured dosage information is not fully provided |
# | definition_zib | Textual description of the complete instructions for use including the period of use. |
# | id_xtehr | EHDSDosaging.text |
# | id_zib | NL-CM:9.12.9581 |
# | name_zib | Description |
# | path_xtehr | EHDSDosaging.text |
# | path_zib | InstructionsForUse.Description |
# | short_xtehr | Free text usage/dosage instructions when structured dosage information is not fully provided |
# | stereotype_zib | data |
# | type_xtehr | string |
# | type_zib | ST |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing |
# | zib | InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule |
# | alias_zib | NL: Toedieningsschema |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | When medication should be administered (period, time of day, frequency, etc) |
# | definition_zib | Specifications of the times at which the medication is to be administered. This is indicated as follows: <br>-  Time(s) (16:00) or indications (“before meals”) at which the medication is to be taken each day.<br>-  A specific number of times the medication is to be taken each day ("3x a day"), indicated with the frequency.<br>-  A time interval between consecutive doses (“Every 2 hours”, “every 3 days”), indicated with the word Interval.<br>-  Combined periods with an interval and duration (“1 daily for three out of four weeks: the pill schedule”)<br><br>If a certain medication is not to be taken daily, the aforementioned can be combined with daily indications: <br>-  One or more week days on which the medication is to be administered (e.g. “Monday, Wednesday, Friday”)<br>-  ”3x a week”, “2x a month”.<br><br>The specified administration “infinite” is automatically to be repeated until:  <br>-  The end date and time has been reached<br>-  The total administration duration has been reached (14 days)<br>-  A specific amount of administrations has been reached (“20 doses”), to be entered in the Frequency concept. |
# | id_xtehr | EHDSDosaging.timing |
# | id_zib | NL-CM:9.12.19948 |
# | name_zib | AdministeringSchedule |
# | path_xtehr | EHDSDosaging.timing |
# | path_zib | InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule |
# | short_xtehr | When medication should be administered (period, time of day, frequency, etc) |
# | stereotype_zib | container |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.code
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.code |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Timing abbreviation (AM - morning, Q4H - once in every 4 hours, BID - twice a day, etc) |
# | id_xtehr | EHDSDosaging.timing.code |
# | path_xtehr | EHDSDosaging.timing.code |
# | short_xtehr | Timing abbreviation (AM - morning, Q4H - once in every 4 hours, BID - twice a day, etc) |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.event
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.event |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | Exact date and/or time of the administration |
# | id_xtehr | EHDSDosaging.timing.event |
# | path_xtehr | EHDSDosaging.timing.event |
# | short_xtehr | Exact date and/or time of the administration |
# | type_xtehr | dateTime |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.repeat
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.repeat |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Repetition of the administration. |
# | id_xtehr | EHDSDosaging.timing.repeat |
# | path_xtehr | EHDSDosaging.timing.repeat |
# | short_xtehr | Repetition of the administration. |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.repeat.bounds
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.repeat.bounds |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Time bounds for the treatment (current dosaging scheme). Only one of the following can exist. |
# | id_xtehr | EHDSDosaging.timing.repeat.bounds |
# | path_xtehr | EHDSDosaging.timing.repeat.bounds |
# | short_xtehr | Time bounds for the treatment (current dosaging scheme). Only one of the following can exist. |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.repeat.bounds.duration
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.repeat.bounds.duration |
# | zib | InstructionsForUse.DosingInstructions.DoseDuration |
# | alias_zib | NL: Doseerduur |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Number of time units, e.g 10 days |
# | definition_zib | The intended time duration for these dosing instructions, e.g. 5 days or 8 weeks. <br>In the case of medication for an indefinite period, the dosing duration is left empty in the last dosing instruction.<br>Permitted units for the duration: hour, day, week, year. |
# | id_xtehr | EHDSDosaging.timing.repeat.bounds.duration |
# | id_zib | NL-CM:9.12.22506 |
# | name_zib | DoseDuration |
# | path_xtehr | EHDSDosaging.timing.repeat.bounds.duration |
# | path_zib | InstructionsForUse.DosingInstructions.DoseDuration |
# | short_xtehr | Number of time units, e.g 10 days |
# | stereotype_zib | data |
# | type_xtehr | Quantity |
# | type_zib | PQ |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.repeat.bounds.period
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.repeat.bounds.period |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Start and end date, 05.08.2023 - 10.08.2023 |
# | id_xtehr | EHDSDosaging.timing.repeat.bounds.period |
# | path_xtehr | EHDSDosaging.timing.repeat.bounds.period |
# | short_xtehr | Start and end date, 05.08.2023 - 10.08.2023 |
# | type_xtehr | Period |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.repeat.bounds.range
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.repeat.bounds.range |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | A range of numbers of time units, 5-10 days |
# | id_xtehr | EHDSDosaging.timing.repeat.bounds.range |
# | path_xtehr | EHDSDosaging.timing.repeat.bounds.range |
# | short_xtehr | A range of numbers of time units, 5-10 days |
# | type_xtehr | Range |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.repeat.count
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.repeat.count |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Number of times to repeat, exact or range |
# | id_xtehr | EHDSDosaging.timing.repeat.count |
# | path_xtehr | EHDSDosaging.timing.repeat.count |
# | short_xtehr | Number of times to repeat, exact or range |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.repeat.count.count
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.repeat.count.count |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Number of times (e.g 'once', '10 times') |
# | id_xtehr | EHDSDosaging.timing.repeat.count.count |
# | path_xtehr | EHDSDosaging.timing.repeat.count.count |
# | short_xtehr | Number of times (e.g 'once', '10 times') |
# | type_xtehr | integer |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.repeat.count.countMax
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.repeat.count.countMax |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Maximum number of times (e.g 'maximum 10 times') |
# | id_xtehr | EHDSDosaging.timing.repeat.count.countMax |
# | path_xtehr | EHDSDosaging.timing.repeat.count.countMax |
# | short_xtehr | Maximum number of times (e.g 'maximum 10 times') |
# | type_xtehr | integer |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.repeat.dayOfWeek
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.repeat.dayOfWeek |
# | zib | InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule.WeekDay |
# | alias_zib | NL: Weekdag |
# | card._xtehr | 0..* |
# | card._zib | 0..* |
# | definition_xtehr | The day of the week of administration, e.g Mon, Tue, etc |
# | definition_zib | WeekDay indicates a pattern of doses on fixed week days. |
# | id_xtehr | EHDSDosaging.timing.repeat.dayOfWeek |
# | id_zib | NL-CM:9.12.19952 |
# | name_zib | AdministeringSchedule.WeekDay |
# | path_xtehr | EHDSDosaging.timing.repeat.dayOfWeek |
# | path_zib | InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule.WeekDay |
# | short_xtehr | The day of the week of administration, e.g Mon, Tue, etc |
# | stereotype_zib | data |
# | type_xtehr | CodeableConcept |
# | type_zib | CD |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.repeat.duration
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.repeat.duration |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Duration of one administration, exact or range |
# | id_xtehr | EHDSDosaging.timing.repeat.duration |
# | path_xtehr | EHDSDosaging.timing.repeat.duration |
# | short_xtehr | Duration of one administration, exact or range |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.repeat.duration.duration
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.repeat.duration.duration |
# | zib | InstructionsForUse.DosingInstructions.Dosage.DurationOfAdministration::TimeInterval |
# | alias_zib | NL: Toedieningsduur::TijdsInterval |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Duration of administration (e.g '5 minutes', '1 hour') |
# | definition_zib | The duration of administration defines the length of time during which the drug is administered and is mainly used in the slow parenteral administration of fluids.<br>Permitted units for the duration: second, minute, hour, day. |
# | id_xtehr | EHDSDosaging.timing.repeat.duration.duration |
# | id_zib | NL-CM:9.12.23141 |
# | name_zib | DurationOfAdministration::TimeInterval |
# | path_xtehr | EHDSDosaging.timing.repeat.duration.duration |
# | path_zib | InstructionsForUse.DosingInstructions.Dosage.DurationOfAdministration::TimeInterval |
# | short_xtehr | Duration of administration (e.g '5 minutes', '1 hour') |
# | stereotype_zib | data,reference |
# | type_xtehr | Quantity |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.repeat.duration.durationMax
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.repeat.duration.durationMax |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Maximum duration of administration (e.g 'maximum 1 hour') |
# | id_xtehr | EHDSDosaging.timing.repeat.duration.durationMax |
# | path_xtehr | EHDSDosaging.timing.repeat.duration.durationMax |
# | short_xtehr | Maximum duration of administration (e.g 'maximum 1 hour') |
# | type_xtehr | Quantity |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.repeat.eventTime
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.repeat.eventTime |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | An event the administration is bound to, e.g 'before meal', '30 min before meal' |
# | id_xtehr | EHDSDosaging.timing.repeat.eventTime |
# | path_xtehr | EHDSDosaging.timing.repeat.eventTime |
# | short_xtehr | An event the administration is bound to, e.g 'before meal', '30 min before meal' |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.repeat.eventTime.offset
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.repeat.eventTime.offset |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | minutes from event, before or after (?not sure how to show before/after with only positive integers) |
# | id_xtehr | EHDSDosaging.timing.repeat.eventTime.offset |
# | path_xtehr | EHDSDosaging.timing.repeat.eventTime.offset |
# | short_xtehr | minutes from event, before or after (?not sure how to show before/after with only positive integers) |
# | type_xtehr | integer |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.repeat.eventTime.when
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.repeat.eventTime.when |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | Time period or event ('before meal', 'immediately', 'morning') |
# | id_xtehr | EHDSDosaging.timing.repeat.eventTime.when |
# | path_xtehr | EHDSDosaging.timing.repeat.eventTime.when |
# | short_xtehr | Time period or event ('before meal', 'immediately', 'morning') |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.repeat.frequency
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.repeat.frequency |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Frequency of intake/administration (e.g 'three times a day') |
# | id_xtehr | EHDSDosaging.timing.repeat.frequency |
# | path_xtehr | EHDSDosaging.timing.repeat.frequency |
# | short_xtehr | Frequency of intake/administration (e.g 'three times a day') |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.repeat.frequency.maxNumberOfTimes
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.repeat.frequency.maxNumberOfTimes |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Maximum number of times per period (e.g. 'maximum 3 times') |
# | id_xtehr | EHDSDosaging.timing.repeat.frequency.maxNumberOfTimes |
# | path_xtehr | EHDSDosaging.timing.repeat.frequency.maxNumberOfTimes |
# | short_xtehr | Maximum number of times per period (e.g. 'maximum 3 times') |
# | type_xtehr | integer |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.repeat.frequency.numberOfTimes
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.repeat.frequency.numberOfTimes |
# | zib | InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule.Frequency::Range |
# | alias_zib | NL: Frequentie::Bereik |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Number of times per period (e.g '3 times') |
# | definition_zib | The frequency indicates the number of dose moments per time unit, usually per day. If this frequency is included, then the Interval will not have been included. Usually, frequency comprises both amount and time unit (3 times a day), but it can occur without the time unit (single use). <br><br>In that case, a reasonable distribution over the day is expected, but exact times are not given. This is left to the patient. It is the most common manner of extramural prescription. In the case of Baxter packs and intramural care, such a prescription is used to draw up a (location-specific) outline for distribution times (logistics). <br><br>The time unit of the frequency must be the same as how it is indicated in the textual description of the dose. <br><br>Example: <br>for a '2x a day...' dose: <br>-  amount = 2 <br>-  time unit = 'day'.<br>for a '3x a week...' dose: <br>-  amount = 3 <br>-  time unit = 'week'.<br><br>Permitted units for the duration: minute, hour, day, week, month, year. |
# | id_xtehr | EHDSDosaging.timing.repeat.frequency.numberOfTimes |
# | id_zib | NL-CM:9.12.19949 |
# | name_zib | AdministeringSchedule.Frequency::Range |
# | path_xtehr | EHDSDosaging.timing.repeat.frequency.numberOfTimes |
# | path_zib | InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule.Frequency::Range |
# | short_xtehr | Number of times per period (e.g '3 times') |
# | stereotype_zib | data,reference |
# | type_xtehr | integer |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.repeat.frequency.period
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.repeat.frequency.period |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Duration to which the frequency applies (e.g '... / 1 day') |
# | id_xtehr | EHDSDosaging.timing.repeat.frequency.period |
# | path_xtehr | EHDSDosaging.timing.repeat.frequency.period |
# | short_xtehr | Duration to which the frequency applies (e.g '... / 1 day') |
# | type_xtehr | Quantity |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.repeat.frequency.periodMax
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.repeat.frequency.periodMax |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Upper limit of the period (e.g ... / 4-6 hours) |
# | id_xtehr | EHDSDosaging.timing.repeat.frequency.periodMax |
# | path_xtehr | EHDSDosaging.timing.repeat.frequency.periodMax |
# | short_xtehr | Upper limit of the period (e.g ... / 4-6 hours) |
# | type_xtehr | Quantity |
#
# ### Comments
#
#
#
# ## EHDSDosaging.timing.repeat.timeOfDay
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDosaging.timing.repeat.timeOfDay |
# | zib | InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule.AdministrationTime |
# | alias_zib | NL: Toedientijd |
# | card._xtehr | 0..* |
# | card._zib | 0..* |
# | definition_xtehr | Time of day of administration (e.g '10:00') |
# | definition_zib | The time of administration is a specific time of day (on the clock). This time usually isn’t (intended to be) exact. There can be multiple administering times in one day. <br> <br>The ideal time of administration can also be entered as a time of day (morning, afternoon, evening, night-time). The administration time is then to be left empty, and the time of day can be entered in the TimeOfDay concept. |
# | id_xtehr | EHDSDosaging.timing.repeat.timeOfDay |
# | id_zib | NL-CM:9.12.19951 |
# | name_zib | AdministeringSchedule.AdministrationTime |
# | path_xtehr | EHDSDosaging.timing.repeat.timeOfDay |
# | path_zib | InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule.AdministrationTime |
# | short_xtehr | Time of day of administration (e.g '10:00') |
# | stereotype_zib | data |
# | type_xtehr | time |
# | type_zib | TS |
#
# ### Comments
#
#
#
# ## zib: InstructionsForUse.DosingInstructions
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | InstructionsForUse.DosingInstructions |
# | alias_zib | NL: Doseerinstructie |
# | card._zib | 0..* |
# | definition_zib | Dosing instructions |
# | id_zib | NL-CM:9.12.22095 |
# | name_zib | DosingInstructions |
# | path_zib | InstructionsForUse.DosingInstructions |
# | stereotype_zib | container |
#
# ### Comments
#
#
#
# ## zib: InstructionsForUse.DosingInstructions.Dosage
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | InstructionsForUse.DosingInstructions.Dosage |
# | alias_zib | NL: Dosering |
# | card._zib | 0..* |
# | definition_zib | Container of the Dosage concept. This container contains all data elements of the Dosage concept. <br> <br>Instructions for the administrator to administer the medication (the patient themselves, a nurse or other aid). When taking stock of medication use, the dosage describes the pattern of use established by the patient. <br> <br>Once the dose schedule (distribution of doses over time) and the dose have been determined, then there should be one single instruction for use. <br> <br>Multiple parallel instructions for use can be included in the event of a changing dose within one day and in the event of a variable use frequency. <br> <br>Multiple sequential instructions for use can be included in the event of changing doses within one period and/or in the event of a changing dose schedule. |
# | id_zib | NL-CM:9.12.19935 |
# | name_zib | Dosage |
# | path_zib | InstructionsForUse.DosingInstructions.Dosage |
# | stereotype_zib | container |
#
# ### Comments
#
#
#
# ## zib: InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule |
# | alias_zib | NL: Toedieningsschema |
# | card._zib | 0..1 |
# | definition_zib | Specifications of the times at which the medication is to be administered. This is indicated as follows: <br>-  Time(s) (16:00) or indications (“before meals”) at which the medication is to be taken each day.<br>-  A specific number of times the medication is to be taken each day ("3x a day"), indicated with the frequency.<br>-  A time interval between consecutive doses (“Every 2 hours”, “every 3 days”), indicated with the word Interval.<br>-  Combined periods with an interval and duration (“1 daily for three out of four weeks: the pill schedule”)<br><br>If a certain medication is not to be taken daily, the aforementioned can be combined with daily indications: <br>-  One or more week days on which the medication is to be administered (e.g. “Monday, Wednesday, Friday”)<br>-  ”3x a week”, “2x a month”.<br><br>The specified administration “infinite” is automatically to be repeated until:  <br>-  The end date and time has been reached<br>-  The total administration duration has been reached (14 days)<br>-  A specific amount of administrations has been reached (“20 doses”), to be entered in the Frequency concept. |
# | id_zib | NL-CM:9.12.19948 |
# | name_zib | AdministeringSchedule |
# | path_zib | InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule |
# | stereotype_zib | container |
#
# ### Comments
#
#
#
# ## zib: InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule.Interval
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule.Interval |
# | alias_zib | NL: Interval |
# | card._zib | 0..1 |
# | definition_zib | Interval indicates the time between dose times. If this is included, then the Frequency will not have been included. <br><br>Examples: every 4 hours. <br><br>The times can now be chosen freely, but distribution throughout the day is more precise, and the interval between times is important (e.g. in the case of antibiotics) <br>In the case of Baxter packs and intramural care, such a prescription is used to draw up a (location-specific) outline for distribution times (logistics). |
# | id_zib | NL-CM:9.12.19950 |
# | name_zib | AdministeringSchedule.Interval |
# | path_zib | InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule.Interval |
# | stereotype_zib | data |
# | type_zib | PQ |
#
# ### Comments
#
#
#
# ## zib: InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule.PartOfDay
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule.PartOfDay |
# | alias_zib | NL: Dagdeel |
# | card._zib | 0..* |
# | definition_zib | Time of day: morning, afternoon, evening, night. |
# | id_zib | NL-CM:9.12.19953 |
# | name_zib | AdministeringSchedule.PartOfDay |
# | path_zib | InstructionsForUse.DosingInstructions.Dosage.AdministeringSchedule.PartOfDay |
# | stereotype_zib | data |
# | type_zib | CD |
#
# ### Comments
#
#
#
# ## zib: InstructionsForUse.DosingInstructions.Dosage.AsNeeded
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | InstructionsForUse.DosingInstructions.Dosage.AsNeeded |
# | alias_zib | NL: Zonodig |
# | card._zib | 0..1 |
# | definition_zib | As needed means that the dose is only to be administered under certain conditions.<br>See also the Instructions section for more information about use of the element. |
# | id_zib | NL-CM:9.12.22512 |
# | name_zib | AsNeeded |
# | path_zib | InstructionsForUse.DosingInstructions.Dosage.AsNeeded |
# | stereotype_zib | container |
#
# ### Comments
#
#
#
# ## zib: InstructionsForUse.DosingInstructions.Dosage.AsNeeded.MaximumDose
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | InstructionsForUse.DosingInstructions.Dosage.AsNeeded.MaximumDose |
# | alias_zib | NL: MaximaleDosering |
# | card._zib | 0..1 |
# | definition_zib | A MaximumDose maximizes (in time) the usage of a drug in an 'as needed' prescription.<br><br>Permitted units for the duration: minute, hour, day, week, year |
# | id_zib | NL-CM:9.12.19946 |
# | name_zib | AsNeeded.MaximumDose |
# | path_zib | InstructionsForUse.DosingInstructions.Dosage.AsNeeded.MaximumDose |
# | stereotype_zib | data |
# | type_zib | PQ |
#
# ### Comments
#
#
#
# ## zib: InstructionsForUse.RepeatPeriodCyclicalSchedule
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | InstructionsForUse.RepeatPeriodCyclicalSchedule |
# | alias_zib | NL: HerhaalperiodeCyclischSchema |
# | card._zib | 0..1 |
# | definition_zib | The repeated period in a cyclical schedule (of one or more dosing instructions). A cyclic schedule is noted in days, the corresponding dosing duration is also in days.<br><br>Examples of a cyclical schedule:  <br>contraceptive pill (21 days, 1 pill 1x a day, then skip for 7 days, repeat), repeat period here is 28 days<br>Permitted units for the duration:  day. |
# | id_zib | NL-CM:9.12.22505 |
# | name_zib | RepeatPeriodCyclicalSchedule |
# | path_zib | InstructionsForUse.RepeatPeriodCyclicalSchedule |
# | stereotype_zib | data |
# | type_zib | PQ |
#
# ### Comments
