# %%
import pandas as pd
import os

# %%
# zibbase = 'zibs2020'
zibbase = 'zibs2024'
zibspath = os.path.join(zibbase, 'mappable')
zibs = os.listdir(zibspath)
[(i, zib) for i, zib in enumerate(zibs)]
# Out:
# [(0, 'Nl.zorg.Alert-v5.0(2024EN).xlsx'),
#  (1, 'Nl.zorg.Condition-v1.1(2024EN).xlsx'),
#  (2, 'Nl.zorg.Diagnosis-v2.0(2024EN).xlsx'),
#  (3, 'nl.zorg.DispenseRequest-v4.0(2024EN).xlsx'),
#  (4, 'Nl.zorg.HealthcareProvider-v3.6(2024EN).xlsx'),
#  (5, 'Nl.zorg.HealthProfessional-v4.0(2024EN).xlsx'),
#  (6, 'Nl.zorg.MedicalDevice-v5.0(2024EN).xlsx'),
#  (7, 'nl.zorg.MedicationAgreement-v4.0(2024EN).xlsx'),
#  (8, 'Nl.zorg.NursingIntervention-v5.0(2024EN).xlsx'),
#  (9, 'Nl.zorg.part.AddressInformation-v1.2(2024EN).xlsx'),
#  (10, 'Nl.zorg.part.AnatomicalLocation-v1.0.4(2024EN).xlsx'),
#  (11, 'Nl.zorg.part.ContactInformation-v1.3.1(2024EN).xlsx'),
#  (12, 'Nl.zorg.part.NameInformation-v1.2(2024EN).xlsx'),
#  (13, 'Nl.zorg.Patient-v4.3(2024EN).xlsx'),
#  (14, 'Nl.zorg.Procedure-v6.0(2024EN).xlsx'),
#  (15, 'Nl.zorg.process.RegistrationData-v1.1.2(2024EN).xlsx')]

# %%
zib = zibs[3]
print(zib)
zibpath = os.path.join(zibspath, zib)
zibdf = pd.read_excel(zibpath)
zibdf
# only for zib2024 condition and diagnosis
# zib = zibs[1]
# print( zib)
# zibpath = os.path.join(zibspath, zib)
# zibdf2 = pd.read_excel(zibpath)
# zibdf = pd.concat([zibdf, zibdf2], ignore_index=True)
# zibdf
# Out:
# nl.zorg.DispenseRequest-v4.0(2024EN).xlsx
#                                             name  \
# 0                                DispenseRequest
# 1           IntendedSupplier::HealthcareProvider
# 2   MedicineToBeDispensed::PharmaceuticalProduct
# 3                            DispenseRequestDate
# 4                     SupplyPeriod::TimeInterval
# 5                                NumberOfRefills
# 6                                         Amount
# 7                               DispenseLocation
# 8                               AdditionalWishes
# 9                          DispenseRequestStatus
# 10                                       Comment
#
#                                                  path  \
# 0                                     DispenseRequest
# 1   DispenseRequest.IntendedSupplier::HealthcarePr...
# 2   DispenseRequest.MedicineToBeDispensed::Pharmac...
# 3                 DispenseRequest.DispenseRequestDate
# 4          DispenseRequest.SupplyPeriod::TimeInterval
# 5                     DispenseRequest.NumberOfRefills
# 6                              DispenseRequest.Amount
# 7                    DispenseRequest.DispenseLocation
# 8                    DispenseRequest.AdditionalWishes
# 9               DispenseRequest.DispenseRequestStatus
# 10                            DispenseRequest.Comment
#
#                                                 alias type card.  \
# 0                            NL: Verstrekkingsverzoek  NaN   NaN
# 1                NL: BeoogdVerstrekker::Zorgaanbieder  NaN  0..1
# 2   NL: TeVerstrekkenGeneesmiddel::FarmaceutischPr...  NaN     1
# 3                       NL: VerstrekkingsverzoekDatum   TS  0..1
# 4                 NL: Verbruiksperiode::TijdsInterval  NaN  0..1
# 5                               NL: AantalHerhalingen  INT  0..1
# 6                        NL: TeVerstrekkenHoeveelheid   PQ  0..1
# 7                                  NL: Afleverlocatie   ST  0..1
# 8                               NL: AanvullendeWensen   CD  0..*
# 9                      NL: VerstrekkingsverzoekStatus   CD     1
# 10                                    NL: Toelichting   ST  0..1
#
#            stereotype                id  \
# 0         rootconcept  NL-CM:9.10.19963
# 1   context,reference  NL-CM:9.10.19966
# 2      data,reference  NL-CM:9.10.22249
# 3                data  NL-CM:9.10.20060
# 4      data,reference  NL-CM:9.10.20062
# 5                data  NL-CM:9.10.22120
# 6                data  NL-CM:9.10.19964
# 7                data  NL-CM:9.10.20068
# 8                data  NL-CM:9.10.22759
# 9                data  NL-CM:9.10.22760
# 10               data  NL-CM:9.10.22274
#
#                                            definition  \
# 0   Root concept of the DispenseRequest informatio...
# 1              The intended supplier is a pharmacist.
# 2                       The medicine to be dispensed.
# 3      Time at which the dispense request is entered.
# 4   During the approved period of use, the pharmac...
# 5   The number of additional times the medication ...
# 6   This is the number of units of the ordered pro...
# 7                                  Dispense location.
# 8   Logistics and other instructions such as: do n...
# 9   Status of the order in the ordering process, s...
# 10  Explanation for the dispense request. \n \nThi...
#
#                                        definitioncode
# 0   SNOMED CT: 52711000146108 Request to dispense ...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  LOINC: 48767-8 Annotation comment [Interpretat...

# %%
xlmbase = 'xtehr'
xlmspath = os.path.join(xlmbase, 'mappable')
xlms = os.listdir(xlmspath)
[(i, xlm) for i, xlm in enumerate(xlms)]
# Out:
# [(0, 'Address.xlsx'),
#  (1, 'AlertFlag.xlsx'),
#  (2, 'AllergyIntolerance.xlsx'),
#  (3, 'BodyStructure.xlsx'),
#  (4, 'Condition.xlsx'),
#  (5, 'DataSet.xlsx'),
#  (6, 'Device.xlsx'),
#  (7, 'DeviceUse.xlsx'),
#  (8, 'HealthProfessional.xlsx'),
#  (9, 'HumanName.xlsx'),
#  (10, 'Location.xlsx'),
#  (11, 'Medication.xlsx'),
#  (12, 'MedicationPrescription.xlsx'),
#  (13, 'Organization.xlsx'),
#  (14, 'Patient.xlsx'),
#  (15, 'Procedure.xlsx'),
#  (16, 'Telecom.xlsx')]

# %%
xlm = xlms[12]
print( xlm)
xlmpath = os.path.join(xlmspath, xlm)
xlmdf = pd.read_excel(xlmpath)
xlmdf
# only for device use and organization
# xlm = xlms[7]
# print( xlm)
# xlmpath = os.path.join(xlmspath, xlm)
# xlmdf2 = pd.read_excel(xlmpath)
# xlmdf = pd.concat([xlmdf, xlmdf2], ignore_index=True)
# xlmdf
# Out:
# MedicationPrescription.xlsx
#                                                    id  \
# 0                          EHDSMedicationPrescription
# 1                   EHDSMedicationPrescription.header
# 2           EHDSMedicationPrescription.header.subject
# 3        EHDSMedicationPrescription.header.identifier
# 4        EHDSMedicationPrescription.header.authorship
# 5   EHDSMedicationPrescription.header.authorship.a...
# 6   EHDSMedicationPrescription.header.authorship.d...
# 7        EHDSMedicationPrescription.header.lastUpdate
# 8            EHDSMedicationPrescription.header.status
# 9   EHDSMedicationPrescription.header.statusReason[x]
# 10         EHDSMedicationPrescription.header.language
# 11          EHDSMedicationPrescription.header.version
# 12           EHDSMedicationPrescription.presentedForm
# 13         EHDSMedicationPrescription.header.recorder
# 14    EHDSMedicationPrescription.header.recordingDate
# 15        EHDSMedicationPrescription.header.validFrom
# 16       EHDSMedicationPrescription.header.validUntil
# 17                 EHDSMedicationPrescription.comment
# 18        EHDSMedicationPrescription.prescriptionItem
# 19  EHDSMedicationPrescription.prescriptionItem.id...
# 20  EHDSMedicationPrescription.prescriptionItem.ca...
# 21  EHDSMedicationPrescription.prescriptionItem.me...
# 22  EHDSMedicationPrescription.prescriptionItem.in...
# 23  EHDSMedicationPrescription.prescriptionItem.in...
# 24  EHDSMedicationPrescription.prescriptionItem.pr...
# 25  EHDSMedicationPrescription.prescriptionItem.tr...
# 26  EHDSMedicationPrescription.prescriptionItem.qu...
# 27  EHDSMedicationPrescription.prescriptionItem.do...
# 28  EHDSMedicationPrescription.prescriptionItem.pr...
# 29  EHDSMedicationPrescription.prescriptionItem.su...
# 30  EHDSMedicationPrescription.prescriptionItem.su...
# 31  EHDSMedicationPrescription.prescriptionItem.su...
# 32  EHDSMedicationPrescription.prescriptionItem.st...
# 33  EHDSMedicationPrescription.prescriptionItem.st...
# 34  EHDSMedicationPrescription.prescriptionItem.re...
# 35  EHDSMedicationPrescription.prescriptionItem.mi...
# 36  EHDSMedicationPrescription.prescriptionItem.of...
# 37  EHDSMedicationPrescription.prescriptionItem.of...
# 38  EHDSMedicationPrescription.prescriptionItem.of...
# 39  EHDSMedicationPrescription.prescriptionItem.co...
#
#                                                  path  \
# 0                          EHDSMedicationPrescription
# 1                   EHDSMedicationPrescription.header
# 2           EHDSMedicationPrescription.header.subject
# 3        EHDSMedicationPrescription.header.identifier
# 4        EHDSMedicationPrescription.header.authorship
# 5   EHDSMedicationPrescription.header.authorship.a...
# 6   EHDSMedicationPrescription.header.authorship.d...
# 7        EHDSMedicationPrescription.header.lastUpdate
# 8            EHDSMedicationPrescription.header.status
# 9   EHDSMedicationPrescription.header.statusReason[x]
# 10         EHDSMedicationPrescription.header.language
# 11          EHDSMedicationPrescription.header.version
# 12           EHDSMedicationPrescription.presentedForm
# 13         EHDSMedicationPrescription.header.recorder
# 14    EHDSMedicationPrescription.header.recordingDate
# 15        EHDSMedicationPrescription.header.validFrom
# 16       EHDSMedicationPrescription.header.validUntil
# 17                 EHDSMedicationPrescription.comment
# 18        EHDSMedicationPrescription.prescriptionItem
# 19  EHDSMedicationPrescription.prescriptionItem.id...
# 20  EHDSMedicationPrescription.prescriptionItem.ca...
# 21  EHDSMedicationPrescription.prescriptionItem.me...
# 22  EHDSMedicationPrescription.prescriptionItem.in...
# 23  EHDSMedicationPrescription.prescriptionItem.in...
# 24  EHDSMedicationPrescription.prescriptionItem.pr...
# 25  EHDSMedicationPrescription.prescriptionItem.tr...
# 26  EHDSMedicationPrescription.prescriptionItem.qu...
# 27  EHDSMedicationPrescription.prescriptionItem.do...
# 28  EHDSMedicationPrescription.prescriptionItem.pr...
# 29  EHDSMedicationPrescription.prescriptionItem.su...
# 30  EHDSMedicationPrescription.prescriptionItem.su...
# 31  EHDSMedicationPrescription.prescriptionItem.su...
# 32  EHDSMedicationPrescription.prescriptionItem.st...
# 33  EHDSMedicationPrescription.prescriptionItem.st...
# 34  EHDSMedicationPrescription.prescriptionItem.re...
# 35  EHDSMedicationPrescription.prescriptionItem.mi...
# 36  EHDSMedicationPrescription.prescriptionItem.of...
# 37  EHDSMedicationPrescription.prescriptionItem.of...
# 38  EHDSMedicationPrescription.prescriptionItem.of...
# 39  EHDSMedicationPrescription.prescriptionItem.co...
#
#                                                 short  \
# 0                       Medication prescription model
# 1                                 Prescription header
# 2   The person for whom the medication is prescrib...
# 3   Business identifier(s) for the prescription. [...
# 4                                          Authorship
# 5   The prescriber, the person who made the prescr...
# 6   Time of issuing (signing) the prescription by ...
# 7    Date and time of the last update to the resource
# 8   Status of the prescription, this should not be...
# 9   Reason for the current status of prescription,...
# 10                                           Language
# 11                                            Version
# 12  Entire prescription as issued. Various formats...
# 13  The recorder of the prescription/draft in the ...
# 14  Time of authoring the prescription/draft in th...
# 15  Effective date of the prescription. The prescr...
# 16  The validity period end date. The prescription...
# 17                 Additional information or comments
# 18  Prescription line for one medication. In many ...
# 19  Identifier for a single item on prescription, ...
# 20  Category or categories of prescription. For ex...
# 21  Prescribed product, branded, generic, virtual,...
# 22  Reason for the prescription (typically diagnos...
# 23  Reason for the prescription in textual form. T...
# 24  Intent of the prescription - prophylaxis, trea...
# 25  Period over which the medication is to be take...
# 26  Overall quantity of prescribed product (e.g nu...
# 27           Dosaging and administration instructions
# 28  Additional instructions about preparation or d...
# 29  Whether and which type of substitution is allo...
# 30  Whether and to what extent substitution is all...
# 31  Reason for the substitution requirement (e.g. ...
# 32  Status of a single item of a multi-item prescr...
# 33  Reason for the current status of prescription,...
# 34                       Number of refills authorized
# 35                          Minimum Dispense Interval
# 36  Indicates that the prescriber has knowingly pr...
# 37  Indicates off-label use. Must be 'true' when ....
# 38  Reason or related clarification for off-label use
# 39                 Additional information or comments
#
#                                            definition                    type  \
# 0   Logical model for medication prescription. A p...                     NaN
# 1                   Prescription header data elements                    Base
# 2                         Patient/subject information             EHDSPatient
# 3                  Business identifier for the object              Identifier
# 4                          Resource authoring details                    Base
# 5   Author(s) by whom the resource was/were author...  EHDSHealthProfessional
# 6   Date and time of the issuing the document/reso...                dateTime
# 7   Date and time of the last update to the docume...                dateTime
# 8                              Status of the resource         CodeableConcept
# 9      Reason for the current status of the resource.         CodeableConcept
# 10  Language in which the resource is written. Lan...         CodeableConcept
# 11                  Business version of the resource.                  string
# 12  A narrative easy-to-read representation of the...          EHDSAttachment
# 13  The recorder of the prescription/draft in the ...  EHDSHealthProfessional
# 14  Time of authoring the prescription/draft in th...                dateTime
# 15  Effective date of the prescription. The prescr...                dateTime
# 16  The validity period end date. The prescription...                dateTime
# 17                 Additional information or comments                  string
# 18  Prescription line for one medication. In many ...                    Base
# 19  Identifier for a single item on prescription, ...              Identifier
# 20  Category or categories of prescription. For ex...         CodeableConcept
# 21  Prescribed product, branded, generic, virtual,...          EHDSMedication
# 22  Reason for the prescription (typically diagnos...         CodeableConcept
# 23  Reason for the prescription in textual form. T...                  string
# 24  Intent of the prescription - prophylaxis, trea...         CodeableConcept
# 25  Period over which the medication is to be take...                  Period
# 26  Overall quantity of prescribed product (e.g nu...                Quantity
# 27           Dosaging and administration instructions            EHDSDosaging
# 28  Additional instructions about preparation or d...                  string
# 29  Whether and which type of substitution is allo...                    Base
# 30  Whether and to what extent substitution is all...                 boolean
# 31  Reason for the substitution requirement (e.g. ...         CodeableConcept
# 32  Status of a single item of a multi-item prescr...         CodeableConcept
# 33  Reason for the current status of prescription,...         CodeableConcept
# 34  How many times the prescription item can be di...                 integer
# 35  If a prescription allows for repeated dispensa...                Quantity
# 36  Indicates that the prescriber has knowingly pr...                    Base
# 37  Indicates off-label use. Must be 'true' when ....                 boolean
# 38  Reason or related clarification for off-label use         CodeableConcept
# 39                 Additional information or comments                  string
#
#    card.                                            binding
# 0   0..*                                                NaN
# 1   1..1                                                NaN
# 2   1..1                                                NaN
# 3   0..*                                                NaN
# 4   1..*                                                NaN
# 5   1..1                                                NaN
# 6   1..1                                                NaN
# 7   0..1                                                NaN
# 8   1..1                                                NaN
# 9   0..1                                                NaN
# 10  0..1  {'strength': 'preferred', 'description': 'BCP ...
# 11  0..1                                                NaN
# 12  0..*                                                NaN
# 13  0..1                                                NaN
# 14  0..1                                                NaN
# 15  0..1                                                NaN
# 16  0..1                                                NaN
# 17  0..*                                                NaN
# 18  1..*                                                NaN
# 19  0..1                                                NaN
# 20  0..*                                                NaN
# 21  1..1                                                NaN
# 22  0..*                                                NaN
# 23  0..1                                                NaN
# 24  0..1                                                NaN
# 25  0..1                                                NaN
# 26  0..1  {'strength': 'preferred', 'description': 'UCUM...
# 27  0..*                                                NaN
# 28  0..1                                                NaN
# 29  0..1                                                NaN
# 30  0..1                                                NaN
# 31  0..1                                                NaN
# 32  1..1                                                NaN
# 33  0..1                                                NaN
# 34  0..1                                                NaN
# 35  0..1                                                NaN
# 36  0..1                                                NaN
# 37  1..1                                                NaN
# 38  0..*                                                NaN
# 39  0..*                                                NaN

# %%
mapbase = 'maps'
maps = os.listdir(mapbase)
[(i, map) for i, map in enumerate(maps)]
# Out:
# [(0, 'Address.xlsx'),
#  (1, 'AlertFlag.xlsx'),
#  (2, 'BodyStructure.xlsx'),
#  (3, 'Condition.xlsx'),
#  (4, 'DataSet.xlsx'),
#  (5, 'Device-and-DeviceUse.xlsx'),
#  (6, 'Diagnosis.xlsx'),
#  (7, 'HealthProfessional.xlsx'),
#  (8, 'HumanName.xlsx'),
#  (9, 'Location-and-Organization.xlsx'),
#  (10, 'Patient.xlsx'),
#  (11, 'Procedure-NusringIntervention.xlsx'),
#  (12, 'Procedure.xlsx'),
#  (13, 'xtehr2zibs'),
#  (14, 'xtehr2zibs2024')]

# %%
file = maps[4]
print(file)
mappath = os.path.join(mapbase, file)
print(mappath)
mapdf = pd.read_excel(mappath)
mapdf
# Out:
# DataSet.xlsx
# maps\DataSet.xlsx
#                                       xtehr  \
# 0                               EHDSDataSet
# 1                        EHDSDataSet.header
# 2                EHDSDataSet.header.subject
# 3             EHDSDataSet.header.identifier
# 4             EHDSDataSet.header.authorship
# 5   EHDSDataSet.header.authorship.author[x]
# 6    EHDSDataSet.header.authorship.datetime
# 7             EHDSDataSet.header.lastUpdate
# 8                 EHDSDataSet.header.status
# 9        EHDSDataSet.header.statusReason[x]
# 10              EHDSDataSet.header.language
# 11               EHDSDataSet.header.version
# 12                EHDSDataSet.presentedForm
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
#
#                                                   zib
# 0                                    RegistrationData
# 1                                    RegistrationData
# 2                                                 NaN
# 3               RegistrationData.IdentificationNumber
# 4                                                 NaN
# 5         RegistrationData.Author::HealthProfessional
# 6               RegistrationData.RegistrationDateTime
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                RegistrationData.RegistrationReason
# 14                  RegistrationData.DatTimeOfClosure
# 15                  RegistrationData.ReasonForClosing
# 16                 RegistrationData.AcquisitionMethod
# 17               RegistrationData.AcquisitionDateTime
# 18                  RegistrationData.ReasonDataAbsent
# 19                     RegistrationData.CopyIndicator
# 20                 RegistrationData.InformationSource
# 21         RegistrationData.InformationSource.Patient
# 22  RegistrationData.InformationSource.HealthProfe...
# 23   RegistrationData.InformationSource.ContactPerson

# %%
mapping = mapdf[['xtehr', 'zib']].merge(zibdf.add_suffix('_zib'), left_on='zib', right_on='path_zib', how='outer').merge(xlmdf.add_suffix('_xtehr'), left_on='xtehr', right_on='path_xtehr', how='outer')
mapping
# Out:
#                                       xtehr  \
# 0                               EHDSDataSet
# 1                        EHDSDataSet.header
# 2             EHDSDataSet.header.authorship
# 3   EHDSDataSet.header.authorship.author[x]
# 4    EHDSDataSet.header.authorship.datetime
# 5             EHDSDataSet.header.identifier
# 6               EHDSDataSet.header.language
# 7             EHDSDataSet.header.lastUpdate
# 8                 EHDSDataSet.header.status
# 9        EHDSDataSet.header.statusReason[x]
# 10               EHDSDataSet.header.subject
# 11               EHDSDataSet.header.version
# 12                EHDSDataSet.presentedForm
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
#
#                                                   zib  \
# 0                                    RegistrationData
# 1                                    RegistrationData
# 2                                                 NaN
# 3         RegistrationData.Author::HealthProfessional
# 4               RegistrationData.RegistrationDateTime
# 5               RegistrationData.IdentificationNumber
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13               RegistrationData.AcquisitionDateTime
# 14                 RegistrationData.AcquisitionMethod
# 15                     RegistrationData.CopyIndicator
# 16                  RegistrationData.DatTimeOfClosure
# 17                 RegistrationData.InformationSource
# 18   RegistrationData.InformationSource.ContactPerson
# 19  RegistrationData.InformationSource.HealthProfe...
# 20         RegistrationData.InformationSource.Patient
# 21                  RegistrationData.ReasonDataAbsent
# 22                  RegistrationData.ReasonForClosing
# 23                RegistrationData.RegistrationReason
#
#                       name_zib  \
# 0             RegistrationData
# 1             RegistrationData
# 2                          NaN
# 3   Author::HealthProfessional
# 4         RegistrationDateTime
# 5         IdentificationNumber
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13         AcquisitionDateTime
# 14           AcquisitionMethod
# 15               CopyIndicator
# 16            DatTimeOfClosure
# 17           InformationSource
# 18               ContactPerson
# 19          HealthProfessional
# 20                     Patient
# 21            ReasonDataAbsent
# 22            ReasonForClosing
# 23          RegistrationReason
#
#                                              path_zib  \
# 0                                    RegistrationData
# 1                                    RegistrationData
# 2                                                 NaN
# 3         RegistrationData.Author::HealthProfessional
# 4               RegistrationData.RegistrationDateTime
# 5               RegistrationData.IdentificationNumber
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13               RegistrationData.AcquisitionDateTime
# 14                 RegistrationData.AcquisitionMethod
# 15                     RegistrationData.CopyIndicator
# 16                  RegistrationData.DatTimeOfClosure
# 17                 RegistrationData.InformationSource
# 18   RegistrationData.InformationSource.ContactPerson
# 19  RegistrationData.InformationSource.HealthProfe...
# 20         RegistrationData.InformationSource.Patient
# 21                  RegistrationData.ReasonDataAbsent
# 22                  RegistrationData.ReasonForClosing
# 23                RegistrationData.RegistrationReason
#
#                        alias_zib type_zib card._zib  stereotype_zib  \
# 0        NL: RegistratieGegevens      NaN       NaN     rootconcept
# 1        NL: RegistratieGegevens      NaN       NaN     rootconcept
# 2                            NaN      NaN       NaN             NaN
# 3       NL: Auteur::Zorgverlener      NaN         1  data,reference
# 4       NL: RegistratieDatumTijd       TS         1            data
# 5        NL: Identificatienummer       II      0..1            data
# 6                            NaN      NaN       NaN             NaN
# 7                            NaN      NaN       NaN             NaN
# 8                            NaN      NaN       NaN             NaN
# 9                            NaN      NaN       NaN             NaN
# 10                           NaN      NaN       NaN             NaN
# 11                           NaN      NaN       NaN             NaN
# 12                           NaN      NaN       NaN             NaN
# 13    NL: DatumTijdVanVerkrijgen       TS      0..1            data
# 14        NL: WijzeVanVerkrijgen       ST         1            data
# 15            NL: KopieIndicator       BL         1            data
# 16          NL: AfsluitDatumTijd       TS      0..1            data
# 17            NL: Informatiebron      NaN      0..1       container
# 18            NL: Contactpersoon      NaN    (0..1)  data,reference
# 19              NL: Zorgverlener      NaN    (0..1)  data,reference
# 20                   NL: Patient      NaN    (0..1)  data,reference
# 21  NL: RedenAfwezigheidGegevens       CD      0..1            data
# 22         NL: RedenVanAfsluiten       ST      0..1            data
# 23        NL: RedenVanVastleggen       ST      0..1            data
#
#            id_zib                                     definition_zib  \
# 0    NL-CM:22.1.1  Root concept of the RegistrationData process d...
# 1    NL-CM:22.1.1  Root concept of the RegistrationData process d...
# 2             NaN                                                NaN
# 3    NL-CM:22.1.2  The author is the one who is responsible for r...
# 4    NL-CM:22.1.3  Date and time when the information was recorde...
# 5   NL-CM:22.1.12  Globally unique number that identifies the ins...
# 6             NaN                                                NaN
# 7             NaN                                                NaN
# 8             NaN                                                NaN
# 9             NaN                                                NaN
# 10            NaN                                                NaN
# 11            NaN                                                NaN
# 12            NaN                                                NaN
# 13   NL-CM:22.1.9  Date and when relevant time when the informati...
# 14   NL-CM:22.1.8  The way in which the information is obtained b...
# 15  NL-CM:22.1.11  Indication that the data has been obtained fro...
# 16   NL-CM:22.1.5  Date and time at which it is recorded in the p...
# 17  NL-CM:22.1.13  Container of the InformationSource concept.Thi...
# 18  NL-CM:22.1.15  The contact person who is the source of the in...
# 19  NL-CM:22.1.14  The health professional who is the source of t...
# 20  NL-CM:22.1.16                  The patient as information source
# 21  NL-CM:22.1.10  Reason why no data is available for the value ...
# 22   NL-CM:22.1.6  Reason why updating the information, or follow...
# 23   NL-CM:22.1.4  Description of the reason for including the in...
#
#                             definitioncode_zib  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5   SNOMED CT: 396278008 Identification number
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 10                                         NaN
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
# 20                                         NaN
# 21                                         NaN
# 22                                         NaN
# 23                                         NaN
#
#                                    id_xtehr  \
# 0                               EHDSDataSet
# 1                        EHDSDataSet.header
# 2             EHDSDataSet.header.authorship
# 3   EHDSDataSet.header.authorship.author[x]
# 4    EHDSDataSet.header.authorship.datetime
# 5             EHDSDataSet.header.identifier
# 6               EHDSDataSet.header.language
# 7             EHDSDataSet.header.lastUpdate
# 8                 EHDSDataSet.header.status
# 9        EHDSDataSet.header.statusReason[x]
# 10               EHDSDataSet.header.subject
# 11               EHDSDataSet.header.version
# 12                EHDSDataSet.presentedForm
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
#
#                                  path_xtehr  \
# 0                               EHDSDataSet
# 1                        EHDSDataSet.header
# 2             EHDSDataSet.header.authorship
# 3   EHDSDataSet.header.authorship.author[x]
# 4    EHDSDataSet.header.authorship.datetime
# 5             EHDSDataSet.header.identifier
# 6               EHDSDataSet.header.language
# 7             EHDSDataSet.header.lastUpdate
# 8                 EHDSDataSet.header.status
# 9        EHDSDataSet.header.statusReason[x]
# 10               EHDSDataSet.header.subject
# 11               EHDSDataSet.header.version
# 12                EHDSDataSet.presentedForm
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
#
#                                           short_xtehr  \
# 0                                       DataSet model
# 1          Common header for all patient-related data
# 2                                          Authorship
# 3                                              Author
# 4                  Date and time of authoring/issuing
# 5                  Business identifier for the object
# 6                                            Language
# 7    Date and time of the last update to the resource
# 8                              Status of the resource
# 9      Reason for the current status of the resource.
# 10                                            Subject
# 11                                            Version
# 12  A narrative easy-to-read representation of the...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
#
#                                      definition_xtehr              type_xtehr  \
# 0   Common elements (including header) for all doc...                     NaN
# 1          Common header for all patient-related data                    Base
# 2                          Resource authoring details                    Base
# 3   Author(s) by whom the resource was/were author...  EHDSHealthProfessional
# 4   Date and time of the issuing the document/reso...                dateTime
# 5                  Business identifier for the object              Identifier
# 6   Language in which the resource is written. Lan...         CodeableConcept
# 7   Date and time of the last update to the docume...                dateTime
# 8                              Status of the resource         CodeableConcept
# 9      Reason for the current status of the resource.         CodeableConcept
# 10                        Patient/subject information             EHDSPatient
# 11                  Business version of the resource.                  string
# 12  A narrative easy-to-read representation of the...          EHDSAttachment
# 13                                                NaN                     NaN
# 14                                                NaN                     NaN
# 15                                                NaN                     NaN
# 16                                                NaN                     NaN
# 17                                                NaN                     NaN
# 18                                                NaN                     NaN
# 19                                                NaN                     NaN
# 20                                                NaN                     NaN
# 21                                                NaN                     NaN
# 22                                                NaN                     NaN
# 23                                                NaN                     NaN
#
#    card._xtehr                                      binding_xtehr
# 0         0..*                                                NaN
# 1         1..1                                                NaN
# 2         1..*                                                NaN
# 3         1..1                                                NaN
# 4         1..1                                                NaN
# 5         0..*                                                NaN
# 6         0..1  {'strength': 'preferred', 'description': 'BCP ...
# 7         0..1                                                NaN
# 8         1..1                                                NaN
# 9         0..1                                                NaN
# 10        1..1                                                NaN
# 11        0..1                                                NaN
# 12        0..*                                                NaN
# 13         NaN                                                NaN
# 14         NaN                                                NaN
# 15         NaN                                                NaN
# 16         NaN                                                NaN
# 17         NaN                                                NaN
# 18         NaN                                                NaN
# 19         NaN                                                NaN
# 20         NaN                                                NaN
# 21         NaN                                                NaN
# 22         NaN                                                NaN
# 23         NaN                                                NaN

# %%
shortmap = mapping[['zib', 'xtehr', 'type_zib','type_xtehr', 'card._zib', 'card._xtehr']]
shortmap
# Out:
#                                                   zib  \
# 0                                    RegistrationData
# 1                                    RegistrationData
# 2                                                 NaN
# 3         RegistrationData.Author::HealthProfessional
# 4               RegistrationData.RegistrationDateTime
# 5               RegistrationData.IdentificationNumber
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13               RegistrationData.AcquisitionDateTime
# 14                 RegistrationData.AcquisitionMethod
# 15                     RegistrationData.CopyIndicator
# 16                  RegistrationData.DatTimeOfClosure
# 17                 RegistrationData.InformationSource
# 18   RegistrationData.InformationSource.ContactPerson
# 19  RegistrationData.InformationSource.HealthProfe...
# 20         RegistrationData.InformationSource.Patient
# 21                  RegistrationData.ReasonDataAbsent
# 22                  RegistrationData.ReasonForClosing
# 23                RegistrationData.RegistrationReason
#
#                                       xtehr type_zib              type_xtehr  \
# 0                               EHDSDataSet      NaN                     NaN
# 1                        EHDSDataSet.header      NaN                    Base
# 2             EHDSDataSet.header.authorship      NaN                    Base
# 3   EHDSDataSet.header.authorship.author[x]      NaN  EHDSHealthProfessional
# 4    EHDSDataSet.header.authorship.datetime       TS                dateTime
# 5             EHDSDataSet.header.identifier       II              Identifier
# 6               EHDSDataSet.header.language      NaN         CodeableConcept
# 7             EHDSDataSet.header.lastUpdate      NaN                dateTime
# 8                 EHDSDataSet.header.status      NaN         CodeableConcept
# 9        EHDSDataSet.header.statusReason[x]      NaN         CodeableConcept
# 10               EHDSDataSet.header.subject      NaN             EHDSPatient
# 11               EHDSDataSet.header.version      NaN                  string
# 12                EHDSDataSet.presentedForm      NaN          EHDSAttachment
# 13                                      NaN       TS                     NaN
# 14                                      NaN       ST                     NaN
# 15                                      NaN       BL                     NaN
# 16                                      NaN       TS                     NaN
# 17                                      NaN      NaN                     NaN
# 18                                      NaN      NaN                     NaN
# 19                                      NaN      NaN                     NaN
# 20                                      NaN      NaN                     NaN
# 21                                      NaN       CD                     NaN
# 22                                      NaN       ST                     NaN
# 23                                      NaN       ST                     NaN
#
#    card._zib card._xtehr
# 0        NaN        0..*
# 1        NaN        1..1
# 2        NaN        1..*
# 3          1        1..1
# 4          1        1..1
# 5       0..1        0..*
# 6        NaN        0..1
# 7        NaN        0..1
# 8        NaN        1..1
# 9        NaN        0..1
# 10       NaN        1..1
# 11       NaN        0..1
# 12       NaN        0..*
# 13      0..1         NaN
# 14         1         NaN
# 15         1         NaN
# 16      0..1         NaN
# 17      0..1         NaN
# 18    (0..1)         NaN
# 19    (0..1)         NaN
# 20    (0..1)         NaN
# 21      0..1         NaN
# 22      0..1         NaN
# 23      0..1         NaN

# %%
mapsoutpath = os.path.join(mapbase, 'xtehr2zibs2024')
filepath = file.replace('.xlsx', '-full.xlsx')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_excel(mappath, index=False)

# %%
filepath = file.replace('.xlsx', '.csv')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_csv(mappath, index=False)

# %%
from IPython.display import Markdown
import numpy as np

content = "# " + mapping.iat[0, 0][4:] + "\n\n"
content += shortmap.fillna('').to_markdown(index=False) + "\n\n"
for i, row in mapping.iterrows():
    # print(i, row)
    content += "\n\n"
    if row.iloc[0] is not np.nan:
        content += "## " + str(row.iloc[0]) + "\n\n"
    else:
        content += "## zib: " + str(row.iloc[1]) + "\n\n"
    content += "### Table" + "\n\n"
    content += "| attribute | value |" + "\n" + "|---|---|" + "\n"
    for j, att in row.fillna('')[0:2].items():
        content += "| " + str(j) + " | " + str(att) + " |" + "\n"
    for j, att in row.fillna('')[2:].sort_index().items():
        if len(str(att)) > 0:
            content += "| " + str(j) + " | " + str(att) + " |" + "\n"    
    content += "\n### Comments" + "\n\n"
with open(os.path.join(mapsoutpath, file.replace('.xlsx', '.md')), 'w') as f:
    f.write(content)
# PAS OP: deze overschrijft de eventueel met de hand gemaakte comments files, alleen gebruiken
# bij eerste keer dat je een mapping maakt, daarna de comments handmatig aanpassen
# with open(os.path.join(mapsoutpath, file.replace('.xlsx', '-comments.md')), 'w') as f:
#     f.write(content)
Markdown(content)
# Out:
# # DataSet
#
# | zib                                                   | xtehr                                   | type_zib   | type_xtehr             | card._zib   | card._xtehr   |
# |:------------------------------------------------------|:----------------------------------------|:-----------|:-----------------------|:------------|:--------------|
# | RegistrationData                                      | EHDSDataSet                             |            |                        |             | 0..*          |
# | RegistrationData                                      | EHDSDataSet.header                      |            | Base                   |             | 1..1          |
# |                                                       | EHDSDataSet.header.authorship           |            | Base                   |             | 1..*          |
# | RegistrationData.Author::HealthProfessional           | EHDSDataSet.header.authorship.author[x] |            | EHDSHealthProfessional | 1           | 1..1          |
# | RegistrationData.RegistrationDateTime                 | EHDSDataSet.header.authorship.datetime  | TS         | dateTime               | 1           | 1..1          |
# | RegistrationData.IdentificationNumber                 | EHDSDataSet.header.identifier           | II         | Identifier             | 0..1        | 0..*          |
# |                                                       | EHDSDataSet.header.language             |            | CodeableConcept        |             | 0..1          |
# |                                                       | EHDSDataSet.header.lastUpdate           |            | dateTime               |             | 0..1          |
# |                                                       | EHDSDataSet.header.status               |            | CodeableConcept        |             | 1..1          |
# |                                                       | EHDSDataSet.header.statusReason[x]      |            | CodeableConcept        |             | 0..1          |
# |                                                       | EHDSDataSet.header.subject              |            | EHDSPatient            |             | 1..1          |
# |                                                       | EHDSDataSet.header.version              |            | string                 |             | 0..1          |
# |                                                       | EHDSDataSet.presentedForm               |            | EHDSAttachment         |             | 0..*          |
# | RegistrationData.AcquisitionDateTime                  |                                         | TS         |                        | 0..1        |               |
# | RegistrationData.AcquisitionMethod                    |                                         | ST         |                        | 1           |               |
# | RegistrationData.CopyIndicator                        |                                         | BL         |                        | 1           |               |
# | RegistrationData.DatTimeOfClosure                     |                                         | TS         |                        | 0..1        |               |
# | RegistrationData.InformationSource                    |                                         |            |                        | 0..1        |               |
# | RegistrationData.InformationSource.ContactPerson      |                                         |            |                        | (0..1)      |               |
# | RegistrationData.InformationSource.HealthProfessional |                                         |            |                        | (0..1)      |               |
# | RegistrationData.InformationSource.Patient            |                                         |            |                        | (0..1)      |               |
# | RegistrationData.ReasonDataAbsent                     |                                         | CD         |                        | 0..1        |               |
# | RegistrationData.ReasonForClosing                     |                                         | ST         |                        | 0..1        |               |
# | RegistrationData.RegistrationReason                   |                                         | ST         |                        | 0..1        |               |
#
#
#
# ## EHDSDataSet
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDataSet |
# | zib | RegistrationData |
# | alias_zib | NL: RegistratieGegevens |
# | card._xtehr | 0..* |
# | definition_xtehr | Common elements (including header) for all documents and their independently functioning parts, e.g FHIR resources. |
# | definition_zib | Root concept of the RegistrationData process data information model. This root concept contains all data elements of the RegistrationData process data information model. |
# | id_xtehr | EHDSDataSet |
# | id_zib | NL-CM:22.1.1 |
# | name_zib | RegistrationData |
# | path_xtehr | EHDSDataSet |
# | path_zib | RegistrationData |
# | short_xtehr | DataSet model |
# | stereotype_zib | rootconcept |
#
# ### Comments
#
#
#
# ## EHDSDataSet.header
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDataSet.header |
# | zib | RegistrationData |
# | alias_zib | NL: RegistratieGegevens |
# | card._xtehr | 1..1 |
# | definition_xtehr | Common header for all patient-related data |
# | definition_zib | Root concept of the RegistrationData process data information model. This root concept contains all data elements of the RegistrationData process data information model. |
# | id_xtehr | EHDSDataSet.header |
# | id_zib | NL-CM:22.1.1 |
# | name_zib | RegistrationData |
# | path_xtehr | EHDSDataSet.header |
# | path_zib | RegistrationData |
# | short_xtehr | Common header for all patient-related data |
# | stereotype_zib | rootconcept |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSDataSet.header.authorship
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDataSet.header.authorship |
# | zib |  |
# | card._xtehr | 1..* |
# | definition_xtehr | Resource authoring details |
# | id_xtehr | EHDSDataSet.header.authorship |
# | path_xtehr | EHDSDataSet.header.authorship |
# | short_xtehr | Authorship |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSDataSet.header.authorship.author[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDataSet.header.authorship.author[x] |
# | zib | RegistrationData.Author::HealthProfessional |
# | alias_zib | NL: Auteur::Zorgverlener |
# | card._xtehr | 1..1 |
# | card._zib | 1 |
# | definition_xtehr | Author(s) by whom the resource was/were authored. Multiple authors could be provided. |
# | definition_zib | The author is the one who is responsible for recording information or having information recorded in the medical record.
# It concerns not only own observations, but also information received from third parties. The author has decided to include the information in the medical record, and if necessary with source reference. |
# | id_xtehr | EHDSDataSet.header.authorship.author[x] |
# | id_zib | NL-CM:22.1.2 |
# | name_zib | Author::HealthProfessional |
# | path_xtehr | EHDSDataSet.header.authorship.author[x] |
# | path_zib | RegistrationData.Author::HealthProfessional |
# | short_xtehr | Author |
# | stereotype_zib | data,reference |
# | type_xtehr | EHDSHealthProfessional |
#
# ### Comments
#
#
#
# ## EHDSDataSet.header.authorship.datetime
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDataSet.header.authorship.datetime |
# | zib | RegistrationData.RegistrationDateTime |
# | alias_zib | NL: RegistratieDatumTijd |
# | card._xtehr | 1..1 |
# | card._zib | 1 |
# | definition_xtehr | Date and time of the issuing the document/resource by its author. |
# | definition_zib | Date and time when the information was recorded in the patient record. |
# | id_xtehr | EHDSDataSet.header.authorship.datetime |
# | id_zib | NL-CM:22.1.3 |
# | name_zib | RegistrationDateTime |
# | path_xtehr | EHDSDataSet.header.authorship.datetime |
# | path_zib | RegistrationData.RegistrationDateTime |
# | short_xtehr | Date and time of authoring/issuing |
# | stereotype_zib | data |
# | type_xtehr | dateTime |
# | type_zib | TS |
#
# ### Comments
#
#
#
# ## EHDSDataSet.header.identifier
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDataSet.header.identifier |
# | zib | RegistrationData.IdentificationNumber |
# | alias_zib | NL: Identificatienummer |
# | card._xtehr | 0..* |
# | card._zib | 0..1 |
# | definition_xtehr | Business identifier for the object |
# | definition_zib | Globally unique number that identifies the instantiation of the information model. The number is composed of an identification of the issuer organization and a unique number assigned by this organization. |
# | definitioncode_zib | SNOMED CT: 396278008 Identification number |
# | id_xtehr | EHDSDataSet.header.identifier |
# | id_zib | NL-CM:22.1.12 |
# | name_zib | IdentificationNumber |
# | path_xtehr | EHDSDataSet.header.identifier |
# | path_zib | RegistrationData.IdentificationNumber |
# | short_xtehr | Business identifier for the object |
# | stereotype_zib | data |
# | type_xtehr | Identifier |
# | type_zib | II |
#
# ### Comments
#
#
#
# ## EHDSDataSet.header.language
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDataSet.header.language |
# | zib |  |
# | binding_xtehr | {'strength': 'preferred', 'description': 'BCP 47'} |
# | card._xtehr | 0..1 |
# | definition_xtehr | Language in which the resource is written. Language is expressed by the IETF language tag. |
# | id_xtehr | EHDSDataSet.header.language |
# | path_xtehr | EHDSDataSet.header.language |
# | short_xtehr | Language |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSDataSet.header.lastUpdate
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDataSet.header.lastUpdate |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Date and time of the last update to the document/information |
# | id_xtehr | EHDSDataSet.header.lastUpdate |
# | path_xtehr | EHDSDataSet.header.lastUpdate |
# | short_xtehr | Date and time of the last update to the resource |
# | type_xtehr | dateTime |
#
# ### Comments
#
#
#
# ## EHDSDataSet.header.status
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDataSet.header.status |
# | zib |  |
# | card._xtehr | 1..1 |
# | definition_xtehr | Status of the resource |
# | id_xtehr | EHDSDataSet.header.status |
# | path_xtehr | EHDSDataSet.header.status |
# | short_xtehr | Status of the resource |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSDataSet.header.statusReason[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDataSet.header.statusReason[x] |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Reason for the current status of the resource. |
# | id_xtehr | EHDSDataSet.header.statusReason[x] |
# | path_xtehr | EHDSDataSet.header.statusReason[x] |
# | short_xtehr | Reason for the current status of the resource. |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSDataSet.header.subject
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDataSet.header.subject |
# | zib |  |
# | card._xtehr | 1..1 |
# | definition_xtehr | Patient/subject information |
# | id_xtehr | EHDSDataSet.header.subject |
# | path_xtehr | EHDSDataSet.header.subject |
# | short_xtehr | Subject |
# | type_xtehr | EHDSPatient |
#
# ### Comments
#
#
#
# ## EHDSDataSet.header.version
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDataSet.header.version |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Business version of the resource. |
# | id_xtehr | EHDSDataSet.header.version |
# | path_xtehr | EHDSDataSet.header.version |
# | short_xtehr | Version |
# | type_xtehr | string |
#
# ### Comments
#
#
#
# ## EHDSDataSet.presentedForm
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDataSet.presentedForm |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | A narrative easy-to-read representation of the full data set, e.g. PDF-version of a document |
# | id_xtehr | EHDSDataSet.presentedForm |
# | path_xtehr | EHDSDataSet.presentedForm |
# | short_xtehr | A narrative easy-to-read representation of the full data set, e.g. PDF-version of a document |
# | type_xtehr | EHDSAttachment |
#
# ### Comments
#
#
#
# ## zib: RegistrationData.AcquisitionDateTime
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | RegistrationData.AcquisitionDateTime |
# | alias_zib | NL: DatumTijdVanVerkrijgen |
# | card._zib | 0..1 |
# | definition_zib | Date and when relevant time when the information became available. This may be an earlier time than the date/time when the information was entered in the patient record. |
# | id_zib | NL-CM:22.1.9 |
# | name_zib | AcquisitionDateTime |
# | path_zib | RegistrationData.AcquisitionDateTime |
# | stereotype_zib | data |
# | type_zib | TS |
#
# ### Comments
#
#
#
# ## zib: RegistrationData.AcquisitionMethod
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | RegistrationData.AcquisitionMethod |
# | alias_zib | NL: WijzeVanVerkrijgen |
# | card._zib | 1 |
# | definition_zib | The way in which the information is obtained by the patient record holder. |
# | id_zib | NL-CM:22.1.8 |
# | name_zib | AcquisitionMethod |
# | path_zib | RegistrationData.AcquisitionMethod |
# | stereotype_zib | data |
# | type_zib | ST |
#
# ### Comments
#
#
#
# ## zib: RegistrationData.CopyIndicator
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | RegistrationData.CopyIndicator |
# | alias_zib | NL: KopieIndicator |
# | card._zib | 1 |
# | definition_zib | Indication that the data has been obtained from the EPR of another healthcare professional/healthcare provider. |
# | id_zib | NL-CM:22.1.11 |
# | name_zib | CopyIndicator |
# | path_zib | RegistrationData.CopyIndicator |
# | stereotype_zib | data |
# | type_zib | BL |
#
# ### Comments
#
#
#
# ## zib: RegistrationData.DatTimeOfClosure
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | RegistrationData.DatTimeOfClosure |
# | alias_zib | NL: AfsluitDatumTijd |
# | card._zib | 0..1 |
# | definition_zib | Date and time at which it is recorded in the patient record that the information is no longer relevant, for example because the information is outdated, no longer requires attention, etc. |
# | id_zib | NL-CM:22.1.5 |
# | name_zib | DatTimeOfClosure |
# | path_zib | RegistrationData.DatTimeOfClosure |
# | stereotype_zib | data |
# | type_zib | TS |
#
# ### Comments
#
#
#
# ## zib: RegistrationData.InformationSource
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | RegistrationData.InformationSource |
# | alias_zib | NL: Informatiebron |
# | card._zib | 0..1 |
# | definition_zib | Container of the InformationSource concept.This container contains all data elements of the InformationSource concept.
# If the recorded information has not been assessed by the attending physician, the source of the information can be recorded. |
# | id_zib | NL-CM:22.1.13 |
# | name_zib | InformationSource |
# | path_zib | RegistrationData.InformationSource |
# | stereotype_zib | container |
#
# ### Comments
#
#
#
# ## zib: RegistrationData.InformationSource.ContactPerson
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | RegistrationData.InformationSource.ContactPerson |
# | alias_zib | NL: Contactpersoon |
# | card._zib | (0..1) |
# | definition_zib | The contact person who is the source of the information. |
# | id_zib | NL-CM:22.1.15 |
# | name_zib | ContactPerson |
# | path_zib | RegistrationData.InformationSource.ContactPerson |
# | stereotype_zib | data,reference |
#
# ### Comments
#
#
#
# ## zib: RegistrationData.InformationSource.HealthProfessional
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | RegistrationData.InformationSource.HealthProfessional |
# | alias_zib | NL: Zorgverlener |
# | card._zib | (0..1) |
# | definition_zib | The health professional who is the source of the information. |
# | id_zib | NL-CM:22.1.14 |
# | name_zib | HealthProfessional |
# | path_zib | RegistrationData.InformationSource.HealthProfessional |
# | stereotype_zib | data,reference |
#
# ### Comments
#
#
#
# ## zib: RegistrationData.InformationSource.Patient
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | RegistrationData.InformationSource.Patient |
# | alias_zib | NL: Patient |
# | card._zib | (0..1) |
# | definition_zib | The patient as information source |
# | id_zib | NL-CM:22.1.16 |
# | name_zib | Patient |
# | path_zib | RegistrationData.InformationSource.Patient |
# | stereotype_zib | data,reference |
#
# ### Comments
#
#
#
# ## zib: RegistrationData.ReasonDataAbsent
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | RegistrationData.ReasonDataAbsent |
# | alias_zib | NL: RedenAfwezigheidGegevens |
# | card._zib | 0..1 |
# | definition_zib | Reason why no data is available for the value of a concept. This includes, for example, all 'Unknown' variants, but also 'Indeterminate', 'Specimen unsatisfactory', etc. |
# | id_zib | NL-CM:22.1.10 |
# | name_zib | ReasonDataAbsent |
# | path_zib | RegistrationData.ReasonDataAbsent |
# | stereotype_zib | data |
# | type_zib | CD |
#
# ### Comments
#
#
#
# ## zib: RegistrationData.ReasonForClosing
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | RegistrationData.ReasonForClosing |
# | alias_zib | NL: RedenVanAfsluiten |
# | card._zib | 0..1 |
# | definition_zib | Reason why updating the information, or following changes in the the concept in question is no longer considered relevant. For example, in the case of a condition, this does not mean that the disease is no longer present, but merely that the holder of the patients record no longer considers the condition as an aspect to be taken into account during care provision. |
# | id_zib | NL-CM:22.1.6 |
# | name_zib | ReasonForClosing |
# | path_zib | RegistrationData.ReasonForClosing |
# | stereotype_zib | data |
# | type_zib | ST |
#
# ### Comments
#
#
#
# ## zib: RegistrationData.RegistrationReason
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | RegistrationData.RegistrationReason |
# | alias_zib | NL: RedenVanVastleggen |
# | card._zib | 0..1 |
# | definition_zib | Description of the reason for including the information in the patient record. |
# | id_zib | NL-CM:22.1.4 |
# | name_zib | RegistrationReason |
# | path_zib | RegistrationData.RegistrationReason |
# | stereotype_zib | data |
# | type_zib | ST |
#
# ### Comments
