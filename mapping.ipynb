# %%
import pandas as pd
import os

# %%
# zibbase = 'zibs2020'
zibbase = 'zibs2024'
zibspath = os.path.join(zibbase, 'mappable')
zibs = os.listdir(zibspath)
[(i, zib) for i, zib in enumerate(zibs)]
# Out:
# [(0, 'Nl.zorg.Alert-v5.0(2024EN).xlsx'),
#  (1, 'Nl.zorg.Condition-v1.1(2024EN).xlsx'),
#  (2, 'Nl.zorg.Diagnosis-v2.0(2024EN).xlsx'),
#  (3, 'Nl.zorg.HealthcareProvider-v3.6(2024EN).xlsx'),
#  (4, 'Nl.zorg.HealthProfessional-v4.0(2024EN).xlsx'),
#  (5, 'Nl.zorg.MedicalDevice-v5.0(2024EN).xlsx'),
#  (6, 'Nl.zorg.NursingIntervention-v5.0(2024EN).xlsx'),
#  (7, 'Nl.zorg.part.AddressInformation-v1.2(2024EN).xlsx'),
#  (8, 'Nl.zorg.part.AnatomicalLocation-v1.0.4(2024EN).xlsx'),
#  (9, 'Nl.zorg.part.ContactInformation-v1.3.1(2024EN).xlsx'),
#  (10, 'Nl.zorg.part.NameInformation-v1.2(2024EN).xlsx'),
#  (11, 'Nl.zorg.Patient-v4.3(2024EN).xlsx'),
#  (12, 'Nl.zorg.Procedure-v6.0(2024EN).xlsx'),
#  (13, 'Nl.zorg.process.RegistrationData-v1.1.2(2024EN).xlsx'),
#  (14, '~$Nl.zorg.Diagnosis-v2.0(2024EN).xlsx')]

# %%
zib = zibs[2]
print(zib)
zibpath = os.path.join(zibspath, zib)
zibdf = pd.read_excel(zibpath)
zibdf
# only for zib2024 condition and diagnosis
# zib = zibs[1]
# print( zib)
# zibpath = os.path.join(zibspath, zib)
# zibdf2 = pd.read_excel(zibpath)
# zibdf = pd.concat([zibdf, zibdf2], ignore_index=True)
# zibdf
# Out:
# Nl.zorg.Diagnosis-v2.0(2024EN).xlsx
# Nl.zorg.Condition-v1.1(2024EN).xlsx
#                                  name  \
# 0                           Diagnosis
# 1   Diagnostician::HealthProfessional
# 2                       DiagnosisDate
# 3                     DiagnosisStatus
# 4                MethodOfConfirmation
# 5                   DiagnosisNameData
# 6                       DiagnosisName
# 7   FurtherSpecificationDiagnosisName
# 8                  AnatomicalLocation
# 9                           Condition
# 10                            Comment
# 11                     IsComplication
# 12                             Reason
# 13                           Incident
# 14                          Procedure
# 15                          Diagnosis
# 16                          Condition
# 17        PeriodPresent::TimeInterval
# 18                         StatusDate
# 19                             Course
# 20                           Severity
# 21                            Comment
#
#                                                  path  \
# 0                                           Diagnosis
# 1         Diagnosis.Diagnostician::HealthProfessional
# 2                             Diagnosis.DiagnosisDate
# 3                           Diagnosis.DiagnosisStatus
# 4                      Diagnosis.MethodOfConfirmation
# 5                         Diagnosis.DiagnosisNameData
# 6           Diagnosis.DiagnosisNameData.DiagnosisName
# 7   Diagnosis.DiagnosisNameData.FurtherSpecificati...
# 8                        Diagnosis.AnatomicalLocation
# 9                                 Diagnosis.Condition
# 10                                  Diagnosis.Comment
# 11                           Diagnosis.IsComplication
# 12                                   Diagnosis.Reason
# 13                          Diagnosis.Reason.Incident
# 14                         Diagnosis.Reason.Procedure
# 15                         Diagnosis.Reason.Diagnosis
# 16                                          Condition
# 17              Condition.PeriodPresent::TimeInterval
# 18                               Condition.StatusDate
# 19                                   Condition.Course
# 20                                 Condition.Severity
# 21                                  Condition.Comment
#
#                                  alias type   card.         stereotype  \
# 0                         NL: Diagnose  NaN     NaN        rootconcept
# 1    NL: DiagnoseSteller::Zorgverlener  NaN       1  context,reference
# 2                    NL: DiagnoseDatum   TS       1               data
# 3                   NL: DiagnoseStatus   CD       1               data
# 4              NL: WijzeVanVaststellen   CD       1               data
# 5             NL: DiagnoseNaamGegevens  NaN    1..*          container
# 6                     NL: DiagnoseNaam   CD       1               data
# 7   NL: NadereSpecificatieDiagnoseNaam   ST    0..1               data
# 8               NL: AnatomischeLocatie  NaN    0..*     data,reference
# 9          NL: AandoeningOfGesteldheid  NaN    0..1     data,reference
# 10                     NL: Toelichting   ST    0..1               data
# 11                   NL: IsComplicatie   BL    0..1               data
# 12                      NL: Aanleiding  NaN    0..*          container
# 13                        NL: Incident   CD  (0..1)               data
# 14                     NL: Verrichting  NaN  (0..1)     data,reference
# 15                        NL: Diagnose  NaN  (0..1)     data,reference
# 16         NL: AandoeningOfGesteldheid  NaN     NaN        rootconcept
# 17  NL: PeriodeAanwezig::TijdsInterval  NaN       1     data,reference
# 18                     NL: StatusDatum   TS       1               data
# 19                          NL: Beloop   CD    0..1               data
# 20                           NL: Ernst   CD       1               data
# 21                     NL: Toelichting   ST    0..1               data
#
#               id                                         definition  \
# 0    NL-CM:5.6.1  Root concept of the Diagnosis information mode...
# 1    NL-CM:5.6.2  The care professional who made the diagnosis. ...
# 2    NL-CM:5.6.3  Date (and time) at which the care professional...
# 3    NL-CM:5.6.4    Indicates the status of the diagnostic process.
# 4    NL-CM:5.6.5  The method that the care professional used to ...
# 5    NL-CM:5.6.6  Container of the DiagnosisNameData concept. Th...
# 6    NL-CM:5.6.7  The term with associated code that the care pr...
# 7    NL-CM:5.6.8  A more detailed description of the DiagnosisNa...
# 8    NL-CM:5.6.9  The location(s) on and/or in the body that is/...
# 9   NL-CM:5.6.10      The Condition to which the Diagnosis applies.
# 10  NL-CM:5.6.11  A comment in free text with respect to the dia...
# 11  NL-CM:5.6.12  Indicates whether or not the diagnosis involve...
# 12  NL-CM:5.6.13  Container of the Reason concept.This container...
# 13  NL-CM:5.6.14  The unintended event during the care process t...
# 14  NL-CM:5.6.15  The procedure that gave rise to the condition ...
# 15  NL-CM:5.6.16  The diagnosis with regard to another condition...
# 16   NL-CM:5.4.1  This is a reference to the root concept of inf...
# 17   NL-CM:5.4.8  The period in which the condition is (was) pre...
# 18   NL-CM:5.4.3  The moment from when the data regarding the co...
# 19   NL-CM:5.4.5  The course of the condition. This is independe...
# 20   NL-CM:5.4.6  Indication of the severity of the condition. A...
# 21   NL-CM:5.4.7  A comment in free text with respect to the con...
#
#                                        definitioncode
# 0               SNOMED CT: 404684003 Clinical finding
# 1                                       PRF performer
# 2              SNOMED CT: 432213005 Date of diagnosis
# 3                                                 NaN
# 4                 SNOMED CT: 418775008 Finding method
# 5                                                 NaN
# 6                      SNOMED CT: 439401001 Diagnosis
# 7                                                 NaN
# 8                 SNOMED CT: 123037004 Body structure
# 9                                                 NaN
# 10  LOINC: 48767-8 Annotation comment [Interpretat...
# 11                                                NaN
# 12                                                NaN
# 13              SNOMED CT: 418019003 Accidental event
# 14                      SNOMED CT: 71388002 Procedure
# 15                                                NaN
# 16                        SNOMED CT: 64572001 Disease
# 17                                                NaN
# 18  SNOMED CT: 350351000146106 Date health conditi...
# 19                                                NaN
# 20                      SNOMED CT: 246112005 Severity
# 21  LOINC: 48767-8 Annotation comment [Interpretat...

# %%
xlmbase = 'xtehr'
xlmspath = os.path.join(xlmbase, 'mappable')
xlms = os.listdir(xlmspath)
[(i, xlm) for i, xlm in enumerate(xlms)]
# Out:
# [(0, 'Address.xlsx'),
#  (1, 'AlertFlag.xlsx'),
#  (2, 'AllergyIntolerance.xlsx'),
#  (3, 'BodyStructure.xlsx'),
#  (4, 'Condition.xlsx'),
#  (5, 'DataSet.xlsx'),
#  (6, 'Device.xlsx'),
#  (7, 'DeviceUse.xlsx'),
#  (8, 'HealthProfessional.xlsx'),
#  (9, 'HumanName.xlsx'),
#  (10, 'Location.xlsx'),
#  (11, 'Medication.xlsx'),
#  (12, 'Organization.xlsx'),
#  (13, 'Patient.xlsx'),
#  (14, 'Procedure.xlsx'),
#  (15, 'Telecom.xlsx')]

# %%
xlm = xlms[4]
print( xlm)
xlmpath = os.path.join(xlmspath, xlm)
xlmdf = pd.read_excel(xlmpath)
xlmdf
# only for device use and organization
# xlm = xlms[7]
# print( xlm)
# xlmpath = os.path.join(xlmspath, xlm)
# xlmdf2 = pd.read_excel(xlmpath)
# xlmdf = pd.concat([xlmdf, xlmdf2], ignore_index=True)
# xlmdf
# Out:
# Condition.xlsx
#                                            id  \
# 0                               EHDSCondition
# 1                        EHDSCondition.header
# 2                EHDSCondition.header.subject
# 3             EHDSCondition.header.identifier
# 4             EHDSCondition.header.authorship
# 5   EHDSCondition.header.authorship.author[x]
# 6    EHDSCondition.header.authorship.datetime
# 7             EHDSCondition.header.lastUpdate
# 8                 EHDSCondition.header.status
# 9        EHDSCondition.header.statusReason[x]
# 10              EHDSCondition.header.language
# 11               EHDSCondition.header.version
# 12                EHDSCondition.presentedForm
# 13                      EHDSCondition.problem
# 14                    EHDSCondition.onsetDate
# 15                      EHDSCondition.endDate
# 16                     EHDSCondition.category
# 17                EHDSCondition.problemStatus
# 18      EHDSCondition.resolutionCircumstances
# 19                     EHDSCondition.severity
# 20             EHDSCondition.anatomicLocation
# 21                        EHDSCondition.stage
# 22     EHDSCondition.diagnosisAssertionStatus
# 23                     EHDSCondition.asserter
# 24                 EHDSCondition.assertedDate
# 25            EHDSCondition.specialistContact
# 26             EHDSCondition.externalResource
#
#                                          path  \
# 0                               EHDSCondition
# 1                        EHDSCondition.header
# 2                EHDSCondition.header.subject
# 3             EHDSCondition.header.identifier
# 4             EHDSCondition.header.authorship
# 5   EHDSCondition.header.authorship.author[x]
# 6    EHDSCondition.header.authorship.datetime
# 7             EHDSCondition.header.lastUpdate
# 8                 EHDSCondition.header.status
# 9        EHDSCondition.header.statusReason[x]
# 10              EHDSCondition.header.language
# 11               EHDSCondition.header.version
# 12                EHDSCondition.presentedForm
# 13                      EHDSCondition.problem
# 14                    EHDSCondition.onsetDate
# 15                      EHDSCondition.endDate
# 16                     EHDSCondition.category
# 17                EHDSCondition.problemStatus
# 18      EHDSCondition.resolutionCircumstances
# 19                     EHDSCondition.severity
# 20             EHDSCondition.anatomicLocation
# 21                        EHDSCondition.stage
# 22     EHDSCondition.diagnosisAssertionStatus
# 23                     EHDSCondition.asserter
# 24                 EHDSCondition.assertedDate
# 25            EHDSCondition.specialistContact
# 26             EHDSCondition.externalResource
#
#                                                 short  \
# 0                                     Condition model
# 1          Common header for all patient-related data
# 2                                             Subject
# 3                  Business identifier for the object
# 4                                          Authorship
# 5                                              Author
# 6                  Date and time of authoring/issuing
# 7    Date and time of the last update to the resource
# 8                              Status of the resource
# 9      Reason for the current status of the resource.
# 10                                           Language
# 11                                            Version
# 12  A narrative easy-to-read representation of the...
# 13  Code identifying the condition, problem or dia...
# 14                  Onset date of a problem/condition
# 15  The date or estimated date that the condition ...
# 16  Category or categories of the problem (e.g. PO...
# 17  Status of the condition/problem (active, resol...
# 18  Describes the reason for which the status of t...
# 19  A subjective assessment of the severity of the...
# 20  The anatomical location including laterality w...
# 21  Stage/grade usually assessed formally using a ...
# 22  Assertion about the certainty associated with ...
# 23                      The asserter of the condition
# 24           Date and time of the diagnosis assertion
# 25  Health Professional who may be specifically re...
# 26  External Resource which may be specifically re...
#
#                                            definition                    type  \
# 0   EHDS refined base model for a clinical conditi...                     NaN
# 1          Common header for all patient-related data                    Base
# 2                         Patient/subject information             EHDSPatient
# 3                  Business identifier for the object              Identifier
# 4                          Resource authoring details                    Base
# 5   Author(s) by whom the resource was/were author...  EHDSHealthProfessional
# 6   Date and time of the issuing the document/reso...                dateTime
# 7   Date and time of the last update to the docume...                dateTime
# 8                              Status of the resource         CodeableConcept
# 9      Reason for the current status of the resource.         CodeableConcept
# 10  Language in which the resource is written. Lan...         CodeableConcept
# 11                  Business version of the resource.                  string
# 12  A narrative easy-to-read representation of the...          EHDSAttachment
# 13  Code identifying the condition, problem or dia...         CodeableConcept
# 14                  Onset date of a problem/condition                dateTime
# 15  The date or estimated date that the condition ...                dateTime
# 16  Category or categories of the problem (e.g. PO...         CodeableConcept
# 17  Status of the condition/problem (active, resol...         CodeableConcept
# 18  This field includes free text if the resolutio...                  string
# 19  A subjective assessment of the severity of the...         CodeableConcept
# 20  The anatomical location including laterality w...       EHDSBodyStructure
# 21  Stage/grade usually assessed formally using a ...         CodeableConcept
# 22  Assertion about the certainty associated with ...         CodeableConcept
# 23                      The asserter of the condition  EHDSHealthProfessional
# 24           Date and time of the diagnosis assertion                dateTime
# 25  Health Professional who may be specifically re...  EHDSHealthProfessional
# 26  External Resource which may be specifically re...                     uri
#
#    card.                                            binding
# 0   0..*                                                NaN
# 1   1..1                                                NaN
# 2   1..1                                                NaN
# 3   0..*                                                NaN
# 4   1..*                                                NaN
# 5   1..1                                                NaN
# 6   1..1                                                NaN
# 7   0..1                                                NaN
# 8   1..1                                                NaN
# 9   0..1                                                NaN
# 10  0..1  {'strength': 'preferred', 'description': 'BCP ...
# 11  0..1                                                NaN
# 12  0..*                                                NaN
# 13  1..1  {'strength': 'preferred', 'description': 'ICD-...
# 14  0..1                                                NaN
# 15  0..1                                                NaN
# 16  0..*                                                NaN
# 17  0..1  {'strength': 'preferred', 'description': 'HL7 ...
# 18  0..*                                                NaN
# 19  0..1  {'strength': 'preferred', 'description': 'HL7 ...
# 20  0..*                                                NaN
# 21  0..*  {'strength': 'preferred', 'description': 'e.g....
# 22  0..1  {'strength': 'preferred', 'description': 'HL7 ...
# 23  0..1                                                NaN
# 24  0..1                                                NaN
# 25  0..*                                                NaN
# 26  0..*                                                NaN

# %%
mapbase = 'maps'
maps = os.listdir(mapbase)
[(i, map) for i, map in enumerate(maps)]
# Out:
# [(0, 'Address.xlsx'),
#  (1, 'AlertFlag.xlsx'),
#  (2, 'BodyStructure.xlsx'),
#  (3, 'Condition.xlsx'),
#  (4, 'DataSet.xlsx'),
#  (5, 'Device-and-DeviceUse.xlsx'),
#  (6, 'Diagnosis.xlsx'),
#  (7, 'HealthProfessional.xlsx'),
#  (8, 'HumanName.xlsx'),
#  (9, 'Location-and-Organization.xlsx'),
#  (10, 'Patient.xlsx'),
#  (11, 'Procedure-NusringIntervention.xlsx'),
#  (12, 'Procedure.xlsx'),
#  (13, 'xtehr2zibs'),
#  (14, 'xtehr2zibs2024')]

# %%
file = maps[6]
print(file)
mappath = os.path.join(mapbase, file)
print(mappath)
mapdf = pd.read_excel(mappath)
mapdf
# Out:
# Diagnosis.xlsx
# maps\Diagnosis.xlsx
#                                         xtehr  \
# 0                               EHDSCondition
# 1                               EHDSCondition
# 2                        EHDSCondition.header
# 3                EHDSCondition.header.subject
# 4             EHDSCondition.header.identifier
# 5             EHDSCondition.header.authorship
# 6   EHDSCondition.header.authorship.author[x]
# 7    EHDSCondition.header.authorship.datetime
# 8             EHDSCondition.header.lastUpdate
# 9                 EHDSCondition.header.status
# 10       EHDSCondition.header.statusReason[x]
# 11              EHDSCondition.header.language
# 12               EHDSCondition.header.version
# 13                EHDSCondition.presentedForm
# 14                     EHDSCondition.asserter
# 15                 EHDSCondition.assertedDate
# 16     EHDSCondition.diagnosisAssertionStatus
# 17                                        NaN
# 18                                        NaN
# 19                      EHDSCondition.problem
# 20                                        NaN
# 21             EHDSCondition.anatomicLocation
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                    EHDSCondition.onsetDate
# 30                      EHDSCondition.endDate
# 31                     EHDSCondition.category
# 32                EHDSCondition.problemStatus
# 33      EHDSCondition.resolutionCircumstances
# 34                     EHDSCondition.severity
# 35                        EHDSCondition.stage
# 36            EHDSCondition.specialistContact
# 37             EHDSCondition.externalResource
# 38                                        NaN
# 39                                        NaN
#
#                                                   zib
# 0                                           Diagnosis
# 1                                           Condition
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14        Diagnosis.Diagnostician::HealthProfessional
# 15                            Diagnosis.DiagnosisDate
# 16                          Diagnosis.DiagnosisStatus
# 17                     Diagnosis.MethodOfConfirmation
# 18                        Diagnosis.DiagnosisNameData
# 19          Diagnosis.DiagnosisNameData.DiagnosisName
# 20  Diagnosis.DiagnosisNameData.FurtherSpecificati...
# 21                       Diagnosis.AnatomicalLocation
# 22                                Diagnosis.Condition
# 23                                  Diagnosis.Comment
# 24                           Diagnosis.IsComplication
# 25                                   Diagnosis.Reason
# 26                          Diagnosis.Reason.Incident
# 27                         Diagnosis.Reason.Procedure
# 28                         Diagnosis.Reason.Diagnosis
# 29              Condition.PeriodPresent::TimeInterval
# 30              Condition.PeriodPresent::TimeInterval
# 31                                                NaN
# 32                                   Condition.Course
# 33                                                NaN
# 34                                 Condition.Severity
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                               Condition.StatusDate
# 39                                  Condition.Comment

# %%
mapping = mapdf[['xtehr', 'zib']].merge(zibdf.add_suffix('_zib'), left_on='zib', right_on='path_zib', how='outer').merge(xlmdf.add_suffix('_xtehr'), left_on='xtehr', right_on='path_xtehr', how='outer')
mapping
# Out:
#                                         xtehr  \
# 0                               EHDSCondition
# 1                               EHDSCondition
# 2              EHDSCondition.anatomicLocation
# 3                  EHDSCondition.assertedDate
# 4                      EHDSCondition.asserter
# 5                      EHDSCondition.category
# 6      EHDSCondition.diagnosisAssertionStatus
# 7                       EHDSCondition.endDate
# 8              EHDSCondition.externalResource
# 9                        EHDSCondition.header
# 10            EHDSCondition.header.authorship
# 11  EHDSCondition.header.authorship.author[x]
# 12   EHDSCondition.header.authorship.datetime
# 13            EHDSCondition.header.identifier
# 14              EHDSCondition.header.language
# 15            EHDSCondition.header.lastUpdate
# 16                EHDSCondition.header.status
# 17       EHDSCondition.header.statusReason[x]
# 18               EHDSCondition.header.subject
# 19               EHDSCondition.header.version
# 20                    EHDSCondition.onsetDate
# 21                EHDSCondition.presentedForm
# 22                      EHDSCondition.problem
# 23                EHDSCondition.problemStatus
# 24      EHDSCondition.resolutionCircumstances
# 25                     EHDSCondition.severity
# 26            EHDSCondition.specialistContact
# 27                        EHDSCondition.stage
# 28                                        NaN
# 29                                        NaN
# 30                                        NaN
# 31                                        NaN
# 32                                        NaN
# 33                                        NaN
# 34                                        NaN
# 35                                        NaN
# 36                                        NaN
# 37                                        NaN
# 38                                        NaN
# 39                                        NaN
#
#                                                   zib  \
# 0                                           Condition
# 1                                           Diagnosis
# 2                        Diagnosis.AnatomicalLocation
# 3                             Diagnosis.DiagnosisDate
# 4         Diagnosis.Diagnostician::HealthProfessional
# 5                                                 NaN
# 6                           Diagnosis.DiagnosisStatus
# 7               Condition.PeriodPresent::TimeInterval
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20              Condition.PeriodPresent::TimeInterval
# 21                                                NaN
# 22          Diagnosis.DiagnosisNameData.DiagnosisName
# 23                                   Condition.Course
# 24                                                NaN
# 25                                 Condition.Severity
# 26                                                NaN
# 27                                                NaN
# 28                                  Condition.Comment
# 29                               Condition.StatusDate
# 30                                  Diagnosis.Comment
# 31                                Diagnosis.Condition
# 32                        Diagnosis.DiagnosisNameData
# 33  Diagnosis.DiagnosisNameData.FurtherSpecificati...
# 34                           Diagnosis.IsComplication
# 35                     Diagnosis.MethodOfConfirmation
# 36                                   Diagnosis.Reason
# 37                         Diagnosis.Reason.Diagnosis
# 38                          Diagnosis.Reason.Incident
# 39                         Diagnosis.Reason.Procedure
#
#                              name_zib  \
# 0                           Condition
# 1                           Diagnosis
# 2                  AnatomicalLocation
# 3                       DiagnosisDate
# 4   Diagnostician::HealthProfessional
# 5                                 NaN
# 6                     DiagnosisStatus
# 7         PeriodPresent::TimeInterval
# 8                                 NaN
# 9                                 NaN
# 10                                NaN
# 11                                NaN
# 12                                NaN
# 13                                NaN
# 14                                NaN
# 15                                NaN
# 16                                NaN
# 17                                NaN
# 18                                NaN
# 19                                NaN
# 20        PeriodPresent::TimeInterval
# 21                                NaN
# 22                      DiagnosisName
# 23                             Course
# 24                                NaN
# 25                           Severity
# 26                                NaN
# 27                                NaN
# 28                            Comment
# 29                         StatusDate
# 30                            Comment
# 31                          Condition
# 32                  DiagnosisNameData
# 33  FurtherSpecificationDiagnosisName
# 34                     IsComplication
# 35               MethodOfConfirmation
# 36                             Reason
# 37                          Diagnosis
# 38                           Incident
# 39                          Procedure
#
#                                              path_zib  \
# 0                                           Condition
# 1                                           Diagnosis
# 2                        Diagnosis.AnatomicalLocation
# 3                             Diagnosis.DiagnosisDate
# 4         Diagnosis.Diagnostician::HealthProfessional
# 5                                                 NaN
# 6                           Diagnosis.DiagnosisStatus
# 7               Condition.PeriodPresent::TimeInterval
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20              Condition.PeriodPresent::TimeInterval
# 21                                                NaN
# 22          Diagnosis.DiagnosisNameData.DiagnosisName
# 23                                   Condition.Course
# 24                                                NaN
# 25                                 Condition.Severity
# 26                                                NaN
# 27                                                NaN
# 28                                  Condition.Comment
# 29                               Condition.StatusDate
# 30                                  Diagnosis.Comment
# 31                                Diagnosis.Condition
# 32                        Diagnosis.DiagnosisNameData
# 33  Diagnosis.DiagnosisNameData.FurtherSpecificati...
# 34                           Diagnosis.IsComplication
# 35                     Diagnosis.MethodOfConfirmation
# 36                                   Diagnosis.Reason
# 37                         Diagnosis.Reason.Diagnosis
# 38                          Diagnosis.Reason.Incident
# 39                         Diagnosis.Reason.Procedure
#
#                              alias_zib type_zib card._zib     stereotype_zib  \
# 0          NL: AandoeningOfGesteldheid      NaN       NaN        rootconcept
# 1                         NL: Diagnose      NaN       NaN        rootconcept
# 2               NL: AnatomischeLocatie      NaN      0..*     data,reference
# 3                    NL: DiagnoseDatum       TS         1               data
# 4    NL: DiagnoseSteller::Zorgverlener      NaN         1  context,reference
# 5                                  NaN      NaN       NaN                NaN
# 6                   NL: DiagnoseStatus       CD         1               data
# 7   NL: PeriodeAanwezig::TijdsInterval      NaN         1     data,reference
# 8                                  NaN      NaN       NaN                NaN
# 9                                  NaN      NaN       NaN                NaN
# 10                                 NaN      NaN       NaN                NaN
# 11                                 NaN      NaN       NaN                NaN
# 12                                 NaN      NaN       NaN                NaN
# 13                                 NaN      NaN       NaN                NaN
# 14                                 NaN      NaN       NaN                NaN
# 15                                 NaN      NaN       NaN                NaN
# 16                                 NaN      NaN       NaN                NaN
# 17                                 NaN      NaN       NaN                NaN
# 18                                 NaN      NaN       NaN                NaN
# 19                                 NaN      NaN       NaN                NaN
# 20  NL: PeriodeAanwezig::TijdsInterval      NaN         1     data,reference
# 21                                 NaN      NaN       NaN                NaN
# 22                    NL: DiagnoseNaam       CD         1               data
# 23                          NL: Beloop       CD      0..1               data
# 24                                 NaN      NaN       NaN                NaN
# 25                           NL: Ernst       CD         1               data
# 26                                 NaN      NaN       NaN                NaN
# 27                                 NaN      NaN       NaN                NaN
# 28                     NL: Toelichting       ST      0..1               data
# 29                     NL: StatusDatum       TS         1               data
# 30                     NL: Toelichting       ST      0..1               data
# 31         NL: AandoeningOfGesteldheid      NaN      0..1     data,reference
# 32            NL: DiagnoseNaamGegevens      NaN      1..*          container
# 33  NL: NadereSpecificatieDiagnoseNaam       ST      0..1               data
# 34                   NL: IsComplicatie       BL      0..1               data
# 35             NL: WijzeVanVaststellen       CD         1               data
# 36                      NL: Aanleiding      NaN      0..*          container
# 37                        NL: Diagnose      NaN    (0..1)     data,reference
# 38                        NL: Incident       CD    (0..1)               data
# 39                     NL: Verrichting      NaN    (0..1)     data,reference
#
#           id_zib                                     definition_zib  \
# 0    NL-CM:5.4.1  This is a reference to the root concept of inf...
# 1    NL-CM:5.6.1  Root concept of the Diagnosis information mode...
# 2    NL-CM:5.6.9  The location(s) on and/or in the body that is/...
# 3    NL-CM:5.6.3  Date (and time) at which the care professional...
# 4    NL-CM:5.6.2  The care professional who made the diagnosis. ...
# 5            NaN                                                NaN
# 6    NL-CM:5.6.4    Indicates the status of the diagnostic process.
# 7    NL-CM:5.4.8  The period in which the condition is (was) pre...
# 8            NaN                                                NaN
# 9            NaN                                                NaN
# 10           NaN                                                NaN
# 11           NaN                                                NaN
# 12           NaN                                                NaN
# 13           NaN                                                NaN
# 14           NaN                                                NaN
# 15           NaN                                                NaN
# 16           NaN                                                NaN
# 17           NaN                                                NaN
# 18           NaN                                                NaN
# 19           NaN                                                NaN
# 20   NL-CM:5.4.8  The period in which the condition is (was) pre...
# 21           NaN                                                NaN
# 22   NL-CM:5.6.7  The term with associated code that the care pr...
# 23   NL-CM:5.4.5  The course of the condition. This is independe...
# 24           NaN                                                NaN
# 25   NL-CM:5.4.6  Indication of the severity of the condition. A...
# 26           NaN                                                NaN
# 27           NaN                                                NaN
# 28   NL-CM:5.4.7  A comment in free text with respect to the con...
# 29   NL-CM:5.4.3  The moment from when the data regarding the co...
# 30  NL-CM:5.6.11  A comment in free text with respect to the dia...
# 31  NL-CM:5.6.10      The Condition to which the Diagnosis applies.
# 32   NL-CM:5.6.6  Container of the DiagnosisNameData concept. Th...
# 33   NL-CM:5.6.8  A more detailed description of the DiagnosisNa...
# 34  NL-CM:5.6.12  Indicates whether or not the diagnosis involve...
# 35   NL-CM:5.6.5  The method that the care professional used to ...
# 36  NL-CM:5.6.13  Container of the Reason concept.This container...
# 37  NL-CM:5.6.16  The diagnosis with regard to another condition...
# 38  NL-CM:5.6.14  The unintended event during the care process t...
# 39  NL-CM:5.6.15  The procedure that gave rise to the condition ...
#
#                                    definitioncode_zib  \
# 0                         SNOMED CT: 64572001 Disease
# 1               SNOMED CT: 404684003 Clinical finding
# 2                 SNOMED CT: 123037004 Body structure
# 3              SNOMED CT: 432213005 Date of diagnosis
# 4                                       PRF performer
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                     SNOMED CT: 439401001 Diagnosis
# 23                                                NaN
# 24                                                NaN
# 25                      SNOMED CT: 246112005 Severity
# 26                                                NaN
# 27                                                NaN
# 28  LOINC: 48767-8 Annotation comment [Interpretat...
# 29  SNOMED CT: 350351000146106 Date health conditi...
# 30  LOINC: 48767-8 Annotation comment [Interpretat...
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                SNOMED CT: 418775008 Finding method
# 36                                                NaN
# 37                                                NaN
# 38              SNOMED CT: 418019003 Accidental event
# 39                      SNOMED CT: 71388002 Procedure
#
#                                      id_xtehr  \
# 0                               EHDSCondition
# 1                               EHDSCondition
# 2              EHDSCondition.anatomicLocation
# 3                  EHDSCondition.assertedDate
# 4                      EHDSCondition.asserter
# 5                      EHDSCondition.category
# 6      EHDSCondition.diagnosisAssertionStatus
# 7                       EHDSCondition.endDate
# 8              EHDSCondition.externalResource
# 9                        EHDSCondition.header
# 10            EHDSCondition.header.authorship
# 11  EHDSCondition.header.authorship.author[x]
# 12   EHDSCondition.header.authorship.datetime
# 13            EHDSCondition.header.identifier
# 14              EHDSCondition.header.language
# 15            EHDSCondition.header.lastUpdate
# 16                EHDSCondition.header.status
# 17       EHDSCondition.header.statusReason[x]
# 18               EHDSCondition.header.subject
# 19               EHDSCondition.header.version
# 20                    EHDSCondition.onsetDate
# 21                EHDSCondition.presentedForm
# 22                      EHDSCondition.problem
# 23                EHDSCondition.problemStatus
# 24      EHDSCondition.resolutionCircumstances
# 25                     EHDSCondition.severity
# 26            EHDSCondition.specialistContact
# 27                        EHDSCondition.stage
# 28                                        NaN
# 29                                        NaN
# 30                                        NaN
# 31                                        NaN
# 32                                        NaN
# 33                                        NaN
# 34                                        NaN
# 35                                        NaN
# 36                                        NaN
# 37                                        NaN
# 38                                        NaN
# 39                                        NaN
#
#                                    path_xtehr  \
# 0                               EHDSCondition
# 1                               EHDSCondition
# 2              EHDSCondition.anatomicLocation
# 3                  EHDSCondition.assertedDate
# 4                      EHDSCondition.asserter
# 5                      EHDSCondition.category
# 6      EHDSCondition.diagnosisAssertionStatus
# 7                       EHDSCondition.endDate
# 8              EHDSCondition.externalResource
# 9                        EHDSCondition.header
# 10            EHDSCondition.header.authorship
# 11  EHDSCondition.header.authorship.author[x]
# 12   EHDSCondition.header.authorship.datetime
# 13            EHDSCondition.header.identifier
# 14              EHDSCondition.header.language
# 15            EHDSCondition.header.lastUpdate
# 16                EHDSCondition.header.status
# 17       EHDSCondition.header.statusReason[x]
# 18               EHDSCondition.header.subject
# 19               EHDSCondition.header.version
# 20                    EHDSCondition.onsetDate
# 21                EHDSCondition.presentedForm
# 22                      EHDSCondition.problem
# 23                EHDSCondition.problemStatus
# 24      EHDSCondition.resolutionCircumstances
# 25                     EHDSCondition.severity
# 26            EHDSCondition.specialistContact
# 27                        EHDSCondition.stage
# 28                                        NaN
# 29                                        NaN
# 30                                        NaN
# 31                                        NaN
# 32                                        NaN
# 33                                        NaN
# 34                                        NaN
# 35                                        NaN
# 36                                        NaN
# 37                                        NaN
# 38                                        NaN
# 39                                        NaN
#
#                                           short_xtehr  \
# 0                                     Condition model
# 1                                     Condition model
# 2   The anatomical location including laterality w...
# 3            Date and time of the diagnosis assertion
# 4                       The asserter of the condition
# 5   Category or categories of the problem (e.g. PO...
# 6   Assertion about the certainty associated with ...
# 7   The date or estimated date that the condition ...
# 8   External Resource which may be specifically re...
# 9          Common header for all patient-related data
# 10                                         Authorship
# 11                                             Author
# 12                 Date and time of authoring/issuing
# 13                 Business identifier for the object
# 14                                           Language
# 15   Date and time of the last update to the resource
# 16                             Status of the resource
# 17     Reason for the current status of the resource.
# 18                                            Subject
# 19                                            Version
# 20                  Onset date of a problem/condition
# 21  A narrative easy-to-read representation of the...
# 22  Code identifying the condition, problem or dia...
# 23  Status of the condition/problem (active, resol...
# 24  Describes the reason for which the status of t...
# 25  A subjective assessment of the severity of the...
# 26  Health Professional who may be specifically re...
# 27  Stage/grade usually assessed formally using a ...
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#                                      definition_xtehr              type_xtehr  \
# 0   EHDS refined base model for a clinical conditi...                     NaN
# 1   EHDS refined base model for a clinical conditi...                     NaN
# 2   The anatomical location including laterality w...       EHDSBodyStructure
# 3            Date and time of the diagnosis assertion                dateTime
# 4                       The asserter of the condition  EHDSHealthProfessional
# 5   Category or categories of the problem (e.g. PO...         CodeableConcept
# 6   Assertion about the certainty associated with ...         CodeableConcept
# 7   The date or estimated date that the condition ...                dateTime
# 8   External Resource which may be specifically re...                     uri
# 9          Common header for all patient-related data                    Base
# 10                         Resource authoring details                    Base
# 11  Author(s) by whom the resource was/were author...  EHDSHealthProfessional
# 12  Date and time of the issuing the document/reso...                dateTime
# 13                 Business identifier for the object              Identifier
# 14  Language in which the resource is written. Lan...         CodeableConcept
# 15  Date and time of the last update to the docume...                dateTime
# 16                             Status of the resource         CodeableConcept
# 17     Reason for the current status of the resource.         CodeableConcept
# 18                        Patient/subject information             EHDSPatient
# 19                  Business version of the resource.                  string
# 20                  Onset date of a problem/condition                dateTime
# 21  A narrative easy-to-read representation of the...          EHDSAttachment
# 22  Code identifying the condition, problem or dia...         CodeableConcept
# 23  Status of the condition/problem (active, resol...         CodeableConcept
# 24  This field includes free text if the resolutio...                  string
# 25  A subjective assessment of the severity of the...         CodeableConcept
# 26  Health Professional who may be specifically re...  EHDSHealthProfessional
# 27  Stage/grade usually assessed formally using a ...         CodeableConcept
# 28                                                NaN                     NaN
# 29                                                NaN                     NaN
# 30                                                NaN                     NaN
# 31                                                NaN                     NaN
# 32                                                NaN                     NaN
# 33                                                NaN                     NaN
# 34                                                NaN                     NaN
# 35                                                NaN                     NaN
# 36                                                NaN                     NaN
# 37                                                NaN                     NaN
# 38                                                NaN                     NaN
# 39                                                NaN                     NaN
#
#    card._xtehr                                      binding_xtehr
# 0         0..*                                                NaN
# 1         0..*                                                NaN
# 2         0..*                                                NaN
# 3         0..1                                                NaN
# 4         0..1                                                NaN
# 5         0..*                                                NaN
# 6         0..1  {'strength': 'preferred', 'description': 'HL7 ...
# 7         0..1                                                NaN
# 8         0..*                                                NaN
# 9         1..1                                                NaN
# 10        1..*                                                NaN
# 11        1..1                                                NaN
# 12        1..1                                                NaN
# 13        0..*                                                NaN
# 14        0..1  {'strength': 'preferred', 'description': 'BCP ...
# 15        0..1                                                NaN
# 16        1..1                                                NaN
# 17        0..1                                                NaN
# 18        1..1                                                NaN
# 19        0..1                                                NaN
# 20        0..1                                                NaN
# 21        0..*                                                NaN
# 22        1..1  {'strength': 'preferred', 'description': 'ICD-...
# 23        0..1  {'strength': 'preferred', 'description': 'HL7 ...
# 24        0..*                                                NaN
# 25        0..1  {'strength': 'preferred', 'description': 'HL7 ...
# 26        0..*                                                NaN
# 27        0..*  {'strength': 'preferred', 'description': 'e.g....
# 28         NaN                                                NaN
# 29         NaN                                                NaN
# 30         NaN                                                NaN
# 31         NaN                                                NaN
# 32         NaN                                                NaN
# 33         NaN                                                NaN
# 34         NaN                                                NaN
# 35         NaN                                                NaN
# 36         NaN                                                NaN
# 37         NaN                                                NaN
# 38         NaN                                                NaN
# 39         NaN                                                NaN

# %%
shortmap = mapping[['zib', 'xtehr', 'type_zib','type_xtehr', 'card._zib', 'card._xtehr']]
shortmap
# Out:
#                                                   zib  \
# 0                                           Condition
# 1                                           Diagnosis
# 2                        Diagnosis.AnatomicalLocation
# 3                             Diagnosis.DiagnosisDate
# 4         Diagnosis.Diagnostician::HealthProfessional
# 5                                                 NaN
# 6                           Diagnosis.DiagnosisStatus
# 7               Condition.PeriodPresent::TimeInterval
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20              Condition.PeriodPresent::TimeInterval
# 21                                                NaN
# 22          Diagnosis.DiagnosisNameData.DiagnosisName
# 23                                   Condition.Course
# 24                                                NaN
# 25                                 Condition.Severity
# 26                                                NaN
# 27                                                NaN
# 28                                  Condition.Comment
# 29                               Condition.StatusDate
# 30                                  Diagnosis.Comment
# 31                                Diagnosis.Condition
# 32                        Diagnosis.DiagnosisNameData
# 33  Diagnosis.DiagnosisNameData.FurtherSpecificati...
# 34                           Diagnosis.IsComplication
# 35                     Diagnosis.MethodOfConfirmation
# 36                                   Diagnosis.Reason
# 37                         Diagnosis.Reason.Diagnosis
# 38                          Diagnosis.Reason.Incident
# 39                         Diagnosis.Reason.Procedure
#
#                                         xtehr type_zib  \
# 0                               EHDSCondition      NaN
# 1                               EHDSCondition      NaN
# 2              EHDSCondition.anatomicLocation      NaN
# 3                  EHDSCondition.assertedDate       TS
# 4                      EHDSCondition.asserter      NaN
# 5                      EHDSCondition.category      NaN
# 6      EHDSCondition.diagnosisAssertionStatus       CD
# 7                       EHDSCondition.endDate      NaN
# 8              EHDSCondition.externalResource      NaN
# 9                        EHDSCondition.header      NaN
# 10            EHDSCondition.header.authorship      NaN
# 11  EHDSCondition.header.authorship.author[x]      NaN
# 12   EHDSCondition.header.authorship.datetime      NaN
# 13            EHDSCondition.header.identifier      NaN
# 14              EHDSCondition.header.language      NaN
# 15            EHDSCondition.header.lastUpdate      NaN
# 16                EHDSCondition.header.status      NaN
# 17       EHDSCondition.header.statusReason[x]      NaN
# 18               EHDSCondition.header.subject      NaN
# 19               EHDSCondition.header.version      NaN
# 20                    EHDSCondition.onsetDate      NaN
# 21                EHDSCondition.presentedForm      NaN
# 22                      EHDSCondition.problem       CD
# 23                EHDSCondition.problemStatus       CD
# 24      EHDSCondition.resolutionCircumstances      NaN
# 25                     EHDSCondition.severity       CD
# 26            EHDSCondition.specialistContact      NaN
# 27                        EHDSCondition.stage      NaN
# 28                                        NaN       ST
# 29                                        NaN       TS
# 30                                        NaN       ST
# 31                                        NaN      NaN
# 32                                        NaN      NaN
# 33                                        NaN       ST
# 34                                        NaN       BL
# 35                                        NaN       CD
# 36                                        NaN      NaN
# 37                                        NaN      NaN
# 38                                        NaN       CD
# 39                                        NaN      NaN
#
#                 type_xtehr card._zib card._xtehr
# 0                      NaN       NaN        0..*
# 1                      NaN       NaN        0..*
# 2        EHDSBodyStructure      0..*        0..*
# 3                 dateTime         1        0..1
# 4   EHDSHealthProfessional         1        0..1
# 5          CodeableConcept       NaN        0..*
# 6          CodeableConcept         1        0..1
# 7                 dateTime         1        0..1
# 8                      uri       NaN        0..*
# 9                     Base       NaN        1..1
# 10                    Base       NaN        1..*
# 11  EHDSHealthProfessional       NaN        1..1
# 12                dateTime       NaN        1..1
# 13              Identifier       NaN        0..*
# 14         CodeableConcept       NaN        0..1
# 15                dateTime       NaN        0..1
# 16         CodeableConcept       NaN        1..1
# 17         CodeableConcept       NaN        0..1
# 18             EHDSPatient       NaN        1..1
# 19                  string       NaN        0..1
# 20                dateTime         1        0..1
# 21          EHDSAttachment       NaN        0..*
# 22         CodeableConcept         1        1..1
# 23         CodeableConcept      0..1        0..1
# 24                  string       NaN        0..*
# 25         CodeableConcept         1        0..1
# 26  EHDSHealthProfessional       NaN        0..*
# 27         CodeableConcept       NaN        0..*
# 28                     NaN      0..1         NaN
# 29                     NaN         1         NaN
# 30                     NaN      0..1         NaN
# 31                     NaN      0..1         NaN
# 32                     NaN      1..*         NaN
# 33                     NaN      0..1         NaN
# 34                     NaN      0..1         NaN
# 35                     NaN         1         NaN
# 36                     NaN      0..*         NaN
# 37                     NaN    (0..1)         NaN
# 38                     NaN    (0..1)         NaN
# 39                     NaN    (0..1)         NaN

# %%
mapsoutpath = os.path.join(mapbase, 'xtehr2zibs2024')
filepath = file.replace('.xlsx', '-full.xlsx')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_excel(mappath, index=False)

# %%
filepath = file.replace('.xlsx', '.csv')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_csv(mappath, index=False)

# %%
from IPython.display import Markdown
import numpy as np

content = "# " + mapping.iat[0, 0][4:] + "\n\n"
content += shortmap.fillna('').to_markdown(index=False) + "\n\n"
for i, row in mapping.iterrows():
    # print(i, row)
    content += "\n\n"
    if row.iloc[0] is not np.nan:
        content += "## " + str(row.iloc[0]) + "\n\n"
    else:
        content += "## zib: " + str(row.iloc[1]) + "\n\n"
    content += "### Table" + "\n\n"
    content += "| attribute | value |" + "\n" + "|---|---|" + "\n"
    for j, att in row.fillna('')[0:2].items():
        content += "| " + str(j) + " | " + str(att) + " |" + "\n"
    for j, att in row.fillna('')[2:].sort_index().items():
        if len(str(att)) > 0:
            content += "| " + str(j) + " | " + str(att) + " |" + "\n"    
    content += "\n### Comments" + "\n\n"
with open(os.path.join(mapsoutpath, file.replace('.xlsx', '.md')), 'w') as f:
    f.write(content)
# PAS OP: deze overschrijft de eventueel met de hand gemaakte comments files, alleen gebruiken
# bij eerste keer dat je een mapping maakt, daarna de comments handmatig aanpassen
# with open(os.path.join(mapsoutpath, file.replace('.xlsx', '-comments.md')), 'w') as f:
#     f.write(content)
Markdown(content)
# Out:
# # Condition
#
# | zib                                                           | xtehr                                     | type_zib   | type_xtehr             | card._zib   | card._xtehr   |
# |:--------------------------------------------------------------|:------------------------------------------|:-----------|:-----------------------|:------------|:--------------|
# | Condition                                                     | EHDSCondition                             |            |                        |             | 0..*          |
# | Diagnosis                                                     | EHDSCondition                             |            |                        |             | 0..*          |
# | Diagnosis.AnatomicalLocation                                  | EHDSCondition.anatomicLocation            |            | EHDSBodyStructure      | 0..*        | 0..*          |
# | Diagnosis.DiagnosisDate                                       | EHDSCondition.assertedDate                | TS         | dateTime               | 1           | 0..1          |
# | Diagnosis.Diagnostician::HealthProfessional                   | EHDSCondition.asserter                    |            | EHDSHealthProfessional | 1           | 0..1          |
# |                                                               | EHDSCondition.category                    |            | CodeableConcept        |             | 0..*          |
# | Diagnosis.DiagnosisStatus                                     | EHDSCondition.diagnosisAssertionStatus    | CD         | CodeableConcept        | 1           | 0..1          |
# | Condition.PeriodPresent::TimeInterval                         | EHDSCondition.endDate                     |            | dateTime               | 1           | 0..1          |
# |                                                               | EHDSCondition.externalResource            |            | uri                    |             | 0..*          |
# |                                                               | EHDSCondition.header                      |            | Base                   |             | 1..1          |
# |                                                               | EHDSCondition.header.authorship           |            | Base                   |             | 1..*          |
# |                                                               | EHDSCondition.header.authorship.author[x] |            | EHDSHealthProfessional |             | 1..1          |
# |                                                               | EHDSCondition.header.authorship.datetime  |            | dateTime               |             | 1..1          |
# |                                                               | EHDSCondition.header.identifier           |            | Identifier             |             | 0..*          |
# |                                                               | EHDSCondition.header.language             |            | CodeableConcept        |             | 0..1          |
# |                                                               | EHDSCondition.header.lastUpdate           |            | dateTime               |             | 0..1          |
# |                                                               | EHDSCondition.header.status               |            | CodeableConcept        |             | 1..1          |
# |                                                               | EHDSCondition.header.statusReason[x]      |            | CodeableConcept        |             | 0..1          |
# |                                                               | EHDSCondition.header.subject              |            | EHDSPatient            |             | 1..1          |
# |                                                               | EHDSCondition.header.version              |            | string                 |             | 0..1          |
# | Condition.PeriodPresent::TimeInterval                         | EHDSCondition.onsetDate                   |            | dateTime               | 1           | 0..1          |
# |                                                               | EHDSCondition.presentedForm               |            | EHDSAttachment         |             | 0..*          |
# | Diagnosis.DiagnosisNameData.DiagnosisName                     | EHDSCondition.problem                     | CD         | CodeableConcept        | 1           | 1..1          |
# | Condition.Course                                              | EHDSCondition.problemStatus               | CD         | CodeableConcept        | 0..1        | 0..1          |
# |                                                               | EHDSCondition.resolutionCircumstances     |            | string                 |             | 0..*          |
# | Condition.Severity                                            | EHDSCondition.severity                    | CD         | CodeableConcept        | 1           | 0..1          |
# |                                                               | EHDSCondition.specialistContact           |            | EHDSHealthProfessional |             | 0..*          |
# |                                                               | EHDSCondition.stage                       |            | CodeableConcept        |             | 0..*          |
# | Condition.Comment                                             |                                           | ST         |                        | 0..1        |               |
# | Condition.StatusDate                                          |                                           | TS         |                        | 1           |               |
# | Diagnosis.Comment                                             |                                           | ST         |                        | 0..1        |               |
# | Diagnosis.Condition                                           |                                           |            |                        | 0..1        |               |
# | Diagnosis.DiagnosisNameData                                   |                                           |            |                        | 1..*        |               |
# | Diagnosis.DiagnosisNameData.FurtherSpecificationDiagnosisName |                                           | ST         |                        | 0..1        |               |
# | Diagnosis.IsComplication                                      |                                           | BL         |                        | 0..1        |               |
# | Diagnosis.MethodOfConfirmation                                |                                           | CD         |                        | 1           |               |
# | Diagnosis.Reason                                              |                                           |            |                        | 0..*        |               |
# | Diagnosis.Reason.Diagnosis                                    |                                           |            |                        | (0..1)      |               |
# | Diagnosis.Reason.Incident                                     |                                           | CD         |                        | (0..1)      |               |
# | Diagnosis.Reason.Procedure                                    |                                           |            |                        | (0..1)      |               |
#
#
#
# ## EHDSCondition
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition |
# | zib | Condition |
# | alias_zib | NL: AandoeningOfGesteldheid |
# | card._xtehr | 0..* |
# | definition_xtehr | EHDS refined base model for a clinical condition, problem, diagnosis, or other event, situation, issue, or clinical concept that has risen to a level of concern. |
# | definition_zib | This is a reference to the root concept of information model Condition. This root concept contains all data elements of the information model Condition. |
# | definitioncode_zib | SNOMED CT: 64572001 Disease |
# | id_xtehr | EHDSCondition |
# | id_zib | NL-CM:5.4.1 |
# | name_zib | Condition |
# | path_xtehr | EHDSCondition |
# | path_zib | Condition |
# | short_xtehr | Condition model |
# | stereotype_zib | rootconcept |
#
# ### Comments
#
#
#
# ## EHDSCondition
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition |
# | zib | Diagnosis |
# | alias_zib | NL: Diagnose |
# | card._xtehr | 0..* |
# | definition_xtehr | EHDS refined base model for a clinical condition, problem, diagnosis, or other event, situation, issue, or clinical concept that has risen to a level of concern. |
# | definition_zib | Root concept of the Diagnosis information model. This root concept contains all data elements of the Diagnosis information model. |
# | definitioncode_zib | SNOMED CT: 404684003 Clinical finding |
# | id_xtehr | EHDSCondition |
# | id_zib | NL-CM:5.6.1 |
# | name_zib | Diagnosis |
# | path_xtehr | EHDSCondition |
# | path_zib | Diagnosis |
# | short_xtehr | Condition model |
# | stereotype_zib | rootconcept |
#
# ### Comments
#
#
#
# ## EHDSCondition.anatomicLocation
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.anatomicLocation |
# | zib | Diagnosis.AnatomicalLocation |
# | alias_zib | NL: AnatomischeLocatie |
# | card._xtehr | 0..* |
# | card._zib | 0..* |
# | definition_xtehr | The anatomical location including laterality where this condition manifests itself. |
# | definition_zib | The location(s) on and/or in the body that is/are affected by the condition, conform the diagnostics. |
# | definitioncode_zib | SNOMED CT: 123037004 Body structure |
# | id_xtehr | EHDSCondition.anatomicLocation |
# | id_zib | NL-CM:5.6.9 |
# | name_zib | AnatomicalLocation |
# | path_xtehr | EHDSCondition.anatomicLocation |
# | path_zib | Diagnosis.AnatomicalLocation |
# | short_xtehr | The anatomical location including laterality where this condition manifests itself. |
# | stereotype_zib | data,reference |
# | type_xtehr | EHDSBodyStructure |
#
# ### Comments
#
#
#
# ## EHDSCondition.assertedDate
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.assertedDate |
# | zib | Diagnosis.DiagnosisDate |
# | alias_zib | NL: DiagnoseDatum |
# | card._xtehr | 0..1 |
# | card._zib | 1 |
# | definition_xtehr | Date and time of the diagnosis assertion |
# | definition_zib | Date (and time) at which the care professional came to the diagnosis. |
# | definitioncode_zib | SNOMED CT: 432213005 Date of diagnosis |
# | id_xtehr | EHDSCondition.assertedDate |
# | id_zib | NL-CM:5.6.3 |
# | name_zib | DiagnosisDate |
# | path_xtehr | EHDSCondition.assertedDate |
# | path_zib | Diagnosis.DiagnosisDate |
# | short_xtehr | Date and time of the diagnosis assertion |
# | stereotype_zib | data |
# | type_xtehr | dateTime |
# | type_zib | TS |
#
# ### Comments
#
#
#
# ## EHDSCondition.asserter
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.asserter |
# | zib | Diagnosis.Diagnostician::HealthProfessional |
# | alias_zib | NL: DiagnoseSteller::Zorgverlener |
# | card._xtehr | 0..1 |
# | card._zib | 1 |
# | definition_xtehr | The asserter of the condition |
# | definition_zib | The care professional who made the diagnosis. This can be a different individual than the person who recorded the diagnosis. |
# | definitioncode_zib | PRF performer |
# | id_xtehr | EHDSCondition.asserter |
# | id_zib | NL-CM:5.6.2 |
# | name_zib | Diagnostician::HealthProfessional |
# | path_xtehr | EHDSCondition.asserter |
# | path_zib | Diagnosis.Diagnostician::HealthProfessional |
# | short_xtehr | The asserter of the condition |
# | stereotype_zib | context,reference |
# | type_xtehr | EHDSHealthProfessional |
#
# ### Comments
#
#
#
# ## EHDSCondition.category
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.category |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | Category or categories of the problem (e.g. POA - present on admission, HAC - hospital aquired condition, and other categorisations). |
# | id_xtehr | EHDSCondition.category |
# | path_xtehr | EHDSCondition.category |
# | short_xtehr | Category or categories of the problem (e.g. POA - present on admission, HAC - hospital aquired condition, and other categorisations). |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSCondition.diagnosisAssertionStatus
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.diagnosisAssertionStatus |
# | zib | Diagnosis.DiagnosisStatus |
# | alias_zib | NL: DiagnoseStatus |
# | binding_xtehr | {'strength': 'preferred', 'description': 'HL7 Condition Verification Status'} |
# | card._xtehr | 0..1 |
# | card._zib | 1 |
# | definition_xtehr | Assertion about the certainty associated with a diagnosis. Diagnostic and/or clinical evidence of condition. |
# | definition_zib | Indicates the status of the diagnostic process. |
# | id_xtehr | EHDSCondition.diagnosisAssertionStatus |
# | id_zib | NL-CM:5.6.4 |
# | name_zib | DiagnosisStatus |
# | path_xtehr | EHDSCondition.diagnosisAssertionStatus |
# | path_zib | Diagnosis.DiagnosisStatus |
# | short_xtehr | Assertion about the certainty associated with a diagnosis. Diagnostic and/or clinical evidence of condition. |
# | stereotype_zib | data |
# | type_xtehr | CodeableConcept |
# | type_zib | CD |
#
# ### Comments
#
#
#
# ## EHDSCondition.endDate
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.endDate |
# | zib | Condition.PeriodPresent::TimeInterval |
# | alias_zib | NL: PeriodeAanwezig::TijdsInterval |
# | card._xtehr | 0..1 |
# | card._zib | 1 |
# | definition_xtehr | The date or estimated date that the condition resolved or went into remission |
# | definition_zib | The period in which the condition is (was) present. |
# | id_xtehr | EHDSCondition.endDate |
# | id_zib | NL-CM:5.4.8 |
# | name_zib | PeriodPresent::TimeInterval |
# | path_xtehr | EHDSCondition.endDate |
# | path_zib | Condition.PeriodPresent::TimeInterval |
# | short_xtehr | The date or estimated date that the condition resolved or went into remission |
# | stereotype_zib | data,reference |
# | type_xtehr | dateTime |
#
# ### Comments
#
#
#
# ## EHDSCondition.externalResource
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.externalResource |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | External Resource which may be specifically related to the problem, for example a link between a rare disease problem and the corresponding guidelines. |
# | id_xtehr | EHDSCondition.externalResource |
# | path_xtehr | EHDSCondition.externalResource |
# | short_xtehr | External Resource which may be specifically related to the problem, for example a link between a rare disease problem and the corresponding guidelines. |
# | type_xtehr | uri |
#
# ### Comments
#
#
#
# ## EHDSCondition.header
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.header |
# | zib |  |
# | card._xtehr | 1..1 |
# | definition_xtehr | Common header for all patient-related data |
# | id_xtehr | EHDSCondition.header |
# | path_xtehr | EHDSCondition.header |
# | short_xtehr | Common header for all patient-related data |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSCondition.header.authorship
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.header.authorship |
# | zib |  |
# | card._xtehr | 1..* |
# | definition_xtehr | Resource authoring details |
# | id_xtehr | EHDSCondition.header.authorship |
# | path_xtehr | EHDSCondition.header.authorship |
# | short_xtehr | Authorship |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSCondition.header.authorship.author[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.header.authorship.author[x] |
# | zib |  |
# | card._xtehr | 1..1 |
# | definition_xtehr | Author(s) by whom the resource was/were authored. Multiple authors could be provided. |
# | id_xtehr | EHDSCondition.header.authorship.author[x] |
# | path_xtehr | EHDSCondition.header.authorship.author[x] |
# | short_xtehr | Author |
# | type_xtehr | EHDSHealthProfessional |
#
# ### Comments
#
#
#
# ## EHDSCondition.header.authorship.datetime
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.header.authorship.datetime |
# | zib |  |
# | card._xtehr | 1..1 |
# | definition_xtehr | Date and time of the issuing the document/resource by its author. |
# | id_xtehr | EHDSCondition.header.authorship.datetime |
# | path_xtehr | EHDSCondition.header.authorship.datetime |
# | short_xtehr | Date and time of authoring/issuing |
# | type_xtehr | dateTime |
#
# ### Comments
#
#
#
# ## EHDSCondition.header.identifier
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.header.identifier |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | Business identifier for the object |
# | id_xtehr | EHDSCondition.header.identifier |
# | path_xtehr | EHDSCondition.header.identifier |
# | short_xtehr | Business identifier for the object |
# | type_xtehr | Identifier |
#
# ### Comments
#
#
#
# ## EHDSCondition.header.language
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.header.language |
# | zib |  |
# | binding_xtehr | {'strength': 'preferred', 'description': 'BCP 47'} |
# | card._xtehr | 0..1 |
# | definition_xtehr | Language in which the resource is written. Language is expressed by the IETF language tag. |
# | id_xtehr | EHDSCondition.header.language |
# | path_xtehr | EHDSCondition.header.language |
# | short_xtehr | Language |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSCondition.header.lastUpdate
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.header.lastUpdate |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Date and time of the last update to the document/information |
# | id_xtehr | EHDSCondition.header.lastUpdate |
# | path_xtehr | EHDSCondition.header.lastUpdate |
# | short_xtehr | Date and time of the last update to the resource |
# | type_xtehr | dateTime |
#
# ### Comments
#
#
#
# ## EHDSCondition.header.status
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.header.status |
# | zib |  |
# | card._xtehr | 1..1 |
# | definition_xtehr | Status of the resource |
# | id_xtehr | EHDSCondition.header.status |
# | path_xtehr | EHDSCondition.header.status |
# | short_xtehr | Status of the resource |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSCondition.header.statusReason[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.header.statusReason[x] |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Reason for the current status of the resource. |
# | id_xtehr | EHDSCondition.header.statusReason[x] |
# | path_xtehr | EHDSCondition.header.statusReason[x] |
# | short_xtehr | Reason for the current status of the resource. |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSCondition.header.subject
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.header.subject |
# | zib |  |
# | card._xtehr | 1..1 |
# | definition_xtehr | Patient/subject information |
# | id_xtehr | EHDSCondition.header.subject |
# | path_xtehr | EHDSCondition.header.subject |
# | short_xtehr | Subject |
# | type_xtehr | EHDSPatient |
#
# ### Comments
#
#
#
# ## EHDSCondition.header.version
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.header.version |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Business version of the resource. |
# | id_xtehr | EHDSCondition.header.version |
# | path_xtehr | EHDSCondition.header.version |
# | short_xtehr | Version |
# | type_xtehr | string |
#
# ### Comments
#
#
#
# ## EHDSCondition.onsetDate
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.onsetDate |
# | zib | Condition.PeriodPresent::TimeInterval |
# | alias_zib | NL: PeriodeAanwezig::TijdsInterval |
# | card._xtehr | 0..1 |
# | card._zib | 1 |
# | definition_xtehr | Onset date of a problem/condition |
# | definition_zib | The period in which the condition is (was) present. |
# | id_xtehr | EHDSCondition.onsetDate |
# | id_zib | NL-CM:5.4.8 |
# | name_zib | PeriodPresent::TimeInterval |
# | path_xtehr | EHDSCondition.onsetDate |
# | path_zib | Condition.PeriodPresent::TimeInterval |
# | short_xtehr | Onset date of a problem/condition |
# | stereotype_zib | data,reference |
# | type_xtehr | dateTime |
#
# ### Comments
#
#
#
# ## EHDSCondition.presentedForm
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.presentedForm |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | A narrative easy-to-read representation of the full data set, e.g. PDF-version of a document |
# | id_xtehr | EHDSCondition.presentedForm |
# | path_xtehr | EHDSCondition.presentedForm |
# | short_xtehr | A narrative easy-to-read representation of the full data set, e.g. PDF-version of a document |
# | type_xtehr | EHDSAttachment |
#
# ### Comments
#
#
#
# ## EHDSCondition.problem
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.problem |
# | zib | Diagnosis.DiagnosisNameData.DiagnosisName |
# | alias_zib | NL: DiagnoseNaam |
# | binding_xtehr | {'strength': 'preferred', 'description': 'ICD-10, SNOMED CT, ICD-O, Orphacode if rare disease is diagnosed'} |
# | card._xtehr | 1..1 |
# | card._zib | 1 |
# | definition_xtehr | Code identifying the condition, problem or diagnosis |
# | definition_zib | The term with associated code that the care professional selects from the used code system with conditions. |
# | definitioncode_zib | SNOMED CT: 439401001 Diagnosis |
# | id_xtehr | EHDSCondition.problem |
# | id_zib | NL-CM:5.6.7 |
# | name_zib | DiagnosisName |
# | path_xtehr | EHDSCondition.problem |
# | path_zib | Diagnosis.DiagnosisNameData.DiagnosisName |
# | short_xtehr | Code identifying the condition, problem or diagnosis |
# | stereotype_zib | data |
# | type_xtehr | CodeableConcept |
# | type_zib | CD |
#
# ### Comments
#
#
#
# ## EHDSCondition.problemStatus
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.problemStatus |
# | zib | Condition.Course |
# | alias_zib | NL: Beloop |
# | binding_xtehr | {'strength': 'preferred', 'description': 'HL7 Condition Clinical Status Codes'} |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Status of the condition/problem (active, resolved, inactive, ...) |
# | definition_zib | The course of the condition. This is independent of the diagnostic insight for the condition. The course indicates how the condition is developing: such as stable, progression, remission, etc.. |
# | id_xtehr | EHDSCondition.problemStatus |
# | id_zib | NL-CM:5.4.5 |
# | name_zib | Course |
# | path_xtehr | EHDSCondition.problemStatus |
# | path_zib | Condition.Course |
# | short_xtehr | Status of the condition/problem (active, resolved, inactive, ...) |
# | stereotype_zib | data |
# | type_xtehr | CodeableConcept |
# | type_zib | CD |
#
# ### Comments
#
#
#
# ## EHDSCondition.resolutionCircumstances
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.resolutionCircumstances |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | This field includes free text if the resolution circumstances are not already included in other fields such as surgical procedure, medical device, etc., e.g. hepatic cystectomy (this will be the resolution circumstances for the problem "hepatic cyst" and will be included in surgical procedures). |
# | id_xtehr | EHDSCondition.resolutionCircumstances |
# | path_xtehr | EHDSCondition.resolutionCircumstances |
# | short_xtehr | Describes the reason for which the status of the problem changed from current to inactive (e.g. surgical procedure, medical treatment, etc.). |
# | type_xtehr | string |
#
# ### Comments
#
#
#
# ## EHDSCondition.severity
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.severity |
# | zib | Condition.Severity |
# | alias_zib | NL: Ernst |
# | binding_xtehr | {'strength': 'preferred', 'description': 'HL7 Condition/Diagnosis Severity; SNOMED CT'} |
# | card._xtehr | 0..1 |
# | card._zib | 1 |
# | definition_xtehr | A subjective assessment of the severity of the condition as evaluated by the clinician. |
# | definition_zib | Indication of the severity of the condition. A condition may cause few or mild symptoms and yet be serious, but the reverse is also possible. |
# | definitioncode_zib | SNOMED CT: 246112005 Severity |
# | id_xtehr | EHDSCondition.severity |
# | id_zib | NL-CM:5.4.6 |
# | name_zib | Severity |
# | path_xtehr | EHDSCondition.severity |
# | path_zib | Condition.Severity |
# | short_xtehr | A subjective assessment of the severity of the condition as evaluated by the clinician. |
# | stereotype_zib | data |
# | type_xtehr | CodeableConcept |
# | type_zib | CD |
#
# ### Comments
#
#
#
# ## EHDSCondition.specialistContact
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.specialistContact |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | Health Professional who may be specifically related to the problem, as a preferred contact. |
# | id_xtehr | EHDSCondition.specialistContact |
# | path_xtehr | EHDSCondition.specialistContact |
# | short_xtehr | Health Professional who may be specifically related to the problem, as a preferred contact. |
# | type_xtehr | EHDSHealthProfessional |
#
# ### Comments
#
#
#
# ## EHDSCondition.stage
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCondition.stage |
# | zib |  |
# | binding_xtehr | {'strength': 'preferred', 'description': 'e.g. TNM, ICD-O-3, Bi-Rads, Li-Rads, …'} |
# | card._xtehr | 0..* |
# | definition_xtehr | Stage/grade usually assessed formally using a specific staging/grading system. Multiple assessment systems could be used. |
# | id_xtehr | EHDSCondition.stage |
# | path_xtehr | EHDSCondition.stage |
# | short_xtehr | Stage/grade usually assessed formally using a specific staging/grading system. Multiple assessment systems could be used. |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## zib: Condition.Comment
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Condition.Comment |
# | alias_zib | NL: Toelichting |
# | card._zib | 0..1 |
# | definition_zib | A comment in free text with respect to the condition, that is not represented by the other data elements in the information model. |
# | definitioncode_zib | LOINC: 48767-8 Annotation comment [Interpretation] Narrative |
# | id_zib | NL-CM:5.4.7 |
# | name_zib | Comment |
# | path_zib | Condition.Comment |
# | stereotype_zib | data |
# | type_zib | ST |
#
# ### Comments
#
#
#
# ## zib: Condition.StatusDate
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Condition.StatusDate |
# | alias_zib | NL: StatusDatum |
# | card._zib | 1 |
# | definition_zib | The moment from when the data regarding the condition apply. It may be a vague moment. |
# | definitioncode_zib | SNOMED CT: 350351000146106 Date health condition changed |
# | id_zib | NL-CM:5.4.3 |
# | name_zib | StatusDate |
# | path_zib | Condition.StatusDate |
# | stereotype_zib | data |
# | type_zib | TS |
#
# ### Comments
#
#
#
# ## zib: Diagnosis.Comment
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Diagnosis.Comment |
# | alias_zib | NL: Toelichting |
# | card._zib | 0..1 |
# | definition_zib | A comment in free text with respect to the diagnosis, that is not represented by the other data elements in the information model. |
# | definitioncode_zib | LOINC: 48767-8 Annotation comment [Interpretation] Narrative |
# | id_zib | NL-CM:5.6.11 |
# | name_zib | Comment |
# | path_zib | Diagnosis.Comment |
# | stereotype_zib | data |
# | type_zib | ST |
#
# ### Comments
#
#
#
# ## zib: Diagnosis.Condition
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Diagnosis.Condition |
# | alias_zib | NL: AandoeningOfGesteldheid |
# | card._zib | 0..1 |
# | definition_zib | The Condition to which the Diagnosis applies. |
# | id_zib | NL-CM:5.6.10 |
# | name_zib | Condition |
# | path_zib | Diagnosis.Condition |
# | stereotype_zib | data,reference |
#
# ### Comments
#
#
#
# ## zib: Diagnosis.DiagnosisNameData
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Diagnosis.DiagnosisNameData |
# | alias_zib | NL: DiagnoseNaamGegevens |
# | card._zib | 1..* |
# | definition_zib | Container of the DiagnosisNameData concept. This container contains all data elements of the DiagnosisNameData concept.
# Represents a disease or physiological condition as part of the diagnosis. |
# | id_zib | NL-CM:5.6.6 |
# | name_zib | DiagnosisNameData |
# | path_zib | Diagnosis.DiagnosisNameData |
# | stereotype_zib | container |
#
# ### Comments
#
#
#
# ## zib: Diagnosis.DiagnosisNameData.FurtherSpecificationDiagnosisName
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Diagnosis.DiagnosisNameData.FurtherSpecificationDiagnosisName |
# | alias_zib | NL: NadereSpecificatieDiagnoseNaam |
# | card._zib | 0..1 |
# | definition_zib | A more detailed description of the DiagnosisName in free text, when this detail is not available in the used code list. |
# | id_zib | NL-CM:5.6.8 |
# | name_zib | FurtherSpecificationDiagnosisName |
# | path_zib | Diagnosis.DiagnosisNameData.FurtherSpecificationDiagnosisName |
# | stereotype_zib | data |
# | type_zib | ST |
#
# ### Comments
#
#
#
# ## zib: Diagnosis.IsComplication
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Diagnosis.IsComplication |
# | alias_zib | NL: IsComplicatie |
# | card._zib | 0..1 |
# | definition_zib | Indicates whether or not the diagnosis involves a complication. |
# | id_zib | NL-CM:5.6.12 |
# | name_zib | IsComplication |
# | path_zib | Diagnosis.IsComplication |
# | stereotype_zib | data |
# | type_zib | BL |
#
# ### Comments
#
#
#
# ## zib: Diagnosis.MethodOfConfirmation
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Diagnosis.MethodOfConfirmation |
# | alias_zib | NL: WijzeVanVaststellen |
# | card._zib | 1 |
# | definition_zib | The method that the care professional used to diagnose the condition, such as history taking only, history taking and physical examination or additional diagnostic examination. |
# | definitioncode_zib | SNOMED CT: 418775008 Finding method |
# | id_zib | NL-CM:5.6.5 |
# | name_zib | MethodOfConfirmation |
# | path_zib | Diagnosis.MethodOfConfirmation |
# | stereotype_zib | data |
# | type_zib | CD |
#
# ### Comments
#
#
#
# ## zib: Diagnosis.Reason
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Diagnosis.Reason |
# | alias_zib | NL: Aanleiding |
# | card._zib | 0..* |
# | definition_zib | Container of the Reason concept.This container contains all data elements of the Reason concept. |
# | id_zib | NL-CM:5.6.13 |
# | name_zib | Reason |
# | path_zib | Diagnosis.Reason |
# | stereotype_zib | container |
#
# ### Comments
#
#
#
# ## zib: Diagnosis.Reason.Diagnosis
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Diagnosis.Reason.Diagnosis |
# | alias_zib | NL: Diagnose |
# | card._zib | (0..1) |
# | definition_zib | The diagnosis with regard to another condition that is seen as a reason for the condition with the current diagnosis. |
# | id_zib | NL-CM:5.6.16 |
# | name_zib | Diagnosis |
# | path_zib | Diagnosis.Reason.Diagnosis |
# | stereotype_zib | data,reference |
#
# ### Comments
#
#
#
# ## zib: Diagnosis.Reason.Incident
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Diagnosis.Reason.Incident |
# | alias_zib | NL: Incident |
# | card._zib | (0..1) |
# | definition_zib | The unintended event during the care process that has led, could have led or could (still) lead to harm to the patient. |
# | definitioncode_zib | SNOMED CT: 418019003 Accidental event |
# | id_zib | NL-CM:5.6.14 |
# | name_zib | Incident |
# | path_zib | Diagnosis.Reason.Incident |
# | stereotype_zib | data |
# | type_zib | CD |
#
# ### Comments
#
#
#
# ## zib: Diagnosis.Reason.Procedure
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Diagnosis.Reason.Procedure |
# | alias_zib | NL: Verrichting |
# | card._zib | (0..1) |
# | definition_zib | The procedure that gave rise to the condition to which the diagnosis relates. |
# | definitioncode_zib | SNOMED CT: 71388002 Procedure |
# | id_zib | NL-CM:5.6.15 |
# | name_zib | Procedure |
# | path_zib | Diagnosis.Reason.Procedure |
# | stereotype_zib | data,reference |
#
# ### Comments
