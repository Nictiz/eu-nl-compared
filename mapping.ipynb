# %%
import pandas as pd
import os
import unicodedata as ud

# %%
# zibbase = 'zibs2020'
zibbase = 'zibs2024'
zibspath = os.path.join(zibbase, 'mappable')
zibs = os.listdir(zibspath)
[(i, zib) for i, zib in enumerate(zibs)]
# Out:
# [(0, 'Nl.zorg.Alert-v5.0(2024EN).xlsx'),
#  (1, 'Nl.zorg.Condition-v1.1(2024EN).xlsx'),
#  (2, 'Nl.zorg.Diagnosis-v2.0(2024EN).xlsx'),
#  (3, 'nl.zorg.DispenseRequest-v4.0(2024EN).xlsx'),
#  (4, 'Nl.zorg.HealthcareProvider-v3.6(2024EN).xlsx'),
#  (5, 'Nl.zorg.HealthProfessional-v4.0(2024EN).xlsx'),
#  (6, 'Nl.zorg.MedicalDevice-v5.0(2024EN).xlsx'),
#  (7, 'nl.zorg.MedicationAgreement-v4.0(2024EN).xlsx'),
#  (8, 'nl.zorg.MedicationDispense-v3.0.1(2024EN).xlsx'),
#  (9, 'Nl.zorg.NursingIntervention-v5.0(2024EN).xlsx'),
#  (10, 'Nl.zorg.part.AddressInformation-v1.2(2024EN).xlsx'),
#  (11, 'Nl.zorg.part.AnatomicalLocation-v1.0.4(2024EN).xlsx'),
#  (12, 'Nl.zorg.part.ContactInformation-v1.3.1(2024EN).xlsx'),
#  (13, 'Nl.zorg.part.InstructionsForUse-v3.1(2024EN).xlsx'),
#  (14, 'Nl.zorg.part.NameInformation-v1.2(2024EN).xlsx'),
#  (15, 'Nl.zorg.part.PharmaceuticalProduct-v2.3(2024EN).xlsx'),
#  (16, 'Nl.zorg.Patient-v4.3(2024EN).xlsx'),
#  (17, 'Nl.zorg.Pregnancy-v4.1(2024EN).xlsx'),
#  (18, 'Nl.zorg.Procedure-v6.0(2024EN).xlsx'),
#  (19, 'Nl.zorg.process.RegistrationData-v1.1.2(2024EN).xlsx')]

# %%
zib = zibs[17]
print(zib)
zibpath = os.path.join(zibspath, zib)
zibdf = pd.read_excel(zibpath)
zibdf['path'] = zibdf['path'].apply(
    lambda x: ud.normalize("NFKC", str(x)).replace("\xa0", " ").strip() if pd.notna(x) else x
)
zibdf
# only for zib2024 condition and diagnosis
# zib = zibs[1]
# print( zib)
# zibpath = os.path.join(zibspath, zib)
# zibdf2 = pd.read_excel(zibpath)
# zibdf = pd.concat([zibdf, zibdf2], ignore_index=True)
# zibdf
# Out:
# Nl.zorg.Pregnancy-v4.1(2024EN).xlsx
#                            name  \
# 0                     Pregnancy
# 1             PregnancyDuration
# 2                        Parity
# 3                     Gravidity
# 4                       Comment
# 5  EstimatedDateOfDeliveryItems
# 6       EstimatedDateOfDelivery
# 7              EstimatingMethod
# 8              DateOfEstimation
# 9          DateLastMenstruation
#
#                                                 path  \
# 0                                          Pregnancy
# 1                        Pregnancy.PregnancyDuration
# 2                                   Pregnancy.Parity
# 3                                Pregnancy.Gravidity
# 4                                  Pregnancy.Comment
# 5             Pregnancy.EstimatedDateOfDeliveryItems
# 6  Pregnancy.EstimatedDateOfDeliveryItems.Estimat...
# 7  Pregnancy.EstimatedDateOfDeliveryItems.Estimat...
# 8  Pregnancy.EstimatedDateOfDeliveryItems.DateOfE...
# 9  Pregnancy.EstimatedDateOfDeliveryItems.DateLas...
#
#                          alias type card.   stereotype             id  \
# 0             NL: Zwangerschap  NaN   NaN  rootconcept   NL-CM:7.14.1
# 1        NL: Zwangerschapsduur   PQ  0..1         data   NL-CM:7.14.4
# 2                 NL: Pariteit  INT  0..1         data   NL-CM:7.14.6
# 3              NL: Graviditeit  INT  0..1         data   NL-CM:7.14.5
# 4              NL: Toelichting   ST  0..1         data   NL-CM:7.14.7
# 5         NL: ATermeDatumItems  NaN  0..1    container   NL-CM:7.14.9
# 6              NL: ATermeDatum   TS  0..1         data   NL-CM:7.14.3
# 7         NL: BepalingsMethode   CD  0..1         data  NL-CM:7.14.10
# 8            NL: DatumBepaling   TS  0..1         data  NL-CM:7.14.11
# 9  NL: DatumLaatsteMenstruatie   TS  0..1         data   NL-CM:7.14.8
#
#                                           definition  \
# 0  Root concept of the Pregnancy information mode...
# 1  Duration of the pregnancy on the day on which ...
# 2  Number of previous pregnancies ending in partu...
# 3  The number of times the woman has gotten pregn...
# 4                          Comment on the pregnancy.
# 5  Container of the EstimatedDateOfDeliveryItems ...
# 6  The date on which the pregnancy is expected to...
# 7    Method by which the delivery date is estimated.
# 8      Date on which the delivery date is estimated.
# 9   The date on which the last menstruation started.
#
#                                       definitioncode
# 0  SNOMED CT: 118185001 Finding related to pregnancy
# 1          SNOMED CT: 57036006 Fetal gestational age
# 2                        SNOMED CT: 364325004 Parity
# 3                       SNOMED CT: 161732006 Gravida
# 4  LOINC: 48767-8 Annotation comment [Interpretat...
# 5                                                NaN
# 6    SNOMED CT: 161714006 Estimated date of delivery
# 7                                                NaN
# 8                                                NaN
# 9  SNOMED CT: 21840007 Date of last menstrual period

# %%
xlmbase = 'xtehr'
xlmspath = os.path.join(xlmbase, 'mappable')
xlms = os.listdir(xlmspath)
[(i, xlm) for i, xlm in enumerate(xlms)]
# Out:
# [(0, 'Address.xlsx'),
#  (1, 'AlertFlag.xlsx'),
#  (2, 'AllergyIntolerance.xlsx'),
#  (3, 'BodyStructure.xlsx'),
#  (4, 'Condition.xlsx'),
#  (5, 'CurrentPregnancy.xlsx'),
#  (6, 'DataSet.xlsx'),
#  (7, 'Device.xlsx'),
#  (8, 'DeviceUse.xlsx'),
#  (9, 'Dosaging.xlsx'),
#  (10, 'HealthProfessional.xlsx'),
#  (11, 'HumanName.xlsx'),
#  (12, 'Location.xlsx'),
#  (13, 'Medication.xlsx'),
#  (14, 'MedicationDispense.xlsx'),
#  (15, 'MedicationPrescription.xlsx'),
#  (16, 'Organization.xlsx'),
#  (17, 'Patient.xlsx'),
#  (18, 'PregnancyHistory.xlsx'),
#  (19, 'Procedure.xlsx'),
#  (20, 'Telecom.xlsx')]

# %%
xlm = xlms[5]
print( xlm)
xlmpath = os.path.join(xlmspath, xlm)
xlmdf = pd.read_excel(xlmpath)
# Normalize + strip (for non-breaking spaces, Unicode issues)
xlmdf['path'] = xlmdf['path'].apply(
    lambda x: ud.normalize("NFKC", str(x)).replace("\xa0", " ").strip() if pd.notna(x) else x
)
xlmdf
# only for device use and organization
# xlm = xlms[7]
# print( xlm)
# xlmpath = os.path.join(xlmspath, xlm)
# xlmdf2 = pd.read_excel(xlmpath)
# xlmdf = pd.concat([xlmdf, xlmdf2], ignore_index=True)
# xlmdf
# Out:
# CurrentPregnancy.xlsx
#                                                   id  \
# 0                               EHDSCurrentPregnancy
# 1                        EHDSCurrentPregnancy.header
# 2                EHDSCurrentPregnancy.header.subject
# 3             EHDSCurrentPregnancy.header.identifier
# 4             EHDSCurrentPregnancy.header.authorship
# 5   EHDSCurrentPregnancy.header.authorship.author[x]
# 6    EHDSCurrentPregnancy.header.authorship.datetime
# 7             EHDSCurrentPregnancy.header.lastUpdate
# 8                 EHDSCurrentPregnancy.header.status
# 9        EHDSCurrentPregnancy.header.statusReason[x]
# 10              EHDSCurrentPregnancy.header.language
# 11               EHDSCurrentPregnancy.header.version
# 12                EHDSCurrentPregnancy.presentedForm
# 13                    EHDSCurrentPregnancy.narrative
# 14       EHDSCurrentPregnancy.currentPregnancyStatus
# 15                 EHDSCurrentPregnancy.dateOfStatus
# 16       EHDSCurrentPregnancy.expectedDateOfDelivery
# 17               EHDSCurrentPregnancy.gestationalAge
#
#                                                 path  \
# 0                               EHDSCurrentPregnancy
# 1                        EHDSCurrentPregnancy.header
# 2                EHDSCurrentPregnancy.header.subject
# 3             EHDSCurrentPregnancy.header.identifier
# 4             EHDSCurrentPregnancy.header.authorship
# 5   EHDSCurrentPregnancy.header.authorship.author[x]
# 6    EHDSCurrentPregnancy.header.authorship.datetime
# 7             EHDSCurrentPregnancy.header.lastUpdate
# 8                 EHDSCurrentPregnancy.header.status
# 9        EHDSCurrentPregnancy.header.statusReason[x]
# 10              EHDSCurrentPregnancy.header.language
# 11               EHDSCurrentPregnancy.header.version
# 12                EHDSCurrentPregnancy.presentedForm
# 13                    EHDSCurrentPregnancy.narrative
# 14       EHDSCurrentPregnancy.currentPregnancyStatus
# 15                 EHDSCurrentPregnancy.dateOfStatus
# 16       EHDSCurrentPregnancy.expectedDateOfDelivery
# 17               EHDSCurrentPregnancy.gestationalAge
#
#                                                 short  \
# 0                      Current pregnancy status model
# 1          Common header for all patient-related data
# 2                                             Subject
# 3                  Business identifier for the object
# 4                                          Authorship
# 5                                              Author
# 6                  Date and time of authoring/issuing
# 7    Date and time of the last update to the resource
# 8                              Status of the resource
# 9      Reason for the current status of the resource.
# 10                                           Language
# 11                                            Version
# 12  A narrative easy-to-read representation of the...
# 13    Textual description of current pregnancy status
# 14                           Current pregnancy status
# 15    Effective date of the current pregnancy status.
# 16  Date in which the woman is due to give birth. ...
# 17              Duration of the pregnancy at this day
#
#                                            definition                    type  \
# 0                            Current pregnancy status                     NaN
# 1          Common header for all patient-related data                    Base
# 2                         Patient/subject information             EHDSPatient
# 3                  Business identifier for the object              Identifier
# 4                          Resource authoring details                    Base
# 5   Author(s) by whom the resource was/were author...  EHDSHealthProfessional
# 6   Date and time of the issuing the document/reso...                dateTime
# 7   Date and time of the last update to the docume...                dateTime
# 8                              Status of the resource         CodeableConcept
# 9      Reason for the current status of the resource.         CodeableConcept
# 10  Language in which the resource is written. Lan...         CodeableConcept
# 11                  Business version of the resource.                  string
# 12  A narrative easy-to-read representation of the...          EHDSAttachment
# 13  Narrative description describing the status of...                  string
# 14  Current state of the pregnancy at the date the...         CodeableConcept
# 15    Effective date of the current pregnancy status.                dateTime
# 16  Date in which the woman is due to give birth. ...                    date
# 17  Gestational age - duration of the pregnancy on...                Quantity
#
#    card.                                            binding
# 0   0..*                                                NaN
# 1   1..1                                                NaN
# 2   1..1                                                NaN
# 3   0..*                                                NaN
# 4   1..*                                                NaN
# 5   1..1                                                NaN
# 6   1..1                                                NaN
# 7   0..1                                                NaN
# 8   1..1                                                NaN
# 9   0..1                                                NaN
# 10  0..1  {'strength': 'preferred', 'description': 'BCP ...
# 11  0..1                                                NaN
# 12  0..*                                                NaN
# 13  0..1                                                NaN
# 14  1..1  {'strength': 'preferred', 'description': 'SNOM...
# 15  0..1                                                NaN
# 16  0..1                                                NaN
# 17  0..1                                                NaN

# %%
mapbase = 'maps'
maps = os.listdir(mapbase)
[(i, map) for i, map in enumerate(maps)]
# Out:
# [(0, 'Address.xlsx'),
#  (1, 'AlertFlag.xlsx'),
#  (2, 'BodyStructure.xlsx'),
#  (3, 'Condition.xlsx'),
#  (4, 'DataSet.xlsx'),
#  (5, 'Device-and-DeviceUse.xlsx'),
#  (6, 'Diagnosis.xlsx'),
#  (7, 'Dosaging.xlsx'),
#  (8, 'HealthProfessional.xlsx'),
#  (9, 'HumanName.xlsx'),
#  (10, 'Location-and-Organization.xlsx'),
#  (11, 'MedicationDispense.xlsx'),
#  (12, 'MedicationPrescription.xlsx'),
#  (13, 'Patient.xlsx'),
#  (14, 'PharmaceuticalProduct.xlsx'),
#  (15, 'Pregnancy-CurrentPregnancy.xlsx'),
#  (16, 'Pregnancy-PregnancyHistory.xlsx'),
#  (17, 'Procedure-NusringIntervention.xlsx'),
#  (18, 'Procedure.xlsx'),
#  (19, 'xtehr2zibs'),
#  (20, 'xtehr2zibs2024')]

# %%
file = maps[15]
print(file)
mappath = os.path.join(mapbase, file)
print(mappath)
mapdf = pd.read_excel(mappath)
# Normalize + strip (for non-breaking spaces, Unicode issues)
mapdf[['zib','xtehr']] = mapdf[['zib','xtehr']].map(
    lambda x: ud.normalize("NFKC", str(x)).replace("\xa0", " ").strip() if pd.notna(x) else x
)
mapdf
# Out:
# Pregnancy-CurrentPregnancy.xlsx
# maps\Pregnancy-CurrentPregnancy.xlsx
#                                                xtehr  \
# 0                               EHDSCurrentPregnancy
# 1                 EHDSCurrentPregnancy.presentedForm
# 2                     EHDSCurrentPregnancy.narrative
# 3        EHDSCurrentPregnancy.currentPregnancyStatus
# 4                  EHDSCurrentPregnancy.dateOfStatus
# 5        EHDSCurrentPregnancy.expectedDateOfDelivery
# 6                EHDSCurrentPregnancy.gestationalAge
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                       EHDSCurrentPregnancy.header
# 14               EHDSCurrentPregnancy.header.subject
# 15            EHDSCurrentPregnancy.header.identifier
# 16            EHDSCurrentPregnancy.header.authorship
# 17  EHDSCurrentPregnancy.header.authorship.author[x]
# 18   EHDSCurrentPregnancy.header.authorship.datetime
# 19            EHDSCurrentPregnancy.header.lastUpdate
# 20                EHDSCurrentPregnancy.header.status
# 21       EHDSCurrentPregnancy.header.statusReason[x]
# 22              EHDSCurrentPregnancy.header.language
# 23               EHDSCurrentPregnancy.header.version
#
#                                                   zib
# 0                                           Pregnancy
# 1                                                 NaN
# 2                                   Pregnancy.Comment
# 3                                                 NaN
# 4                                                 NaN
# 5   Pregnancy.EstimatedDateOfDeliveryItems.Estimat...
# 6                         Pregnancy.PregnancyDuration
# 7                                    Pregnancy.Parity
# 8                                 Pregnancy.Gravidity
# 9              Pregnancy.EstimatedDateOfDeliveryItems
# 10  Pregnancy.EstimatedDateOfDeliveryItems.Estimat...
# 11  Pregnancy.EstimatedDateOfDeliveryItems.DateOfE...
# 12  Pregnancy.EstimatedDateOfDeliveryItems.DateLas...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN

# %%
mapping = mapdf[['xtehr', 'zib']].merge(zibdf.add_suffix('_zib'), left_on='zib', right_on='path_zib', how='outer').merge(xlmdf.add_suffix('_xtehr'), left_on='xtehr', right_on='path_xtehr', how='outer')
mapping
# Out:
#                                                xtehr  \
# 0                               EHDSCurrentPregnancy
# 1        EHDSCurrentPregnancy.currentPregnancyStatus
# 2                  EHDSCurrentPregnancy.dateOfStatus
# 3        EHDSCurrentPregnancy.expectedDateOfDelivery
# 4                EHDSCurrentPregnancy.gestationalAge
# 5                        EHDSCurrentPregnancy.header
# 6             EHDSCurrentPregnancy.header.authorship
# 7   EHDSCurrentPregnancy.header.authorship.author[x]
# 8    EHDSCurrentPregnancy.header.authorship.datetime
# 9             EHDSCurrentPregnancy.header.identifier
# 10              EHDSCurrentPregnancy.header.language
# 11            EHDSCurrentPregnancy.header.lastUpdate
# 12                EHDSCurrentPregnancy.header.status
# 13       EHDSCurrentPregnancy.header.statusReason[x]
# 14               EHDSCurrentPregnancy.header.subject
# 15               EHDSCurrentPregnancy.header.version
# 16                    EHDSCurrentPregnancy.narrative
# 17                EHDSCurrentPregnancy.presentedForm
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
#
#                                                   zib  \
# 0                                           Pregnancy
# 1                                                 NaN
# 2                                                 NaN
# 3   Pregnancy.EstimatedDateOfDeliveryItems.Estimat...
# 4                         Pregnancy.PregnancyDuration
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                  Pregnancy.Comment
# 17                                                NaN
# 18             Pregnancy.EstimatedDateOfDeliveryItems
# 19  Pregnancy.EstimatedDateOfDeliveryItems.DateLas...
# 20  Pregnancy.EstimatedDateOfDeliveryItems.DateOfE...
# 21  Pregnancy.EstimatedDateOfDeliveryItems.Estimat...
# 22                                Pregnancy.Gravidity
# 23                                   Pregnancy.Parity
#
#                         name_zib  \
# 0                      Pregnancy
# 1                            NaN
# 2                            NaN
# 3        EstimatedDateOfDelivery
# 4              PregnancyDuration
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                       Comment
# 17                           NaN
# 18  EstimatedDateOfDeliveryItems
# 19          DateLastMenstruation
# 20              DateOfEstimation
# 21              EstimatingMethod
# 22                     Gravidity
# 23                        Parity
#
#                                              path_zib  \
# 0                                           Pregnancy
# 1                                                 NaN
# 2                                                 NaN
# 3   Pregnancy.EstimatedDateOfDeliveryItems.Estimat...
# 4                         Pregnancy.PregnancyDuration
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                  Pregnancy.Comment
# 17                                                NaN
# 18             Pregnancy.EstimatedDateOfDeliveryItems
# 19  Pregnancy.EstimatedDateOfDeliveryItems.DateLas...
# 20  Pregnancy.EstimatedDateOfDeliveryItems.DateOfE...
# 21  Pregnancy.EstimatedDateOfDeliveryItems.Estimat...
# 22                                Pregnancy.Gravidity
# 23                                   Pregnancy.Parity
#
#                       alias_zib type_zib card._zib stereotype_zib  \
# 0              NL: Zwangerschap      NaN       NaN    rootconcept
# 1                           NaN      NaN       NaN            NaN
# 2                           NaN      NaN       NaN            NaN
# 3               NL: ATermeDatum       TS      0..1           data
# 4         NL: Zwangerschapsduur       PQ      0..1           data
# 5                           NaN      NaN       NaN            NaN
# 6                           NaN      NaN       NaN            NaN
# 7                           NaN      NaN       NaN            NaN
# 8                           NaN      NaN       NaN            NaN
# 9                           NaN      NaN       NaN            NaN
# 10                          NaN      NaN       NaN            NaN
# 11                          NaN      NaN       NaN            NaN
# 12                          NaN      NaN       NaN            NaN
# 13                          NaN      NaN       NaN            NaN
# 14                          NaN      NaN       NaN            NaN
# 15                          NaN      NaN       NaN            NaN
# 16              NL: Toelichting       ST      0..1           data
# 17                          NaN      NaN       NaN            NaN
# 18         NL: ATermeDatumItems      NaN      0..1      container
# 19  NL: DatumLaatsteMenstruatie       TS      0..1           data
# 20            NL: DatumBepaling       TS      0..1           data
# 21         NL: BepalingsMethode       CD      0..1           data
# 22              NL: Graviditeit      INT      0..1           data
# 23                 NL: Pariteit      INT      0..1           data
#
#            id_zib                                     definition_zib  \
# 0    NL-CM:7.14.1  Root concept of the Pregnancy information mode...
# 1             NaN                                                NaN
# 2             NaN                                                NaN
# 3    NL-CM:7.14.3  The date on which the pregnancy is expected to...
# 4    NL-CM:7.14.4  Duration of the pregnancy on the day on which ...
# 5             NaN                                                NaN
# 6             NaN                                                NaN
# 7             NaN                                                NaN
# 8             NaN                                                NaN
# 9             NaN                                                NaN
# 10            NaN                                                NaN
# 11            NaN                                                NaN
# 12            NaN                                                NaN
# 13            NaN                                                NaN
# 14            NaN                                                NaN
# 15            NaN                                                NaN
# 16   NL-CM:7.14.7                          Comment on the pregnancy.
# 17            NaN                                                NaN
# 18   NL-CM:7.14.9  Container of the EstimatedDateOfDeliveryItems ...
# 19   NL-CM:7.14.8   The date on which the last menstruation started.
# 20  NL-CM:7.14.11      Date on which the delivery date is estimated.
# 21  NL-CM:7.14.10    Method by which the delivery date is estimated.
# 22   NL-CM:7.14.5  The number of times the woman has gotten pregn...
# 23   NL-CM:7.14.6  Number of previous pregnancies ending in partu...
#
#                                    definitioncode_zib  \
# 0   SNOMED CT: 118185001 Finding related to pregnancy
# 1                                                 NaN
# 2                                                 NaN
# 3     SNOMED CT: 161714006 Estimated date of delivery
# 4           SNOMED CT: 57036006 Fetal gestational age
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  LOINC: 48767-8 Annotation comment [Interpretat...
# 17                                                NaN
# 18                                                NaN
# 19  SNOMED CT: 21840007 Date of last menstrual period
# 20                                                NaN
# 21                                                NaN
# 22                       SNOMED CT: 161732006 Gravida
# 23                        SNOMED CT: 364325004 Parity
#
#                                             id_xtehr  \
# 0                               EHDSCurrentPregnancy
# 1        EHDSCurrentPregnancy.currentPregnancyStatus
# 2                  EHDSCurrentPregnancy.dateOfStatus
# 3        EHDSCurrentPregnancy.expectedDateOfDelivery
# 4                EHDSCurrentPregnancy.gestationalAge
# 5                        EHDSCurrentPregnancy.header
# 6             EHDSCurrentPregnancy.header.authorship
# 7   EHDSCurrentPregnancy.header.authorship.author[x]
# 8    EHDSCurrentPregnancy.header.authorship.datetime
# 9             EHDSCurrentPregnancy.header.identifier
# 10              EHDSCurrentPregnancy.header.language
# 11            EHDSCurrentPregnancy.header.lastUpdate
# 12                EHDSCurrentPregnancy.header.status
# 13       EHDSCurrentPregnancy.header.statusReason[x]
# 14               EHDSCurrentPregnancy.header.subject
# 15               EHDSCurrentPregnancy.header.version
# 16                    EHDSCurrentPregnancy.narrative
# 17                EHDSCurrentPregnancy.presentedForm
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
#
#                                           path_xtehr  \
# 0                               EHDSCurrentPregnancy
# 1        EHDSCurrentPregnancy.currentPregnancyStatus
# 2                  EHDSCurrentPregnancy.dateOfStatus
# 3        EHDSCurrentPregnancy.expectedDateOfDelivery
# 4                EHDSCurrentPregnancy.gestationalAge
# 5                        EHDSCurrentPregnancy.header
# 6             EHDSCurrentPregnancy.header.authorship
# 7   EHDSCurrentPregnancy.header.authorship.author[x]
# 8    EHDSCurrentPregnancy.header.authorship.datetime
# 9             EHDSCurrentPregnancy.header.identifier
# 10              EHDSCurrentPregnancy.header.language
# 11            EHDSCurrentPregnancy.header.lastUpdate
# 12                EHDSCurrentPregnancy.header.status
# 13       EHDSCurrentPregnancy.header.statusReason[x]
# 14               EHDSCurrentPregnancy.header.subject
# 15               EHDSCurrentPregnancy.header.version
# 16                    EHDSCurrentPregnancy.narrative
# 17                EHDSCurrentPregnancy.presentedForm
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
#
#                                           short_xtehr  \
# 0                      Current pregnancy status model
# 1                            Current pregnancy status
# 2     Effective date of the current pregnancy status.
# 3   Date in which the woman is due to give birth. ...
# 4               Duration of the pregnancy at this day
# 5          Common header for all patient-related data
# 6                                          Authorship
# 7                                              Author
# 8                  Date and time of authoring/issuing
# 9                  Business identifier for the object
# 10                                           Language
# 11   Date and time of the last update to the resource
# 12                             Status of the resource
# 13     Reason for the current status of the resource.
# 14                                            Subject
# 15                                            Version
# 16    Textual description of current pregnancy status
# 17  A narrative easy-to-read representation of the...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
#
#                                      definition_xtehr              type_xtehr  \
# 0                            Current pregnancy status                     NaN
# 1   Current state of the pregnancy at the date the...         CodeableConcept
# 2     Effective date of the current pregnancy status.                dateTime
# 3   Date in which the woman is due to give birth. ...                    date
# 4   Gestational age - duration of the pregnancy on...                Quantity
# 5          Common header for all patient-related data                    Base
# 6                          Resource authoring details                    Base
# 7   Author(s) by whom the resource was/were author...  EHDSHealthProfessional
# 8   Date and time of the issuing the document/reso...                dateTime
# 9                  Business identifier for the object              Identifier
# 10  Language in which the resource is written. Lan...         CodeableConcept
# 11  Date and time of the last update to the docume...                dateTime
# 12                             Status of the resource         CodeableConcept
# 13     Reason for the current status of the resource.         CodeableConcept
# 14                        Patient/subject information             EHDSPatient
# 15                  Business version of the resource.                  string
# 16  Narrative description describing the status of...                  string
# 17  A narrative easy-to-read representation of the...          EHDSAttachment
# 18                                                NaN                     NaN
# 19                                                NaN                     NaN
# 20                                                NaN                     NaN
# 21                                                NaN                     NaN
# 22                                                NaN                     NaN
# 23                                                NaN                     NaN
#
#    card._xtehr                                      binding_xtehr
# 0         0..*                                                NaN
# 1         1..1  {'strength': 'preferred', 'description': 'SNOM...
# 2         0..1                                                NaN
# 3         0..1                                                NaN
# 4         0..1                                                NaN
# 5         1..1                                                NaN
# 6         1..*                                                NaN
# 7         1..1                                                NaN
# 8         1..1                                                NaN
# 9         0..*                                                NaN
# 10        0..1  {'strength': 'preferred', 'description': 'BCP ...
# 11        0..1                                                NaN
# 12        1..1                                                NaN
# 13        0..1                                                NaN
# 14        1..1                                                NaN
# 15        0..1                                                NaN
# 16        0..1                                                NaN
# 17        0..*                                                NaN
# 18         NaN                                                NaN
# 19         NaN                                                NaN
# 20         NaN                                                NaN
# 21         NaN                                                NaN
# 22         NaN                                                NaN
# 23         NaN                                                NaN

# %%
shortmap = mapping[['zib', 'xtehr', 'type_zib','type_xtehr', 'card._zib', 'card._xtehr']]
shortmap
# Out:
#                                                   zib  \
# 0                                           Pregnancy
# 1                                                 NaN
# 2                                                 NaN
# 3   Pregnancy.EstimatedDateOfDeliveryItems.Estimat...
# 4                         Pregnancy.PregnancyDuration
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                  Pregnancy.Comment
# 17                                                NaN
# 18             Pregnancy.EstimatedDateOfDeliveryItems
# 19  Pregnancy.EstimatedDateOfDeliveryItems.DateLas...
# 20  Pregnancy.EstimatedDateOfDeliveryItems.DateOfE...
# 21  Pregnancy.EstimatedDateOfDeliveryItems.Estimat...
# 22                                Pregnancy.Gravidity
# 23                                   Pregnancy.Parity
#
#                                                xtehr type_zib  \
# 0                               EHDSCurrentPregnancy      NaN
# 1        EHDSCurrentPregnancy.currentPregnancyStatus      NaN
# 2                  EHDSCurrentPregnancy.dateOfStatus      NaN
# 3        EHDSCurrentPregnancy.expectedDateOfDelivery       TS
# 4                EHDSCurrentPregnancy.gestationalAge       PQ
# 5                        EHDSCurrentPregnancy.header      NaN
# 6             EHDSCurrentPregnancy.header.authorship      NaN
# 7   EHDSCurrentPregnancy.header.authorship.author[x]      NaN
# 8    EHDSCurrentPregnancy.header.authorship.datetime      NaN
# 9             EHDSCurrentPregnancy.header.identifier      NaN
# 10              EHDSCurrentPregnancy.header.language      NaN
# 11            EHDSCurrentPregnancy.header.lastUpdate      NaN
# 12                EHDSCurrentPregnancy.header.status      NaN
# 13       EHDSCurrentPregnancy.header.statusReason[x]      NaN
# 14               EHDSCurrentPregnancy.header.subject      NaN
# 15               EHDSCurrentPregnancy.header.version      NaN
# 16                    EHDSCurrentPregnancy.narrative       ST
# 17                EHDSCurrentPregnancy.presentedForm      NaN
# 18                                               NaN      NaN
# 19                                               NaN       TS
# 20                                               NaN       TS
# 21                                               NaN       CD
# 22                                               NaN      INT
# 23                                               NaN      INT
#
#                 type_xtehr card._zib card._xtehr
# 0                      NaN       NaN        0..*
# 1          CodeableConcept       NaN        1..1
# 2                 dateTime       NaN        0..1
# 3                     date      0..1        0..1
# 4                 Quantity      0..1        0..1
# 5                     Base       NaN        1..1
# 6                     Base       NaN        1..*
# 7   EHDSHealthProfessional       NaN        1..1
# 8                 dateTime       NaN        1..1
# 9               Identifier       NaN        0..*
# 10         CodeableConcept       NaN        0..1
# 11                dateTime       NaN        0..1
# 12         CodeableConcept       NaN        1..1
# 13         CodeableConcept       NaN        0..1
# 14             EHDSPatient       NaN        1..1
# 15                  string       NaN        0..1
# 16                  string      0..1        0..1
# 17          EHDSAttachment       NaN        0..*
# 18                     NaN      0..1         NaN
# 19                     NaN      0..1         NaN
# 20                     NaN      0..1         NaN
# 21                     NaN      0..1         NaN
# 22                     NaN      0..1         NaN
# 23                     NaN      0..1         NaN

# %%
mapsoutpath = os.path.join(mapbase, 'xtehr2zibs2024')
filepath = file.replace('.xlsx', '-full.xlsx')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_excel(mappath, index=False)

# %%
filepath = file.replace('.xlsx', '.csv')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_csv(mappath, index=False)

# %%
from IPython.display import Markdown
import numpy as np

content = "# " + mapping.iat[0, 0][4:] + "\n\n"

# shortmap: linefeeds naar <br> vlak vóór to_markdown
shortmap_md = shortmap.fillna('').map(
    lambda x: x.replace("\r\n", "<br>").replace("\n", "<br>") if isinstance(x, str) else x
)
content += shortmap_md.to_markdown(index=False) + "\n\n"

for i, row in mapping.iterrows():
    content += "\n\n"
    if row.iloc[0] is not np.nan:  # desgewenst: gebruik pd.notna(row.iloc[0])
        content += "## " + str(row.iloc[0]) + "\n\n"
    else:
        content += "## zib: " + str(row.iloc[1]) + "\n\n"

    content += "### Table" + "\n\n"
    content += "| attribute | value |\n|---|---|\n"

    # Eerste 2 kolommen
    for j, att in row.fillna('')[0:2].items():
        content += "| " + str(j) + " | " + (att.replace("\r\n","<br>").replace("\n","<br>") if isinstance(att, str) else str(att)) + " |\n" 

    # Rest, gesorteerd
    for j, att in row.fillna('')[2:].sort_index().items():
        if len(str(att)) > 0:
            content += "| " + str(j) + " | " + (att.replace("\r\n","<br>").replace("\n","<br>") if isinstance(att, str) else str(att)) + " |\n"

    content += "\n### Comments\n\n"

with open(os.path.join(mapsoutpath, file.replace('.xlsx', '.md')), 'w') as f:
    f.write(content)

# PAS OP: deze overschrijft de evt. handmatige comments; alleen bij eerste keer mapping
# with open(os.path.join(mapsoutpath, file.replace('.xlsx', '-comments.md')), 'w') as f:
#     f.write(content)

Markdown(content)
# Out:
# # CurrentPregnancy
#
# | zib                                                            | xtehr                                            | type_zib   | type_xtehr             | card._zib   | card._xtehr   |
# |:---------------------------------------------------------------|:-------------------------------------------------|:-----------|:-----------------------|:------------|:--------------|
# | Pregnancy                                                      | EHDSCurrentPregnancy                             |            |                        |             | 0..*          |
# |                                                                | EHDSCurrentPregnancy.currentPregnancyStatus      |            | CodeableConcept        |             | 1..1          |
# |                                                                | EHDSCurrentPregnancy.dateOfStatus                |            | dateTime               |             | 0..1          |
# | Pregnancy.EstimatedDateOfDeliveryItems.EstimatedDateOfDelivery | EHDSCurrentPregnancy.expectedDateOfDelivery      | TS         | date                   | 0..1        | 0..1          |
# | Pregnancy.PregnancyDuration                                    | EHDSCurrentPregnancy.gestationalAge              | PQ         | Quantity               | 0..1        | 0..1          |
# |                                                                | EHDSCurrentPregnancy.header                      |            | Base                   |             | 1..1          |
# |                                                                | EHDSCurrentPregnancy.header.authorship           |            | Base                   |             | 1..*          |
# |                                                                | EHDSCurrentPregnancy.header.authorship.author[x] |            | EHDSHealthProfessional |             | 1..1          |
# |                                                                | EHDSCurrentPregnancy.header.authorship.datetime  |            | dateTime               |             | 1..1          |
# |                                                                | EHDSCurrentPregnancy.header.identifier           |            | Identifier             |             | 0..*          |
# |                                                                | EHDSCurrentPregnancy.header.language             |            | CodeableConcept        |             | 0..1          |
# |                                                                | EHDSCurrentPregnancy.header.lastUpdate           |            | dateTime               |             | 0..1          |
# |                                                                | EHDSCurrentPregnancy.header.status               |            | CodeableConcept        |             | 1..1          |
# |                                                                | EHDSCurrentPregnancy.header.statusReason[x]      |            | CodeableConcept        |             | 0..1          |
# |                                                                | EHDSCurrentPregnancy.header.subject              |            | EHDSPatient            |             | 1..1          |
# |                                                                | EHDSCurrentPregnancy.header.version              |            | string                 |             | 0..1          |
# | Pregnancy.Comment                                              | EHDSCurrentPregnancy.narrative                   | ST         | string                 | 0..1        | 0..1          |
# |                                                                | EHDSCurrentPregnancy.presentedForm               |            | EHDSAttachment         |             | 0..*          |
# | Pregnancy.EstimatedDateOfDeliveryItems                         |                                                  |            |                        | 0..1        |               |
# | Pregnancy.EstimatedDateOfDeliveryItems.DateLastMenstruation    |                                                  | TS         |                        | 0..1        |               |
# | Pregnancy.EstimatedDateOfDeliveryItems.DateOfEstimation        |                                                  | TS         |                        | 0..1        |               |
# | Pregnancy.EstimatedDateOfDeliveryItems.EstimatingMethod        |                                                  | CD         |                        | 0..1        |               |
# | Pregnancy.Gravidity                                            |                                                  | INT        |                        | 0..1        |               |
# | Pregnancy.Parity                                               |                                                  | INT        |                        | 0..1        |               |
#
#
#
# ## EHDSCurrentPregnancy
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCurrentPregnancy |
# | zib | Pregnancy |
# | alias_zib | NL: Zwangerschap |
# | card._xtehr | 0..* |
# | definition_xtehr | Current pregnancy status |
# | definition_zib | Root concept of the Pregnancy information model. This root concept contains all data elements of the Pregnancy information model. |
# | definitioncode_zib | SNOMED CT: 118185001 Finding related to pregnancy |
# | id_xtehr | EHDSCurrentPregnancy |
# | id_zib | NL-CM:7.14.1 |
# | name_zib | Pregnancy |
# | path_xtehr | EHDSCurrentPregnancy |
# | path_zib | Pregnancy |
# | short_xtehr | Current pregnancy status model |
# | stereotype_zib | rootconcept |
#
# ### Comments
#
#
#
# ## EHDSCurrentPregnancy.currentPregnancyStatus
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCurrentPregnancy.currentPregnancyStatus |
# | zib |  |
# | binding_xtehr | {'strength': 'preferred', 'description': 'SNOMED CT'} |
# | card._xtehr | 1..1 |
# | definition_xtehr | Current state of the pregnancy at the date the observation was made, e.g. pregnant, not pregnant, unknown. |
# | id_xtehr | EHDSCurrentPregnancy.currentPregnancyStatus |
# | path_xtehr | EHDSCurrentPregnancy.currentPregnancyStatus |
# | short_xtehr | Current pregnancy status |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSCurrentPregnancy.dateOfStatus
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCurrentPregnancy.dateOfStatus |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Effective date of the current pregnancy status. |
# | id_xtehr | EHDSCurrentPregnancy.dateOfStatus |
# | path_xtehr | EHDSCurrentPregnancy.dateOfStatus |
# | short_xtehr | Effective date of the current pregnancy status. |
# | type_xtehr | dateTime |
#
# ### Comments
#
#
#
# ## EHDSCurrentPregnancy.expectedDateOfDelivery
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCurrentPregnancy.expectedDateOfDelivery |
# | zib | Pregnancy.EstimatedDateOfDeliveryItems.EstimatedDateOfDelivery |
# | alias_zib | NL: ATermeDatum |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Date in which the woman is due to give birth. Year, day and month are required. |
# | definition_zib | The date on which the pregnancy is expected to be 40w 0d (280 days). Different due dates are used at various points in the pregnancy. |
# | definitioncode_zib | SNOMED CT: 161714006 Estimated date of delivery |
# | id_xtehr | EHDSCurrentPregnancy.expectedDateOfDelivery |
# | id_zib | NL-CM:7.14.3 |
# | name_zib | EstimatedDateOfDelivery |
# | path_xtehr | EHDSCurrentPregnancy.expectedDateOfDelivery |
# | path_zib | Pregnancy.EstimatedDateOfDeliveryItems.EstimatedDateOfDelivery |
# | short_xtehr | Date in which the woman is due to give birth. Year, day and month are required. |
# | stereotype_zib | data |
# | type_xtehr | date |
# | type_zib | TS |
#
# ### Comments
#
#
#
# ## EHDSCurrentPregnancy.gestationalAge
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCurrentPregnancy.gestationalAge |
# | zib | Pregnancy.PregnancyDuration |
# | alias_zib | NL: Zwangerschapsduur |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Gestational age - duration of the pregnancy on the day on which the patient was asked or at the delivery. The duration can be given in weeks and/or days. |
# | definition_zib | Duration of the pregnancy on the day on which the patient was asked. The duration can be given in days (d) or weeks (wk). |
# | definitioncode_zib | SNOMED CT: 57036006 Fetal gestational age |
# | id_xtehr | EHDSCurrentPregnancy.gestationalAge |
# | id_zib | NL-CM:7.14.4 |
# | name_zib | PregnancyDuration |
# | path_xtehr | EHDSCurrentPregnancy.gestationalAge |
# | path_zib | Pregnancy.PregnancyDuration |
# | short_xtehr | Duration of the pregnancy at this day |
# | stereotype_zib | data |
# | type_xtehr | Quantity |
# | type_zib | PQ |
#
# ### Comments
#
#
#
# ## EHDSCurrentPregnancy.header
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCurrentPregnancy.header |
# | zib |  |
# | card._xtehr | 1..1 |
# | definition_xtehr | Common header for all patient-related data |
# | id_xtehr | EHDSCurrentPregnancy.header |
# | path_xtehr | EHDSCurrentPregnancy.header |
# | short_xtehr | Common header for all patient-related data |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSCurrentPregnancy.header.authorship
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCurrentPregnancy.header.authorship |
# | zib |  |
# | card._xtehr | 1..* |
# | definition_xtehr | Resource authoring details |
# | id_xtehr | EHDSCurrentPregnancy.header.authorship |
# | path_xtehr | EHDSCurrentPregnancy.header.authorship |
# | short_xtehr | Authorship |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSCurrentPregnancy.header.authorship.author[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCurrentPregnancy.header.authorship.author[x] |
# | zib |  |
# | card._xtehr | 1..1 |
# | definition_xtehr | Author(s) by whom the resource was/were authored. Multiple authors could be provided. |
# | id_xtehr | EHDSCurrentPregnancy.header.authorship.author[x] |
# | path_xtehr | EHDSCurrentPregnancy.header.authorship.author[x] |
# | short_xtehr | Author |
# | type_xtehr | EHDSHealthProfessional |
#
# ### Comments
#
#
#
# ## EHDSCurrentPregnancy.header.authorship.datetime
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCurrentPregnancy.header.authorship.datetime |
# | zib |  |
# | card._xtehr | 1..1 |
# | definition_xtehr | Date and time of the issuing the document/resource by its author. |
# | id_xtehr | EHDSCurrentPregnancy.header.authorship.datetime |
# | path_xtehr | EHDSCurrentPregnancy.header.authorship.datetime |
# | short_xtehr | Date and time of authoring/issuing |
# | type_xtehr | dateTime |
#
# ### Comments
#
#
#
# ## EHDSCurrentPregnancy.header.identifier
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCurrentPregnancy.header.identifier |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | Business identifier for the object |
# | id_xtehr | EHDSCurrentPregnancy.header.identifier |
# | path_xtehr | EHDSCurrentPregnancy.header.identifier |
# | short_xtehr | Business identifier for the object |
# | type_xtehr | Identifier |
#
# ### Comments
#
#
#
# ## EHDSCurrentPregnancy.header.language
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCurrentPregnancy.header.language |
# | zib |  |
# | binding_xtehr | {'strength': 'preferred', 'description': 'BCP 47'} |
# | card._xtehr | 0..1 |
# | definition_xtehr | Language in which the resource is written. Language is expressed by the IETF language tag. |
# | id_xtehr | EHDSCurrentPregnancy.header.language |
# | path_xtehr | EHDSCurrentPregnancy.header.language |
# | short_xtehr | Language |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSCurrentPregnancy.header.lastUpdate
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCurrentPregnancy.header.lastUpdate |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Date and time of the last update to the document/information |
# | id_xtehr | EHDSCurrentPregnancy.header.lastUpdate |
# | path_xtehr | EHDSCurrentPregnancy.header.lastUpdate |
# | short_xtehr | Date and time of the last update to the resource |
# | type_xtehr | dateTime |
#
# ### Comments
#
#
#
# ## EHDSCurrentPregnancy.header.status
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCurrentPregnancy.header.status |
# | zib |  |
# | card._xtehr | 1..1 |
# | definition_xtehr | Status of the resource |
# | id_xtehr | EHDSCurrentPregnancy.header.status |
# | path_xtehr | EHDSCurrentPregnancy.header.status |
# | short_xtehr | Status of the resource |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSCurrentPregnancy.header.statusReason[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCurrentPregnancy.header.statusReason[x] |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Reason for the current status of the resource. |
# | id_xtehr | EHDSCurrentPregnancy.header.statusReason[x] |
# | path_xtehr | EHDSCurrentPregnancy.header.statusReason[x] |
# | short_xtehr | Reason for the current status of the resource. |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSCurrentPregnancy.header.subject
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCurrentPregnancy.header.subject |
# | zib |  |
# | card._xtehr | 1..1 |
# | definition_xtehr | Patient/subject information |
# | id_xtehr | EHDSCurrentPregnancy.header.subject |
# | path_xtehr | EHDSCurrentPregnancy.header.subject |
# | short_xtehr | Subject |
# | type_xtehr | EHDSPatient |
#
# ### Comments
#
#
#
# ## EHDSCurrentPregnancy.header.version
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCurrentPregnancy.header.version |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Business version of the resource. |
# | id_xtehr | EHDSCurrentPregnancy.header.version |
# | path_xtehr | EHDSCurrentPregnancy.header.version |
# | short_xtehr | Version |
# | type_xtehr | string |
#
# ### Comments
#
#
#
# ## EHDSCurrentPregnancy.narrative
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCurrentPregnancy.narrative |
# | zib | Pregnancy.Comment |
# | alias_zib | NL: Toelichting |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Narrative description describing the status of the current pregnancy. |
# | definition_zib | Comment on the pregnancy. |
# | definitioncode_zib | LOINC: 48767-8 Annotation comment [Interpretation] Narrative |
# | id_xtehr | EHDSCurrentPregnancy.narrative |
# | id_zib | NL-CM:7.14.7 |
# | name_zib | Comment |
# | path_xtehr | EHDSCurrentPregnancy.narrative |
# | path_zib | Pregnancy.Comment |
# | short_xtehr | Textual description of current pregnancy status |
# | stereotype_zib | data |
# | type_xtehr | string |
# | type_zib | ST |
#
# ### Comments
#
#
#
# ## EHDSCurrentPregnancy.presentedForm
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSCurrentPregnancy.presentedForm |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | A narrative easy-to-read representation of the full data set, e.g. PDF-version of a document |
# | id_xtehr | EHDSCurrentPregnancy.presentedForm |
# | path_xtehr | EHDSCurrentPregnancy.presentedForm |
# | short_xtehr | A narrative easy-to-read representation of the full data set, e.g. PDF-version of a document |
# | type_xtehr | EHDSAttachment |
#
# ### Comments
#
#
#
# ## zib: Pregnancy.EstimatedDateOfDeliveryItems
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Pregnancy.EstimatedDateOfDeliveryItems |
# | alias_zib | NL: ATermeDatumItems |
# | card._zib | 0..1 |
# | definition_zib | Container of the EstimatedDateOfDeliveryItems concept.This container contains all data elements of the EstimatedDateOfDeliveryItems concept. |
# | id_zib | NL-CM:7.14.9 |
# | name_zib | EstimatedDateOfDeliveryItems |
# | path_zib | Pregnancy.EstimatedDateOfDeliveryItems |
# | stereotype_zib | container |
#
# ### Comments
#
#
#
# ## zib: Pregnancy.EstimatedDateOfDeliveryItems.DateLastMenstruation
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Pregnancy.EstimatedDateOfDeliveryItems.DateLastMenstruation |
# | alias_zib | NL: DatumLaatsteMenstruatie |
# | card._zib | 0..1 |
# | definition_zib | The date on which the last menstruation started. |
# | definitioncode_zib | SNOMED CT: 21840007 Date of last menstrual period |
# | id_zib | NL-CM:7.14.8 |
# | name_zib | DateLastMenstruation |
# | path_zib | Pregnancy.EstimatedDateOfDeliveryItems.DateLastMenstruation |
# | stereotype_zib | data |
# | type_zib | TS |
#
# ### Comments
#
#
#
# ## zib: Pregnancy.EstimatedDateOfDeliveryItems.DateOfEstimation
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Pregnancy.EstimatedDateOfDeliveryItems.DateOfEstimation |
# | alias_zib | NL: DatumBepaling |
# | card._zib | 0..1 |
# | definition_zib | Date on which the delivery date is estimated. |
# | id_zib | NL-CM:7.14.11 |
# | name_zib | DateOfEstimation |
# | path_zib | Pregnancy.EstimatedDateOfDeliveryItems.DateOfEstimation |
# | stereotype_zib | data |
# | type_zib | TS |
#
# ### Comments
#
#
#
# ## zib: Pregnancy.EstimatedDateOfDeliveryItems.EstimatingMethod
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Pregnancy.EstimatedDateOfDeliveryItems.EstimatingMethod |
# | alias_zib | NL: BepalingsMethode |
# | card._zib | 0..1 |
# | definition_zib | Method by which the delivery date is estimated. |
# | id_zib | NL-CM:7.14.10 |
# | name_zib | EstimatingMethod |
# | path_zib | Pregnancy.EstimatedDateOfDeliveryItems.EstimatingMethod |
# | stereotype_zib | data |
# | type_zib | CD |
#
# ### Comments
#
#
#
# ## zib: Pregnancy.Gravidity
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Pregnancy.Gravidity |
# | alias_zib | NL: Graviditeit |
# | card._zib | 0..1 |
# | definition_zib | The number of times the woman has gotten pregnant (including this one). |
# | definitioncode_zib | SNOMED CT: 161732006 Gravida |
# | id_zib | NL-CM:7.14.5 |
# | name_zib | Gravidity |
# | path_zib | Pregnancy.Gravidity |
# | stereotype_zib | data |
# | type_zib | INT |
#
# ### Comments
#
#
#
# ## zib: Pregnancy.Parity
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | Pregnancy.Parity |
# | alias_zib | NL: Pariteit |
# | card._zib | 0..1 |
# | definition_zib | Number of previous pregnancies ending in partum (>= 16w 0d / 112 days). |
# | definitioncode_zib | SNOMED CT: 364325004 Parity |
# | id_zib | NL-CM:7.14.6 |
# | name_zib | Parity |
# | path_zib | Pregnancy.Parity |
# | stereotype_zib | data |
# | type_zib | INT |
#
# ### Comments
