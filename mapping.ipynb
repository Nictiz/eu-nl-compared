# %%
import pandas as pd
import os

# %%
# zibbase = 'zibs2020'
zibbase = 'zibs2024'
zibspath = os.path.join(zibbase, 'mappable')
zibs = os.listdir(zibspath)
[(i, zib) for i, zib in enumerate(zibs)]
# Out:
# [(0, 'Nl.zorg.Alert-v5.0(2024EN).xlsx'),
#  (1, 'Nl.zorg.HealthcareProvider-v3.6(2024EN).xlsx'),
#  (2, 'Nl.zorg.HealthProfessional-v4.0(2024EN).xlsx'),
#  (3, 'Nl.zorg.MedicalDevice-v5.0(2024EN).xlsx'),
#  (4, 'Nl.zorg.part.AddressInformation-v1.2(2024EN).xlsx'),
#  (5, 'Nl.zorg.part.AnatomicalLocation-v1.0.4(2024EN).xlsx'),
#  (6, 'Nl.zorg.part.ContactInformation-v1.3.1(2024EN).xlsx'),
#  (7, 'Nl.zorg.part.NameInformation-v1.2(2024EN).xlsx'),
#  (8, 'Nl.zorg.Patient-v4.3(2024EN).xlsx'),
#  (9, 'Nl.zorg.Procedure-v6.0(2024EN).xlsx'),
#  (10, 'Nl.zorg.process.RegistrationData-v1.1.2(2024EN).xlsx')]

# %%
zib = zibs[9]
print(zib)
zibpath = os.path.join(zibspath, zib)
zibdf = pd.read_excel(zibpath)
zibdf
# Out:
# Nl.zorg.Procedure-v6.0(2024EN).xlsx
#                                                name  \
# 0                                         Procedure
# 1                                ProcedureStartDate
# 2                                  ProcedureEndDate
# 3                     Performer::HealthProfessional
# 4                      Location::HealthcareProvider
# 5   ProcedureAnatomicalLocation::AnatomicalLocation
# 6                                        Indication
# 7                                         Diagnosis
# 8                                          Reaction
# 9                                           Symptom
# 10                                  ProcedureMethod
# 11                                    MedicalDevice
# 12                                    ProcedureType
#
#                                                  path  \
# 0                                           Procedure
# 1                        Procedure.ProcedureStartDate
# 2                          Procedure.ProcedureEndDate
# 3             Procedure.Performer::HealthProfessional
# 4              Procedure.Location::HealthcareProvider
# 5   Procedure.ProcedureAnatomicalLocation::Anatomi...
# 6                                Procedure.Indication
# 7                      Procedure.Indication.Diagnosis
# 8                       Procedure.Indication.Reaction
# 9                        Procedure.Indication.Symptom
# 10                          Procedure.ProcedureMethod
# 11                            Procedure.MedicalDevice
# 12                            Procedure.ProcedureType
#
#                                                 alias type   card.  \
# 0                                     NL: Verrichting  NaN     NaN
# 1                           NL: VerrichtingStartDatum   TS    0..1
# 2                            NL: VerrichtingEindDatum   TS    0..1
# 3                        NL: Uitvoerder::Zorgverlener  NaN    0..*
# 4                          NL: Locatie::Zorgaanbieder  NaN    0..1
# 5   NL: VerrichtingAnatomischeLocatie::Anatomische...  NaN    0..1
# 6                                       NL: Indicatie  NaN    0..*
# 7                                        NL: Diagnose  NaN  (0..1)
# 8                                         NL: Reactie  NaN  (0..1)
# 9                                        NL: Symptoom  NaN  (0..1)
# 10                             NL: VerrichtingMethode   CD    0..*
# 11                              NL: MedischHulpmiddel  NaN    0..*
# 12                                NL: VerrichtingType   CD       1
#
#            stereotype             id  \
# 0         rootconcept   NL-CM:14.1.1
# 1                data   NL-CM:14.1.2
# 2                data   NL-CM:14.1.3
# 3   context,reference   NL-CM:14.1.6
# 4   context,reference   NL-CM:14.1.5
# 5      data,reference  NL-CM:14.1.13
# 6           container  NL-CM:14.1.14
# 7      data,reference  NL-CM:14.1.15
# 8      data,reference  NL-CM:14.1.16
# 9      data,reference  NL-CM:14.1.17
# 10               data  NL-CM:14.1.12
# 11     data,reference   NL-CM:14.1.7
# 12               data   NL-CM:14.1.4
#
#                                            definition  \
# 0   Root concept of the Procedure information mode...
# 1   The (desired) start date (and if possible star...
# 2   The end date (and if possible end time) of the...
# 3   The healthcare professional who carried out or...
# 4   The healthcare provider where the procedure wa...
# 5   Anatomical location that is the focus of the p...
# 6   Container of the Indication concept.This conta...
# 7   A diagnosis that serves as an indication for t...
# 8   An undesired reaction to a substance or radiat...
# 9   A symptom that serves as an indication for the...
# 10  The method or technique that is going to be or...
# 11  The product, the placing of which in or on the...
# 12  The name of the procedure.<br />Choices are th...
#
#                                   definitioncode
# 0                  SNOMED CT: 71388002 Procedure
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5   SNOMED CT: 405813007 Procedure site - Direct
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                   SNOMED CT: 260686004 Method
# 11         SNOMED CT: 405815000 Procedure device
# 12                                           NaN

# %%
xlmbase = 'xtehr'
xlmspath = os.path.join(xlmbase, 'mappable')
xlms = os.listdir(xlmspath)
[(i, xlm) for i, xlm in enumerate(xlms)]
# Out:
# [(0, 'Address.xlsx'),
#  (1, 'AlertFlag.xlsx'),
#  (2, 'AllergyIntolerance.xlsx'),
#  (3, 'BodyStructure.xlsx'),
#  (4, 'Condition.xlsx'),
#  (5, 'DataSet.xlsx'),
#  (6, 'Device.xlsx'),
#  (7, 'DeviceUse.xlsx'),
#  (8, 'HealthProfessional.xlsx'),
#  (9, 'HumanName.xlsx'),
#  (10, 'Location.xlsx'),
#  (11, 'Medication.xlsx'),
#  (12, 'Organization.xlsx'),
#  (13, 'Patient.xlsx'),
#  (14, 'Procedure.xlsx'),
#  (15, 'Telecom.xlsx')]

# %%
xlm = xlms[14]
print( xlm)
xlmpath = os.path.join(xlmspath, xlm)
xlmdf = pd.read_excel(xlmpath)
xlmdf
# only for device use and organization
#xlm = xlms[11]
#print( xlm)
#xlmpath = os.path.join(xlmspath, xlm)
#xlmdf2 = pd.read_excel(xlmpath)
#xlmdf = pd.concat([xlmdf, xlmdf2], ignore_index=True)
#xlmdf
# Out:
# Procedure.xlsx
#                                            id  \
# 0                               EHDSProcedure
# 1                        EHDSProcedure.header
# 2                EHDSProcedure.header.subject
# 3             EHDSProcedure.header.identifier
# 4             EHDSProcedure.header.authorship
# 5   EHDSProcedure.header.authorship.author[x]
# 6    EHDSProcedure.header.authorship.datetime
# 7             EHDSProcedure.header.lastUpdate
# 8                 EHDSProcedure.header.status
# 9        EHDSProcedure.header.statusReason[x]
# 10              EHDSProcedure.header.language
# 11               EHDSProcedure.header.version
# 12                EHDSProcedure.presentedForm
# 13                         EHDSProcedure.code
# 14                      EHDSProcedure.date[x]
# 15                    EHDSProcedure.performer
# 16                     EHDSProcedure.bodySite
# 17                    EHDSProcedure.reason[x]
# 18                      EHDSProcedure.outcome
# 19                 EHDSProcedure.complication
# 20                   EHDSProcedure.deviceUsed
# 21                  EHDSProcedure.focalDevice
# 22                         EHDSProcedure.note
#
#                                          path  \
# 0                               EHDSProcedure
# 1                        EHDSProcedure.header
# 2                EHDSProcedure.header.subject
# 3             EHDSProcedure.header.identifier
# 4             EHDSProcedure.header.authorship
# 5   EHDSProcedure.header.authorship.author[x]
# 6    EHDSProcedure.header.authorship.datetime
# 7             EHDSProcedure.header.lastUpdate
# 8                 EHDSProcedure.header.status
# 9        EHDSProcedure.header.statusReason[x]
# 10              EHDSProcedure.header.language
# 11               EHDSProcedure.header.version
# 12                EHDSProcedure.presentedForm
# 13                         EHDSProcedure.code
# 14                      EHDSProcedure.date[x]
# 15                    EHDSProcedure.performer
# 16                     EHDSProcedure.bodySite
# 17                    EHDSProcedure.reason[x]
# 18                      EHDSProcedure.outcome
# 19                 EHDSProcedure.complication
# 20                   EHDSProcedure.deviceUsed
# 21                  EHDSProcedure.focalDevice
# 22                         EHDSProcedure.note
#
#                                                 short  \
# 0                                     Procedure model
# 1          Common header for all patient-related data
# 2                                             Subject
# 3                  Business identifier for the object
# 4                                          Authorship
# 5                                              Author
# 6                  Date and time of authoring/issuing
# 7    Date and time of the last update to the resource
# 8                              Status of the resource
# 9      Reason for the current status of the resource.
# 10                                           Language
# 11                                            Version
# 12  A narrative easy-to-read representation of the...
# 13                     Code identifying the procedure
# 14  Date and time of the procedure or interval of ...
# 15               An actor who performed the procedure
# 16  Procedure target body site. Details of where t...
# 17  The reason why the procedure was performed. Th...
# 18  The outcome of the procedure - did it resolve ...
# 19  Any complications that occurred during the pro...
# 20               Device used to perform the procedure
# 21  Device(s) that is/are implanted, removed, or o...
# 22         Additional information about the procedure
#
#                                            definition                    type  \
# 0   EHDS refined base model for an action that is ...                     NaN
# 1          Common header for all patient-related data                    Base
# 2                         Patient/subject information             EHDSPatient
# 3                  Business identifier for the object              Identifier
# 4                          Resource authoring details                    Base
# 5   Author(s) by whom the resource was/were author...  EHDSHealthProfessional
# 6   Date and time of the issuing the document/reso...                dateTime
# 7   Date and time of the last update to the docume...                dateTime
# 8                              Status of the resource         CodeableConcept
# 9      Reason for the current status of the resource.         CodeableConcept
# 10  Language in which the resource is written. Lan...         CodeableConcept
# 11                  Business version of the resource.                  string
# 12  A narrative easy-to-read representation of the...          EHDSAttachment
# 13                     Code identifying the procedure         CodeableConcept
# 14  Date and time of the procedure or interval of ...                dateTime
# 15               An actor who performed the procedure  EHDSHealthProfessional
# 16  Procedure target body site. Details of where t...       EHDSBodyStructure
# 17  The reason why the procedure was performed. Th...         CodeableConcept
# 18  The outcome of the procedure - did it resolve ...         CodeableConcept
# 19  Any complications that occurred during the pro...         CodeableConcept
# 20               Device used to perform the procedure              EHDSDevice
# 21  Device(s) that is/are implanted, removed, or o...              EHDSDevice
# 22         Additional information about the procedure                  string
#
#    card.                                            binding
# 0   0..*                                                NaN
# 1   1..1                                                NaN
# 2   1..1                                                NaN
# 3   0..*                                                NaN
# 4   1..*                                                NaN
# 5   1..1                                                NaN
# 6   1..1                                                NaN
# 7   0..1                                                NaN
# 8   1..1                                                NaN
# 9   0..1                                                NaN
# 10  0..1  {'strength': 'preferred', 'description': 'BCP ...
# 11  0..1                                                NaN
# 12  0..*                                                NaN
# 13  0..1  {'strength': 'preferred', 'description': 'SNOM...
# 14  0..1                                                NaN
# 15  0..*                                                NaN
# 16  0..*                                                NaN
# 17  0..*  {'strength': 'preferred', 'description': 'SNOM...
# 18  0..1  {'strength': 'preferred', 'description': 'SNOM...
# 19  0..*  {'strength': 'preferred', 'description': 'ICD-...
# 20  0..*                                                NaN
# 21  0..*                                                NaN
# 22  0..1                                                NaN

# %%
mapbase = 'maps'
maps = os.listdir(mapbase)
[(i, map) for i, map in enumerate(maps)]
# Out:
# [(0, 'Address.xlsx'),
#  (1, 'AlertFlag.xlsx'),
#  (2, 'BodyStructure.xlsx'),
#  (3, 'Condition.xlsx'),
#  (4, 'DataSet.xlsx'),
#  (5, 'Device-and-DeviceUse.xlsx'),
#  (6, 'HealthProfessional.xlsx'),
#  (7, 'HumanName.xlsx'),
#  (8, 'Location-and-Organization.xlsx'),
#  (9, 'Patient.xlsx'),
#  (10, 'Procedure.xlsx'),
#  (11, 'xtehr2zibs'),
#  (12, 'xtehr2zibs2024')]

# %%
file = maps[10]
print(file)
mappath = os.path.join(mapbase, file)
print(mappath)
mapdf = pd.read_excel(mappath)
mapdf
# Out:
# Procedure.xlsx
# maps\Procedure.xlsx
#                                         xtehr  \
# 0                               EHDSProcedure
# 1                        EHDSProcedure.header
# 2                EHDSProcedure.header.subject
# 3             EHDSProcedure.header.identifier
# 4             EHDSProcedure.header.authorship
# 5   EHDSProcedure.header.authorship.author[x]
# 6    EHDSProcedure.header.authorship.datetime
# 7             EHDSProcedure.header.lastUpdate
# 8                 EHDSProcedure.header.status
# 9        EHDSProcedure.header.statusReason[x]
# 10              EHDSProcedure.header.language
# 11               EHDSProcedure.header.version
# 12                EHDSProcedure.presentedForm
# 13                         EHDSProcedure.code
# 14                      EHDSProcedure.date[x]
# 15                      EHDSProcedure.date[x]
# 16                    EHDSProcedure.performer
# 17                                        NaN
# 18                     EHDSProcedure.bodySite
# 19                    EHDSProcedure.reason[x]
# 20                      EHDSProcedure.outcome
# 21                 EHDSProcedure.complication
# 22                   EHDSProcedure.deviceUsed
# 23                                        NaN
# 24                  EHDSProcedure.focalDevice
# 25                     EHDSProcedure.location
# 26                         EHDSProcedure.note
# 27                    EHDSProcedure.reason[x]
# 28                    EHDSProcedure.reason[x]
# 29                    EHDSProcedure.reason[x]
# 30                    EHDSProcedure.reason[x]
#
#                                                   zib 2020 2024
# 0                                           Procedure    x    x
# 1            Registratiegegevens, zie DataSet mapping  NaN  NaN
# 2                                                 NaN  NaN  NaN
# 3                                                 NaN  NaN  NaN
# 4                                                 NaN  NaN  NaN
# 5                                                 NaN  NaN  NaN
# 6                                                 NaN  NaN  NaN
# 7                                                 NaN  NaN  NaN
# 8                                                 NaN  NaN  NaN
# 9                                                 NaN  NaN  NaN
# 10                                                NaN  NaN  NaN
# 11                                                NaN  NaN  NaN
# 12                                                NaN  NaN  NaN
# 13                            Procedure.ProcedureType    x    x
# 14                       Procedure.ProcedureStartDate    x    x
# 15                         Procedure.ProcedureEndDate    x    x
# 16            Procedure.Performer::HealthProfessional    x    x
# 17            Procedure.Requester::HealthProfessional    x  NaN
# 18  Procedure.ProcedureAnatomicalLocation::Anatomi...    x    x
# 19                      Procedure.Indication::Problem    x  NaN
# 20                                                NaN  NaN  NaN
# 21                                                NaN  NaN  NaN
# 22                                                NaN  NaN  NaN
# 23                          Procedure.ProcedureMethod    x    x
# 24                            Procedure.MedicalDevice    x    x
# 25             Procedure.Location::HealthcareProvider    x    x
# 26                                                NaN  NaN  NaN
# 27                               Procedure.Indication  NaN    x
# 28                     Procedure.Indication.Diagnosis  NaN    x
# 29                      Procedure.Indication.Reaction  NaN    x
# 30                       Procedure.Indication.Symptom  NaN    x

# %%
mapping = mapdf[['xtehr', 'zib']].merge(zibdf.add_suffix('_zib'), left_on='zib', right_on='path_zib', how='outer').merge(xlmdf.add_suffix('_xtehr'), left_on='xtehr', right_on='path_xtehr', how='outer')
mapping
# Out:
#                                         xtehr  \
# 0                               EHDSProcedure
# 1                      EHDSProcedure.bodySite
# 2                          EHDSProcedure.code
# 3                  EHDSProcedure.complication
# 4                       EHDSProcedure.date[x]
# 5                       EHDSProcedure.date[x]
# 6                    EHDSProcedure.deviceUsed
# 7                   EHDSProcedure.focalDevice
# 8                        EHDSProcedure.header
# 9             EHDSProcedure.header.authorship
# 10  EHDSProcedure.header.authorship.author[x]
# 11   EHDSProcedure.header.authorship.datetime
# 12            EHDSProcedure.header.identifier
# 13              EHDSProcedure.header.language
# 14            EHDSProcedure.header.lastUpdate
# 15                EHDSProcedure.header.status
# 16       EHDSProcedure.header.statusReason[x]
# 17               EHDSProcedure.header.subject
# 18               EHDSProcedure.header.version
# 19                     EHDSProcedure.location
# 20                         EHDSProcedure.note
# 21                      EHDSProcedure.outcome
# 22                    EHDSProcedure.performer
# 23                EHDSProcedure.presentedForm
# 24                    EHDSProcedure.reason[x]
# 25                    EHDSProcedure.reason[x]
# 26                    EHDSProcedure.reason[x]
# 27                    EHDSProcedure.reason[x]
# 28                    EHDSProcedure.reason[x]
# 29                                        NaN
# 30                                        NaN
#
#                                                   zib  \
# 0                                           Procedure
# 1   Procedure.ProcedureAnatomicalLocation::Anatomi...
# 2                             Procedure.ProcedureType
# 3                                                 NaN
# 4                          Procedure.ProcedureEndDate
# 5                        Procedure.ProcedureStartDate
# 6                                                 NaN
# 7                             Procedure.MedicalDevice
# 8            Registratiegegevens, zie DataSet mapping
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19             Procedure.Location::HealthcareProvider
# 20                                                NaN
# 21                                                NaN
# 22            Procedure.Performer::HealthProfessional
# 23                                                NaN
# 24                               Procedure.Indication
# 25                     Procedure.Indication.Diagnosis
# 26                      Procedure.Indication.Reaction
# 27                       Procedure.Indication.Symptom
# 28                      Procedure.Indication::Problem
# 29                          Procedure.ProcedureMethod
# 30            Procedure.Requester::HealthProfessional
#
#                                            name_zib  \
# 0                                         Procedure
# 1   ProcedureAnatomicalLocation::AnatomicalLocation
# 2                                     ProcedureType
# 3                                               NaN
# 4                                  ProcedureEndDate
# 5                                ProcedureStartDate
# 6                                               NaN
# 7                                     MedicalDevice
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15                                              NaN
# 16                                              NaN
# 17                                              NaN
# 18                                              NaN
# 19                     Location::HealthcareProvider
# 20                                              NaN
# 21                                              NaN
# 22                    Performer::HealthProfessional
# 23                                              NaN
# 24                                       Indication
# 25                                        Diagnosis
# 26                                         Reaction
# 27                                          Symptom
# 28                                              NaN
# 29                                  ProcedureMethod
# 30                                              NaN
#
#                                              path_zib  \
# 0                                           Procedure
# 1   Procedure.ProcedureAnatomicalLocation::Anatomi...
# 2                             Procedure.ProcedureType
# 3                                                 NaN
# 4                          Procedure.ProcedureEndDate
# 5                        Procedure.ProcedureStartDate
# 6                                                 NaN
# 7                             Procedure.MedicalDevice
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19             Procedure.Location::HealthcareProvider
# 20                                                NaN
# 21                                                NaN
# 22            Procedure.Performer::HealthProfessional
# 23                                                NaN
# 24                               Procedure.Indication
# 25                     Procedure.Indication.Diagnosis
# 26                      Procedure.Indication.Reaction
# 27                       Procedure.Indication.Symptom
# 28                                                NaN
# 29                          Procedure.ProcedureMethod
# 30                                                NaN
#
#                                             alias_zib type_zib card._zib  \
# 0                                     NL: Verrichting      NaN       NaN
# 1   NL: VerrichtingAnatomischeLocatie::Anatomische...      NaN      0..1
# 2                                 NL: VerrichtingType       CD         1
# 3                                                 NaN      NaN       NaN
# 4                            NL: VerrichtingEindDatum       TS      0..1
# 5                           NL: VerrichtingStartDatum       TS      0..1
# 6                                                 NaN      NaN       NaN
# 7                               NL: MedischHulpmiddel      NaN      0..*
# 8                                                 NaN      NaN       NaN
# 9                                                 NaN      NaN       NaN
# 10                                                NaN      NaN       NaN
# 11                                                NaN      NaN       NaN
# 12                                                NaN      NaN       NaN
# 13                                                NaN      NaN       NaN
# 14                                                NaN      NaN       NaN
# 15                                                NaN      NaN       NaN
# 16                                                NaN      NaN       NaN
# 17                                                NaN      NaN       NaN
# 18                                                NaN      NaN       NaN
# 19                         NL: Locatie::Zorgaanbieder      NaN      0..1
# 20                                                NaN      NaN       NaN
# 21                                                NaN      NaN       NaN
# 22                       NL: Uitvoerder::Zorgverlener      NaN      0..*
# 23                                                NaN      NaN       NaN
# 24                                      NL: Indicatie      NaN      0..*
# 25                                       NL: Diagnose      NaN    (0..1)
# 26                                        NL: Reactie      NaN    (0..1)
# 27                                       NL: Symptoom      NaN    (0..1)
# 28                                                NaN      NaN       NaN
# 29                             NL: VerrichtingMethode       CD      0..*
# 30                                                NaN      NaN       NaN
#
#        stereotype_zib         id_zib  \
# 0         rootconcept   NL-CM:14.1.1
# 1      data,reference  NL-CM:14.1.13
# 2                data   NL-CM:14.1.4
# 3                 NaN            NaN
# 4                data   NL-CM:14.1.3
# 5                data   NL-CM:14.1.2
# 6                 NaN            NaN
# 7      data,reference   NL-CM:14.1.7
# 8                 NaN            NaN
# 9                 NaN            NaN
# 10                NaN            NaN
# 11                NaN            NaN
# 12                NaN            NaN
# 13                NaN            NaN
# 14                NaN            NaN
# 15                NaN            NaN
# 16                NaN            NaN
# 17                NaN            NaN
# 18                NaN            NaN
# 19  context,reference   NL-CM:14.1.5
# 20                NaN            NaN
# 21                NaN            NaN
# 22  context,reference   NL-CM:14.1.6
# 23                NaN            NaN
# 24          container  NL-CM:14.1.14
# 25     data,reference  NL-CM:14.1.15
# 26     data,reference  NL-CM:14.1.16
# 27     data,reference  NL-CM:14.1.17
# 28                NaN            NaN
# 29               data  NL-CM:14.1.12
# 30                NaN            NaN
#
#                                        definition_zib  \
# 0   Root concept of the Procedure information mode...
# 1   Anatomical location that is the focus of the p...
# 2   The name of the procedure.<br />Choices are th...
# 3                                                 NaN
# 4   The end date (and if possible end time) of the...
# 5   The (desired) start date (and if possible star...
# 6                                                 NaN
# 7   The product, the placing of which in or on the...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  The healthcare provider where the procedure wa...
# 20                                                NaN
# 21                                                NaN
# 22  The healthcare professional who carried out or...
# 23                                                NaN
# 24  Container of the Indication concept.This conta...
# 25  A diagnosis that serves as an indication for t...
# 26  An undesired reaction to a substance or radiat...
# 27  A symptom that serves as an indication for the...
# 28                                                NaN
# 29  The method or technique that is going to be or...
# 30                                                NaN
#
#                               definitioncode_zib  \
# 0                  SNOMED CT: 71388002 Procedure
# 1   SNOMED CT: 405813007 Procedure site - Direct
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7          SNOMED CT: 405815000 Procedure device
# 8                                            NaN
# 9                                            NaN
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
# 14                                           NaN
# 15                                           NaN
# 16                                           NaN
# 17                                           NaN
# 18                                           NaN
# 19                                           NaN
# 20                                           NaN
# 21                                           NaN
# 22                                           NaN
# 23                                           NaN
# 24                                           NaN
# 25                                           NaN
# 26                                           NaN
# 27                                           NaN
# 28                                           NaN
# 29                   SNOMED CT: 260686004 Method
# 30                                           NaN
#
#                                      id_xtehr  \
# 0                               EHDSProcedure
# 1                      EHDSProcedure.bodySite
# 2                          EHDSProcedure.code
# 3                  EHDSProcedure.complication
# 4                       EHDSProcedure.date[x]
# 5                       EHDSProcedure.date[x]
# 6                    EHDSProcedure.deviceUsed
# 7                   EHDSProcedure.focalDevice
# 8                        EHDSProcedure.header
# 9             EHDSProcedure.header.authorship
# 10  EHDSProcedure.header.authorship.author[x]
# 11   EHDSProcedure.header.authorship.datetime
# 12            EHDSProcedure.header.identifier
# 13              EHDSProcedure.header.language
# 14            EHDSProcedure.header.lastUpdate
# 15                EHDSProcedure.header.status
# 16       EHDSProcedure.header.statusReason[x]
# 17               EHDSProcedure.header.subject
# 18               EHDSProcedure.header.version
# 19                                        NaN
# 20                         EHDSProcedure.note
# 21                      EHDSProcedure.outcome
# 22                    EHDSProcedure.performer
# 23                EHDSProcedure.presentedForm
# 24                    EHDSProcedure.reason[x]
# 25                    EHDSProcedure.reason[x]
# 26                    EHDSProcedure.reason[x]
# 27                    EHDSProcedure.reason[x]
# 28                    EHDSProcedure.reason[x]
# 29                                        NaN
# 30                                        NaN
#
#                                    path_xtehr  \
# 0                               EHDSProcedure
# 1                      EHDSProcedure.bodySite
# 2                          EHDSProcedure.code
# 3                  EHDSProcedure.complication
# 4                       EHDSProcedure.date[x]
# 5                       EHDSProcedure.date[x]
# 6                    EHDSProcedure.deviceUsed
# 7                   EHDSProcedure.focalDevice
# 8                        EHDSProcedure.header
# 9             EHDSProcedure.header.authorship
# 10  EHDSProcedure.header.authorship.author[x]
# 11   EHDSProcedure.header.authorship.datetime
# 12            EHDSProcedure.header.identifier
# 13              EHDSProcedure.header.language
# 14            EHDSProcedure.header.lastUpdate
# 15                EHDSProcedure.header.status
# 16       EHDSProcedure.header.statusReason[x]
# 17               EHDSProcedure.header.subject
# 18               EHDSProcedure.header.version
# 19                                        NaN
# 20                         EHDSProcedure.note
# 21                      EHDSProcedure.outcome
# 22                    EHDSProcedure.performer
# 23                EHDSProcedure.presentedForm
# 24                    EHDSProcedure.reason[x]
# 25                    EHDSProcedure.reason[x]
# 26                    EHDSProcedure.reason[x]
# 27                    EHDSProcedure.reason[x]
# 28                    EHDSProcedure.reason[x]
# 29                                        NaN
# 30                                        NaN
#
#                                           short_xtehr  \
# 0                                     Procedure model
# 1   Procedure target body site. Details of where t...
# 2                      Code identifying the procedure
# 3   Any complications that occurred during the pro...
# 4   Date and time of the procedure or interval of ...
# 5   Date and time of the procedure or interval of ...
# 6                Device used to perform the procedure
# 7   Device(s) that is/are implanted, removed, or o...
# 8          Common header for all patient-related data
# 9                                          Authorship
# 10                                             Author
# 11                 Date and time of authoring/issuing
# 12                 Business identifier for the object
# 13                                           Language
# 14   Date and time of the last update to the resource
# 15                             Status of the resource
# 16     Reason for the current status of the resource.
# 17                                            Subject
# 18                                            Version
# 19                                                NaN
# 20         Additional information about the procedure
# 21  The outcome of the procedure - did it resolve ...
# 22               An actor who performed the procedure
# 23  A narrative easy-to-read representation of the...
# 24  The reason why the procedure was performed. Th...
# 25  The reason why the procedure was performed. Th...
# 26  The reason why the procedure was performed. Th...
# 27  The reason why the procedure was performed. Th...
# 28  The reason why the procedure was performed. Th...
# 29                                                NaN
# 30                                                NaN
#
#                                      definition_xtehr              type_xtehr  \
# 0   EHDS refined base model for an action that is ...                     NaN
# 1   Procedure target body site. Details of where t...       EHDSBodyStructure
# 2                      Code identifying the procedure         CodeableConcept
# 3   Any complications that occurred during the pro...         CodeableConcept
# 4   Date and time of the procedure or interval of ...                dateTime
# 5   Date and time of the procedure or interval of ...                dateTime
# 6                Device used to perform the procedure              EHDSDevice
# 7   Device(s) that is/are implanted, removed, or o...              EHDSDevice
# 8          Common header for all patient-related data                    Base
# 9                          Resource authoring details                    Base
# 10  Author(s) by whom the resource was/were author...  EHDSHealthProfessional
# 11  Date and time of the issuing the document/reso...                dateTime
# 12                 Business identifier for the object              Identifier
# 13  Language in which the resource is written. Lan...         CodeableConcept
# 14  Date and time of the last update to the docume...                dateTime
# 15                             Status of the resource         CodeableConcept
# 16     Reason for the current status of the resource.         CodeableConcept
# 17                        Patient/subject information             EHDSPatient
# 18                  Business version of the resource.                  string
# 19                                                NaN                     NaN
# 20         Additional information about the procedure                  string
# 21  The outcome of the procedure - did it resolve ...         CodeableConcept
# 22               An actor who performed the procedure  EHDSHealthProfessional
# 23  A narrative easy-to-read representation of the...          EHDSAttachment
# 24  The reason why the procedure was performed. Th...         CodeableConcept
# 25  The reason why the procedure was performed. Th...         CodeableConcept
# 26  The reason why the procedure was performed. Th...         CodeableConcept
# 27  The reason why the procedure was performed. Th...         CodeableConcept
# 28  The reason why the procedure was performed. Th...         CodeableConcept
# 29                                                NaN                     NaN
# 30                                                NaN                     NaN
#
#    card._xtehr                                      binding_xtehr
# 0         0..*                                                NaN
# 1         0..*                                                NaN
# 2         0..1  {'strength': 'preferred', 'description': 'SNOM...
# 3         0..*  {'strength': 'preferred', 'description': 'ICD-...
# 4         0..1                                                NaN
# 5         0..1                                                NaN
# 6         0..*                                                NaN
# 7         0..*                                                NaN
# 8         1..1                                                NaN
# 9         1..*                                                NaN
# 10        1..1                                                NaN
# 11        1..1                                                NaN
# 12        0..*                                                NaN
# 13        0..1  {'strength': 'preferred', 'description': 'BCP ...
# 14        0..1                                                NaN
# 15        1..1                                                NaN
# 16        0..1                                                NaN
# 17        1..1                                                NaN
# 18        0..1                                                NaN
# 19         NaN                                                NaN
# 20        0..1                                                NaN
# 21        0..1  {'strength': 'preferred', 'description': 'SNOM...
# 22        0..*                                                NaN
# 23        0..*                                                NaN
# 24        0..*  {'strength': 'preferred', 'description': 'SNOM...
# 25        0..*  {'strength': 'preferred', 'description': 'SNOM...
# 26        0..*  {'strength': 'preferred', 'description': 'SNOM...
# 27        0..*  {'strength': 'preferred', 'description': 'SNOM...
# 28        0..*  {'strength': 'preferred', 'description': 'SNOM...
# 29         NaN                                                NaN
# 30         NaN                                                NaN

# %%
shortmap = mapping[['zib', 'xtehr', 'type_zib','type_xtehr', 'card._zib', 'card._xtehr']]
shortmap
# Out:
#                                                   zib  \
# 0                                           Procedure
# 1   Procedure.ProcedureAnatomicalLocation::Anatomi...
# 2                             Procedure.ProcedureType
# 3                                                 NaN
# 4                          Procedure.ProcedureEndDate
# 5                        Procedure.ProcedureStartDate
# 6                                                 NaN
# 7                             Procedure.MedicalDevice
# 8            Registratiegegevens, zie DataSet mapping
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19             Procedure.Location::HealthcareProvider
# 20                                                NaN
# 21                                                NaN
# 22            Procedure.Performer::HealthProfessional
# 23                                                NaN
# 24                               Procedure.Indication
# 25                     Procedure.Indication.Diagnosis
# 26                      Procedure.Indication.Reaction
# 27                       Procedure.Indication.Symptom
# 28                      Procedure.Indication::Problem
# 29                          Procedure.ProcedureMethod
# 30            Procedure.Requester::HealthProfessional
#
#                                         xtehr type_zib  \
# 0                               EHDSProcedure      NaN
# 1                      EHDSProcedure.bodySite      NaN
# 2                          EHDSProcedure.code       CD
# 3                  EHDSProcedure.complication      NaN
# 4                       EHDSProcedure.date[x]       TS
# 5                       EHDSProcedure.date[x]       TS
# 6                    EHDSProcedure.deviceUsed      NaN
# 7                   EHDSProcedure.focalDevice      NaN
# 8                        EHDSProcedure.header      NaN
# 9             EHDSProcedure.header.authorship      NaN
# 10  EHDSProcedure.header.authorship.author[x]      NaN
# 11   EHDSProcedure.header.authorship.datetime      NaN
# 12            EHDSProcedure.header.identifier      NaN
# 13              EHDSProcedure.header.language      NaN
# 14            EHDSProcedure.header.lastUpdate      NaN
# 15                EHDSProcedure.header.status      NaN
# 16       EHDSProcedure.header.statusReason[x]      NaN
# 17               EHDSProcedure.header.subject      NaN
# 18               EHDSProcedure.header.version      NaN
# 19                     EHDSProcedure.location      NaN
# 20                         EHDSProcedure.note      NaN
# 21                      EHDSProcedure.outcome      NaN
# 22                    EHDSProcedure.performer      NaN
# 23                EHDSProcedure.presentedForm      NaN
# 24                    EHDSProcedure.reason[x]      NaN
# 25                    EHDSProcedure.reason[x]      NaN
# 26                    EHDSProcedure.reason[x]      NaN
# 27                    EHDSProcedure.reason[x]      NaN
# 28                    EHDSProcedure.reason[x]      NaN
# 29                                        NaN       CD
# 30                                        NaN      NaN
#
#                 type_xtehr card._zib card._xtehr
# 0                      NaN       NaN        0..*
# 1        EHDSBodyStructure      0..1        0..*
# 2          CodeableConcept         1        0..1
# 3          CodeableConcept       NaN        0..*
# 4                 dateTime      0..1        0..1
# 5                 dateTime      0..1        0..1
# 6               EHDSDevice       NaN        0..*
# 7               EHDSDevice      0..*        0..*
# 8                     Base       NaN        1..1
# 9                     Base       NaN        1..*
# 10  EHDSHealthProfessional       NaN        1..1
# 11                dateTime       NaN        1..1
# 12              Identifier       NaN        0..*
# 13         CodeableConcept       NaN        0..1
# 14                dateTime       NaN        0..1
# 15         CodeableConcept       NaN        1..1
# 16         CodeableConcept       NaN        0..1
# 17             EHDSPatient       NaN        1..1
# 18                  string       NaN        0..1
# 19                     NaN      0..1         NaN
# 20                  string       NaN        0..1
# 21         CodeableConcept       NaN        0..1
# 22  EHDSHealthProfessional      0..*        0..*
# 23          EHDSAttachment       NaN        0..*
# 24         CodeableConcept      0..*        0..*
# 25         CodeableConcept    (0..1)        0..*
# 26         CodeableConcept    (0..1)        0..*
# 27         CodeableConcept    (0..1)        0..*
# 28         CodeableConcept       NaN        0..*
# 29                     NaN      0..*         NaN
# 30                     NaN       NaN         NaN

# %%
mapsoutpath = os.path.join(mapbase, 'xtehr2zibs2024')
filepath = file.replace('.xlsx', '-full.xlsx')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_excel(mappath, index=False)

# %%
filepath = file.replace('.xlsx', '.csv')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_csv(mappath, index=False)

# %%
from IPython.display import Markdown
import numpy as np

content = "# " + mapping.iat[0, 0][4:] + "\n\n"
content += shortmap.fillna('').to_markdown(index=False) + "\n\n"
for i, row in mapping.iterrows():
    # print(i, row)
    content += "\n\n"
    if row.iloc[0] is not np.nan:
        content += "## " + str(row.iloc[0]) + "\n\n"
    else:
        content += "## zib: " + str(row.iloc[1]) + "\n\n"
    content += "### Table" + "\n\n"
    content += "| attribute | value |" + "\n" + "|---|---|" + "\n"
    for j, att in row.fillna('')[0:2].items():
        content += "| " + str(j) + " | " + str(att) + " |" + "\n"
    for j, att in row.fillna('')[2:].sort_index().items():
        content += "| " + str(j) + " | " + str(att) + " |" + "\n"    
    content += "\n### Comments" + "\n\n"
with open(os.path.join(mapsoutpath, file.replace('.xlsx', '.md')), 'w') as f:
    f.write(content)
# PAS OP: deze overschrijft de eventueel met de hand gemaakte comments files, alleen gebriuken
# bij eerste keer dat je een mapping maakt, daarna de comments handmatig aanpassen
# with open(os.path.join(mapsoutpath, file.replace('.xlsx', '-comments.md')), 'w') as f:
#     f.write(content)
#Markdown(content)
