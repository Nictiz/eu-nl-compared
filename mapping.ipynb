# %%
import pandas as pd
import os

# %%
# zibbase = 'zibs2020'
zibbase = 'zibs2024'
zibspath = os.path.join(zibbase, 'mappable')
zibs = os.listdir(zibspath)
[(i, zib) for i, zib in enumerate(zibs)]
# Out:
# [(0, 'Nl.zorg.Alert-v5.0(2024EN).xlsx'),
#  (1, 'Nl.zorg.HealthcareProvider-v3.6(2024EN).xlsx'),
#  (2, 'Nl.zorg.HealthProfessional-v4.0(2024EN).xlsx'),
#  (3, 'Nl.zorg.MedicalDevice-v5.0(2024EN).xlsx'),
#  (4, 'Nl.zorg.NursingIntervention-v5.0(2024EN).xlsx'),
#  (5, 'Nl.zorg.part.AddressInformation-v1.2(2024EN).xlsx'),
#  (6, 'Nl.zorg.part.AnatomicalLocation-v1.0.4(2024EN).xlsx'),
#  (7, 'Nl.zorg.part.ContactInformation-v1.3.1(2024EN).xlsx'),
#  (8, 'Nl.zorg.part.NameInformation-v1.2(2024EN).xlsx'),
#  (9, 'Nl.zorg.Patient-v4.3(2024EN).xlsx'),
#  (10, 'Nl.zorg.Procedure-v6.0(2024EN).xlsx'),
#  (11, 'Nl.zorg.process.RegistrationData-v1.1.2(2024EN).xlsx')]

# %%
zib = zibs[3]
print(zib)
zibpath = os.path.join(zibspath, zib)
zibdf = pd.read_excel(zibpath)
zibdf
# Out:
# Nl.zorg.MedicalDevice-v5.0(2024EN).xlsx
#                             name                                        path  \
# 0                  MedicalDevice                               MedicalDevice
# 1          Indication::Diagnosis         MedicalDevice.Indication::Diagnosis
# 2   Location::HealthcareProvider  MedicalDevice.Location::HealthcareProvider
# 3             HealthProfessional            MedicalDevice.HealthProfessional
# 4                        Product                       MedicalDevice.Product
# 5                    ProductType           MedicalDevice.Product.ProductType
# 6                      ProductID             MedicalDevice.Product.ProductID
# 7             ProductDescription            MedicalDevice.ProductDescription
# 8             AnatomicalLocation            MedicalDevice.AnatomicalLocation
# 9                      StartDate                     MedicalDevice.StartDate
# 10                       EndDate                       MedicalDevice.EndDate
# 11                       Comment                       MedicalDevice.Comment
#
#                          alias type card.         stereotype             id  \
# 0        NL: MedischHulpmiddel  NaN   NaN        rootconcept   NL-CM:10.1.1
# 1      NL: Indicatie::Diagnose  NaN  0..*  context,reference  NL-CM:10.1.17
# 2   NL: Locatie::Zorgaanbieder  NaN  0..1  context,reference   NL-CM:10.1.8
# 3             NL: Zorgverlener  NaN  0..1  context,reference   NL-CM:10.1.9
# 4                  NL: Product  NaN     1          container   NL-CM:10.1.2
# 5              NL: ProductType   CD  0..1               data   NL-CM:10.1.3
# 6                NL: ProductID   ST  0..1               data  NL-CM:10.1.16
# 7      NL: ProductOmschrijving   ST  0..1               data  NL-CM:10.1.13
# 8       NL: AnatomischeLocatie  NaN  0..1     data,reference  NL-CM:10.1.15
# 9               NL: BeginDatum   TS  0..1               data  NL-CM:10.1.11
# 10               NL: EindDatum   TS  0..1               data  NL-CM:10.1.14
# 11             NL: Toelichting   ST  0..1               data  NL-CM:10.1.10
#
#                                            definition  \
# 0   Root concept of the MedicalDevice information ...
# 1   The diagnosis as indication for the medical de...
# 2   The healthcare provider where use of the medic...
# 3   The health professional involved in the indica...
# 4      The medical device (internally or externally).
# 5                    The code of the type of product.
# 6   Globally unique identification of the product,...
# 7                 Textual description of the product.
# 8   Patient’s anatomical location of the medical d...
# 9   The start date of the first use or implant of ...
# 10  The end date of the last use or explant of the...
# 11  Comment about use or information on the medica...
#
#                                        definitioncode
# 0                          SNOMED CT: 49062001 Device
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4               SNOMED CT: 405815000 Procedure device
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                   SNOMED CT: 363698007 Finding site
# 9                                                 NaN
# 10                                                NaN
# 11  LOINC: 48767-8 Annotation comment [Interpretat...

# %%
xlmbase = 'xtehr'
xlmspath = os.path.join(xlmbase, 'mappable')
xlms = os.listdir(xlmspath)
[(i, xlm) for i, xlm in enumerate(xlms)]
# Out:
# [(0, 'Address.xlsx'),
#  (1, 'AlertFlag.xlsx'),
#  (2, 'AllergyIntolerance.xlsx'),
#  (3, 'BodyStructure.xlsx'),
#  (4, 'Condition.xlsx'),
#  (5, 'DataSet.xlsx'),
#  (6, 'Device.xlsx'),
#  (7, 'DeviceUse.xlsx'),
#  (8, 'HealthProfessional.xlsx'),
#  (9, 'HumanName.xlsx'),
#  (10, 'Location.xlsx'),
#  (11, 'Medication.xlsx'),
#  (12, 'Organization.xlsx'),
#  (13, 'Patient.xlsx'),
#  (14, 'Procedure.xlsx'),
#  (15, 'Telecom.xlsx')]

# %%
xlm = xlms[6]
print( xlm)
xlmpath = os.path.join(xlmspath, xlm)
xlmdf = pd.read_excel(xlmpath)
xlmdf
# only for device use and organization
# xlm = xlms[7]
# print( xlm)
# xlmpath = os.path.join(xlmspath, xlm)
# xlmdf2 = pd.read_excel(xlmpath)
# xlmdf = pd.concat([xlmdf, xlmdf2], ignore_index=True)
# xlmdf
# Out:
# Device.xlsx
# DeviceUse.xlsx
#                                            id  \
# 0                                  EHDSDevice
# 1                       EHDSDevice.identifier
# 2                     EHDSDevice.manufacturer
# 3                  EHDSDevice.manufactureDate
# 4                       EHDSDevice.expiryDate
# 5                        EHDSDevice.lotNumber
# 6                     EHDSDevice.serialNumber
# 7                             EHDSDevice.name
# 8                      EHDSDevice.modelNumber
# 9                          EHDSDevice.version
# 10                            EHDSDevice.type
# 11                            EHDSDevice.note
# 12                              EHDSDeviceUse
# 13                       EHDSDeviceUse.header
# 14               EHDSDeviceUse.header.subject
# 15            EHDSDeviceUse.header.identifier
# 16            EHDSDeviceUse.header.authorship
# 17  EHDSDeviceUse.header.authorship.author[x]
# 18   EHDSDeviceUse.header.authorship.datetime
# 19            EHDSDeviceUse.header.lastUpdate
# 20                EHDSDeviceUse.header.status
# 21       EHDSDeviceUse.header.statusReason[x]
# 22              EHDSDeviceUse.header.language
# 23               EHDSDeviceUse.header.version
# 24                EHDSDeviceUse.presentedForm
# 25                    EHDSDeviceUse.startDate
# 26                      EHDSDeviceUse.endDate
# 27                    EHDSDeviceUse.device[x]
# 28                     EHDSDeviceUse.bodySite
# 29                    EHDSDeviceUse.reason[x]
# 30                    EHDSDeviceUse.source[x]
# 31                         EHDSDeviceUse.note
#
#                                          path  \
# 0                                  EHDSDevice
# 1                       EHDSDevice.identifier
# 2                     EHDSDevice.manufacturer
# 3                  EHDSDevice.manufactureDate
# 4                       EHDSDevice.expiryDate
# 5                        EHDSDevice.lotNumber
# 6                     EHDSDevice.serialNumber
# 7                             EHDSDevice.name
# 8                      EHDSDevice.modelNumber
# 9                          EHDSDevice.version
# 10                            EHDSDevice.type
# 11                            EHDSDevice.note
# 12                              EHDSDeviceUse
# 13                       EHDSDeviceUse.header
# 14               EHDSDeviceUse.header.subject
# 15            EHDSDeviceUse.header.identifier
# 16            EHDSDeviceUse.header.authorship
# 17  EHDSDeviceUse.header.authorship.author[x]
# 18   EHDSDeviceUse.header.authorship.datetime
# 19            EHDSDeviceUse.header.lastUpdate
# 20                EHDSDeviceUse.header.status
# 21       EHDSDeviceUse.header.statusReason[x]
# 22              EHDSDeviceUse.header.language
# 23               EHDSDeviceUse.header.version
# 24                EHDSDeviceUse.presentedForm
# 25                    EHDSDeviceUse.startDate
# 26                      EHDSDeviceUse.endDate
# 27                    EHDSDeviceUse.device[x]
# 28                     EHDSDeviceUse.bodySite
# 29                    EHDSDeviceUse.reason[x]
# 30                    EHDSDeviceUse.source[x]
# 31                         EHDSDeviceUse.note
#
#                                                 short  \
# 0                                        Device model
# 1   Normalised identifier of the device instance, ...
# 2                         Name of device manufacturer
# 3   The date and time when the device was manufact...
# 4   The date and time beyond which this device is ...
# 5                           Lot number of manufacture
# 6          Serial number assigned by the manufacturer
# 7   The name and name type of the device as known ...
# 8      The manufacturer's model number for the device
# 9   The actual design of the device or software ve...
# 10                                        Device type
# 11                          Device notes and comments
# 12                                   Device use model
# 13         Common header for all patient-related data
# 14                                            Subject
# 15                 Business identifier for the object
# 16                                         Authorship
# 17                                             Author
# 18                 Date and time of authoring/issuing
# 19   Date and time of the last update to the resource
# 20                Current status of the device usage.
# 21     Reason for the current status of the resource.
# 22                                           Language
# 23                                            Version
# 24  A narrative easy-to-read representation of the...
# 25  Date when the device was implantable to the pa...
# 26  Date when the device was explanted from the pa...
# 27                    The details of the device used.
# 28  Anatomical location of the device. May include...
# 29  Reason or justification for the use of the dev...
# 30  Who reported the device was being used by the ...
# 31  Note about the device statement that were not ...
#
#                                            definition                    type  \
# 0      EHDS refined base model for Device information                     NaN
# 1   Normalised identifier of the device instance, ...              Identifier
# 2                         Name of device manufacturer                  string
# 3   The date and time when the device was manufact...                dateTime
# 4   The date and time beyond which this device is ...                dateTime
# 5                           Lot number of manufacture                  string
# 6          Serial number assigned by the manufacturer                  string
# 7   The name and name type of the device as known ...                  string
# 8      The manufacturer's model number for the device                  string
# 9   The actual design of the device or software ve...                  string
# 10                                        Device type         CodeableConcept
# 11                          Device notes and comments                  string
# 12  EHDS refined base model for device use informa...                     NaN
# 13         Common header for all patient-related data                    Base
# 14                        Patient/subject information             EHDSPatient
# 15                 Business identifier for the object              Identifier
# 16                         Resource authoring details                    Base
# 17  Author(s) by whom the resource was/were author...  EHDSHealthProfessional
# 18  Date and time of the issuing the document/reso...                dateTime
# 19  Date and time of the last update to the docume...                dateTime
# 20                             Status of the resource         CodeableConcept
# 21     Reason for the current status of the resource.         CodeableConcept
# 22  Language in which the resource is written. Lan...         CodeableConcept
# 23                  Business version of the resource.                  string
# 24  A narrative easy-to-read representation of the...          EHDSAttachment
# 25  Date when the device was implantable to the pa...                dateTime
# 26  Date when the device was explanted from the pa...                dateTime
# 27                    The details of the device used.         CodeableConcept
# 28  Anatomical location of the device. May include...       EHDSBodyStructure
# 29  Reason or justification for the use of the dev...         CodeableConcept
# 30  Who reported the device was being used by the ...             EHDSPatient
# 31  Note about the device statement that were not ...                  string
#
#    card.                                            binding
# 0   0..*                                                NaN
# 1   1..*                                                NaN
# 2   0..1                                                NaN
# 3   0..1                                                NaN
# 4   0..1                                                NaN
# 5   0..1                                                NaN
# 6   0..1                                                NaN
# 7   0..*                                                NaN
# 8   0..1                                                NaN
# 9   0..1                                                NaN
# 10  0..*  {'strength': 'preferred', 'description': 'SNOM...
# 11  0..*                                                NaN
# 12  0..*                                                NaN
# 13  1..1                                                NaN
# 14  1..1                                                NaN
# 15  0..*                                                NaN
# 16  1..*                                                NaN
# 17  1..1                                                NaN
# 18  1..1                                                NaN
# 19  0..1                                                NaN
# 20  1..1  {'strength': 'preferred', 'description': 'HL7 ...
# 21  0..1                                                NaN
# 22  0..1  {'strength': 'preferred', 'description': 'BCP ...
# 23  0..1                                                NaN
# 24  0..*                                                NaN
# 25  0..1                                                NaN
# 26  0..1                                                NaN
# 27  1..1                                                NaN
# 28  0..1                                                NaN
# 29  0..*                                                NaN
# 30  0..1                                                NaN
# 31  0..*                                                NaN

# %%
mapbase = 'maps'
maps = os.listdir(mapbase)
[(i, map) for i, map in enumerate(maps)]
# Out:
# [(0, 'Address.xlsx'),
#  (1, 'AlertFlag.xlsx'),
#  (2, 'BodyStructure.xlsx'),
#  (3, 'Condition.xlsx'),
#  (4, 'DataSet.xlsx'),
#  (5, 'Device-and-DeviceUse.xlsx'),
#  (6, 'HealthProfessional.xlsx'),
#  (7, 'HumanName.xlsx'),
#  (8, 'Location-and-Organization.xlsx'),
#  (9, 'Patient.xlsx'),
#  (10, 'Procedure-NusringIntervention.xlsx'),
#  (11, 'Procedure.xlsx'),
#  (12, 'xtehr2zibs'),
#  (13, 'xtehr2zibs2024')]

# %%
file = maps[5]
print(file)
mappath = os.path.join(mapbase, file)
print(mappath)
mapdf = pd.read_excel(mappath)
mapdf
# Out:
# Device-and-DeviceUse.xlsx
# maps\Device-and-DeviceUse.xlsx
#                                         xtehr  \
# 0                                  EHDSDevice
# 1                     EHDSDevice.manufacturer
# 2                  EHDSDevice.manufactureDate
# 3                       EHDSDevice.expiryDate
# 4                        EHDSDevice.lotNumber
# 5                     EHDSDevice.serialNumber
# 6                             EHDSDevice.name
# 7                      EHDSDevice.modelNumber
# 8                          EHDSDevice.version
# 9                             EHDSDevice.type
# 10                            EHDSDevice.note
# 11                              EHDSDeviceUse
# 12                       EHDSDeviceUse.header
# 13               EHDSDeviceUse.header.subject
# 14            EHDSDeviceUse.header.identifier
# 15            EHDSDeviceUse.header.authorship
# 16  EHDSDeviceUse.header.authorship.author[x]
# 17   EHDSDeviceUse.header.authorship.datetime
# 18            EHDSDeviceUse.header.lastUpdate
# 19                EHDSDeviceUse.header.status
# 20       EHDSDeviceUse.header.statusReason[x]
# 21              EHDSDeviceUse.header.language
# 22               EHDSDeviceUse.header.version
# 23                EHDSDeviceUse.presentedForm
# 24                       EHDSDeviceUse.status
# 25                    EHDSDeviceUse.startDate
# 26                      EHDSDeviceUse.endDate
# 27                    EHDSDeviceUse.device[x]
# 28                     EHDSDeviceUse.bodySite
# 29                         EHDSDeviceUse.note
# 30                     EHDSDeviceUse.recorded
# 31                    EHDSDeviceUse.source[x]
# 32                                        NaN
# 33                                        NaN
# 34                                        NaN
# 35                    EHDSDeviceUse.reason[x]
#
#                                            zib
# 0                        MedicalDevice.Product
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9            MedicalDevice.Product.ProductType
# 10                                         NaN
# 11                               MedicalDevice
# 12                                         NaN
# 13                                         NaN
# 14             MedicalDevice.Product.ProductID
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
# 20                                         NaN
# 21                                         NaN
# 22                                         NaN
# 23                                         NaN
# 24                                         NaN
# 25                     MedicalDevice.StartDate
# 26                       MedicalDevice.EndDate
# 27                                         NaN
# 28            MedicalDevice.AnatomicalLocation
# 29                       MedicalDevice.Comment
# 30                                         NaN
# 31                                         NaN
# 32            MedicalDevice.ProductDescription
# 33  MedicalDevice.Location::HealthcareProvider
# 34            MedicalDevice.HealthProfessional
# 35         MedicalDevice.Indication::Diagnosis

# %%
mapping = mapdf[['xtehr', 'zib']].merge(zibdf.add_suffix('_zib'), left_on='zib', right_on='path_zib', how='outer').merge(xlmdf.add_suffix('_xtehr'), left_on='xtehr', right_on='path_xtehr', how='outer')
mapping
# Out:
#                                         xtehr  \
# 0                                  EHDSDevice
# 1                       EHDSDevice.expiryDate
# 2                                         NaN
# 3                        EHDSDevice.lotNumber
# 4                  EHDSDevice.manufactureDate
# 5                     EHDSDevice.manufacturer
# 6                      EHDSDevice.modelNumber
# 7                             EHDSDevice.name
# 8                             EHDSDevice.note
# 9                     EHDSDevice.serialNumber
# 10                            EHDSDevice.type
# 11                         EHDSDevice.version
# 12                              EHDSDeviceUse
# 13                     EHDSDeviceUse.bodySite
# 14                    EHDSDeviceUse.device[x]
# 15                      EHDSDeviceUse.endDate
# 16                       EHDSDeviceUse.header
# 17            EHDSDeviceUse.header.authorship
# 18  EHDSDeviceUse.header.authorship.author[x]
# 19   EHDSDeviceUse.header.authorship.datetime
# 20            EHDSDeviceUse.header.identifier
# 21              EHDSDeviceUse.header.language
# 22            EHDSDeviceUse.header.lastUpdate
# 23                EHDSDeviceUse.header.status
# 24       EHDSDeviceUse.header.statusReason[x]
# 25               EHDSDeviceUse.header.subject
# 26               EHDSDeviceUse.header.version
# 27                         EHDSDeviceUse.note
# 28                EHDSDeviceUse.presentedForm
# 29                    EHDSDeviceUse.reason[x]
# 30                     EHDSDeviceUse.recorded
# 31                    EHDSDeviceUse.source[x]
# 32                    EHDSDeviceUse.startDate
# 33                       EHDSDeviceUse.status
# 34                                        NaN
# 35                                        NaN
# 36                                        NaN
#
#                                            zib                      name_zib  \
# 0                        MedicalDevice.Product                       Product
# 1                                          NaN                           NaN
# 2                                          NaN                           NaN
# 3                                          NaN                           NaN
# 4                                          NaN                           NaN
# 5                                          NaN                           NaN
# 6                                          NaN                           NaN
# 7                                          NaN                           NaN
# 8                                          NaN                           NaN
# 9                                          NaN                           NaN
# 10           MedicalDevice.Product.ProductType                   ProductType
# 11                                         NaN                           NaN
# 12                               MedicalDevice                 MedicalDevice
# 13            MedicalDevice.AnatomicalLocation            AnatomicalLocation
# 14                                         NaN                           NaN
# 15                       MedicalDevice.EndDate                       EndDate
# 16                                         NaN                           NaN
# 17                                         NaN                           NaN
# 18                                         NaN                           NaN
# 19                                         NaN                           NaN
# 20             MedicalDevice.Product.ProductID                     ProductID
# 21                                         NaN                           NaN
# 22                                         NaN                           NaN
# 23                                         NaN                           NaN
# 24                                         NaN                           NaN
# 25                                         NaN                           NaN
# 26                                         NaN                           NaN
# 27                       MedicalDevice.Comment                       Comment
# 28                                         NaN                           NaN
# 29         MedicalDevice.Indication::Diagnosis         Indication::Diagnosis
# 30                                         NaN                           NaN
# 31                                         NaN                           NaN
# 32                     MedicalDevice.StartDate                     StartDate
# 33                                         NaN                           NaN
# 34            MedicalDevice.HealthProfessional            HealthProfessional
# 35  MedicalDevice.Location::HealthcareProvider  Location::HealthcareProvider
# 36            MedicalDevice.ProductDescription            ProductDescription
#
#                                       path_zib                   alias_zib  \
# 0                        MedicalDevice.Product                 NL: Product
# 1                                          NaN                         NaN
# 2                                          NaN                         NaN
# 3                                          NaN                         NaN
# 4                                          NaN                         NaN
# 5                                          NaN                         NaN
# 6                                          NaN                         NaN
# 7                                          NaN                         NaN
# 8                                          NaN                         NaN
# 9                                          NaN                         NaN
# 10           MedicalDevice.Product.ProductType             NL: ProductType
# 11                                         NaN                         NaN
# 12                               MedicalDevice       NL: MedischHulpmiddel
# 13            MedicalDevice.AnatomicalLocation      NL: AnatomischeLocatie
# 14                                         NaN                         NaN
# 15                       MedicalDevice.EndDate               NL: EindDatum
# 16                                         NaN                         NaN
# 17                                         NaN                         NaN
# 18                                         NaN                         NaN
# 19                                         NaN                         NaN
# 20             MedicalDevice.Product.ProductID               NL: ProductID
# 21                                         NaN                         NaN
# 22                                         NaN                         NaN
# 23                                         NaN                         NaN
# 24                                         NaN                         NaN
# 25                                         NaN                         NaN
# 26                                         NaN                         NaN
# 27                       MedicalDevice.Comment             NL: Toelichting
# 28                                         NaN                         NaN
# 29         MedicalDevice.Indication::Diagnosis     NL: Indicatie::Diagnose
# 30                                         NaN                         NaN
# 31                                         NaN                         NaN
# 32                     MedicalDevice.StartDate              NL: BeginDatum
# 33                                         NaN                         NaN
# 34            MedicalDevice.HealthProfessional            NL: Zorgverlener
# 35  MedicalDevice.Location::HealthcareProvider  NL: Locatie::Zorgaanbieder
# 36            MedicalDevice.ProductDescription     NL: ProductOmschrijving
#
#    type_zib card._zib     stereotype_zib         id_zib  \
# 0       NaN         1          container   NL-CM:10.1.2
# 1       NaN       NaN                NaN            NaN
# 2       NaN       NaN                NaN            NaN
# 3       NaN       NaN                NaN            NaN
# 4       NaN       NaN                NaN            NaN
# 5       NaN       NaN                NaN            NaN
# 6       NaN       NaN                NaN            NaN
# 7       NaN       NaN                NaN            NaN
# 8       NaN       NaN                NaN            NaN
# 9       NaN       NaN                NaN            NaN
# 10       CD      0..1               data   NL-CM:10.1.3
# 11      NaN       NaN                NaN            NaN
# 12      NaN       NaN        rootconcept   NL-CM:10.1.1
# 13      NaN      0..1     data,reference  NL-CM:10.1.15
# 14      NaN       NaN                NaN            NaN
# 15       TS      0..1               data  NL-CM:10.1.14
# 16      NaN       NaN                NaN            NaN
# 17      NaN       NaN                NaN            NaN
# 18      NaN       NaN                NaN            NaN
# 19      NaN       NaN                NaN            NaN
# 20       ST      0..1               data  NL-CM:10.1.16
# 21      NaN       NaN                NaN            NaN
# 22      NaN       NaN                NaN            NaN
# 23      NaN       NaN                NaN            NaN
# 24      NaN       NaN                NaN            NaN
# 25      NaN       NaN                NaN            NaN
# 26      NaN       NaN                NaN            NaN
# 27       ST      0..1               data  NL-CM:10.1.10
# 28      NaN       NaN                NaN            NaN
# 29      NaN      0..*  context,reference  NL-CM:10.1.17
# 30      NaN       NaN                NaN            NaN
# 31      NaN       NaN                NaN            NaN
# 32       TS      0..1               data  NL-CM:10.1.11
# 33      NaN       NaN                NaN            NaN
# 34      NaN      0..1  context,reference   NL-CM:10.1.9
# 35      NaN      0..1  context,reference   NL-CM:10.1.8
# 36       ST      0..1               data  NL-CM:10.1.13
#
#                                        definition_zib  \
# 0      The medical device (internally or externally).
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                   The code of the type of product.
# 11                                                NaN
# 12  Root concept of the MedicalDevice information ...
# 13  Patient’s anatomical location of the medical d...
# 14                                                NaN
# 15  The end date of the last use or explant of the...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  Globally unique identification of the product,...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  Comment about use or information on the medica...
# 28                                                NaN
# 29  The diagnosis as indication for the medical de...
# 30                                                NaN
# 31                                                NaN
# 32  The start date of the first use or implant of ...
# 33                                                NaN
# 34  The health professional involved in the indica...
# 35  The healthcare provider where use of the medic...
# 36                Textual description of the product.
#
#                                    definitioncode_zib  \
# 0               SNOMED CT: 405815000 Procedure device
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                         SNOMED CT: 49062001 Device
# 13                  SNOMED CT: 363698007 Finding site
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  LOINC: 48767-8 Annotation comment [Interpretat...
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
#
#                                      id_xtehr  \
# 0                                  EHDSDevice
# 1                       EHDSDevice.expiryDate
# 2                       EHDSDevice.identifier
# 3                        EHDSDevice.lotNumber
# 4                  EHDSDevice.manufactureDate
# 5                     EHDSDevice.manufacturer
# 6                      EHDSDevice.modelNumber
# 7                             EHDSDevice.name
# 8                             EHDSDevice.note
# 9                     EHDSDevice.serialNumber
# 10                            EHDSDevice.type
# 11                         EHDSDevice.version
# 12                              EHDSDeviceUse
# 13                     EHDSDeviceUse.bodySite
# 14                    EHDSDeviceUse.device[x]
# 15                      EHDSDeviceUse.endDate
# 16                       EHDSDeviceUse.header
# 17            EHDSDeviceUse.header.authorship
# 18  EHDSDeviceUse.header.authorship.author[x]
# 19   EHDSDeviceUse.header.authorship.datetime
# 20            EHDSDeviceUse.header.identifier
# 21              EHDSDeviceUse.header.language
# 22            EHDSDeviceUse.header.lastUpdate
# 23                EHDSDeviceUse.header.status
# 24       EHDSDeviceUse.header.statusReason[x]
# 25               EHDSDeviceUse.header.subject
# 26               EHDSDeviceUse.header.version
# 27                         EHDSDeviceUse.note
# 28                EHDSDeviceUse.presentedForm
# 29                    EHDSDeviceUse.reason[x]
# 30                                        NaN
# 31                    EHDSDeviceUse.source[x]
# 32                    EHDSDeviceUse.startDate
# 33                                        NaN
# 34                                        NaN
# 35                                        NaN
# 36                                        NaN
#
#                                    path_xtehr  \
# 0                                  EHDSDevice
# 1                       EHDSDevice.expiryDate
# 2                       EHDSDevice.identifier
# 3                        EHDSDevice.lotNumber
# 4                  EHDSDevice.manufactureDate
# 5                     EHDSDevice.manufacturer
# 6                      EHDSDevice.modelNumber
# 7                             EHDSDevice.name
# 8                             EHDSDevice.note
# 9                     EHDSDevice.serialNumber
# 10                            EHDSDevice.type
# 11                         EHDSDevice.version
# 12                              EHDSDeviceUse
# 13                     EHDSDeviceUse.bodySite
# 14                    EHDSDeviceUse.device[x]
# 15                      EHDSDeviceUse.endDate
# 16                       EHDSDeviceUse.header
# 17            EHDSDeviceUse.header.authorship
# 18  EHDSDeviceUse.header.authorship.author[x]
# 19   EHDSDeviceUse.header.authorship.datetime
# 20            EHDSDeviceUse.header.identifier
# 21              EHDSDeviceUse.header.language
# 22            EHDSDeviceUse.header.lastUpdate
# 23                EHDSDeviceUse.header.status
# 24       EHDSDeviceUse.header.statusReason[x]
# 25               EHDSDeviceUse.header.subject
# 26               EHDSDeviceUse.header.version
# 27                         EHDSDeviceUse.note
# 28                EHDSDeviceUse.presentedForm
# 29                    EHDSDeviceUse.reason[x]
# 30                                        NaN
# 31                    EHDSDeviceUse.source[x]
# 32                    EHDSDeviceUse.startDate
# 33                                        NaN
# 34                                        NaN
# 35                                        NaN
# 36                                        NaN
#
#                                           short_xtehr  \
# 0                                        Device model
# 1   The date and time beyond which this device is ...
# 2   Normalised identifier of the device instance, ...
# 3                           Lot number of manufacture
# 4   The date and time when the device was manufact...
# 5                         Name of device manufacturer
# 6      The manufacturer's model number for the device
# 7   The name and name type of the device as known ...
# 8                           Device notes and comments
# 9          Serial number assigned by the manufacturer
# 10                                        Device type
# 11  The actual design of the device or software ve...
# 12                                   Device use model
# 13  Anatomical location of the device. May include...
# 14                    The details of the device used.
# 15  Date when the device was explanted from the pa...
# 16         Common header for all patient-related data
# 17                                         Authorship
# 18                                             Author
# 19                 Date and time of authoring/issuing
# 20                 Business identifier for the object
# 21                                           Language
# 22   Date and time of the last update to the resource
# 23                Current status of the device usage.
# 24     Reason for the current status of the resource.
# 25                                            Subject
# 26                                            Version
# 27  Note about the device statement that were not ...
# 28  A narrative easy-to-read representation of the...
# 29  Reason or justification for the use of the dev...
# 30                                                NaN
# 31  Who reported the device was being used by the ...
# 32  Date when the device was implantable to the pa...
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
#
#                                      definition_xtehr              type_xtehr  \
# 0      EHDS refined base model for Device information                     NaN
# 1   The date and time beyond which this device is ...                dateTime
# 2   Normalised identifier of the device instance, ...              Identifier
# 3                           Lot number of manufacture                  string
# 4   The date and time when the device was manufact...                dateTime
# 5                         Name of device manufacturer                  string
# 6      The manufacturer's model number for the device                  string
# 7   The name and name type of the device as known ...                  string
# 8                           Device notes and comments                  string
# 9          Serial number assigned by the manufacturer                  string
# 10                                        Device type         CodeableConcept
# 11  The actual design of the device or software ve...                  string
# 12  EHDS refined base model for device use informa...                     NaN
# 13  Anatomical location of the device. May include...       EHDSBodyStructure
# 14                    The details of the device used.         CodeableConcept
# 15  Date when the device was explanted from the pa...                dateTime
# 16         Common header for all patient-related data                    Base
# 17                         Resource authoring details                    Base
# 18  Author(s) by whom the resource was/were author...  EHDSHealthProfessional
# 19  Date and time of the issuing the document/reso...                dateTime
# 20                 Business identifier for the object              Identifier
# 21  Language in which the resource is written. Lan...         CodeableConcept
# 22  Date and time of the last update to the docume...                dateTime
# 23                             Status of the resource         CodeableConcept
# 24     Reason for the current status of the resource.         CodeableConcept
# 25                        Patient/subject information             EHDSPatient
# 26                  Business version of the resource.                  string
# 27  Note about the device statement that were not ...                  string
# 28  A narrative easy-to-read representation of the...          EHDSAttachment
# 29  Reason or justification for the use of the dev...         CodeableConcept
# 30                                                NaN                     NaN
# 31  Who reported the device was being used by the ...             EHDSPatient
# 32  Date when the device was implantable to the pa...                dateTime
# 33                                                NaN                     NaN
# 34                                                NaN                     NaN
# 35                                                NaN                     NaN
# 36                                                NaN                     NaN
#
#    card._xtehr                                      binding_xtehr
# 0         0..*                                                NaN
# 1         0..1                                                NaN
# 2         1..*                                                NaN
# 3         0..1                                                NaN
# 4         0..1                                                NaN
# 5         0..1                                                NaN
# 6         0..1                                                NaN
# 7         0..*                                                NaN
# 8         0..*                                                NaN
# 9         0..1                                                NaN
# 10        0..*  {'strength': 'preferred', 'description': 'SNOM...
# 11        0..1                                                NaN
# 12        0..*                                                NaN
# 13        0..1                                                NaN
# 14        1..1                                                NaN
# 15        0..1                                                NaN
# 16        1..1                                                NaN
# 17        1..*                                                NaN
# 18        1..1                                                NaN
# 19        1..1                                                NaN
# 20        0..*                                                NaN
# 21        0..1  {'strength': 'preferred', 'description': 'BCP ...
# 22        0..1                                                NaN
# 23        1..1  {'strength': 'preferred', 'description': 'HL7 ...
# 24        0..1                                                NaN
# 25        1..1                                                NaN
# 26        0..1                                                NaN
# 27        0..*                                                NaN
# 28        0..*                                                NaN
# 29        0..*                                                NaN
# 30         NaN                                                NaN
# 31        0..1                                                NaN
# 32        0..1                                                NaN
# 33         NaN                                                NaN
# 34         NaN                                                NaN
# 35         NaN                                                NaN
# 36         NaN                                                NaN

# %%
shortmap = mapping[['zib', 'xtehr', 'type_zib','type_xtehr', 'card._zib', 'card._xtehr']]
shortmap
# Out:
#                                            zib  \
# 0                        MedicalDevice.Product
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 10           MedicalDevice.Product.ProductType
# 11                                         NaN
# 12                               MedicalDevice
# 13            MedicalDevice.AnatomicalLocation
# 14                                         NaN
# 15                       MedicalDevice.EndDate
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
# 20             MedicalDevice.Product.ProductID
# 21                                         NaN
# 22                                         NaN
# 23                                         NaN
# 24                                         NaN
# 25                                         NaN
# 26                                         NaN
# 27                       MedicalDevice.Comment
# 28                                         NaN
# 29         MedicalDevice.Indication::Diagnosis
# 30                                         NaN
# 31                                         NaN
# 32                     MedicalDevice.StartDate
# 33                                         NaN
# 34            MedicalDevice.HealthProfessional
# 35  MedicalDevice.Location::HealthcareProvider
# 36            MedicalDevice.ProductDescription
#
#                                         xtehr type_zib  \
# 0                                  EHDSDevice      NaN
# 1                       EHDSDevice.expiryDate      NaN
# 2                                         NaN      NaN
# 3                        EHDSDevice.lotNumber      NaN
# 4                  EHDSDevice.manufactureDate      NaN
# 5                     EHDSDevice.manufacturer      NaN
# 6                      EHDSDevice.modelNumber      NaN
# 7                             EHDSDevice.name      NaN
# 8                             EHDSDevice.note      NaN
# 9                     EHDSDevice.serialNumber      NaN
# 10                            EHDSDevice.type       CD
# 11                         EHDSDevice.version      NaN
# 12                              EHDSDeviceUse      NaN
# 13                     EHDSDeviceUse.bodySite      NaN
# 14                    EHDSDeviceUse.device[x]      NaN
# 15                      EHDSDeviceUse.endDate       TS
# 16                       EHDSDeviceUse.header      NaN
# 17            EHDSDeviceUse.header.authorship      NaN
# 18  EHDSDeviceUse.header.authorship.author[x]      NaN
# 19   EHDSDeviceUse.header.authorship.datetime      NaN
# 20            EHDSDeviceUse.header.identifier       ST
# 21              EHDSDeviceUse.header.language      NaN
# 22            EHDSDeviceUse.header.lastUpdate      NaN
# 23                EHDSDeviceUse.header.status      NaN
# 24       EHDSDeviceUse.header.statusReason[x]      NaN
# 25               EHDSDeviceUse.header.subject      NaN
# 26               EHDSDeviceUse.header.version      NaN
# 27                         EHDSDeviceUse.note       ST
# 28                EHDSDeviceUse.presentedForm      NaN
# 29                    EHDSDeviceUse.reason[x]      NaN
# 30                     EHDSDeviceUse.recorded      NaN
# 31                    EHDSDeviceUse.source[x]      NaN
# 32                    EHDSDeviceUse.startDate       TS
# 33                       EHDSDeviceUse.status      NaN
# 34                                        NaN      NaN
# 35                                        NaN      NaN
# 36                                        NaN       ST
#
#                 type_xtehr card._zib card._xtehr
# 0                      NaN         1        0..*
# 1                 dateTime       NaN        0..1
# 2               Identifier       NaN        1..*
# 3                   string       NaN        0..1
# 4                 dateTime       NaN        0..1
# 5                   string       NaN        0..1
# 6                   string       NaN        0..1
# 7                   string       NaN        0..*
# 8                   string       NaN        0..*
# 9                   string       NaN        0..1
# 10         CodeableConcept      0..1        0..*
# 11                  string       NaN        0..1
# 12                     NaN       NaN        0..*
# 13       EHDSBodyStructure      0..1        0..1
# 14         CodeableConcept       NaN        1..1
# 15                dateTime      0..1        0..1
# 16                    Base       NaN        1..1
# 17                    Base       NaN        1..*
# 18  EHDSHealthProfessional       NaN        1..1
# 19                dateTime       NaN        1..1
# 20              Identifier      0..1        0..*
# 21         CodeableConcept       NaN        0..1
# 22                dateTime       NaN        0..1
# 23         CodeableConcept       NaN        1..1
# 24         CodeableConcept       NaN        0..1
# 25             EHDSPatient       NaN        1..1
# 26                  string       NaN        0..1
# 27                  string      0..1        0..*
# 28          EHDSAttachment       NaN        0..*
# 29         CodeableConcept      0..*        0..*
# 30                     NaN       NaN         NaN
# 31             EHDSPatient       NaN        0..1
# 32                dateTime      0..1        0..1
# 33                     NaN       NaN         NaN
# 34                     NaN      0..1         NaN
# 35                     NaN      0..1         NaN
# 36                     NaN      0..1         NaN

# %%
mapsoutpath = os.path.join(mapbase, 'xtehr2zibs2024')
filepath = file.replace('.xlsx', '-full.xlsx')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_excel(mappath, index=False)

# %%
filepath = file.replace('.xlsx', '.csv')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_csv(mappath, index=False)

# %%
from IPython.display import Markdown
import numpy as np

content = "# " + mapping.iat[0, 0][4:] + "\n\n"
content += shortmap.fillna('').to_markdown(index=False) + "\n\n"
for i, row in mapping.iterrows():
    # print(i, row)
    content += "\n\n"
    if row.iloc[0] is not np.nan:
        content += "## " + str(row.iloc[0]) + "\n\n"
    else:
        content += "## zib: " + str(row.iloc[1]) + "\n\n"
    content += "### Table" + "\n\n"
    content += "| attribute | value |" + "\n" + "|---|---|" + "\n"
    for j, att in row.fillna('')[0:2].items():
        content += "| " + str(j) + " | " + str(att) + " |" + "\n"
    for j, att in row.fillna('')[2:].sort_index().items():
        content += "| " + str(j) + " | " + str(att) + " |" + "\n"    
    content += "\n### Comments" + "\n\n"
with open(os.path.join(mapsoutpath, file.replace('.xlsx', '.md')), 'w') as f:
    f.write(content)
# PAS OP: deze overschrijft de eventueel met de hand gemaakte comments files, alleen gebriuken
# bij eerste keer dat je een mapping maakt, daarna de comments handmatig aanpassen
# with open(os.path.join(mapsoutpath, file.replace('.xlsx', '-comments.md')), 'w') as f:
#     f.write(content)
# Markdown(content)
# Out:
# # Device
#
# | zib                                        | xtehr                                     | type_zib   | type_xtehr             | card._zib   | card._xtehr   |
# |:-------------------------------------------|:------------------------------------------|:-----------|:-----------------------|:------------|:--------------|
# | MedicalDevice.Product                      | EHDSDevice                                |            |                        | 1           | 0..*          |
# |                                            | EHDSDevice.expiryDate                     |            | dateTime               |             | 0..1          |
# |                                            |                                           |            | Identifier             |             | 1..*          |
# |                                            | EHDSDevice.lotNumber                      |            | string                 |             | 0..1          |
# |                                            | EHDSDevice.manufactureDate                |            | dateTime               |             | 0..1          |
# |                                            | EHDSDevice.manufacturer                   |            | string                 |             | 0..1          |
# |                                            | EHDSDevice.modelNumber                    |            | string                 |             | 0..1          |
# |                                            | EHDSDevice.name                           |            | string                 |             | 0..*          |
# |                                            | EHDSDevice.note                           |            | string                 |             | 0..*          |
# |                                            | EHDSDevice.serialNumber                   |            | string                 |             | 0..1          |
# | MedicalDevice.Product.ProductType          | EHDSDevice.type                           | CD         | CodeableConcept        | 0..1        | 0..*          |
# |                                            | EHDSDevice.version                        |            | string                 |             | 0..1          |
# | MedicalDevice                              | EHDSDeviceUse                             |            |                        |             | 0..*          |
# | MedicalDevice.AnatomicalLocation           | EHDSDeviceUse.bodySite                    |            | EHDSBodyStructure      | 0..1        | 0..1          |
# |                                            | EHDSDeviceUse.device[x]                   |            | CodeableConcept        |             | 1..1          |
# | MedicalDevice.EndDate                      | EHDSDeviceUse.endDate                     | TS         | dateTime               | 0..1        | 0..1          |
# |                                            | EHDSDeviceUse.header                      |            | Base                   |             | 1..1          |
# |                                            | EHDSDeviceUse.header.authorship           |            | Base                   |             | 1..*          |
# |                                            | EHDSDeviceUse.header.authorship.author[x] |            | EHDSHealthProfessional |             | 1..1          |
# |                                            | EHDSDeviceUse.header.authorship.datetime  |            | dateTime               |             | 1..1          |
# | MedicalDevice.Product.ProductID            | EHDSDeviceUse.header.identifier           | ST         | Identifier             | 0..1        | 0..*          |
# |                                            | EHDSDeviceUse.header.language             |            | CodeableConcept        |             | 0..1          |
# |                                            | EHDSDeviceUse.header.lastUpdate           |            | dateTime               |             | 0..1          |
# |                                            | EHDSDeviceUse.header.status               |            | CodeableConcept        |             | 1..1          |
# |                                            | EHDSDeviceUse.header.statusReason[x]      |            | CodeableConcept        |             | 0..1          |
# |                                            | EHDSDeviceUse.header.subject              |            | EHDSPatient            |             | 1..1          |
# |                                            | EHDSDeviceUse.header.version              |            | string                 |             | 0..1          |
# | MedicalDevice.Comment                      | EHDSDeviceUse.note                        | ST         | string                 | 0..1        | 0..*          |
# |                                            | EHDSDeviceUse.presentedForm               |            | EHDSAttachment         |             | 0..*          |
# | MedicalDevice.Indication::Diagnosis        | EHDSDeviceUse.reason[x]                   |            | CodeableConcept        | 0..*        | 0..*          |
# |                                            | EHDSDeviceUse.recorded                    |            |                        |             |               |
# |                                            | EHDSDeviceUse.source[x]                   |            | EHDSPatient            |             | 0..1          |
# | MedicalDevice.StartDate                    | EHDSDeviceUse.startDate                   | TS         | dateTime               | 0..1        | 0..1          |
# |                                            | EHDSDeviceUse.status                      |            |                        |             |               |
# | MedicalDevice.HealthProfessional           |                                           |            |                        | 0..1        |               |
# | MedicalDevice.Location::HealthcareProvider |                                           |            |                        | 0..1        |               |
# | MedicalDevice.ProductDescription           |                                           | ST         |                        | 0..1        |               |
#
#
#
# ## EHDSDevice
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice |
# | zib | MedicalDevice.Product |
# | alias_zib | NL: Product |
# | binding_xtehr |  |
# | card._xtehr | 0..* |
# | card._zib | 1 |
# | definition_xtehr | EHDS refined base model for Device information |
# | definition_zib | The medical device (internally or externally). |
# | definitioncode_zib | SNOMED CT: 405815000 Procedure device |
# | id_xtehr | EHDSDevice |
# | id_zib | NL-CM:10.1.2 |
# | name_zib | Product |
# | path_xtehr | EHDSDevice |
# | path_zib | MedicalDevice.Product |
# | short_xtehr | Device model |
# | stereotype_zib | container |
# | type_xtehr |  |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDevice.expiryDate
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice.expiryDate |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib |  |
# | definition_xtehr | The date and time beyond which this device is no longer valid or should not be used (if applicable). |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.expiryDate |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDevice.expiryDate |
# | path_zib |  |
# | short_xtehr | The date and time beyond which this device is no longer valid or should not be used (if applicable). |
# | stereotype_zib |  |
# | type_xtehr | dateTime |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## zib: nan
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr | 1..* |
# | card._zib |  |
# | definition_xtehr | Normalised identifier of the device instance, such as UDI according to REGULATION (EU) 2017/745. Multiple identifiers can be used. |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.identifier |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDevice.identifier |
# | path_zib |  |
# | short_xtehr | Normalised identifier of the device instance, such as UDI according to REGULATION (EU) 2017/745. Multiple identifiers can be used. |
# | stereotype_zib |  |
# | type_xtehr | Identifier |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDevice.lotNumber
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice.lotNumber |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib |  |
# | definition_xtehr | Lot number of manufacture |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.lotNumber |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDevice.lotNumber |
# | path_zib |  |
# | short_xtehr | Lot number of manufacture |
# | stereotype_zib |  |
# | type_xtehr | string |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDevice.manufactureDate
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice.manufactureDate |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib |  |
# | definition_xtehr | The date and time when the device was manufactured |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.manufactureDate |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDevice.manufactureDate |
# | path_zib |  |
# | short_xtehr | The date and time when the device was manufactured |
# | stereotype_zib |  |
# | type_xtehr | dateTime |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDevice.manufacturer
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice.manufacturer |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib |  |
# | definition_xtehr | Name of device manufacturer |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.manufacturer |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDevice.manufacturer |
# | path_zib |  |
# | short_xtehr | Name of device manufacturer |
# | stereotype_zib |  |
# | type_xtehr | string |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDevice.modelNumber
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice.modelNumber |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib |  |
# | definition_xtehr | The manufacturer's model number for the device |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.modelNumber |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDevice.modelNumber |
# | path_zib |  |
# | short_xtehr | The manufacturer's model number for the device |
# | stereotype_zib |  |
# | type_xtehr | string |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDevice.name
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice.name |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..* |
# | card._zib |  |
# | definition_xtehr | The name and name type of the device as known to the manufacturer and/or patient |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.name |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDevice.name |
# | path_zib |  |
# | short_xtehr | The name and name type of the device as known to the manufacturer and/or patient |
# | stereotype_zib |  |
# | type_xtehr | string |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDevice.note
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice.note |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..* |
# | card._zib |  |
# | definition_xtehr | Device notes and comments |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.note |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDevice.note |
# | path_zib |  |
# | short_xtehr | Device notes and comments |
# | stereotype_zib |  |
# | type_xtehr | string |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDevice.serialNumber
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice.serialNumber |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib |  |
# | definition_xtehr | Serial number assigned by the manufacturer |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.serialNumber |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDevice.serialNumber |
# | path_zib |  |
# | short_xtehr | Serial number assigned by the manufacturer |
# | stereotype_zib |  |
# | type_xtehr | string |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDevice.type
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice.type |
# | zib | MedicalDevice.Product.ProductType |
# | alias_zib | NL: ProductType |
# | binding_xtehr | {'strength': 'preferred', 'description': 'SNOMED CT, EMDN'} |
# | card._xtehr | 0..* |
# | card._zib | 0..1 |
# | definition_xtehr | Device type |
# | definition_zib | The code of the type of product. |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.type |
# | id_zib | NL-CM:10.1.3 |
# | name_zib | ProductType |
# | path_xtehr | EHDSDevice.type |
# | path_zib | MedicalDevice.Product.ProductType |
# | short_xtehr | Device type |
# | stereotype_zib | data |
# | type_xtehr | CodeableConcept |
# | type_zib | CD |
#
# ### Comments
#
#
#
# ## EHDSDevice.version
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDevice.version |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib |  |
# | definition_xtehr | The actual design of the device or software version running on the device |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDevice.version |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDevice.version |
# | path_zib |  |
# | short_xtehr | The actual design of the device or software version running on the device |
# | stereotype_zib |  |
# | type_xtehr | string |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse |
# | zib | MedicalDevice |
# | alias_zib | NL: MedischHulpmiddel |
# | binding_xtehr |  |
# | card._xtehr | 0..* |
# | card._zib |  |
# | definition_xtehr | EHDS refined base model for device use information |
# | definition_zib | Root concept of the MedicalDevice information model. This root concept contains all data elements of the MedicalDevice information model. |
# | definitioncode_zib | SNOMED CT: 49062001 Device |
# | id_xtehr | EHDSDeviceUse |
# | id_zib | NL-CM:10.1.1 |
# | name_zib | MedicalDevice |
# | path_xtehr | EHDSDeviceUse |
# | path_zib | MedicalDevice |
# | short_xtehr | Device use model |
# | stereotype_zib | rootconcept |
# | type_xtehr |  |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.bodySite
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.bodySite |
# | zib | MedicalDevice.AnatomicalLocation |
# | alias_zib | NL: AnatomischeLocatie |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Anatomical location of the device. May include laterality. |
# | definition_zib | Patient’s anatomical location of the medical device used. |
# | definitioncode_zib | SNOMED CT: 363698007 Finding site |
# | id_xtehr | EHDSDeviceUse.bodySite |
# | id_zib | NL-CM:10.1.15 |
# | name_zib | AnatomicalLocation |
# | path_xtehr | EHDSDeviceUse.bodySite |
# | path_zib | MedicalDevice.AnatomicalLocation |
# | short_xtehr | Anatomical location of the device. May include laterality. |
# | stereotype_zib | data,reference |
# | type_xtehr | EHDSBodyStructure |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.device[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.device[x] |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr | 1..1 |
# | card._zib |  |
# | definition_xtehr | The details of the device used. |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.device[x] |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDeviceUse.device[x] |
# | path_zib |  |
# | short_xtehr | The details of the device used. |
# | stereotype_zib |  |
# | type_xtehr | CodeableConcept |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.endDate
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.endDate |
# | zib | MedicalDevice.EndDate |
# | alias_zib | NL: EindDatum |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Date when the device was explanted from the patient or the external device was no longer in use. |
# | definition_zib | The end date of the last use or explant of the medical device. A ‘vague’ date, such as only the year, is permitted. |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.endDate |
# | id_zib | NL-CM:10.1.14 |
# | name_zib | EndDate |
# | path_xtehr | EHDSDeviceUse.endDate |
# | path_zib | MedicalDevice.EndDate |
# | short_xtehr | Date when the device was explanted from the patient or the external device was no longer in use. |
# | stereotype_zib | data |
# | type_xtehr | dateTime |
# | type_zib | TS |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.header
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.header |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr | 1..1 |
# | card._zib |  |
# | definition_xtehr | Common header for all patient-related data |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.header |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDeviceUse.header |
# | path_zib |  |
# | short_xtehr | Common header for all patient-related data |
# | stereotype_zib |  |
# | type_xtehr | Base |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.header.authorship
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.header.authorship |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr | 1..* |
# | card._zib |  |
# | definition_xtehr | Resource authoring details |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.header.authorship |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDeviceUse.header.authorship |
# | path_zib |  |
# | short_xtehr | Authorship |
# | stereotype_zib |  |
# | type_xtehr | Base |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.header.authorship.author[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.header.authorship.author[x] |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr | 1..1 |
# | card._zib |  |
# | definition_xtehr | Author(s) by whom the resource was/were authored. Multiple authors could be provided. |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.header.authorship.author[x] |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDeviceUse.header.authorship.author[x] |
# | path_zib |  |
# | short_xtehr | Author |
# | stereotype_zib |  |
# | type_xtehr | EHDSHealthProfessional |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.header.authorship.datetime
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.header.authorship.datetime |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr | 1..1 |
# | card._zib |  |
# | definition_xtehr | Date and time of the issuing the document/resource by its author. |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.header.authorship.datetime |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDeviceUse.header.authorship.datetime |
# | path_zib |  |
# | short_xtehr | Date and time of authoring/issuing |
# | stereotype_zib |  |
# | type_xtehr | dateTime |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.header.identifier
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.header.identifier |
# | zib | MedicalDevice.Product.ProductID |
# | alias_zib | NL: ProductID |
# | binding_xtehr |  |
# | card._xtehr | 0..* |
# | card._zib | 0..1 |
# | definition_xtehr | Business identifier for the object |
# | definition_zib | Globally unique identification of the product, for example the serial number or a UDI (unique device identifier). For some products, the law requires the use of a UDI. Commonly used coding systems are HIBC and GS1/GTIN.
#
# A UDI often contains more information than just an ID, but also, for example, an expiration date. If a UDI is used, the entire code can be included as text in ProductID, so that no important information is lost. |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.header.identifier |
# | id_zib | NL-CM:10.1.16 |
# | name_zib | ProductID |
# | path_xtehr | EHDSDeviceUse.header.identifier |
# | path_zib | MedicalDevice.Product.ProductID |
# | short_xtehr | Business identifier for the object |
# | stereotype_zib | data |
# | type_xtehr | Identifier |
# | type_zib | ST |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.header.language
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.header.language |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr | {'strength': 'preferred', 'description': 'BCP 47'} |
# | card._xtehr | 0..1 |
# | card._zib |  |
# | definition_xtehr | Language in which the resource is written. Language is expressed by the IETF language tag. |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.header.language |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDeviceUse.header.language |
# | path_zib |  |
# | short_xtehr | Language |
# | stereotype_zib |  |
# | type_xtehr | CodeableConcept |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.header.lastUpdate
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.header.lastUpdate |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib |  |
# | definition_xtehr | Date and time of the last update to the document/information |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.header.lastUpdate |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDeviceUse.header.lastUpdate |
# | path_zib |  |
# | short_xtehr | Date and time of the last update to the resource |
# | stereotype_zib |  |
# | type_xtehr | dateTime |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.header.status
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.header.status |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr | {'strength': 'preferred', 'description': 'HL7 device-statement-status'} |
# | card._xtehr | 1..1 |
# | card._zib |  |
# | definition_xtehr | Status of the resource |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.header.status |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDeviceUse.header.status |
# | path_zib |  |
# | short_xtehr | Current status of the device usage. |
# | stereotype_zib |  |
# | type_xtehr | CodeableConcept |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.header.statusReason[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.header.statusReason[x] |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib |  |
# | definition_xtehr | Reason for the current status of the resource. |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.header.statusReason[x] |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDeviceUse.header.statusReason[x] |
# | path_zib |  |
# | short_xtehr | Reason for the current status of the resource. |
# | stereotype_zib |  |
# | type_xtehr | CodeableConcept |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.header.subject
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.header.subject |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr | 1..1 |
# | card._zib |  |
# | definition_xtehr | Patient/subject information |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.header.subject |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDeviceUse.header.subject |
# | path_zib |  |
# | short_xtehr | Subject |
# | stereotype_zib |  |
# | type_xtehr | EHDSPatient |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.header.version
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.header.version |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib |  |
# | definition_xtehr | Business version of the resource. |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.header.version |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDeviceUse.header.version |
# | path_zib |  |
# | short_xtehr | Version |
# | stereotype_zib |  |
# | type_xtehr | string |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.note
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.note |
# | zib | MedicalDevice.Comment |
# | alias_zib | NL: Toelichting |
# | binding_xtehr |  |
# | card._xtehr | 0..* |
# | card._zib | 0..1 |
# | definition_xtehr | Note about the device statement that were not represented at all or sufficiently in one of the attributes provided in a class. These may include for example a comment, an instruction, or a note associated with the statement. |
# | definition_zib | Comment about use or information on the medical device used. |
# | definitioncode_zib | LOINC: 48767-8 Annotation comment [Interpretation] Narrative |
# | id_xtehr | EHDSDeviceUse.note |
# | id_zib | NL-CM:10.1.10 |
# | name_zib | Comment |
# | path_xtehr | EHDSDeviceUse.note |
# | path_zib | MedicalDevice.Comment |
# | short_xtehr | Note about the device statement that were not represented at all or sufficiently in one of the attributes provided in a class. These may include for example a comment, an instruction, or a note associated with the statement. |
# | stereotype_zib | data |
# | type_xtehr | string |
# | type_zib | ST |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.presentedForm
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.presentedForm |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..* |
# | card._zib |  |
# | definition_xtehr | A narrative easy-to-read representation of the full data set, e.g. PDF-version of a document |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.presentedForm |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDeviceUse.presentedForm |
# | path_zib |  |
# | short_xtehr | A narrative easy-to-read representation of the full data set, e.g. PDF-version of a document |
# | stereotype_zib |  |
# | type_xtehr | EHDSAttachment |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.reason[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.reason[x] |
# | zib | MedicalDevice.Indication::Diagnosis |
# | alias_zib | NL: Indicatie::Diagnose |
# | binding_xtehr |  |
# | card._xtehr | 0..* |
# | card._zib | 0..* |
# | definition_xtehr | Reason or justification for the use of the device. |
# | definition_zib | The diagnosis as indication for the medical device. |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.reason[x] |
# | id_zib | NL-CM:10.1.17 |
# | name_zib | Indication::Diagnosis |
# | path_xtehr | EHDSDeviceUse.reason[x] |
# | path_zib | MedicalDevice.Indication::Diagnosis |
# | short_xtehr | Reason or justification for the use of the device. |
# | stereotype_zib | context,reference |
# | type_xtehr | CodeableConcept |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.recorded
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.recorded |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr |  |
# | card._zib |  |
# | definition_xtehr |  |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr |  |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr |  |
# | path_zib |  |
# | short_xtehr |  |
# | stereotype_zib |  |
# | type_xtehr |  |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.source[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.source[x] |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib |  |
# | definition_xtehr | Who reported the device was being used by the patient. |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.source[x] |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr | EHDSDeviceUse.source[x] |
# | path_zib |  |
# | short_xtehr | Who reported the device was being used by the patient. |
# | stereotype_zib |  |
# | type_xtehr | EHDSPatient |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.startDate
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.startDate |
# | zib | MedicalDevice.StartDate |
# | alias_zib | NL: BeginDatum |
# | binding_xtehr |  |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Date when the device was implantable to the patient or the external device was first in use. |
# | definition_zib | The start date of the first use or implant of the medical device. A ‘vague’ date, such as only the year, is permitted. |
# | definitioncode_zib |  |
# | id_xtehr | EHDSDeviceUse.startDate |
# | id_zib | NL-CM:10.1.11 |
# | name_zib | StartDate |
# | path_xtehr | EHDSDeviceUse.startDate |
# | path_zib | MedicalDevice.StartDate |
# | short_xtehr | Date when the device was implantable to the patient or the external device was first in use. |
# | stereotype_zib | data |
# | type_xtehr | dateTime |
# | type_zib | TS |
#
# ### Comments
#
#
#
# ## EHDSDeviceUse.status
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSDeviceUse.status |
# | zib |  |
# | alias_zib |  |
# | binding_xtehr |  |
# | card._xtehr |  |
# | card._zib |  |
# | definition_xtehr |  |
# | definition_zib |  |
# | definitioncode_zib |  |
# | id_xtehr |  |
# | id_zib |  |
# | name_zib |  |
# | path_xtehr |  |
# | path_zib |  |
# | short_xtehr |  |
# | stereotype_zib |  |
# | type_xtehr |  |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## zib: MedicalDevice.HealthProfessional
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | MedicalDevice.HealthProfessional |
# | alias_zib | NL: Zorgverlener |
# | binding_xtehr |  |
# | card._xtehr |  |
# | card._zib | 0..1 |
# | definition_xtehr |  |
# | definition_zib | The health professional involved in the indication for use of the medical device implant. |
# | definitioncode_zib |  |
# | id_xtehr |  |
# | id_zib | NL-CM:10.1.9 |
# | name_zib | HealthProfessional |
# | path_xtehr |  |
# | path_zib | MedicalDevice.HealthProfessional |
# | short_xtehr |  |
# | stereotype_zib | context,reference |
# | type_xtehr |  |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## zib: MedicalDevice.Location::HealthcareProvider
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | MedicalDevice.Location::HealthcareProvider |
# | alias_zib | NL: Locatie::Zorgaanbieder |
# | binding_xtehr |  |
# | card._xtehr |  |
# | card._zib | 0..1 |
# | definition_xtehr |  |
# | definition_zib | The healthcare provider where use of the medical device was initiated or where the aid was implanted. |
# | definitioncode_zib |  |
# | id_xtehr |  |
# | id_zib | NL-CM:10.1.8 |
# | name_zib | Location::HealthcareProvider |
# | path_xtehr |  |
# | path_zib | MedicalDevice.Location::HealthcareProvider |
# | short_xtehr |  |
# | stereotype_zib | context,reference |
# | type_xtehr |  |
# | type_zib |  |
#
# ### Comments
#
#
#
# ## zib: MedicalDevice.ProductDescription
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | MedicalDevice.ProductDescription |
# | alias_zib | NL: ProductOmschrijving |
# | binding_xtehr |  |
# | card._xtehr |  |
# | card._zib | 0..1 |
# | definition_xtehr |  |
# | definition_zib | Textual description of the product. |
# | definitioncode_zib |  |
# | id_xtehr |  |
# | id_zib | NL-CM:10.1.13 |
# | name_zib | ProductDescription |
# | path_xtehr |  |
# | path_zib | MedicalDevice.ProductDescription |
# | short_xtehr |  |
# | stereotype_zib | data |
# | type_xtehr |  |
# | type_zib | ST |
#
# ### Comments
