# %%
import pandas as pd
import os
import unicodedata as ud

# %%
# zibbase = 'zibs2020'
zibbase = 'zibs2024'
zibspath = os.path.join(zibbase, 'mappable')
zibs = os.listdir(zibspath)
[(i, zib) for i, zib in enumerate(zibs)]
# Out:
# [(0, 'nl.zorg.MedicationAgreement-v4.0(2024EN).xlsx'),
#  (1, 'nl.zorg.MedicationAdministration2-v3.0(2024EN).xlsx'),
#  (2, 'nl.zorg.HealthcareProvider-v3.6(2024EN).xlsx'),
#  (3, 'nl.zorg.DispenseRequest-v4.0(2024EN).xlsx'),
#  (4, 'Nl.zorg.part.PharmaceuticalProduct-v2.3(2024EN).xlsx'),
#  (5, 'nl.zorg.AdministrationAgreement-v3.0(2024EN).xlsx'),
#  (6, 'nl.zorg.MedicationDispense-v3.0.1(2024EN).xlsx'),
#  (7, 'nl.zorg.MedicationUse2-v3.0(2024EN).xlsx')]

# %%
zib = zibs[4]
print(zib)
zibpath = os.path.join(zibspath, zib)
zibdf = pd.read_excel(zibpath)
zibdf['path'] = zibdf['path'].apply(
    lambda x: ud.normalize("NFKC", str(x)).replace("\xa0", " ").strip() if pd.notna(x) else x
)
zibdf
# only for zib2024 condition and diagnosis
# zib = zibs[1]
# print( zib)
# zibpath = os.path.join(zibspath, zib)
# zibdf2 = pd.read_excel(zibpath)
# zibdf = pd.concat([zibdf, zibdf2], ignore_index=True)
# zibdf
# Out:
# Nl.zorg.part.PharmaceuticalProduct-v2.3(2024EN).xlsx
#                      name                                               path  \
# 0   PharmaceuticalProduct                              PharmaceuticalProduct
# 1          MedicationCode               PharmaceuticalProduct.MedicationCode
# 2   ProductSpecifications        PharmaceuticalProduct.ProductSpecifications
# 3         Batch/lotNumber  PharmaceuticalProduct.ProductSpecifications.Ba...
# 4             SerieNumber  PharmaceuticalProduct.ProductSpecifications.Se...
# 5      PharmaceuticalForm  PharmaceuticalProduct.ProductSpecifications.Ph...
# 6              Medication  PharmaceuticalProduct.ProductSpecifications.Me...
# 7             Description  PharmaceuticalProduct.ProductSpecifications.De...
# 8              Ingredient  PharmaceuticalProduct.ProductSpecifications.In...
# 9           SubstanceCode  PharmaceuticalProduct.ProductSpecifications.In...
# 10          Concentration  PharmaceuticalProduct.ProductSpecifications.In...
# 11       IngredientAmount  PharmaceuticalProduct.ProductSpecifications.In...
# 12          ProductAmount  PharmaceuticalProduct.ProductSpecifications.In...
#
#                         alias type card.   stereotype               id  \
# 0    NL: FarmaceutischProduct  NaN   NaN  rootconcept  NL-CM:9.7.19926
# 1             NL: ProductCode   CD  0..1         data  NL-CM:9.7.19927
# 2     NL: ProductSpecificatie  NaN  0..1    container  NL-CM:9.7.19928
# 3         NL: Batch/lotNummer   ST  0..1         data  NL-CM:9.7.22279
# 4             NL: SerieNummer   ST  0..1         data  NL-CM:9.7.22280
# 5      NL: FarmaceutischeVorm   CD  0..1         data  NL-CM:9.7.19931
# 6             NL: ProductNaam   ST  0..1         data  NL-CM:9.7.19929
# 7            NL: Omschrijving   ST  0..1         data  NL-CM:9.7.19784
# 8              NL: Ingredient  NaN  0..*    container  NL-CM:9.7.19932
# 9          NL: IngredientCode   CD  0..1         data  NL-CM:9.7.19934
# 10                NL: Sterkte  NaN  0..1    container  NL-CM:9.7.19933
# 11  NL: IngredientHoeveelheid   PQ  0..1         data  NL-CM:9.7.22277
# 12     NL: ProductHoeveelheid   PQ  0..1         data  NL-CM:9.7.22278
#
#                                            definition  definitioncode
# 0   Root concept of the PharmaceuticalProduct part...             NaN
# 1   Coding medication in the Netherlands is done o...             NaN
# 2   Container of the ProductSpecifications concept...             NaN
# 3   The batch/lot number provides a unique identif...             NaN
# 4   The serial number uniquely identifies the sour...             NaN
# 5   The pharmaceutical form indicates the form of ...             NaN
# 6   For medication which has no code, enter the co...             NaN
# 7   A textual description of the type of medicatio...             NaN
# 8   Container of the Ingredient concept. This cont...             NaN
# 9   Active substance or excipient. \nHere, the sam...             NaN
# 10  The relative amount of this ingredient in this...             NaN
# 11  The amount and unit of this ingredient. This i...             NaN
# 12  Amount of the product. This is the denominator...             NaN

# %%
xlmbase = 'xtehr'
xlmspath = os.path.join(xlmbase, 'mappable')
xlms = os.listdir(xlmspath)
[(i, xlm) for i, xlm in enumerate(xlms)]
# Out:
# [(0, 'Medication.xlsx'),
#  (1, 'Location.xlsx'),
#  (2, 'Dosaging.xlsx'),
#  (3, 'DispenseDecline.xlsx'),
#  (4, 'MedicationDispense.xlsx'),
#  (5, 'MedicationPrescription.xlsx')]

# %%
xlm = xlms[0]
print( xlm)
xlmpath = os.path.join(xlmspath, xlm)
xlmdf = pd.read_excel(xlmpath)
# Normalize + strip (for non-breaking spaces, Unicode issues)
xlmdf['path'] = xlmdf['path'].apply(
    lambda x: ud.normalize("NFKC", str(x)).replace("\xa0", " ").strip() if pd.notna(x) else x
)
xlmdf
# only for device use and organization
# xlm = xlms[7]
# print( xlm)
# xlmpath = os.path.join(xlmspath, xlm)
# xlmdf2 = pd.read_excel(xlmpath)
# xlmdf = pd.concat([xlmdf, xlmdf2], ignore_index=True)
# xlmdf
# Out:
# Medication.xlsx
#                                                    id  \
# 0                                      EHDSMedication
# 1                   EHDSMedication.identifyingCode[x]
# 2                       EHDSMedication.classification
# 3                          EHDSMedication.productName
# 4         EHDSMedication.marketingAuthorisationHolder
# 5   EHDSMedication.marketingAuthorisationHolder.or...
# 6   EHDSMedication.marketingAuthorisationHolder.or...
# 7                             EHDSMedication.doseForm
# 8                             EHDSMedication.packSize
# 9                                 EHDSMedication.item
# 10                       EHDSMedication.item.doseForm
# 11                     EHDSMedication.item.ingredient
# 12            EHDSMedication.item.ingredient.isActive
# 13           EHDSMedication.item.ingredient.substance
# 14        EHDSMedication.item.ingredient.strengthInfo
# 15  EHDSMedication.item.ingredient.strengthInfo.st...
# 16  EHDSMedication.item.ingredient.strengthInfo.ba...
# 17             EHDSMedication.item.unitOfPresentation
# 18              EHDSMedication.item.containedQuantity
# 19                         EHDSMedication.item.amount
# 20                    EHDSMedication.item.packageType
# 21                              EHDSMedication.device
# 22               EHDSMedication.device.deviceQuantity
# 23                    EHDSMedication.device.device[x]
# 24                      EHDSMedication.characteristic
# 25                 EHDSMedication.characteristic.type
# 26             EHDSMedication.characteristic.value[x]
# 27                               EHDSMedication.batch
# 28                     EHDSMedication.batch.lotNumber
# 29                EHDSMedication.batch.expirationDate
#
#                                                  path  \
# 0                                      EHDSMedication
# 1                   EHDSMedication.identifyingCode[x]
# 2                       EHDSMedication.classification
# 3                          EHDSMedication.productName
# 4         EHDSMedication.marketingAuthorisationHolder
# 5   EHDSMedication.marketingAuthorisationHolder.or...
# 6   EHDSMedication.marketingAuthorisationHolder.or...
# 7                             EHDSMedication.doseForm
# 8                             EHDSMedication.packSize
# 9                                 EHDSMedication.item
# 10                       EHDSMedication.item.doseForm
# 11                     EHDSMedication.item.ingredient
# 12            EHDSMedication.item.ingredient.isActive
# 13           EHDSMedication.item.ingredient.substance
# 14        EHDSMedication.item.ingredient.strengthInfo
# 15  EHDSMedication.item.ingredient.strengthInfo.st...
# 16  EHDSMedication.item.ingredient.strengthInfo.ba...
# 17             EHDSMedication.item.unitOfPresentation
# 18              EHDSMedication.item.containedQuantity
# 19                         EHDSMedication.item.amount
# 20                    EHDSMedication.item.packageType
# 21                              EHDSMedication.device
# 22               EHDSMedication.device.deviceQuantity
# 23                    EHDSMedication.device.device[x]
# 24                      EHDSMedication.characteristic
# 25                 EHDSMedication.characteristic.type
# 26             EHDSMedication.characteristic.value[x]
# 27                               EHDSMedication.batch
# 28                     EHDSMedication.batch.lotNumber
# 29                EHDSMedication.batch.expirationDate
#
#                                                 short  \
# 0                                    Medication model
# 1   Identifier or code for the product (virtual pr...
# 2   Classification (e.g. ATC; narcotic/psychotropi...
# 3   Name of the product (full name, invented name,...
# 4   Marketing authorisation holder or manufacturer...
# 5   Name of the organisation holding the authorisa...
# 6   Identifier of the organisation and/or its phys...
# 7   Dose form(s) on a product level. Dose form for...
# 8   Overall amount of product in one package (100m...
# 9   A medication item. For combination packs, this...
# 10                                          Dose form
# 11                                        Ingredients
# 12  Marks if the ingredient is considered an activ...
# 13                                          Substance
# 14  Strength of the product - amount of substance ...
# 15  Concentration or presentation strength, e.g 10...
# 16  Substance that the strength refers to, in case...
# 17  Unit of presentation for the manufactured item...
# 18  Manufactured item quantity for liquids (3ml / ...
# 19  Number of such manufactured items in this prod...
# 20             Type of package of the medication item
# 21      Administration device included in the product
# 22                             Number of such devices
# 23                                       Device coded
# 24                      Other features of the product
# 25       A code expressing the type of characteristic
# 26                  Description of the characteristic
# 27  Batch information of a medicinal product. Typi...
# 28          Batch identifier of the medicinal product
# 29    Batch expiration date of the medicinal product.
#
#                                            definition             type card.  \
# 0   Logical model for prescribed/dispensed medicat...              NaN  0..*
# 1   Identifier or code for the product (virtual pr...  CodeableConcept  0..*
# 2   Classification (e.g. ATC; narcotic/psychotropi...  CodeableConcept  0..*
# 3   Name of the product (full name, invented name,...           string  0..1
# 4   Marketing authorisation holder or manufacturer...             Base  0..1
# 5   Name of the organisation holding the authorisa...           string  0..1
# 6   Identifier of the organisation and/or its phys...       Identifier  0..*
# 7   Dose form(s) on a product level. Dose form for...  CodeableConcept  0..1
# 8   Overall amount of product in one package (100m...         Quantity  0..*
# 9   A medication item. For combination packs, this...             Base  0..*
# 10                                          Dose form  CodeableConcept  0..1
# 11                                        Ingredients             Base  1..*
# 12  Marks if the ingredient is considered an activ...          boolean  0..1
# 13                                          Substance  CodeableConcept  1..1
# 14  Strength of the product - amount of substance ...             Base  0..1
# 15  Concentration or presentation strength, e.g 10...            Ratio  1..1
# 16  Substance that the strength refers to, in case...  CodeableConcept  0..1
# 17  Unit of presentation for the manufactured item...  CodeableConcept  0..1
# 18  Manufactured item quantity for liquids (3ml / ...            Ratio  0..1
# 19  Number of such manufactured items in this prod...         Quantity  0..1
# 20             Type of package of the medication item  CodeableConcept  0..1
# 21      Administration device included in the product             Base  0..*
# 22                             Number of such devices         Quantity  1..1
# 23                                       Device coded  CodeableConcept  1..1
# 24                      Other features of the product             Base  0..*
# 25       A code expressing the type of characteristic  CodeableConcept  1..1
# 26                  Description of the characteristic          boolean  0..1
# 27  Batch information of a medicinal product. Typi...             Base  0..1
# 28          Batch identifier of the medicinal product           string  0..1
# 29    Batch expiration date of the medicinal product.         dateTime  0..1
#
#                                               binding
# 0                                                 NaN
# 1                                                 NaN
# 2   {'strength': 'preferred', 'description': 'WHO ...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'strength': 'preferred', 'description': 'EDQM...
# 8   {'strength': 'preferred', 'description': 'UCUM...
# 9                                                 NaN
# 10  {'strength': 'preferred', 'description': 'EDQM...
# 11                                                NaN
# 12                                                NaN
# 13  {'strength': 'preferred', 'description': 'EMA ...
# 14                                                NaN
# 15                                                NaN
# 16  {'strength': 'preferred', 'description': 'EMA ...
# 17  {'strength': 'preferred', 'description': 'EDQM...
# 18                                                NaN
# 19  {'strength': 'preferred', 'description': 'UCUM...
# 20  {'strength': 'preferred', 'description': 'EDQM...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN

# %%
mapbase = 'maps'
maps = os.listdir(mapbase)
[(i, map) for i, map in enumerate(maps)]
# Out:
# [(0, '.DS_Store'),
#  (1, 'PharmaceuticalProduct.xlsx'),
#  (2, 'XtEHR2zibs2024'),
#  (3, 'MedDispense.xlsx')]

# %%
file = maps[1]
print(file)
mappath = os.path.join(mapbase, file)
print(mappath)
mapdf = pd.read_excel(mappath)
# Normalize + strip (for non-breaking spaces, Unicode issues)
mapdf[['zib','xtehr']] = mapdf[['zib','xtehr']].map(
    lambda x: ud.normalize("NFKC", str(x)).replace("\xa0", " ").strip() if pd.notna(x) else x
)
mapdf
# Out:
# PharmaceuticalProduct.xlsx
# maps/PharmaceuticalProduct.xlsx
#                                                 xtehr  \
# 0                                      EHDSMedication
# 1                   EHDSMedication.identifyingCode[x]
# 2                       EHDSMedication.classification
# 3                          EHDSMedication.productName
# 4         EHDSMedication.marketingAuthorisationHolder
# 5   EHDSMedication.marketingAuthorisationHolder.or...
# 6   EHDSMedication.marketingAuthorisationHolder.or...
# 7                             EHDSMedication.doseForm
# 8                             EHDSMedication.packSize
# 9                                 EHDSMedication.item
# 10                       EHDSMedication.item.doseForm
# 11                     EHDSMedication.item.ingredient
# 12            EHDSMedication.item.ingredient.isActive
# 13           EHDSMedication.item.ingredient.substance
# 14        EHDSMedication.item.ingredient.strengthInfo
# 15  EHDSMedication.item.ingredient.strengthInfo.st...
# 16  EHDSMedication.item.ingredient.strengthInfo.ba...
# 17             EHDSMedication.item.unitOfPresentation
# 18              EHDSMedication.item.containedQuantity
# 19                         EHDSMedication.item.amount
# 20                    EHDSMedication.item.packageType
# 21                              EHDSMedication.device
# 22               EHDSMedication.device.deviceQuantity
# 23                    EHDSMedication.device.device[x]
# 24                      EHDSMedication.characteristic
# 25                 EHDSMedication.characteristic.type
# 26             EHDSMedication.characteristic.value[x]
# 27                               EHDSMedication.batch
# 28                     EHDSMedication.batch.lotNumber
# 29                EHDSMedication.batch.expirationDate
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
#
#                                                   zib  name_zib  path_zib  \
# 0                               PharmaceuticalProduct       NaN       NaN
# 1                PharmaceuticalProduct.MedicationCode       NaN       NaN
# 2                                                 NaN       NaN       NaN
# 3   PharmaceuticalProduct.ProductSpecifications.Me...       NaN       NaN
# 4                                                 NaN       NaN       NaN
# 5                                                 NaN       NaN       NaN
# 6                                                 NaN       NaN       NaN
# 7                                                 NaN       NaN       NaN
# 8                                                 NaN       NaN       NaN
# 9                                                 NaN       NaN       NaN
# 10  PharmaceuticalProduct.ProductSpecifications.Ph...       NaN       NaN
# 11  PharmaceuticalProduct.ProductSpecifications.In...       NaN       NaN
# 12                                                NaN       NaN       NaN
# 13  PharmaceuticalProduct.ProductSpecifications.In...       NaN       NaN
# 14                                                NaN       NaN       NaN
# 15  PharmaceuticalProduct.ProductSpecifications.In...       NaN       NaN
# 16                                                NaN       NaN       NaN
# 17                                                NaN       NaN       NaN
# 18  PharmaceuticalProduct.ProductSpecifications.In...       NaN       NaN
# 19                                                NaN       NaN       NaN
# 20                                                NaN       NaN       NaN
# 21                                                NaN       NaN       NaN
# 22                                                NaN       NaN       NaN
# 23                                                NaN       NaN       NaN
# 24                                                NaN       NaN       NaN
# 25                                                NaN       NaN       NaN
# 26                                                NaN       NaN       NaN
# 27                                                NaN       NaN       NaN
# 28  PharmaceuticalProduct.ProductSpecifications.Ba...       NaN       NaN
# 29                                                NaN       NaN       NaN
# 30        PharmaceuticalProduct.ProductSpecifications       NaN       NaN
# 31  PharmaceuticalProduct.ProductSpecifications.Se...       NaN       NaN
# 32  PharmaceuticalProduct.ProductSpecifications.De...       NaN       NaN
# 33  PharmaceuticalProduct.ProductSpecifications.In...       NaN       NaN
# 34               PharmaceuticalProduct.MedicationCode       NaN       NaN
#
#     alias_zib  type_zib  card._zib  stereotype_zib  id_zib  definition_zib  \
# 0         NaN       NaN        NaN             NaN     NaN             NaN
# 1         NaN       NaN        NaN             NaN     NaN             NaN
# 2         NaN       NaN        NaN             NaN     NaN             NaN
# 3         NaN       NaN        NaN             NaN     NaN             NaN
# 4         NaN       NaN        NaN             NaN     NaN             NaN
# 5         NaN       NaN        NaN             NaN     NaN             NaN
# 6         NaN       NaN        NaN             NaN     NaN             NaN
# 7         NaN       NaN        NaN             NaN     NaN             NaN
# 8         NaN       NaN        NaN             NaN     NaN             NaN
# 9         NaN       NaN        NaN             NaN     NaN             NaN
# 10        NaN       NaN        NaN             NaN     NaN             NaN
# 11        NaN       NaN        NaN             NaN     NaN             NaN
# 12        NaN       NaN        NaN             NaN     NaN             NaN
# 13        NaN       NaN        NaN             NaN     NaN             NaN
# 14        NaN       NaN        NaN             NaN     NaN             NaN
# 15        NaN       NaN        NaN             NaN     NaN             NaN
# 16        NaN       NaN        NaN             NaN     NaN             NaN
# 17        NaN       NaN        NaN             NaN     NaN             NaN
# 18        NaN       NaN        NaN             NaN     NaN             NaN
# 19        NaN       NaN        NaN             NaN     NaN             NaN
# 20        NaN       NaN        NaN             NaN     NaN             NaN
# 21        NaN       NaN        NaN             NaN     NaN             NaN
# 22        NaN       NaN        NaN             NaN     NaN             NaN
# 23        NaN       NaN        NaN             NaN     NaN             NaN
# 24        NaN       NaN        NaN             NaN     NaN             NaN
# 25        NaN       NaN        NaN             NaN     NaN             NaN
# 26        NaN       NaN        NaN             NaN     NaN             NaN
# 27        NaN       NaN        NaN             NaN     NaN             NaN
# 28        NaN       NaN        NaN             NaN     NaN             NaN
# 29        NaN       NaN        NaN             NaN     NaN             NaN
# 30        NaN       NaN        NaN             NaN     NaN             NaN
# 31        NaN       NaN        NaN             NaN     NaN             NaN
# 32        NaN       NaN        NaN             NaN     NaN             NaN
# 33        NaN       NaN        NaN             NaN     NaN             NaN
# 34        NaN       NaN        NaN             NaN     NaN             NaN
#
#     definitioncode_zib  id_xtehr  path_xtehr  short_xtehr  definition_xtehr  \
# 0                  NaN       NaN         NaN          NaN               NaN
# 1                  NaN       NaN         NaN          NaN               NaN
# 2                  NaN       NaN         NaN          NaN               NaN
# 3                  NaN       NaN         NaN          NaN               NaN
# 4                  NaN       NaN         NaN          NaN               NaN
# 5                  NaN       NaN         NaN          NaN               NaN
# 6                  NaN       NaN         NaN          NaN               NaN
# 7                  NaN       NaN         NaN          NaN               NaN
# 8                  NaN       NaN         NaN          NaN               NaN
# 9                  NaN       NaN         NaN          NaN               NaN
# 10                 NaN       NaN         NaN          NaN               NaN
# 11                 NaN       NaN         NaN          NaN               NaN
# 12                 NaN       NaN         NaN          NaN               NaN
# 13                 NaN       NaN         NaN          NaN               NaN
# 14                 NaN       NaN         NaN          NaN               NaN
# 15                 NaN       NaN         NaN          NaN               NaN
# 16                 NaN       NaN         NaN          NaN               NaN
# 17                 NaN       NaN         NaN          NaN               NaN
# 18                 NaN       NaN         NaN          NaN               NaN
# 19                 NaN       NaN         NaN          NaN               NaN
# 20                 NaN       NaN         NaN          NaN               NaN
# 21                 NaN       NaN         NaN          NaN               NaN
# 22                 NaN       NaN         NaN          NaN               NaN
# 23                 NaN       NaN         NaN          NaN               NaN
# 24                 NaN       NaN         NaN          NaN               NaN
# 25                 NaN       NaN         NaN          NaN               NaN
# 26                 NaN       NaN         NaN          NaN               NaN
# 27                 NaN       NaN         NaN          NaN               NaN
# 28                 NaN       NaN         NaN          NaN               NaN
# 29                 NaN       NaN         NaN          NaN               NaN
# 30                 NaN       NaN         NaN          NaN               NaN
# 31                 NaN       NaN         NaN          NaN               NaN
# 32                 NaN       NaN         NaN          NaN               NaN
# 33                 NaN       NaN         NaN          NaN               NaN
# 34                 NaN       NaN         NaN          NaN               NaN
#
#     type_xtehr  card._xtehr  binding_xtehr
# 0          NaN          NaN            NaN
# 1          NaN          NaN            NaN
# 2          NaN          NaN            NaN
# 3          NaN          NaN            NaN
# 4          NaN          NaN            NaN
# 5          NaN          NaN            NaN
# 6          NaN          NaN            NaN
# 7          NaN          NaN            NaN
# 8          NaN          NaN            NaN
# 9          NaN          NaN            NaN
# 10         NaN          NaN            NaN
# 11         NaN          NaN            NaN
# 12         NaN          NaN            NaN
# 13         NaN          NaN            NaN
# 14         NaN          NaN            NaN
# 15         NaN          NaN            NaN
# 16         NaN          NaN            NaN
# 17         NaN          NaN            NaN
# 18         NaN          NaN            NaN
# 19         NaN          NaN            NaN
# 20         NaN          NaN            NaN
# 21         NaN          NaN            NaN
# 22         NaN          NaN            NaN
# 23         NaN          NaN            NaN
# 24         NaN          NaN            NaN
# 25         NaN          NaN            NaN
# 26         NaN          NaN            NaN
# 27         NaN          NaN            NaN
# 28         NaN          NaN            NaN
# 29         NaN          NaN            NaN
# 30         NaN          NaN            NaN
# 31         NaN          NaN            NaN
# 32         NaN          NaN            NaN
# 33         NaN          NaN            NaN
# 34         NaN          NaN            NaN

# %%
mapping = mapdf[['xtehr', 'zib']].merge(zibdf.add_suffix('_zib'), left_on='zib', right_on='path_zib', how='outer').merge(xlmdf.add_suffix('_xtehr'), left_on='xtehr', right_on='path_xtehr', how='outer')
mapping
# Out:
#                                                 xtehr  \
# 0                                      EHDSMedication
# 1                                EHDSMedication.batch
# 2                 EHDSMedication.batch.expirationDate
# 3                      EHDSMedication.batch.lotNumber
# 4                       EHDSMedication.characteristic
# 5                  EHDSMedication.characteristic.type
# 6              EHDSMedication.characteristic.value[x]
# 7                       EHDSMedication.classification
# 8                               EHDSMedication.device
# 9                EHDSMedication.device.deviceQuantity
# 10                    EHDSMedication.device.device[x]
# 11                            EHDSMedication.doseForm
# 12                  EHDSMedication.identifyingCode[x]
# 13                                EHDSMedication.item
# 14                         EHDSMedication.item.amount
# 15              EHDSMedication.item.containedQuantity
# 16                       EHDSMedication.item.doseForm
# 17                     EHDSMedication.item.ingredient
# 18            EHDSMedication.item.ingredient.isActive
# 19        EHDSMedication.item.ingredient.strengthInfo
# 20  EHDSMedication.item.ingredient.strengthInfo.ba...
# 21  EHDSMedication.item.ingredient.strengthInfo.st...
# 22           EHDSMedication.item.ingredient.substance
# 23                    EHDSMedication.item.packageType
# 24             EHDSMedication.item.unitOfPresentation
# 25        EHDSMedication.marketingAuthorisationHolder
# 26  EHDSMedication.marketingAuthorisationHolder.or...
# 27  EHDSMedication.marketingAuthorisationHolder.or...
# 28                            EHDSMedication.packSize
# 29                         EHDSMedication.productName
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
#
#                                                   zib               name_zib  \
# 0                               PharmaceuticalProduct  PharmaceuticalProduct
# 1                                                 NaN                    NaN
# 2                                                 NaN                    NaN
# 3   PharmaceuticalProduct.ProductSpecifications.Ba...        Batch/lotNumber
# 4                                                 NaN                    NaN
# 5                                                 NaN                    NaN
# 6                                                 NaN                    NaN
# 7                                                 NaN                    NaN
# 8                                                 NaN                    NaN
# 9                                                 NaN                    NaN
# 10                                                NaN                    NaN
# 11                                                NaN                    NaN
# 12               PharmaceuticalProduct.MedicationCode         MedicationCode
# 13                                                NaN                    NaN
# 14                                                NaN                    NaN
# 15  PharmaceuticalProduct.ProductSpecifications.In...          ProductAmount
# 16  PharmaceuticalProduct.ProductSpecifications.Ph...     PharmaceuticalForm
# 17  PharmaceuticalProduct.ProductSpecifications.In...             Ingredient
# 18                                                NaN                    NaN
# 19                                                NaN                    NaN
# 20                                                NaN                    NaN
# 21  PharmaceuticalProduct.ProductSpecifications.In...          Concentration
# 22  PharmaceuticalProduct.ProductSpecifications.In...          SubstanceCode
# 23                                                NaN                    NaN
# 24                                                NaN                    NaN
# 25                                                NaN                    NaN
# 26                                                NaN                    NaN
# 27                                                NaN                    NaN
# 28                                                NaN                    NaN
# 29  PharmaceuticalProduct.ProductSpecifications.Me...             Medication
# 30               PharmaceuticalProduct.MedicationCode         MedicationCode
# 31        PharmaceuticalProduct.ProductSpecifications  ProductSpecifications
# 32  PharmaceuticalProduct.ProductSpecifications.De...            Description
# 33  PharmaceuticalProduct.ProductSpecifications.In...       IngredientAmount
# 34  PharmaceuticalProduct.ProductSpecifications.Se...            SerieNumber
#
#                                              path_zib  \
# 0                               PharmaceuticalProduct
# 1                                                 NaN
# 2                                                 NaN
# 3   PharmaceuticalProduct.ProductSpecifications.Ba...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12               PharmaceuticalProduct.MedicationCode
# 13                                                NaN
# 14                                                NaN
# 15  PharmaceuticalProduct.ProductSpecifications.In...
# 16  PharmaceuticalProduct.ProductSpecifications.Ph...
# 17  PharmaceuticalProduct.ProductSpecifications.In...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  PharmaceuticalProduct.ProductSpecifications.In...
# 22  PharmaceuticalProduct.ProductSpecifications.In...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  PharmaceuticalProduct.ProductSpecifications.Me...
# 30               PharmaceuticalProduct.MedicationCode
# 31        PharmaceuticalProduct.ProductSpecifications
# 32  PharmaceuticalProduct.ProductSpecifications.De...
# 33  PharmaceuticalProduct.ProductSpecifications.In...
# 34  PharmaceuticalProduct.ProductSpecifications.Se...
#
#                     alias_zib type_zib card._zib stereotype_zib  \
# 0    NL: FarmaceutischProduct      NaN       NaN    rootconcept
# 1                         NaN      NaN       NaN            NaN
# 2                         NaN      NaN       NaN            NaN
# 3         NL: Batch/lotNummer       ST      0..1           data
# 4                         NaN      NaN       NaN            NaN
# 5                         NaN      NaN       NaN            NaN
# 6                         NaN      NaN       NaN            NaN
# 7                         NaN      NaN       NaN            NaN
# 8                         NaN      NaN       NaN            NaN
# 9                         NaN      NaN       NaN            NaN
# 10                        NaN      NaN       NaN            NaN
# 11                        NaN      NaN       NaN            NaN
# 12            NL: ProductCode       CD      0..1           data
# 13                        NaN      NaN       NaN            NaN
# 14                        NaN      NaN       NaN            NaN
# 15     NL: ProductHoeveelheid       PQ      0..1           data
# 16     NL: FarmaceutischeVorm       CD      0..1           data
# 17             NL: Ingredient      NaN      0..*      container
# 18                        NaN      NaN       NaN            NaN
# 19                        NaN      NaN       NaN            NaN
# 20                        NaN      NaN       NaN            NaN
# 21                NL: Sterkte      NaN      0..1      container
# 22         NL: IngredientCode       CD      0..1           data
# 23                        NaN      NaN       NaN            NaN
# 24                        NaN      NaN       NaN            NaN
# 25                        NaN      NaN       NaN            NaN
# 26                        NaN      NaN       NaN            NaN
# 27                        NaN      NaN       NaN            NaN
# 28                        NaN      NaN       NaN            NaN
# 29            NL: ProductNaam       ST      0..1           data
# 30            NL: ProductCode       CD      0..1           data
# 31    NL: ProductSpecificatie      NaN      0..1      container
# 32           NL: Omschrijving       ST      0..1           data
# 33  NL: IngredientHoeveelheid       PQ      0..1           data
# 34            NL: SerieNummer       ST      0..1           data
#
#              id_zib                                     definition_zib  \
# 0   NL-CM:9.7.19926  Root concept of the PharmaceuticalProduct part...
# 1               NaN                                                NaN
# 2               NaN                                                NaN
# 3   NL-CM:9.7.22279  The batch/lot number provides a unique identif...
# 4               NaN                                                NaN
# 5               NaN                                                NaN
# 6               NaN                                                NaN
# 7               NaN                                                NaN
# 8               NaN                                                NaN
# 9               NaN                                                NaN
# 10              NaN                                                NaN
# 11              NaN                                                NaN
# 12  NL-CM:9.7.19927  Coding medication in the Netherlands is done o...
# 13              NaN                                                NaN
# 14              NaN                                                NaN
# 15  NL-CM:9.7.22278  Amount of the product. This is the denominator...
# 16  NL-CM:9.7.19931  The pharmaceutical form indicates the form of ...
# 17  NL-CM:9.7.19932  Container of the Ingredient concept. This cont...
# 18              NaN                                                NaN
# 19              NaN                                                NaN
# 20              NaN                                                NaN
# 21  NL-CM:9.7.19933  The relative amount of this ingredient in this...
# 22  NL-CM:9.7.19934  Active substance or excipient. \nHere, the sam...
# 23              NaN                                                NaN
# 24              NaN                                                NaN
# 25              NaN                                                NaN
# 26              NaN                                                NaN
# 27              NaN                                                NaN
# 28              NaN                                                NaN
# 29  NL-CM:9.7.19929  For medication which has no code, enter the co...
# 30  NL-CM:9.7.19927  Coding medication in the Netherlands is done o...
# 31  NL-CM:9.7.19928  Container of the ProductSpecifications concept...
# 32  NL-CM:9.7.19784  A textual description of the type of medicatio...
# 33  NL-CM:9.7.22277  The amount and unit of this ingredient. This i...
# 34  NL-CM:9.7.22280  The serial number uniquely identifies the sour...
#
#     definitioncode_zib                                           id_xtehr  \
# 0                  NaN                                     EHDSMedication
# 1                  NaN                               EHDSMedication.batch
# 2                  NaN                EHDSMedication.batch.expirationDate
# 3                  NaN                     EHDSMedication.batch.lotNumber
# 4                  NaN                      EHDSMedication.characteristic
# 5                  NaN                 EHDSMedication.characteristic.type
# 6                  NaN             EHDSMedication.characteristic.value[x]
# 7                  NaN                      EHDSMedication.classification
# 8                  NaN                              EHDSMedication.device
# 9                  NaN               EHDSMedication.device.deviceQuantity
# 10                 NaN                    EHDSMedication.device.device[x]
# 11                 NaN                            EHDSMedication.doseForm
# 12                 NaN                  EHDSMedication.identifyingCode[x]
# 13                 NaN                                EHDSMedication.item
# 14                 NaN                         EHDSMedication.item.amount
# 15                 NaN              EHDSMedication.item.containedQuantity
# 16                 NaN                       EHDSMedication.item.doseForm
# 17                 NaN                     EHDSMedication.item.ingredient
# 18                 NaN            EHDSMedication.item.ingredient.isActive
# 19                 NaN        EHDSMedication.item.ingredient.strengthInfo
# 20                 NaN  EHDSMedication.item.ingredient.strengthInfo.ba...
# 21                 NaN  EHDSMedication.item.ingredient.strengthInfo.st...
# 22                 NaN           EHDSMedication.item.ingredient.substance
# 23                 NaN                    EHDSMedication.item.packageType
# 24                 NaN             EHDSMedication.item.unitOfPresentation
# 25                 NaN        EHDSMedication.marketingAuthorisationHolder
# 26                 NaN  EHDSMedication.marketingAuthorisationHolder.or...
# 27                 NaN  EHDSMedication.marketingAuthorisationHolder.or...
# 28                 NaN                            EHDSMedication.packSize
# 29                 NaN                         EHDSMedication.productName
# 30                 NaN                                                NaN
# 31                 NaN                                                NaN
# 32                 NaN                                                NaN
# 33                 NaN                                                NaN
# 34                 NaN                                                NaN
#
#                                            path_xtehr  \
# 0                                      EHDSMedication
# 1                                EHDSMedication.batch
# 2                 EHDSMedication.batch.expirationDate
# 3                      EHDSMedication.batch.lotNumber
# 4                       EHDSMedication.characteristic
# 5                  EHDSMedication.characteristic.type
# 6              EHDSMedication.characteristic.value[x]
# 7                       EHDSMedication.classification
# 8                               EHDSMedication.device
# 9                EHDSMedication.device.deviceQuantity
# 10                    EHDSMedication.device.device[x]
# 11                            EHDSMedication.doseForm
# 12                  EHDSMedication.identifyingCode[x]
# 13                                EHDSMedication.item
# 14                         EHDSMedication.item.amount
# 15              EHDSMedication.item.containedQuantity
# 16                       EHDSMedication.item.doseForm
# 17                     EHDSMedication.item.ingredient
# 18            EHDSMedication.item.ingredient.isActive
# 19        EHDSMedication.item.ingredient.strengthInfo
# 20  EHDSMedication.item.ingredient.strengthInfo.ba...
# 21  EHDSMedication.item.ingredient.strengthInfo.st...
# 22           EHDSMedication.item.ingredient.substance
# 23                    EHDSMedication.item.packageType
# 24             EHDSMedication.item.unitOfPresentation
# 25        EHDSMedication.marketingAuthorisationHolder
# 26  EHDSMedication.marketingAuthorisationHolder.or...
# 27  EHDSMedication.marketingAuthorisationHolder.or...
# 28                            EHDSMedication.packSize
# 29                         EHDSMedication.productName
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
#
#                                           short_xtehr  \
# 0                                    Medication model
# 1   Batch information of a medicinal product. Typi...
# 2     Batch expiration date of the medicinal product.
# 3           Batch identifier of the medicinal product
# 4                       Other features of the product
# 5        A code expressing the type of characteristic
# 6                   Description of the characteristic
# 7   Classification (e.g. ATC; narcotic/psychotropi...
# 8       Administration device included in the product
# 9                              Number of such devices
# 10                                       Device coded
# 11  Dose form(s) on a product level. Dose form for...
# 12  Identifier or code for the product (virtual pr...
# 13  A medication item. For combination packs, this...
# 14  Number of such manufactured items in this prod...
# 15  Manufactured item quantity for liquids (3ml / ...
# 16                                          Dose form
# 17                                        Ingredients
# 18  Marks if the ingredient is considered an activ...
# 19  Strength of the product - amount of substance ...
# 20  Substance that the strength refers to, in case...
# 21  Concentration or presentation strength, e.g 10...
# 22                                          Substance
# 23             Type of package of the medication item
# 24  Unit of presentation for the manufactured item...
# 25  Marketing authorisation holder or manufacturer...
# 26  Identifier of the organisation and/or its phys...
# 27  Name of the organisation holding the authorisa...
# 28  Overall amount of product in one package (100m...
# 29  Name of the product (full name, invented name,...
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
#
#                                      definition_xtehr       type_xtehr  \
# 0   Logical model for prescribed/dispensed medicat...              NaN
# 1   Batch information of a medicinal product. Typi...             Base
# 2     Batch expiration date of the medicinal product.         dateTime
# 3           Batch identifier of the medicinal product           string
# 4                       Other features of the product             Base
# 5        A code expressing the type of characteristic  CodeableConcept
# 6                   Description of the characteristic          boolean
# 7   Classification (e.g. ATC; narcotic/psychotropi...  CodeableConcept
# 8       Administration device included in the product             Base
# 9                              Number of such devices         Quantity
# 10                                       Device coded  CodeableConcept
# 11  Dose form(s) on a product level. Dose form for...  CodeableConcept
# 12  Identifier or code for the product (virtual pr...  CodeableConcept
# 13  A medication item. For combination packs, this...             Base
# 14  Number of such manufactured items in this prod...         Quantity
# 15  Manufactured item quantity for liquids (3ml / ...            Ratio
# 16                                          Dose form  CodeableConcept
# 17                                        Ingredients             Base
# 18  Marks if the ingredient is considered an activ...          boolean
# 19  Strength of the product - amount of substance ...             Base
# 20  Substance that the strength refers to, in case...  CodeableConcept
# 21  Concentration or presentation strength, e.g 10...            Ratio
# 22                                          Substance  CodeableConcept
# 23             Type of package of the medication item  CodeableConcept
# 24  Unit of presentation for the manufactured item...  CodeableConcept
# 25  Marketing authorisation holder or manufacturer...             Base
# 26  Identifier of the organisation and/or its phys...       Identifier
# 27  Name of the organisation holding the authorisa...           string
# 28  Overall amount of product in one package (100m...         Quantity
# 29  Name of the product (full name, invented name,...           string
# 30                                                NaN              NaN
# 31                                                NaN              NaN
# 32                                                NaN              NaN
# 33                                                NaN              NaN
# 34                                                NaN              NaN
#
#    card._xtehr                                      binding_xtehr
# 0         0..*                                                NaN
# 1         0..1                                                NaN
# 2         0..1                                                NaN
# 3         0..1                                                NaN
# 4         0..*                                                NaN
# 5         1..1                                                NaN
# 6         0..1                                                NaN
# 7         0..*  {'strength': 'preferred', 'description': 'WHO ...
# 8         0..*                                                NaN
# 9         1..1                                                NaN
# 10        1..1                                                NaN
# 11        0..1  {'strength': 'preferred', 'description': 'EDQM...
# 12        0..*                                                NaN
# 13        0..*                                                NaN
# 14        0..1  {'strength': 'preferred', 'description': 'UCUM...
# 15        0..1                                                NaN
# 16        0..1  {'strength': 'preferred', 'description': 'EDQM...
# 17        1..*                                                NaN
# 18        0..1                                                NaN
# 19        0..1                                                NaN
# 20        0..1  {'strength': 'preferred', 'description': 'EMA ...
# 21        1..1                                                NaN
# 22        1..1  {'strength': 'preferred', 'description': 'EMA ...
# 23        0..1  {'strength': 'preferred', 'description': 'EDQM...
# 24        0..1  {'strength': 'preferred', 'description': 'EDQM...
# 25        0..1                                                NaN
# 26        0..*                                                NaN
# 27        0..1                                                NaN
# 28        0..*  {'strength': 'preferred', 'description': 'UCUM...
# 29        0..1                                                NaN
# 30         NaN                                                NaN
# 31         NaN                                                NaN
# 32         NaN                                                NaN
# 33         NaN                                                NaN
# 34         NaN                                                NaN

# %%
shortmap = mapping[['zib', 'xtehr', 'type_zib','type_xtehr', 'card._zib', 'card._xtehr']]
shortmap
# Out:
#                                                   zib  \
# 0                               PharmaceuticalProduct
# 1                                                 NaN
# 2                                                 NaN
# 3   PharmaceuticalProduct.ProductSpecifications.Ba...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12               PharmaceuticalProduct.MedicationCode
# 13                                                NaN
# 14                                                NaN
# 15  PharmaceuticalProduct.ProductSpecifications.In...
# 16  PharmaceuticalProduct.ProductSpecifications.Ph...
# 17  PharmaceuticalProduct.ProductSpecifications.In...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  PharmaceuticalProduct.ProductSpecifications.In...
# 22  PharmaceuticalProduct.ProductSpecifications.In...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  PharmaceuticalProduct.ProductSpecifications.Me...
# 30               PharmaceuticalProduct.MedicationCode
# 31        PharmaceuticalProduct.ProductSpecifications
# 32  PharmaceuticalProduct.ProductSpecifications.De...
# 33  PharmaceuticalProduct.ProductSpecifications.In...
# 34  PharmaceuticalProduct.ProductSpecifications.Se...
#
#                                                 xtehr type_zib  \
# 0                                      EHDSMedication      NaN
# 1                                EHDSMedication.batch      NaN
# 2                 EHDSMedication.batch.expirationDate      NaN
# 3                      EHDSMedication.batch.lotNumber       ST
# 4                       EHDSMedication.characteristic      NaN
# 5                  EHDSMedication.characteristic.type      NaN
# 6              EHDSMedication.characteristic.value[x]      NaN
# 7                       EHDSMedication.classification      NaN
# 8                               EHDSMedication.device      NaN
# 9                EHDSMedication.device.deviceQuantity      NaN
# 10                    EHDSMedication.device.device[x]      NaN
# 11                            EHDSMedication.doseForm      NaN
# 12                  EHDSMedication.identifyingCode[x]       CD
# 13                                EHDSMedication.item      NaN
# 14                         EHDSMedication.item.amount      NaN
# 15              EHDSMedication.item.containedQuantity       PQ
# 16                       EHDSMedication.item.doseForm       CD
# 17                     EHDSMedication.item.ingredient      NaN
# 18            EHDSMedication.item.ingredient.isActive      NaN
# 19        EHDSMedication.item.ingredient.strengthInfo      NaN
# 20  EHDSMedication.item.ingredient.strengthInfo.ba...      NaN
# 21  EHDSMedication.item.ingredient.strengthInfo.st...      NaN
# 22           EHDSMedication.item.ingredient.substance       CD
# 23                    EHDSMedication.item.packageType      NaN
# 24             EHDSMedication.item.unitOfPresentation      NaN
# 25        EHDSMedication.marketingAuthorisationHolder      NaN
# 26  EHDSMedication.marketingAuthorisationHolder.or...      NaN
# 27  EHDSMedication.marketingAuthorisationHolder.or...      NaN
# 28                            EHDSMedication.packSize      NaN
# 29                         EHDSMedication.productName       ST
# 30                                                NaN       CD
# 31                                                NaN      NaN
# 32                                                NaN       ST
# 33                                                NaN       PQ
# 34                                                NaN       ST
#
#          type_xtehr card._zib card._xtehr
# 0               NaN       NaN        0..*
# 1              Base       NaN        0..1
# 2          dateTime       NaN        0..1
# 3            string      0..1        0..1
# 4              Base       NaN        0..*
# 5   CodeableConcept       NaN        1..1
# 6           boolean       NaN        0..1
# 7   CodeableConcept       NaN        0..*
# 8              Base       NaN        0..*
# 9          Quantity       NaN        1..1
# 10  CodeableConcept       NaN        1..1
# 11  CodeableConcept       NaN        0..1
# 12  CodeableConcept      0..1        0..*
# 13             Base       NaN        0..*
# 14         Quantity       NaN        0..1
# 15            Ratio      0..1        0..1
# 16  CodeableConcept      0..1        0..1
# 17             Base      0..*        1..*
# 18          boolean       NaN        0..1
# 19             Base       NaN        0..1
# 20  CodeableConcept       NaN        0..1
# 21            Ratio      0..1        1..1
# 22  CodeableConcept      0..1        1..1
# 23  CodeableConcept       NaN        0..1
# 24  CodeableConcept       NaN        0..1
# 25             Base       NaN        0..1
# 26       Identifier       NaN        0..*
# 27           string       NaN        0..1
# 28         Quantity       NaN        0..*
# 29           string      0..1        0..1
# 30              NaN      0..1         NaN
# 31              NaN      0..1         NaN
# 32              NaN      0..1         NaN
# 33              NaN      0..1         NaN
# 34              NaN      0..1         NaN

# %%
mapsoutpath = os.path.join(mapbase, 'xtehr2zibs2024')
filepath = file.replace('.xlsx', '-full.xlsx')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_excel(mappath, index=False)

# %%
filepath = file.replace('.xlsx', '.csv')
mappath = os.path.join(mapsoutpath, filepath)
mapping.to_csv(mappath, index=False)

# %%
from IPython.display import Markdown
import numpy as np

content = "# " + mapping.iat[0, 0][4:] + "\n\n"

# shortmap: linefeeds naar <br> vlak vóór to_markdown
shortmap_md = shortmap.fillna('').map(
    lambda x: x.replace("\r\n", "<br>").replace("\n", "<br>") if isinstance(x, str) else x
)
content += shortmap_md.to_markdown(index=False) + "\n\n"

for i, row in mapping.iterrows():
    content += "\n\n"
    if row.iloc[0] is not np.nan:  # desgewenst: gebruik pd.notna(row.iloc[0])
        content += "## " + str(row.iloc[0]) + "\n\n"
    else:
        content += "## zib: " + str(row.iloc[1]) + "\n\n"

    content += "### Table" + "\n\n"
    content += "| attribute | value |\n|---|---|\n"

    # Eerste 2 kolommen
    for j, att in row.fillna('')[0:2].items():
        content += "| " + str(j) + " | " + (att.replace("\r\n","<br>").replace("\n","<br>") if isinstance(att, str) else str(att)) + " |\n" 

    # Rest, gesorteerd
    for j, att in row.fillna('')[2:].sort_index().items():
        if len(str(att)) > 0:
            content += "| " + str(j) + " | " + (att.replace("\r\n","<br>").replace("\n","<br>") if isinstance(att, str) else str(att)) + " |\n"

    content += "\n### Comments\n\n"

with open(os.path.join(mapsoutpath, file.replace('.xlsx', '.md')), 'w') as f:
    f.write(content)

# PAS OP: deze overschrijft de evt. handmatige comments; alleen bij eerste keer mapping
# with open(os.path.join(mapsoutpath, file.replace('.xlsx', '-comments.md')), 'w') as f:
#     f.write(content)

Markdown(content)
# Out:
# # Medication
#
# | zib                                                                                   | xtehr                                                                | type_zib   | type_xtehr      | card._zib   | card._xtehr   |
# |:--------------------------------------------------------------------------------------|:---------------------------------------------------------------------|:-----------|:----------------|:------------|:--------------|
# | PharmaceuticalProduct                                                                 | EHDSMedication                                                       |            |                 |             | 0..*          |
# |                                                                                       | EHDSMedication.batch                                                 |            | Base            |             | 0..1          |
# |                                                                                       | EHDSMedication.batch.expirationDate                                  |            | dateTime        |             | 0..1          |
# | PharmaceuticalProduct.ProductSpecifications.Batch/lotNumber                           | EHDSMedication.batch.lotNumber                                       | ST         | string          | 0..1        | 0..1          |
# |                                                                                       | EHDSMedication.characteristic                                        |            | Base            |             | 0..*          |
# |                                                                                       | EHDSMedication.characteristic.type                                   |            | CodeableConcept |             | 1..1          |
# |                                                                                       | EHDSMedication.characteristic.value[x]                               |            | boolean         |             | 0..1          |
# |                                                                                       | EHDSMedication.classification                                        |            | CodeableConcept |             | 0..*          |
# |                                                                                       | EHDSMedication.device                                                |            | Base            |             | 0..*          |
# |                                                                                       | EHDSMedication.device.deviceQuantity                                 |            | Quantity        |             | 1..1          |
# |                                                                                       | EHDSMedication.device.device[x]                                      |            | CodeableConcept |             | 1..1          |
# |                                                                                       | EHDSMedication.doseForm                                              |            | CodeableConcept |             | 0..1          |
# | PharmaceuticalProduct.MedicationCode                                                  | EHDSMedication.identifyingCode[x]                                    | CD         | CodeableConcept | 0..1        | 0..*          |
# |                                                                                       | EHDSMedication.item                                                  |            | Base            |             | 0..*          |
# |                                                                                       | EHDSMedication.item.amount                                           |            | Quantity        |             | 0..1          |
# | PharmaceuticalProduct.ProductSpecifications.Ingredient.Concentration.ProductAmount    | EHDSMedication.item.containedQuantity                                | PQ         | Ratio           | 0..1        | 0..1          |
# | PharmaceuticalProduct.ProductSpecifications.PharmaceuticalForm                        | EHDSMedication.item.doseForm                                         | CD         | CodeableConcept | 0..1        | 0..1          |
# | PharmaceuticalProduct.ProductSpecifications.Ingredient                                | EHDSMedication.item.ingredient                                       |            | Base            | 0..*        | 1..*          |
# |                                                                                       | EHDSMedication.item.ingredient.isActive                              |            | boolean         |             | 0..1          |
# |                                                                                       | EHDSMedication.item.ingredient.strengthInfo                          |            | Base            |             | 0..1          |
# |                                                                                       | EHDSMedication.item.ingredient.strengthInfo.basisOfStrengthSubstance |            | CodeableConcept |             | 0..1          |
# | PharmaceuticalProduct.ProductSpecifications.Ingredient.Concentration                  | EHDSMedication.item.ingredient.strengthInfo.strength                 |            | Ratio           | 0..1        | 1..1          |
# | PharmaceuticalProduct.ProductSpecifications.Ingredient.SubstanceCode                  | EHDSMedication.item.ingredient.substance                             | CD         | CodeableConcept | 0..1        | 1..1          |
# |                                                                                       | EHDSMedication.item.packageType                                      |            | CodeableConcept |             | 0..1          |
# |                                                                                       | EHDSMedication.item.unitOfPresentation                               |            | CodeableConcept |             | 0..1          |
# |                                                                                       | EHDSMedication.marketingAuthorisationHolder                          |            | Base            |             | 0..1          |
# |                                                                                       | EHDSMedication.marketingAuthorisationHolder.organisationIdentifier   |            | Identifier      |             | 0..*          |
# |                                                                                       | EHDSMedication.marketingAuthorisationHolder.organisationName         |            | string          |             | 0..1          |
# |                                                                                       | EHDSMedication.packSize                                              |            | Quantity        |             | 0..*          |
# | PharmaceuticalProduct.ProductSpecifications.Medication                                | EHDSMedication.productName                                           | ST         | string          | 0..1        | 0..1          |
# | PharmaceuticalProduct.MedicationCode                                                  |                                                                      | CD         |                 | 0..1        |               |
# | PharmaceuticalProduct.ProductSpecifications                                           |                                                                      |            |                 | 0..1        |               |
# | PharmaceuticalProduct.ProductSpecifications.Description                               |                                                                      | ST         |                 | 0..1        |               |
# | PharmaceuticalProduct.ProductSpecifications.Ingredient.Concentration.IngredientAmount |                                                                      | PQ         |                 | 0..1        |               |
# | PharmaceuticalProduct.ProductSpecifications.SerieNumber                               |                                                                      | ST         |                 | 0..1        |               |
#
#
#
# ## EHDSMedication
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication |
# | zib | PharmaceuticalProduct |
# | alias_zib | NL: FarmaceutischProduct |
# | card._xtehr | 0..* |
# | definition_xtehr | Logical model for prescribed/dispensed medication. The model is shared by statements, requests, dispensations, and treatment lines. Each of those may have different restrictions in FHIR profile. Model is suitable for generic/virtual medications as well as branded/real products. |
# | definition_zib | Root concept of the PharmaceuticalProduct partial information model. This root concept contains all data elements of the PharmaceuticalProduct partial information model. |
# | id_xtehr | EHDSMedication |
# | id_zib | NL-CM:9.7.19926 |
# | name_zib | PharmaceuticalProduct |
# | path_xtehr | EHDSMedication |
# | path_zib | PharmaceuticalProduct |
# | short_xtehr | Medication model |
# | stereotype_zib | rootconcept |
#
# ### Comments
#
#
#
# ## EHDSMedication.batch
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.batch |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Batch information of a medicinal product. Typically recorded during dispense or administration, rarely known or relevant for a prescription/request. |
# | id_xtehr | EHDSMedication.batch |
# | path_xtehr | EHDSMedication.batch |
# | short_xtehr | Batch information of a medicinal product. Typically recorded during dispense or administration, rarely known or relevant for a prescription/request. |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSMedication.batch.expirationDate
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.batch.expirationDate |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Batch expiration date of the medicinal product. |
# | id_xtehr | EHDSMedication.batch.expirationDate |
# | path_xtehr | EHDSMedication.batch.expirationDate |
# | short_xtehr | Batch expiration date of the medicinal product. |
# | type_xtehr | dateTime |
#
# ### Comments
#
#
#
# ## EHDSMedication.batch.lotNumber
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.batch.lotNumber |
# | zib | PharmaceuticalProduct.ProductSpecifications.Batch/lotNumber |
# | alias_zib | NL: Batch/lotNummer |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Batch identifier of the medicinal product |
# | definition_zib | The batch/lot number provides a unique identification of the origin of information such as the production batch or machine number. The number is constructed according to the GS1 standard AI(10).( https://www.gs1.nl/sectorafspraken-over-standaarden/unieke-identificatie-en-productdata-gezondheidszorg/gs1-barcodes-2#application-identifiers-ais ) |
# | id_xtehr | EHDSMedication.batch.lotNumber |
# | id_zib | NL-CM:9.7.22279 |
# | name_zib | Batch/lotNumber |
# | path_xtehr | EHDSMedication.batch.lotNumber |
# | path_zib | PharmaceuticalProduct.ProductSpecifications.Batch/lotNumber |
# | short_xtehr | Batch identifier of the medicinal product |
# | stereotype_zib | data |
# | type_xtehr | string |
# | type_zib | ST |
#
# ### Comments
#
#
#
# ## EHDSMedication.characteristic
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.characteristic |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | Other features of the product |
# | id_xtehr | EHDSMedication.characteristic |
# | path_xtehr | EHDSMedication.characteristic |
# | short_xtehr | Other features of the product |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSMedication.characteristic.type
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.characteristic.type |
# | zib |  |
# | card._xtehr | 1..1 |
# | definition_xtehr | A code expressing the type of characteristic |
# | id_xtehr | EHDSMedication.characteristic.type |
# | path_xtehr | EHDSMedication.characteristic.type |
# | short_xtehr | A code expressing the type of characteristic |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSMedication.characteristic.value[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.characteristic.value[x] |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Description of the characteristic |
# | id_xtehr | EHDSMedication.characteristic.value[x] |
# | path_xtehr | EHDSMedication.characteristic.value[x] |
# | short_xtehr | Description of the characteristic |
# | type_xtehr | boolean |
#
# ### Comments
#
#
#
# ## EHDSMedication.classification
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.classification |
# | zib |  |
# | binding_xtehr | {'strength': 'preferred', 'description': 'WHO ATC'} |
# | card._xtehr | 0..* |
# | definition_xtehr | Classification (e.g. ATC; narcotic/psychotropic; orphan drug; etc.) |
# | id_xtehr | EHDSMedication.classification |
# | path_xtehr | EHDSMedication.classification |
# | short_xtehr | Classification (e.g. ATC; narcotic/psychotropic; orphan drug; etc.) |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSMedication.device
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.device |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | Administration device included in the product |
# | id_xtehr | EHDSMedication.device |
# | path_xtehr | EHDSMedication.device |
# | short_xtehr | Administration device included in the product |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSMedication.device.deviceQuantity
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.device.deviceQuantity |
# | zib |  |
# | card._xtehr | 1..1 |
# | definition_xtehr | Number of such devices |
# | id_xtehr | EHDSMedication.device.deviceQuantity |
# | path_xtehr | EHDSMedication.device.deviceQuantity |
# | short_xtehr | Number of such devices |
# | type_xtehr | Quantity |
#
# ### Comments
#
#
#
# ## EHDSMedication.device.device[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.device.device[x] |
# | zib |  |
# | card._xtehr | 1..1 |
# | definition_xtehr | Device coded |
# | id_xtehr | EHDSMedication.device.device[x] |
# | path_xtehr | EHDSMedication.device.device[x] |
# | short_xtehr | Device coded |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSMedication.doseForm
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.doseForm |
# | zib |  |
# | binding_xtehr | {'strength': 'preferred', 'description': 'EDQM Standard Terms'} |
# | card._xtehr | 0..1 |
# | definition_xtehr | Dose form(s) on a product level. Dose form for a single package item is defined below. |
# | id_xtehr | EHDSMedication.doseForm |
# | path_xtehr | EHDSMedication.doseForm |
# | short_xtehr | Dose form(s) on a product level. Dose form for a single package item is defined below. |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSMedication.identifyingCode[x]
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.identifyingCode[x] |
# | zib | PharmaceuticalProduct.MedicationCode |
# | alias_zib | NL: ProductCode |
# | card._xtehr | 0..* |
# | card._zib | 0..1 |
# | definition_xtehr | Identifier or code for the product (virtual product, branded product or package). If several identifiers are specified, they shall not have conflicting meanings or very different granularities. |
# | definition_zib | Coding medication in the Netherlands is done on the basis of the G standard (issued by Z index), which is filled under the direction of KNMP. <br>The coded medication can be expressed as:<br>-  Global Trade Item Number (GTIN) <br>-  Z index number (ZI number) <br>-  Trade product code (HPK) <br>-  Prescription code (PRK) <br>-  Generic product code (GPK) <br>-  Anatomic Therapeutic Classification code (ATC) <br>-  SNOMED CT code<br>The GTIN enables identification of the product including its origin with a barcode.<br>The ZI number represents the trade product and the package size. <br>The HPK is the code for the trade product (with the brand name) as used per dose/per time the medication is taken (1 pill, 1 puff, 1ml).<br>The PRK contains als GPK information supplemented with information needed to prescribe the right product. This level is intended to facilitate generic prescription of drugs. <br>The GPK defines the pharmaceutical characteristics of a product: ingredients, strengths, units, pharmaceutical form and route of administration. <br>The Substance Name Code (SNK) is the (active) compound. <br>Further information about the G Standaard levels see https://www.z-index.nl .<br>So-called 90.000.000 numbers are used in local IT systems. These numbers shall not be used for external communication. In this case only the description (not the code) may be included. This is in accordance with national agreements (Nictiz Standard).<br><br><br>SNOMED CT can be used as an alternative coding of a pharmaceutical product, it is used, for example, to more generically describe vaccinations from the National Vaccination Programme based on the combination of substances (e.g. DKTP vaccine). For vaccines registered in the past, a code from the G-standard is not always present, but it is recommended to record it for current processing. In addition, the SNOMED CT code can be registered as an alternative for the same product. |
# | id_xtehr | EHDSMedication.identifyingCode[x] |
# | id_zib | NL-CM:9.7.19927 |
# | name_zib | MedicationCode |
# | path_xtehr | EHDSMedication.identifyingCode[x] |
# | path_zib | PharmaceuticalProduct.MedicationCode |
# | short_xtehr | Identifier or code for the product (virtual product, branded product or package). If several identifiers are specified, they shall not have conflicting meanings or very different granularities. |
# | stereotype_zib | data |
# | type_xtehr | CodeableConcept |
# | type_zib | CD |
#
# ### Comments
#
#
#
# ## EHDSMedication.item
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.item |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | A medication item. For combination packs, this can be manufactured items with each item having its own dose form and ingredients+strengths defined |
# | id_xtehr | EHDSMedication.item |
# | path_xtehr | EHDSMedication.item |
# | short_xtehr | A medication item. For combination packs, this can be manufactured items with each item having its own dose form and ingredients+strengths defined |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSMedication.item.amount
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.item.amount |
# | zib |  |
# | binding_xtehr | {'strength': 'preferred', 'description': 'UCUM for units of measure. EDQM Standard Terms for units of presentation.'} |
# | card._xtehr | 0..1 |
# | definition_xtehr | Number of such manufactured items in this product (5 vials) |
# | id_xtehr | EHDSMedication.item.amount |
# | path_xtehr | EHDSMedication.item.amount |
# | short_xtehr | Number of such manufactured items in this product (5 vials) |
# | type_xtehr | Quantity |
#
# ### Comments
#
#
#
# ## EHDSMedication.item.containedQuantity
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.item.containedQuantity |
# | zib | PharmaceuticalProduct.ProductSpecifications.Ingredient.Concentration.ProductAmount |
# | alias_zib | NL: ProductHoeveelheid |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Manufactured item quantity for liquids (3ml / 1 vial) |
# | definition_zib | Amount of the product. This is the denominator for the calculation of the concentration. Optionally a translation to NHG table Gebruiksvoorschriften (Table 25) is also allowed. |
# | id_xtehr | EHDSMedication.item.containedQuantity |
# | id_zib | NL-CM:9.7.22278 |
# | name_zib | ProductAmount |
# | path_xtehr | EHDSMedication.item.containedQuantity |
# | path_zib | PharmaceuticalProduct.ProductSpecifications.Ingredient.Concentration.ProductAmount |
# | short_xtehr | Manufactured item quantity for liquids (3ml / 1 vial) |
# | stereotype_zib | data |
# | type_xtehr | Ratio |
# | type_zib | PQ |
#
# ### Comments
#
#
#
# ## EHDSMedication.item.doseForm
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.item.doseForm |
# | zib | PharmaceuticalProduct.ProductSpecifications.PharmaceuticalForm |
# | alias_zib | NL: FarmaceutischeVorm |
# | binding_xtehr | {'strength': 'preferred', 'description': 'EDQM Standard Terms'} |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Dose form |
# | definition_zib | The pharmaceutical form indicates the form of the medication. Examples include: tablet, suppository, infusion liquid, ointment. If the product has a GPK code in the G standard, the form will be known in the G standard. For products without a code (free text, preparation by the pharmacy), the means of administration can be entered. |
# | id_xtehr | EHDSMedication.item.doseForm |
# | id_zib | NL-CM:9.7.19931 |
# | name_zib | PharmaceuticalForm |
# | path_xtehr | EHDSMedication.item.doseForm |
# | path_zib | PharmaceuticalProduct.ProductSpecifications.PharmaceuticalForm |
# | short_xtehr | Dose form |
# | stereotype_zib | data |
# | type_xtehr | CodeableConcept |
# | type_zib | CD |
#
# ### Comments
#
#
#
# ## EHDSMedication.item.ingredient
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.item.ingredient |
# | zib | PharmaceuticalProduct.ProductSpecifications.Ingredient |
# | alias_zib | NL: Ingredient |
# | card._xtehr | 1..* |
# | card._zib | 0..* |
# | definition_xtehr | Ingredients |
# | definition_zib | Container of the Ingredient concept. This container contains all data elements of the Ingredient concept. <br>A product contains one or more active substances and excipients. These are usually determined by the product code. For medication prepared or compounded by the local pharmacy, each ingredient must be entered separately. <br><br>The active substances play an important role, as they: <br>a) determine the pharmacotherapeutic effect of the medication and <br>b) serve as the basis for the indication of the strength of the medication (e.g. 200 mg). |
# | id_xtehr | EHDSMedication.item.ingredient |
# | id_zib | NL-CM:9.7.19932 |
# | name_zib | Ingredient |
# | path_xtehr | EHDSMedication.item.ingredient |
# | path_zib | PharmaceuticalProduct.ProductSpecifications.Ingredient |
# | short_xtehr | Ingredients |
# | stereotype_zib | container |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSMedication.item.ingredient.isActive
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.item.ingredient.isActive |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Marks if the ingredient is considered an active ingredient. Typically excipients are not needed, so by default active ingredients are expected. |
# | id_xtehr | EHDSMedication.item.ingredient.isActive |
# | path_xtehr | EHDSMedication.item.ingredient.isActive |
# | short_xtehr | Marks if the ingredient is considered an active ingredient. Typically excipients are not needed, so by default active ingredients are expected. |
# | type_xtehr | boolean |
#
# ### Comments
#
#
#
# ## EHDSMedication.item.ingredient.strengthInfo
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.item.ingredient.strengthInfo |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Strength of the product - amount of substance per unit |
# | id_xtehr | EHDSMedication.item.ingredient.strengthInfo |
# | path_xtehr | EHDSMedication.item.ingredient.strengthInfo |
# | short_xtehr | Strength of the product - amount of substance per unit |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSMedication.item.ingredient.strengthInfo.basisOfStrengthSubstance
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.item.ingredient.strengthInfo.basisOfStrengthSubstance |
# | zib |  |
# | binding_xtehr | {'strength': 'preferred', 'description': 'EMA SPOR SMS'} |
# | card._xtehr | 0..1 |
# | definition_xtehr | Substance that the strength refers to, in case it's different from the main substance |
# | id_xtehr | EHDSMedication.item.ingredient.strengthInfo.basisOfStrengthSubstance |
# | path_xtehr | EHDSMedication.item.ingredient.strengthInfo.basisOfStrengthSubstance |
# | short_xtehr | Substance that the strength refers to, in case it's different from the main substance |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSMedication.item.ingredient.strengthInfo.strength
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.item.ingredient.strengthInfo.strength |
# | zib | PharmaceuticalProduct.ProductSpecifications.Ingredient.Concentration |
# | alias_zib | NL: Sterkte |
# | card._xtehr | 1..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Concentration or presentation strength, e.g 100mg/1ml or 500mg per 1 tablet |
# | definition_zib | The relative amount of this ingredient in this product.  <br>Calculation of Concentration = Ingredient Amount ÷ Product Amount. <br> <br>This could be a concentration if the medication is dissolved in liquid, for example. |
# | id_xtehr | EHDSMedication.item.ingredient.strengthInfo.strength |
# | id_zib | NL-CM:9.7.19933 |
# | name_zib | Concentration |
# | path_xtehr | EHDSMedication.item.ingredient.strengthInfo.strength |
# | path_zib | PharmaceuticalProduct.ProductSpecifications.Ingredient.Concentration |
# | short_xtehr | Concentration or presentation strength, e.g 100mg/1ml or 500mg per 1 tablet |
# | stereotype_zib | container |
# | type_xtehr | Ratio |
#
# ### Comments
#
#
#
# ## EHDSMedication.item.ingredient.substance
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.item.ingredient.substance |
# | zib | PharmaceuticalProduct.ProductSpecifications.Ingredient.SubstanceCode |
# | alias_zib | NL: IngredientCode |
# | binding_xtehr | {'strength': 'preferred', 'description': 'EMA SPOR SMS'} |
# | card._xtehr | 1..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Substance |
# | definition_zib | Active substance or excipient. <br>Here, the same codes can be used as for the ProductCode (for dilutions and compounds in particular), but now, the SSK and SNK codes can also be used to indicate a substance (to list ingredients of local products prepared by the pharmacy).<br>-  GTIN International Article Number <br>-  Z-index number (ZI-number) <br>-  Trade product code (HPK) <br>-  Prescription code (PRK) <br>-  Generic product code (GPK) <br>-  Anatomic therapeutic classification (ATC) <br>-  Substance name code (SNK) <br>-  Substance name code with route of administration (SKK) |
# | id_xtehr | EHDSMedication.item.ingredient.substance |
# | id_zib | NL-CM:9.7.19934 |
# | name_zib | SubstanceCode |
# | path_xtehr | EHDSMedication.item.ingredient.substance |
# | path_zib | PharmaceuticalProduct.ProductSpecifications.Ingredient.SubstanceCode |
# | short_xtehr | Substance |
# | stereotype_zib | data |
# | type_xtehr | CodeableConcept |
# | type_zib | CD |
#
# ### Comments
#
#
#
# ## EHDSMedication.item.packageType
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.item.packageType |
# | zib |  |
# | binding_xtehr | {'strength': 'preferred', 'description': 'EDQM Standard Terms for packaging.'} |
# | card._xtehr | 0..1 |
# | definition_xtehr | Type of package of the medication item |
# | id_xtehr | EHDSMedication.item.packageType |
# | path_xtehr | EHDSMedication.item.packageType |
# | short_xtehr | Type of package of the medication item |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSMedication.item.unitOfPresentation
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.item.unitOfPresentation |
# | zib |  |
# | binding_xtehr | {'strength': 'preferred', 'description': 'EDQM Standard Terms'} |
# | card._xtehr | 0..1 |
# | definition_xtehr | Unit of presentation for the manufactured item (tablet, vial, tube). Typically, the smallest countable object in the package. |
# | id_xtehr | EHDSMedication.item.unitOfPresentation |
# | path_xtehr | EHDSMedication.item.unitOfPresentation |
# | short_xtehr | Unit of presentation for the manufactured item (tablet, vial, tube). Typically, the smallest countable object in the package. |
# | type_xtehr | CodeableConcept |
#
# ### Comments
#
#
#
# ## EHDSMedication.marketingAuthorisationHolder
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.marketingAuthorisationHolder |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Marketing authorisation holder or manufacturer of the medicinal product. Relevant for identifying the exact product. |
# | id_xtehr | EHDSMedication.marketingAuthorisationHolder |
# | path_xtehr | EHDSMedication.marketingAuthorisationHolder |
# | short_xtehr | Marketing authorisation holder or manufacturer of the medicinal product. Relevant for identifying the exact product. |
# | type_xtehr | Base |
#
# ### Comments
#
#
#
# ## EHDSMedication.marketingAuthorisationHolder.organisationIdentifier
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.marketingAuthorisationHolder.organisationIdentifier |
# | zib |  |
# | card._xtehr | 0..* |
# | definition_xtehr | Identifier of the organisation and/or its physical location |
# | id_xtehr | EHDSMedication.marketingAuthorisationHolder.organisationIdentifier |
# | path_xtehr | EHDSMedication.marketingAuthorisationHolder.organisationIdentifier |
# | short_xtehr | Identifier of the organisation and/or its physical location |
# | type_xtehr | Identifier |
#
# ### Comments
#
#
#
# ## EHDSMedication.marketingAuthorisationHolder.organisationName
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.marketingAuthorisationHolder.organisationName |
# | zib |  |
# | card._xtehr | 0..1 |
# | definition_xtehr | Name of the organisation holding the authorisation for marketing/mahufacturing |
# | id_xtehr | EHDSMedication.marketingAuthorisationHolder.organisationName |
# | path_xtehr | EHDSMedication.marketingAuthorisationHolder.organisationName |
# | short_xtehr | Name of the organisation holding the authorisation for marketing/mahufacturing |
# | type_xtehr | string |
#
# ### Comments
#
#
#
# ## EHDSMedication.packSize
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.packSize |
# | zib |  |
# | binding_xtehr | {'strength': 'preferred', 'description': 'UCUM for units of measure. EDQM Standard Terms for units of presentation.'} |
# | card._xtehr | 0..* |
# | definition_xtehr | Overall amount of product in one package (100ml; 20 tablets; 1 creme & 6 pessaries) |
# | id_xtehr | EHDSMedication.packSize |
# | path_xtehr | EHDSMedication.packSize |
# | short_xtehr | Overall amount of product in one package (100ml; 20 tablets; 1 creme & 6 pessaries) |
# | type_xtehr | Quantity |
#
# ### Comments
#
#
#
# ## EHDSMedication.productName
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr | EHDSMedication.productName |
# | zib | PharmaceuticalProduct.ProductSpecifications.Medication |
# | alias_zib | NL: ProductNaam |
# | card._xtehr | 0..1 |
# | card._zib | 0..1 |
# | definition_xtehr | Name of the product (full name, invented name, other). When the product has different names, the appropriate one for the context should be used. Translations of names can be provided. |
# | definition_zib | For medication which has no code, enter the complete name of the pharmaceutical product here. |
# | id_xtehr | EHDSMedication.productName |
# | id_zib | NL-CM:9.7.19929 |
# | name_zib | Medication |
# | path_xtehr | EHDSMedication.productName |
# | path_zib | PharmaceuticalProduct.ProductSpecifications.Medication |
# | short_xtehr | Name of the product (full name, invented name, other). When the product has different names, the appropriate one for the context should be used. Translations of names can be provided. |
# | stereotype_zib | data |
# | type_xtehr | string |
# | type_zib | ST |
#
# ### Comments
#
#
#
# ## zib: PharmaceuticalProduct.MedicationCode
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | PharmaceuticalProduct.MedicationCode |
# | alias_zib | NL: ProductCode |
# | card._zib | 0..1 |
# | definition_zib | Coding medication in the Netherlands is done on the basis of the G standard (issued by Z index), which is filled under the direction of KNMP. <br>The coded medication can be expressed as:<br>-  Global Trade Item Number (GTIN) <br>-  Z index number (ZI number) <br>-  Trade product code (HPK) <br>-  Prescription code (PRK) <br>-  Generic product code (GPK) <br>-  Anatomic Therapeutic Classification code (ATC) <br>-  SNOMED CT code<br>The GTIN enables identification of the product including its origin with a barcode.<br>The ZI number represents the trade product and the package size. <br>The HPK is the code for the trade product (with the brand name) as used per dose/per time the medication is taken (1 pill, 1 puff, 1ml).<br>The PRK contains als GPK information supplemented with information needed to prescribe the right product. This level is intended to facilitate generic prescription of drugs. <br>The GPK defines the pharmaceutical characteristics of a product: ingredients, strengths, units, pharmaceutical form and route of administration. <br>The Substance Name Code (SNK) is the (active) compound. <br>Further information about the G Standaard levels see https://www.z-index.nl .<br>So-called 90.000.000 numbers are used in local IT systems. These numbers shall not be used for external communication. In this case only the description (not the code) may be included. This is in accordance with national agreements (Nictiz Standard).<br><br><br>SNOMED CT can be used as an alternative coding of a pharmaceutical product, it is used, for example, to more generically describe vaccinations from the National Vaccination Programme based on the combination of substances (e.g. DKTP vaccine). For vaccines registered in the past, a code from the G-standard is not always present, but it is recommended to record it for current processing. In addition, the SNOMED CT code can be registered as an alternative for the same product. |
# | id_zib | NL-CM:9.7.19927 |
# | name_zib | MedicationCode |
# | path_zib | PharmaceuticalProduct.MedicationCode |
# | stereotype_zib | data |
# | type_zib | CD |
#
# ### Comments
#
#
#
# ## zib: PharmaceuticalProduct.ProductSpecifications
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | PharmaceuticalProduct.ProductSpecifications |
# | alias_zib | NL: ProductSpecificatie |
# | card._zib | 0..1 |
# | definition_zib | Container of the ProductSpecifications concept. This container contains all data elements of the ProductSpecifications concept. <br>Product specifications are required if the product code is not sufficient to ascertain the active substances and strength. |
# | id_zib | NL-CM:9.7.19928 |
# | name_zib | ProductSpecifications |
# | path_zib | PharmaceuticalProduct.ProductSpecifications |
# | stereotype_zib | container |
#
# ### Comments
#
#
#
# ## zib: PharmaceuticalProduct.ProductSpecifications.Description
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | PharmaceuticalProduct.ProductSpecifications.Description |
# | alias_zib | NL: Omschrijving |
# | card._zib | 0..1 |
# | definition_zib | A textual description of the type of medication (including relevant properties of the composition and preparation method if possible), which is only used if no coded indication from the G Standard is available (historical data regarding magistral preparation which has been entered as free text instead of entering the substance codes). |
# | id_zib | NL-CM:9.7.19784 |
# | name_zib | Description |
# | path_zib | PharmaceuticalProduct.ProductSpecifications.Description |
# | stereotype_zib | data |
# | type_zib | ST |
#
# ### Comments
#
#
#
# ## zib: PharmaceuticalProduct.ProductSpecifications.Ingredient.Concentration.IngredientAmount
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | PharmaceuticalProduct.ProductSpecifications.Ingredient.Concentration.IngredientAmount |
# | alias_zib | NL: IngredientHoeveelheid |
# | card._zib | 0..1 |
# | definition_zib | The amount and unit of this ingredient. This is the numerator for the calculation of the concentration. The unit should be selected from the G Standard (Table 902). |
# | id_zib | NL-CM:9.7.22277 |
# | name_zib | IngredientAmount |
# | path_zib | PharmaceuticalProduct.ProductSpecifications.Ingredient.Concentration.IngredientAmount |
# | stereotype_zib | data |
# | type_zib | PQ |
#
# ### Comments
#
#
#
# ## zib: PharmaceuticalProduct.ProductSpecifications.SerieNumber
#
# ### Table
#
# | attribute | value |
# |---|---|
# | xtehr |  |
# | zib | PharmaceuticalProduct.ProductSpecifications.SerieNumber |
# | alias_zib | NL: SerieNummer |
# | card._zib | 0..1 |
# | definition_zib | The serial number uniquely identifies the source of information of the dose itself. The number is constructed according to the GS1 standard AI(21). (https://www.gs1.nl/sectorafspraken-over-standaarden/unieke-identificatie-en-productdata-gezondheidszorg/gs1-barcodes-2#application-identifiers-ais) |
# | id_zib | NL-CM:9.7.22280 |
# | name_zib | SerieNumber |
# | path_zib | PharmaceuticalProduct.ProductSpecifications.SerieNumber |
# | stereotype_zib | data |
# | type_zib | ST |
#
# ### Comments
